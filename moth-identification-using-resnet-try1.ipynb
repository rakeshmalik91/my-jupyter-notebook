# %%
# !pip install torch torchvision
# !pip install matplotlib pandas scikit-learn
# !pip install pillow
# !pip install opencv-python

# %%
dataset_dir = "insect-dataset/moth"

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import shutil
import time
import datetime
import random
import numpy as np
from pathlib import Path
from PIL import Image
import torch
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision import models
import torch.nn as nn
import torch.nn.functional as F

# %%
def split_data_for_train_and_val(data_dir, test_dir, val_dir, train_dir, test_data_weight, val_data_weight, min_file_cnt_for_val):
    train_data_cnt = 0
    val_data_cnt = 0
    test_data_cnt = 0
    class_cnt = 0
    
    for class_dir in Path(data_dir).iterdir():
        if class_dir.is_dir() and os.listdir(class_dir):
            class_cnt = class_cnt + 1
            file_count = sum(1 for file in class_dir.iterdir() if file.is_file())
            for file in Path(class_dir).iterdir():
                if file.is_file():
                    random_float = random.random()
                    class_dir_name = class_dir.name
                    if file_count >= min_file_cnt_for_val and random_float < test_data_weight:
                        target_dir = test_dir
                        test_data_cnt = test_data_cnt + 1
                    elif file_count >= min_file_cnt_for_val and random_float < test_data_weight + val_data_weight:
                        target_dir = val_dir
                        val_data_cnt = val_data_cnt + 1
                    else:
                        target_dir = train_dir
                        train_data_cnt = train_data_cnt + 1
                    target_dir_path = f"{target_dir}/{class_dir_name}"
                    if not os.path.exists(target_dir_path):
                        os.makedirs(target_dir_path)
                    shutil.copy(file, target_dir_path)

    print(f"Class count: {class_cnt}")
    print(f"Training data count: {train_data_cnt}")
    print(f"Validation data count: {val_data_cnt}")
    print(f"Test data count: {test_data_cnt}")

# %%
def init_model_for_training(train_dir, val_dir, batch_size):
    transform = {
        'train': transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
        'val': transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]),
    }
    training_datasets = {
        'train': datasets.ImageFolder(root=train_dir, transform=transform['train']),
        'val': datasets.ImageFolder(root=val_dir, transform=transform['val']),
    }
    dataloaders = {
        'train': DataLoader(training_datasets['train'], batch_size=batch_size, shuffle=True),
        'val': DataLoader(training_datasets['val'], batch_size=batch_size, shuffle=False),
    }
    class_names = training_datasets['train'].classes
    
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
    num_classes = len(class_names)
    num_features = model.fc.in_features
    model.fc = nn.Linear(num_features, num_classes)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

    return {
        'model': model,
        'device': device,
        'transform': transform,
        'datasets': training_datasets,
        'dataloaders': dataloaders,
        'class_names': class_names,
        'num_classes': num_classes,
        'num_features': num_features,
        'criterion': criterion,
        'optimizer': optimizer,
        'scheduler': scheduler
    }

# %%
def train(model_data, num_epochs, model_path):
    start_time = time.time()
    for epoch in range(num_epochs):
        print(f"Epoch {(epoch+1):4} / {num_epochs:4}", end=' ')
        for phase in ['train', 'val']:
            if phase == 'train':
                model_data['model'].train()
            else:
                model_data['model'].eval()
            running_loss = 0.0
            running_corrects = 0
            for inputs, labels in model_data['dataloaders'][phase]:
                inputs, labels = inputs.to(model_data['device']), labels.to(model_data['device'])
                model_data['optimizer'].zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model_data['model'](inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = model_data['criterion'](outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        model_data['optimizer'].step()
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
    
            epoch_loss = running_loss / len(model_data['datasets'][phase])
            epoch_acc = running_corrects.double() / len(model_data['datasets'][phase])
            print(f" | {phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}", end=' ')
            if phase == 'train':
                model_data['scheduler'].step()
        print(f" | Elapsed time: {datetime.timedelta(seconds=(time.time() - start_time))}")
        torch.save(model_data['model'].state_dict(), model_path)

# %%
def predict(image_path, model_data):
    image = Image.open(image_path).convert("RGB")
    image = model_data['transform']['val'](image).unsqueeze(0).to(model_data['device'])
    with torch.no_grad():
        outputs = model_data['model'](image)
        _, preds = torch.max(outputs, 1)
    try:
        return model_data['class_names'][preds[0]]
    except (Exception):
        return None

def predict_top_k(image_path, model_data, k):
    image = Image.open(image_path).convert("RGB")
    image = model_data['transform']['val'](image).unsqueeze(0).to(model_data['device'])
    with torch.no_grad():
        outputs = model_data['model'](image)
        probabilities = F.softmax(outputs, dim=1)
        top_probs, top_indices = torch.topk(probabilities, k)
    try:
        return {model_data['class_names'][top_indices[0][i]]: top_probs[0][i].item() for i in range(0, k)}
    except (Exception):
        return None

# %% [markdown]
# # Manually create phases(egg/larva/pupa/moth) dataset

# %% [markdown]
# # Split phases dataset for train/val

# %%
if os.path.exists(f"{dataset_dir}/phases-train"):
    shutil.rmtree(f"{dataset_dir}/phases-train")
if os.path.exists(f"{dataset_dir}/phases-val"):
    shutil.rmtree(f"{dataset_dir}/phases-val")
    
split_data_for_train_and_val(f"{dataset_dir}/phases-data", None, f"{dataset_dir}/phases-val", f"{dataset_dir}/phases-train", 0, 0.2, 4)
# Out:
# Class count: 4
# Training data count: 1899
# Validation data count: 499
# Test data count: 0

# %% [markdown]
# # Train model to seperate phases

# %%
phases_model_data = init_model_for_training(f'{dataset_dir}/phases-train', f'{dataset_dir}/phases-val', 32)

# %%
train(phases_model_data, 25, f"{dataset_dir}/phases_checkpoint_latest.pth")
# Out:
# Epoch    1 /   25  | Train Loss: 0.0490 Acc: 0.9821  | Val Loss: 8.5694 Acc: 0.0180  | Elapsed time: 0:00:13.910416
# Epoch    2 /   25  | Train Loss: 0.0479 Acc: 0.9842  | Val Loss: 8.1367 Acc: 0.0220  | Elapsed time: 0:00:28.820473
# Epoch    3 /   25  | Train Loss: 0.0438 Acc: 0.9863  | Val Loss: 8.4808 Acc: 0.0180  | Elapsed time: 0:00:44.175050
# Epoch    4 /   25  | Train Loss: 0.0448 Acc: 0.9831  | Val Loss: 8.3880 Acc: 0.0200  | Elapsed time: 0:00:59.713113
# Epoch    5 /   25  | Train Loss: 0.0391 Acc: 0.9884  | Val Loss: 8.6596 Acc: 0.0180  | Elapsed time: 0:01:15.259200
# Epoch    6 /   25  | Train Loss: 0.0440 Acc: 0.9847  | Val Loss: 8.3532 Acc: 0.0180  | Elapsed time: 0:01:30.669789
# Epoch    7 /   25  | Train Loss: 0.0397 Acc: 0.9863  | Val Loss: 8.7578 Acc: 0.0180  | Elapsed time: 0:01:46.244852
# Epoch    8 /   25  | Train Loss: 0.0371 Acc: 0.9879  | Val Loss: 8.6134 Acc: 0.0200  | Elapsed time: 0:02:02.156901
# Epoch    9 /   25  | Train Loss: 0.0434 Acc: 0.9858  | Val Loss: 8.5128 Acc: 0.0200  | Elapsed time: 0:02:17.853951
# Epoch   10 /   25  | Train Loss: 0.0376 Acc: 0.9900  | Val Loss: 8.6772 Acc: 0.0200  | Elapsed time: 0:02:33.423555
# Epoch   11 /   25  | Train Loss: 0.0368 Acc: 0.9874  | Val Loss: 8.6078 Acc: 0.0200  | Elapsed time: 0:02:48.950746
# Epoch   12 /   25  | Train Loss: 0.0422 Acc: 0.9868  | Val Loss: 8.5641 Acc: 0.0200  | Elapsed time: 0:03:04.644728
# Epoch   13 /   25  | Train Loss: 0.0354 Acc: 0.9905  | Val Loss: 8.5526 Acc: 0.0200  | Elapsed time: 0:03:20.278778
# Epoch   14 /   25  | Train Loss: 0.0406 Acc: 0.9858  | Val Loss: 8.5356 Acc: 0.0180  | Elapsed time: 0:03:36.032383
# Epoch   15 /   25  | Train Loss: 0.0382 Acc: 0.9863  | Val Loss: 8.4526 Acc: 0.0200  | Elapsed time: 0:03:51.639478
# Epoch   16 /   25  | Train Loss: 0.0418 Acc: 0.9884  | Val Loss: 8.4433 Acc: 0.0200  | Elapsed time: 0:04:07.250556
# Epoch   17 /   25  | Train Loss: 0.0356 Acc: 0.9900  | Val Loss: 8.7725 Acc: 0.0180  | Elapsed time: 0:04:23.253177
# Epoch   18 /   25  | Train Loss: 0.0388 Acc: 0.9858  | Val Loss: 8.4219 Acc: 0.0200  | Elapsed time: 0:04:39.366751
# Epoch   19 /   25  | Train Loss: 0.0349 Acc: 0.9900  | Val Loss: 8.6529 Acc: 0.0180  | Elapsed time: 0:04:56.257835
# Epoch   20 /   25  | Train Loss: 0.0406 Acc: 0.9874  | Val Loss: 8.3992 Acc: 0.0200  | Elapsed time: 0:05:12.005882
# Epoch   21 /   25  | Train Loss: 0.0348 Acc: 0.9884  | Val Loss: 8.4422 Acc: 0.0220  | Elapsed time: 0:05:27.623034
# Epoch   22 /   25  | Train Loss: 0.0355 Acc: 0.9900  | Val Loss: 8.6507 Acc: 0.0200  | Elapsed time: 0:05:43.417603
# Epoch   23 /   25  | Train Loss: 0.0377 Acc: 0.9889  | Val Loss: 8.4188 Acc: 0.0200  | Elapsed time: 0:05:58.942652
# Epoch   24 /   25  | Train Loss: 0.0366 Acc: 0.9874  | Val Loss: 8.4532 Acc: 0.0180  | Elapsed time: 0:06:14.523699
# Epoch   25 /   25  | Train Loss: 0.0381 Acc: 0.9868  | Val Loss: 8.9047 Acc: 0.0160  | Elapsed time: 0:06:30.167260

# %% [markdown]
# # Discard egg/larva/pupa data using phases model

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math

def plot_predictions(predictions, cols):
    n_images = len(predictions)
    rows = math.ceil(n_images / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(5 * cols, 5 * rows))
    axes = axes.flatten()
    for i, prediction in enumerate(predictions):
        image = mpimg.imread(prediction['file'])
        axes[i].imshow(image)
        axes[i].set_title(prediction['prediction'], fontsize=30)
        axes[i].axis('off')
    for i in range(len(predictions), len(axes)):
        axes[i].axis('off')
    plt.tight_layout()
    plt.show()

# %%
from pathlib import Path

clean_dataset_dir = f"{dataset_dir}/clean-data"
discarded_dataset_dir = f"{dataset_dir}/discarded-data"
min_data_cnt_to_retain_all = 5

if os.path.exists(clean_dataset_dir):
    shutil.rmtree(clean_dataset_dir)
if os.path.exists(discarded_dataset_dir):
    shutil.rmtree(discarded_dataset_dir)

def discard_unwanted_data(data_dir, limit=-1):
    predictions = []
    moth_class_cnt = 0
    larva_class_cnt = 0
    for species_dir in Path(data_dir).iterdir():
        if species_dir.is_dir():
            file_count = sum(1 for file in species_dir.iterdir() if file.is_file())
            for file in Path(f"{species_dir}").iterdir():
                if file.is_file():
                    prediction = predict(file, phases_model_data)
                    species_name = str(file.resolve().as_posix()).split("/")[-2]
                    if prediction == 'moth' or file_count < min_data_cnt_to_retain_all:
                        target_dir = f"{clean_dataset_dir}/{species_name}"
                        if not os.path.exists(target_dir):
                            moth_class_cnt = moth_class_cnt + 1
                            os.makedirs(target_dir)
                    else:
                        target_dir = f"{discarded_dataset_dir}/{species_name}"
                        if not os.path.exists(target_dir):
                            larva_class_cnt = larva_class_cnt + 1
                            os.makedirs(target_dir)
                    shutil.copy(file, target_dir)
                    predictions.append({
                        'file': file,
                        'prediction': prediction
                    })
                    limit = limit - 1
                    if(limit == 0): return predictions
    # print(f"{larva_class_cnt} discarded & {moth_class_cnt} retained")
    return predictions

start_time = time.time()
phases_model_data['model'].load_state_dict(torch.load(f"{dataset_dir}/phases_checkpoint_latest.pth", weights_only=False))
phases_model_data['model'].eval()
predictions = discard_unwanted_data(f'{dataset_dir}/data')

print(f"Elapsed time: {datetime.timedelta(seconds=(time.time() - start_time))}")

# plot_predictions([p for p in predictions if p['prediction'] != 'moth'][:30], 6)
# Out:
# Elapsed time: 0:13:43.031402

# %% [markdown]
# # Split dataset for train/val/test

# %%
import shutil
from pathlib import Path
import random
import os
import time
import datetime

if os.path.exists(f"{dataset_dir}/test"):
    shutil.rmtree(f"{dataset_dir}/test")
if os.path.exists(f"{dataset_dir}/val"):
    shutil.rmtree(f"{dataset_dir}/val")
if os.path.exists(f"{dataset_dir}/train"):
    shutil.rmtree(f"{dataset_dir}/train")

start_time = time.time()
split_data_for_train_and_val(f"{dataset_dir}/clean-data", f"{dataset_dir}/test", f"{dataset_dir}/val", f"{dataset_dir}/train", 0.05, 0.15, 4)
print(f"Elapsed time: {datetime.timedelta(seconds=(time.time() - start_time))}")
# Out:
# Class count: 3048
# Training data count: 34618
# Validation data count: 6085
# Test data count: 2105
# Elapsed time: 0:02:43.535177

# %% [markdown]
# # Train model

# %%
model_data = init_model_for_training(f'{dataset_dir}/train', f'{dataset_dir}/val', 32)

# %%
train(model_data, 25, f"{dataset_dir}/checkpoint_latest.pth")
# Out:
# Epoch    1 /   25  | Train Loss: 3.9159 Acc: 0.2084  | Val Loss: 18.0966 Acc: 0.0005  | Elapsed time: 0:04:44.085452
# Epoch    2 /   25  | Train Loss: 2.8968 Acc: 0.3528  | Val Loss: 19.4684 Acc: 0.0007  | Elapsed time: 0:09:23.433819
# Epoch    3 /   25  | Train Loss: 2.6383 Acc: 0.3988  | Val Loss: 20.2678 Acc: 0.0003  | Elapsed time: 0:14:02.541753
# Epoch    4 /   25  | Train Loss: 2.4828 Acc: 0.4260  | Val Loss: 20.5795 Acc: 0.0005  | Elapsed time: 0:18:42.919077
# Epoch    5 /   25  | Train Loss: 2.3558 Acc: 0.4524  | Val Loss: 21.6312 Acc: 0.0002  | Elapsed time: 0:23:23.834475
# Epoch    6 /   25  | Train Loss: 2.2246 Acc: 0.4792  | Val Loss: 21.6839 Acc: 0.0005  | Elapsed time: 0:28:02.378643
# Epoch    7 /   25  | Train Loss: 2.1243 Acc: 0.4973  | Val Loss: 22.2613 Acc: 0.0005  | Elapsed time: 0:32:42.767700
# Epoch    8 /   25  | Train Loss: 2.0044 Acc: 0.5243  | Val Loss: 23.0975 Acc: 0.0003  | Elapsed time: 0:37:23.766092
# Epoch    9 /   25  | Train Loss: 1.8559 Acc: 0.5615  | Val Loss: 22.9160 Acc: 0.0002  | Elapsed time: 0:42:04.886870
# Epoch   10 /   25  | Train Loss: 1.8351 Acc: 0.5661  | Val Loss: 22.9198 Acc: 0.0002  | Elapsed time: 0:46:45.378789
# Epoch   11 /   25  | Train Loss: 1.8212 Acc: 0.5676  | Val Loss: 23.2097 Acc: 0.0002  | Elapsed time: 0:51:29.615949
# Epoch   12 /   25  | Train Loss: 1.8032 Acc: 0.5707  | Val Loss: 23.1327 Acc: 0.0003  | Elapsed time: 0:56:10.294433
# Epoch   13 /   25  | Train Loss: 1.7967 Acc: 0.5762  | Val Loss: 22.9664 Acc: 0.0003  | Elapsed time: 1:00:47.888435
# Epoch   14 /   25  | Train Loss: 1.7892 Acc: 0.5768  | Val Loss: 23.4360 Acc: 0.0002  | Elapsed time: 1:05:29.150806
# Epoch   15 /   25  | Train Loss: 1.7698 Acc: 0.5821  | Val Loss: 23.3810 Acc: 0.0002  | Elapsed time: 1:10:07.750249
# Epoch   16 /   25  | Train Loss: 1.7582 Acc: 0.5854  | Val Loss: 23.2698 Acc: 0.0002  | Elapsed time: 1:14:47.536794
# Epoch   17 /   25  | Train Loss: 1.7547 Acc: 0.5877  | Val Loss: 23.2689 Acc: 0.0002  | Elapsed time: 1:19:27.448508
# Epoch   18 /   25  | Train Loss: 1.7509 Acc: 0.5861  | Val Loss: 23.2541 Acc: 0.0002  | Elapsed time: 1:24:03.908150
# Epoch   19 /   25  | Train Loss: 1.7475 Acc: 0.5869  | Val Loss: 23.3943 Acc: 0.0002  | Elapsed time: 1:28:40.067271
# Epoch   20 /   25  | Train Loss: 1.7487 Acc: 0.5870  | Val Loss: 23.2327 Acc: 0.0002  | Elapsed time: 1:33:21.508123
# Epoch   21 /   25  | Train Loss: 1.7463 Acc: 0.5873  | Val Loss: 23.2120 Acc: 0.0003  | Elapsed time: 1:37:57.572037
# Epoch   22 /   25  | Train Loss: 1.7456 Acc: 0.5852  | Val Loss: 23.4046 Acc: 0.0002  | Elapsed time: 1:42:34.265274
# Epoch   23 /   25  | Train Loss: 1.7396 Acc: 0.5902  | Val Loss: 23.3722 Acc: 0.0002  | Elapsed time: 1:47:10.348305
# Epoch   24 /   25  | Train Loss: 1.7445 Acc: 0.5872  | Val Loss: 23.1578 Acc: 0.0002  | Elapsed time: 1:51:45.964884
# Epoch   25 /   25  | Train Loss: 1.7413 Acc: 0.5885  | Val Loss: 23.3500 Acc: 0.0002  | Elapsed time: 1:56:20.889000

# %% [markdown]
# # Test model

# %%
import pprint

def validate_prediction_in_dir(test_dir, model_data):
    total = 0
    success = 0
    failures = {}
    for species_dir in Path(test_dir).iterdir():
        if species_dir.is_dir():
            for file in Path(f"{species_dir}").iterdir():
                if file.is_file():
                    species = file.parts[-2]
                    prediction = predict(file, model_data)
                    is_success = (species==prediction)
                    if not is_success:
                        failures[species] = prediction
                    total = total + 1
                    if is_success:
                        success = success + 1
    return {
        'total': total, 
        'success': success,
        'failures': failures
    }

def test(checkpoint, test_dir):
    model_data['model'].load_state_dict(torch.load(checkpoint, weights_only=False))
    model_data['model'].eval()
    start_time = time.time()
    prediction = validate_prediction_in_dir(test_dir, model_data)
    print(f"Accuracy: {prediction['success']} / {prediction['total']} -> {100*prediction['success']/prediction['total']:.2f}%")
    print(f"Elapsed time: {datetime.timedelta(seconds=(time.time() - start_time))}")
    print("-"*10)
    print("Failures:")
    pprint.pprint(prediction['failures'])

# %%
test(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/test")
# Out:
# Accuracy: 814 / 2105 -> 38.67%
# Elapsed time: 0:00:16.496665
# ----------
# Failures:
# {'Aiteta-spp': 'banisia-spp',
#  'Alcis-periphracta': 'dasyboarmia-spp',
#  'Apha-floralis': 'banisia-spp',
#  'Boeotarcha-martinalis': 'oxaenanus-brontesalis',
#  'Calamotropha-corticellus': 'westermannia-superba',
#  'Calletaera-obliquata': 'Luxiaria-hypaphanes',
#  'Callopistria-pulchrilinea': 'dudusa-sphingiformis',
#  'Carea-obsolescens': 'oxymacaria-palliata',
#  'Chalcosiopsis-variata': 'Mosopia-kononenkoi',
#  'Charitoprepes-lubricosa': 'crambidae-genera-spp',
#  'Chloroplaga-pallida': 'Somatina-densifasciaria',
#  'Chusaris-spp': 'rhesala-spp',
#  'Comibaena-biplaga': 'poliobotys-ablactalis',
#  'Cusiala-raptaria': 'Cusiala-spp',
#  'Cusiala-spp': 'phalera-spp',
#  'Daplasa-irrorata': 'aegocera-venulia',
#  'Ecpyrrhorrhoe-spp': 'perina-nuda',
#  'Floridasura-tricolor': 'Moorasura-inflexa',
#  'Goniocraspidum-ennomoide': 'lasiocampidae-genera-spp',
#  'Harutaea-flavizona': 'heterostegane-spp',
#  'Hyperythra-swinhoei': 'apona-caschmirensis',
#  'Hypolamprus-bastialis': 'parapoynx-stagnalis',
#  'Lamprosema-spp': 'digama-marchalii',
#  'Luxiaria-hypaphanes': 'canucha-specularis',
#  'Meganola-major': 'Athetis-bremusa',
#  'Metacosmesis-laxeuta': 'hypeninae-genera-spp',
#  'Miltochrista-spp': 'nepita-conferta',
#  'Moorasura-gloriosa': 'Moorasura-inflexa',
#  'Mosopia-kononenkoi': 'phocoderma-velutina',
#  'Orothalassodes-hypocrites': 'pelagodes-thalassodes-spp',
#  'Perixera-illepidaria': 'eupterote-patula',
#  'Petavia-attenuata': 'euproctis-plagiata',
#  'Pingasa-rubicunda': 'dysphania-percota',
#  'Psilalcis-conspicuata': 'chiasmia-emersaria',
#  'Rhodoneura-fimbriata': 'notarcha-aurolinealis',
#  'Rhodoneura-lobulata': 'syngamia-falsidicalis',
#  'Spodoptera-frugiperda': 'Pectinophora-gossypiella',
#  'Striatella-nigralba': 'problepsis-spp',
#  'Tambana-subflava': 'amblychia-nimia',
#  'Teleclita-grisea': 'lophoptera-spp',
#  'abraxas-spp': 'micraloa-spp',
#  'acantholipes-circumdata': 'acmeshachia-gigantea',
#  'acantholipes-trajecta': 'trigonodes-hyppasia',
#  'achaea-janata': 'hypsopygia-spp',
#  'achaea-serva': 'scopula-opicata',
#  'achelura-bifasciata': 'lymantria-similis',
#  'acherontia-lachesis': 'spodoptera-litura',
#  'acherontia-styx': 'callopistria-spp',
#  'achrosis-intexta': 'endotricha-spp',
#  'achrosis-rondelaria': 'herpetogramma-spp',
#  'achrosis-spp': 'mocis-undata',
#  'acontia-crocata': 'macrocilix-maia',
#  'acontia-marmoralis': 'pseudoadites-frigida',
#  'acontia-spp': 'miresa-spp',
#  'acosmeryx-akanshi': 'psilogramma-increta',
#  'acosmeryx-anceus': 'acosmeryx-pseudonaga',
#  'actias-parasinensis': 'antheraea-paphia',
#  'actias-selene': 'arctornis-spp',
#  'adisura-spp': 'Rhynchina-spp',
#  'adoxophyes-spp': 'eois-phaneroscia',
#  'aegocera-venulia': 'tonica-niviferana',
#  'agalope-hyalina': 'abraxas-spp',
#  'agassiziella-picalis': 'diaphania-indica',
#  'agathia-lycaenaria': 'Comibaena-biplaga',
#  'aglaomorpha-plagiata': 'Macrobrochis-flavicincta',
#  'agrioglypta-eurytusalis': 'cirrhochrista-pulchellalis',
#  'agrius-convolvuli': 'hypena-laceratalis',
#  'agrotera-basinotata': 'lithosiini-genera-spp',
#  'alcanola-tympanistis': 'nyctemera-lacticinia',
#  'alcis-perspicuata': 'ectropidia-shoreae',
#  'alcis-spp': 'cleora-spp',
#  'aloa-lactinea': 'actias-selene',
#  'aloa-neoaloa-spp': 'vamuna-remelana',
#  'amata-cyssea': 'amata-passalis',
#  'amata-elongata': 'glyphodes-bicolor',
#  'amata-extensa': 'oeonistis-spp',
#  'amata-passalis': 'nepita-conferta',
#  'amata-sperbius': 'spilarctia-spp',
#  'amblychia-pardicelata': 'biston-suppressaria',
#  'ambulyx-belli': 'asota-caricae',
#  'ambulyx-liturata': 'theretra-clotho',
#  'ambulyx-moorei': 'calesia-haemorrhoa',
#  'amerila-astreus': 'brunia-antica',
#  'amerila-eugenia': 'digama-marchalii',
#  'ammatho-cuneonotatus': 'thinopteryx-nebulosa',
#  'ammatho-spp': 'anomis-flava',
#  'amyna-spp': 'ozarba-spp',
#  'anabasis-obliquifasciella': 'phycitinae-genera-spp',
#  'anadevidia-peponis': 'syntomoides-imaon',
#  'analyta-diaphana': 'aporodes-floralis',
#  'andraca-trilochoides': 'orvasca-subnotata',
#  'angonyx-krishna': 'ambulyx-moorei',
#  'angonyx-testacea': 'pergesa-acteus',
#  'anisoneura-aluco': 'spodoptera-litura',
#  'anomis-flava': 'cerynea-spp',
#  'antheraea-assamensis': 'penicillaria-jocosatrix',
#  'antheraea-frithi': 'plutodes-exquisita',
#  'antheraea-paphia': 'mocis-undata',
#  'anticarsia-irrorata': 'drepana-pallida',
#  'antigastra-catalaunalis': 'creatonotos-transiens',
#  'antipercnia-belluaria': 'zeuzerini-genera-spp',
#  'aphendala-spp': 'nola-taeniata',
#  'archaeoattacus-edwardsii': 'macroglossum-gyrans',
#  'archiplutodes-prasina': 'polynesia-sunandava',
#  'archips-spp': 'idaea-spp',
#  'arcte-polygrapha': 'erebus-ephesperis',
#  'arctioblepsis-rubida': 'gangarides-vittipalpis',
#  'arctornis-spp': 'abraxas-spp',
#  'areas-galactina': 'pterophoridae-genera-spp',
#  'argina-astrea': 'chiasmia-spp',
#  'argonestis-flammans': 'cheromettia-apicata',
#  'argyrocosma-inductaria': 'ornithospila-avicularia',
#  'arichanna-jaguarinaria': 'pachyodes-haemataria',
#  'arichanna-schnitzleri': 'nausinoe-perspectata',
#  'arna-bipunctapex': 'rhagastis-olivacea',
#  'aroa-campbelli': 'orgyia-postica',
#  'aroa-spp': 'Aiteta-spp',
#  'artaxa-spp': 'earias-spp',
#  'arthroschista-hilaralis': 'comostola-laesaria',
#  'artona-quadrimaculata': 'hyblaea-puera-complex',
#  'ascotis-spp': 'cleora-spp',
#  'asota-caricae': 'earias-vittella',
#  'asota-ficus': 'cyana-spp',
#  'asota-plana': 'abraxas-spp',
#  'asta-quadrilinea': 'bastilla-arcuata',
#  'astygisa-spp': 'lygniodes-spp',
#  'asura-miltochrista-group-spp': 'lobobasis-niveimaculata',
#  'atacira-melanephra': 'sinarella-discisigna',
#  'athetis-delecta': 'calliteara-spp',
#  'atkinsonia-clerodendronella': 'lasiocampidae-genera-spp',
#  'attacus-taprobanis': 'petavia-erycinoides',
#  'attatha-ino': 'allata-spp',
#  'atteva-fabriciella': 'acherontia-lachesis',
#  'autoba-silicula': 'hypomecis-spp',
#  'autocharis-fessalis': 'vamuna-maculata',
#  'auzata-semipavonaria': 'drepanidae-genera-spp',
#  'avatha-discolor': 'asta-quadrilinea',
#  'avatha-leksawasdi': 'naarda-spp',
#  'azygophleps-scalaris': 'creatonotos-transiens',
#  'bamra-albicola': 'lymantria-spp',
#  'baniana-semilugens': 'endotricha-ruminalis',
#  'banisia-spp': 'Teinoptila-spp',
#  'barsaurea-phaeoxanthia': 'ovipennis-flavivenosa',
#  'barsine-genera-group-spp': 'hypochrosis-hyadaria-complex',
#  'barsine-group-spp': 'orvasca-subnotata',
#  'bastilla-acuta': 'artena-dotata',
#  'bastilla-conficiens': 'chalciope-mygdon',
#  'bastilla-crameri': 'trilocha-varians',
#  'bastilla-simillima': 'erebus-macrops',
#  'beara-spp': 'rhesala-spp',
#  'berta-spp': 'cleora-spp',
#  'bertula-abjudicalis': 'spoladea-recurvalis',
#  'bharetta-cinnamomea': 'amblychia-angeronaria',
#  'bireta-longivitta': 'olene-mendosa',
#  'biston-bengaliaria': 'biston-contectaria',
#  'biston-strigaria': 'chlororithra-fea',
#  'biston-suppressaria': 'lassaba-albidaria',
#  'blasticorhinus-rivulosa': 'pericyma-glaucinans',
#  'boarmiini-genera-spp': 'phycitinae-genera-spp',
#  'bocchoris-inspersalis': 'plusiinae-genera-spp',
#  'bocula-spp': 'ozarba-spp',
#  'botyodes-asialis': 'omiodes-indicata',
#  'botyodes-principalis': 'botyodes-asialis',
#  'bradina-adhaesalis': 'orgyiini-genera-spp',
#  'bradina-diagonalis': 'bradina-admixtalis',
#  'brahmaea-hearseyi': 'glyphodes-caesalis',
#  'brenthia-spp': 'spirama-spp',
#  'britha-pactalis': 'digama-insulana',
#  'britha-spp': 'gesonia-spp',
#  'brunia-antica': 'Tamba-lala',
#  'calesia-fuscicorpus': 'calesia-dasypterus',
#  'calesia-haemorrhoa': 'eudocima-homaena',
#  'calesia-stillifera': 'gonodontis-spp',
#  'callambulyx-rubricosa': 'hippotion-celerio',
#  'callidrepana-argenteola': 'sirinopteryx-rufivinctata',
#  'callidrepana-patrana': 'agnidra-discispilaria',
#  'callindra-equitalis': 'chrysodeixis-spp',
#  'calliteara-complicata': 'perciana-marmorea',
#  'calliteara-horsfieldii': 'oxymacaria-palliata',
#  'calliteara-spp': 'arctornis-spp',
#  'callopistria-minuta': 'spodoptera-litura',
#  'callopistria-repleta': 'pericyma-cruegeri',
#  'callyna-semivitta': 'rajendra-biguttata',
#  'calyptra-spp': 'selepa-spp',
#  'camptoloma-binotatum': 'nygmiini-genera-spp',
#  'campylotes-histrionicus': 'aglaomorpha-plagiata',
#  'canucha-specularis': 'hydatocapnia-spp',
#  'carea-angulata': 'maurilia-iconica',
#  'casama-vilis': 'garella-ruficirra',
#  'cechetra-lineosa': 'marumba-dyras',
#  'cechetra-scotti': 'pergesa-acteus',
#  'celenna-festivaria': 'nephele-hespera',
#  'cephonodes-hylas': 'chasmina-candida',
#  'cephonodes-spp': 'acantholipes-spp',
#  'cerynea-igniaria': 'anoba-polyspila',
#  'cerynea-punctilinealis': 'helicoverpa-armigera',
#  'cerynea-spp': 'ericeia-spp',
#  'ceryx-diptera': 'aloa-lactinea',
#  'chabula-acamasalis': 'brahmaea-wallichii',
#  'chadisra-bipars': 'olene-mendosa',
#  'chadisra-spp': 'condica-spp',
#  'chalcosia-diana': 'vamuna-remelana',
#  'chamaita-nympha': 'himala-argentea',
#  'chasmina-spp': 'hemithea-spp',
#  'chiasmia-eleonora': 'isturgia-disputaria',
#  'chiasmia-fidoniata': 'epiplema-reticulata',
#  'chiasmia-nora': 'gadirtha-spp',
#  'chiasmia-spp': 'achaea-serva',
#  'chilena-similis': 'carea-angulata',
#  'chilkasa-falcata': 'artaxa-guttata',
#  'chlumetia-spp': 'feliniopsis-spp',
#  'chlumetia-transversa': 'sameodes-cancellalis',
#  'chorodna-adumbrata': 'agnidra-discispilaria',
#  'chorsia-mollicula': 'maliattha-separata',
#  'chrysocraspeda-abhadraca': 'blepharoctenucha-virescens',
#  'chrysocraspeda-faganaria': 'orphanostigma-abruptalis',
#  'chrysocraspeda-spp': 'oreta-griseotincta',
#  'chrysodeixis-eriosoma': 'chabulina-onychinalis',
#  'chrysodeixis-spp': 'idaea-macrospila',
#  'chrysorabdia-bivitta': 'Paraona-splendens',
#  'cidariini-genera-spp': 'lithosiini-genera-spp',
#  'cirrhochrista-fumipalpis': 'creatonotos-transiens',
#  'clanidopsis-exusta': 'arctioblepsis-rubida',
#  'clanis-bilineata': 'olene-mendosa',
#  'clanis-phalaris': 'kunugia-lineata',
#  'clelea-sapphirina': 'episteme-adulatrix',
#  'cleora-alienaria': 'ophthalmitis-spp',
#  'cleora-fraterna': 'metoeca-foedalis',
#  'clostera-fulgurita': 'lymantria-grandis',
#  'clostera-restitura': 'hyposidra-talaca',
#  'cnaphalocrocis-patnalis': 'cnaphalocrocis-rutilalis',
#  'cnaphalocrocis-rutilalis': 'agassiziella-fuscifusale',
#  'comibaena-albimarginata': 'linguisaccus-subhyalina',
#  'comibaena-cassidara': 'argyrocosma-inductaria',
#  'comibaena-spp': 'comostola-spp',
#  'comostola-spp': 'comostola-inops',
#  'condica-spp': 'athetis-spp',
#  'conogethes-punctiferalis': 'eurrhyparodes-tricoloralis',
#  'conogethes-semifascialis-complex': 'pachynoa-spilosomoides-complex',
#  'conogethes-spp': 'orgyia-postica',
#  'corgatha-dictaria': 'anticarsia-irrorata',
#  'corymica-deducta': 'heliothis-peltigera',
#  'corymica-spp': 'parasa-lepida',
#  'crambidae-genera-spp': 'hypeninae-genera-spp',
#  'crambinae-genera-spp': 'ammatho-cuneonotatus',
#  'creatonotos-transiens': 'nygmiini-genera-spp',
#  'cretonia-spp': 'condica-spp',
#  'cricula-trifenestrata': 'sameodes-cancellalis',
#  'crocidolomia-luteolalis': 'indarbela-tetraonis',
#  'cruxoruza-reticulata': 'dichocrocis-definita',
#  'ctenoplusia-albostriata': 'epipleminae-genera-spp',
#  'ctenoplusia-placida': 'spataliini-genera-spp',
#  'ctenoplusia-tarassota': 'noctuinae-genera-spp',
#  'curoba-sangarida': 'spodoptera-litura',
#  'cusiala-boarmoides': 'psilalcis-breta',
#  'cyana-adita': 'cyana-signa',
#  'cyana-detrita': 'lymantria-spp',
#  'cyana-gazella': 'sinna-extrema',
#  'cyana-peregrina': 'epiplema-himala',
#  'cyana-perornata': 'tinolius-hypsana',
#  'cyana-signa': 'cyana-spp',
#  'cyana-spp': 'utetheisa-spp',
#  'cyclidia-rectificata': 'micronia-aculeata',
#  'cyclidia-substigmaria': 'chiasmia-emersaria',
#  'cyclodes-omma': 'digama-marchalii',
#  'cyclosia-latipennis': 'macrobrochis-gigas',
#  'cyclosia-midamia': 'carea-angulata',
#  'cyclosia-papilionaris': 'macrobrochis-gigas',
#  'cyclothea-disjuncta': 'traminda-aventiaria',
#  'cydalima-laticostalis': 'crambinae-genera-spp',
#  'cydalima-spp': 'abraxas-spp',
#  'cypa-enodis': 'theretra-alecto',
#  'dalima-intricata': 'herochroma-spp',
#  'dalima-truncataria': 'scopula-emissaria',
#  'daphnis-nerii': 'mocis-undata',
#  'decetia-spp': 'ozola-spp',
#  'degia-spp': 'tisis-spp',
#  'deilephila-rivularis': 'thysanoplusia-spp',
#  'deroca-inconclusa': 'pycnarmon-cribrata',
#  'diaphania-indica': 'endotricha-spp',
#  'diasemia-spp': 'eoophyla-spp',
#  'dichocrocis-definita': 'haritalodes-derogata',
#  'dichromia-quadralis': 'eudocima-phalonia',
#  'dichromia-sagitta': 'spodoptera-litura',
#  'dichromia-spp': 'hydrillodes-spp',
#  'digama-hearseyana': 'cephonodes-hylas',
#  'dindicodes-crocina': 'cephonodes-hylas',
#  'discoglypha-locupletata': 'chrysocraspeda-faganaria',
#  'drepanidae-genera-spp': 'cyclidia-substigmaria',
#  'dudusa-sphingiformis': 'neogurelca-himachala',
#  'dudusa-synopla': 'spodoptera-litura',
#  'dura-alba': 'ericeia-spp',
#  'dyrzela-plagiata': 'eupterote-undata',
#  'dysgonia-latifascia': 'parallelia-stuposa',
#  'dysgonia-torrida': 'achaea-janata',
#  'dysodia-spp': 'bocula-spp',
#  'dysphania-percota': 'cyclosia-latipennis',
#  'earias-cupreoviridis': 'eustrotia-marginata',
#  'earias-flavida': 'trabala-spp',
#  'earias-vittella': 'gesonia-spp',
#  'ecliptopera-dissecta': 'acantholipes-trajecta',
#  'ecliptopera-fulvotincta': 'hymenia-perspectalis',
#  'ecliptopera-rectilinea': 'sphingomorpha-chlorea',
#  'ecliptopera-substituta': 'paracymoriza-vagalis',
#  'ectropis-spp': 'petelia-spp',
#  'egens-egens': 'tetragonus-catamitus',
#  'egnasia-accingalis': 'syntomoides-imaon',
#  'egnasia-ephyrodalis': 'Calletaera-postvittata',
#  'electrophaes-spp': 'xyleutes-persona',
#  'eligma-narcissus': 'agrius-convolvuli',
#  'elusa-spp': 'fodina-stola',
#  'endoclita-malabaricus': 'hyblaea-puera-complex',
#  'endotricha-olivacealis': 'Piletocera-flexiguttalis',
#  'endotricha-ruminalis': 'talanga-sexpunctalis',
#  'endotricha-spp': 'trilocha-varians',
#  'enispa-elataria': 'astygisa-spp',
#  'ennominae-genera-spp': 'arichanna-transectata',
#  'entomogramma-fautrix': 'chiasmia-emersaria',
#  'entomogramma-torsa': 'ourapteryx-marginata',
#  'eoophyla-spp': 'manulea-spp',
#  'epicopeia-polydora': 'curoba-sangarida',
#  'epicrocis-spp': 'cania-sericea',
#  'epipagis-peritalis': 'digama-insulana',
#  'epiparbattia-gloriosalis': 'leucostola-argyrosticta',
#  'epipaschiinae-genera-spp': 'achrosis-incitata-complex',
#  'episothalma-robustaria': 'argyrocosma-inductaria',
#  'episparis-liturata': 'lacera-procellosa',
#  'ercheia-cyllaria': 'noorda-blitealis',
#  'erebus-ephesperis': 'chiasmia-eleonora',
#  'erebus-macrops': 'metanastria-spp',
#  'eressa-confinis': 'eressa-spp',
#  'ericeia-inangulata': 'heterostegane-urbica',
#  'ericeia-pertendens': 'Luxiaria-hypaphanes',
#  'ericeia-spp': 'cleora-spp',
#  'eriocottidae-genera-spp': 'phycitinae-genera-spp',
#  'ernolatia-moorei': 'trilocha-varians',
#  'eterusia-aedea': 'Mimeusemia-ceylonica',
#  'eterusia-raja': 'selepa-spp',
#  'eublemma-baccalix': 'nolinae-genera-spp',
#  'eublemma-dimidialis': 'eublemma-accedens',
#  'eublemma-olivacea': 'orvasca-subnotata',
#  'eublemma-quadrapex': 'entomogramma-torsa',
#  'eublemma-semirufa': 'helicoverpa-armigera',
#  'euchromia-polymena': 'Nephelomilta-suffusa',
#  'euchromius-ocellea': 'lithosiini-genera-spp',
#  'euclasta-spp': 'arsacia-rectalis',
#  'eucyclodes-divapala-complex': 'pelagodes-thalassodes-spp',
#  'eucyclodes-picturata': 'calindoea-argentalis',
#  'eucyclodes-semialba': 'rhimphalea-trogusalis',
#  'eucyclodes-textilis': 'comostola-inops',
#  'eudocima-homaena': 'barsine-group-spp',
#  'eudocima-hypermnestra': 'notodontidae-genera-spp',
#  'eudocima-materna': 'aethaloessa-calidalis',
#  'eudocima-phalonia': 'crocidolomia-pavonana',
#  'eudocima-salaminia': 'tanaoctenia-haliaria',
#  'eudocima-spp': 'thyatira-batis',
#  'euhampsonia-niveiceps': 'endocrossis-flavibasalis',
#  'eupitheciini-genera-spp': 'chundana-emarginata',
#  'euproctis-hampsoni': 'plotheia-decrescens',
#  'euproctis-leithiana': 'nygmiini-genera-spp',
#  'euproctis-magna': 'thyas-coronata',
#  'euproctis-plagiata': 'gastropacha-spp',
#  'eupterote-gardneri': 'thinopteryx-nebulosa',
#  'eupterote-spp': 'achaea-janata',
#  'eupterote-undata': 'hyposidra-talaca',
#  'eurrhyparodes-bracteolalis': 'archaeoattacus-edwardsii',
#  'euteliidae-genera-spp': 'paracymoriza-rivularis',
#  'euthrix-laeta': 'miresa-spp',
#  'fascellina-chromataria': 'traminda-mundissima',
#  'fascellina-plagiata': 'laelia-exclamationis',
#  'fascellina-porphyreofusa': 'parotis-marginata-complex',
#  'fentonia-baibarana': 'psilogramma-vates',
#  'filodes-fulvidorsalis': 'cephonodes-hylas',
#  'gabala-polyspilalis': 'nyctemera-coleta',
#  'galleria-mellonella': 'hydriris-ornatalis',
#  'ganisa-spp': 'ericeia-spp',
#  'garaeus-apicata': 'agnidra-vinacea',
#  'gastropacha-spp': 'euproctis-varia',
#  'gaurena-florens': 'arichanna-sparsa',
#  'gaurena-florescens': 'brahmaea-hearseyi',
#  'gazalina-chrysolopha': 'drepanidae-genera-spp',
#  'gelechiidae-genera-spp': 'hyblaea-puera-complex',
#  'gesonia-spp': 'ischyja-spp',
#  'glycythyma-chrysorycta': 'cnaphalocrocis-trebiusalis',
#  'glyphodes-caesalis': 'haritalodes-derogata',
#  'glyphodes-crithealis': 'nausinoe-geometralis',
#  'glyphodes-stolalis': 'pygospila-tyres',
#  'gnophos-spp': 'pingasa-spp',
#  'goniorhynchus-gratalis': 'cnaphalocrocis-rutilalis',
#  'gonodontis-clelia': 'chrysocraspeda-spp',
#  'gonodontis-spp': 'hyposidra-talaca',
#  'grammodes-geometrica': 'pterophoridae-genera-spp',
#  'grammodes-stolida': 'chalciope-mygdon',
#  'gunda-ochracea': 'rectipalpula-billeti',
#  'habrosyne-violacea': 'creatonotos-gangis-interrupta-complex',
#  'hadennia-spp': 'bastilla-arcuata',
#  'haritalodes-derogata': 'juxtarctia-multiguttata',
#  'helicoverpa-armigera': 'lithosiini-genera-spp',
#  'helicoverpa-assulta': 'egnasia-accingalis',
#  'heliothis-peltigera': 'corymica-deducta',
#  'hellula-undalis': 'digama-insulana',
#  'hemonia-orbiferana': 'hemonia-rotundata',
#  'hendecasis-duplifascialis': 'pelagodes-thalassodes-spp',
#  'heortia-vitessoides': 'dysphania-percota',
#  'herminiinae-genera-spp': 'nordstromia-bicostata',
#  'herpetogramma-basalis': 'crambidae-genera-spp',
#  'herpetogramma-spp': 'orudiza-protheclaria',
#  'heterostegane-urbica': 'hastina-pluristrigata',
#  'heterothera-spp': 'athetis-delecta',
#  'himala-argentea': 'gazalina-apsara',
#  'hipoepa-biasalis': 'attonda-adspersa',
#  'hipoepa-fractalis': 'euthrix-inobtrusa',
#  'hippotion-celerio': 'spoladea-recurvalis',
#  'hippotion-rosetta': 'thyas-coronata',
#  'hippotion-spp': 'clanis-titan',
#  'histia-flabellicornis': 'abrostola-anophioides',
#  'homaea-clathrum': 'pygospila-tyres',
#  'hulodes-caranea': 'hyposidra-talaca',
#  'hyalobathra-miniosalis': 'stigmatophora-roseivena',
#  'hyalobathra-phoenicozona': 'cnaphalocrocis-medinalis',
#  'hyblaea-puera-complex': 'macroglossum-bombylans',
#  'hydrillodes-spp': 'carea-angulata',
#  'hydrorybina-polusalis': 'helicoverpa-armigera',
#  'hyles-livornica': 'daphnis-nerii',
#  'hymenia-perspectalis': 'erebus-hieroglyphica',
#  'hypena-iconicalis': 'lymantria-incerta',
#  'hypena-laceratalis': 'orgyiini-genera-spp',
#  'hypena-obacerralis': 'orvasca-subnotata',
#  'hypeninae-genera-spp': 'noctuinae-genera-spp',
#  'hypersypnoides-constellata': 'epipaschiinae-genera-spp',
#  'hyperythra-lutea': 'artaxa-guttata',
#  'hypocala-deflorata': 'scopula-emissaria',
#  'hypocala-subsatura': 'gastropacha-spp',
#  'hypochrosis-abstractaria': 'craspediopsis-bimaculata',
#  'hypochrosis-flavifusata': 'plutodes-transmutata',
#  'hypochrosis-hyadaria-complex': 'Herpetogramma-rudis%20species-group',
#  'hypochrosis-iris': 'agnidra-vinacea',
#  'hypochrosis-sternaria': 'dichromia-quadralis',
#  'hypolamprus-angulalis': 'discoglypha-aureifloris',
#  'hypomecis-cineracea': 'Hypomecis-tamilensis',
#  'hypomecis-separata': 'psilalcis-breta',
#  'hypomecis-spp': 'naxidia-irrorata',
#  'hypomecis-transcissa': 'psilalcis-breta',
#  'hypopyra-meridionalis': 'fascellina-chromataria',
#  'hypopyra-spp': 'hyposidra-spp',
#  'hyposidra-infixaria': 'hydatocapnia-spp',
#  'hyposidra-spp': 'lygniodes-spp',
#  'hyposidra-talaca': 'zitha-torridalis',
#  'hypospila-bolinoides': 'endotricha-ruminalis',
#  'hypsopygia-spp': 'plecoptera-recta',
#  'idaea-costiguttata': 'erebus-ephesperis',
#  'idaea-spp': 'luxiaria-spp',
#  'idaea-violacea': 'maruca-vitrata',
#  'idiochlora-spp': 'parotis-spp',
#  'ilema-chloroptera': 'habrosyne-fraterna',
#  'ischyja-manlia': 'mocis-undata',
#  'isocentris-filalis': 'gesonia-spp',
#  'isturgia-disputaria': 'spoladea-recurvalis',
#  'janseodes-melanospila': 'Aeolanthes-rhodochrysa',
#  'juxtarctia-multiguttata': 'zeuzerini-genera-spp',
#  'katha-conformis': 'asota-caricae',
#  'krananda-semihyalina': 'amblychia-angeronaria',
#  'kunugia-lineata': 'manulea-spp',
#  'labdia-spp': 'cyana-spp',
#  'lacera-noctilio': 'aporodes-floralis',
#  'laelia-exclamationis': 'chasmina-judicata',
#  'lamoria-spp': 'degia-spp',
#  'lamprosema-tampiusalis': 'eupitheciini-genera-spp',
#  'langia-zenzeroides': 'creatonotos-gangis-interrupta-complex',
#  'leucania-spp': 'earias-spp',
#  'leucania-yu': 'Ecpyrrhorrhoe-spp',
#  'leucoma-clara': 'arctornis-spp',
#  'ligdia-coctata': 'psyra-cuneata',
#  'limacodinae-genera-spp': 'xenochroa-chlorostigma',
#  'liparopsis-postalbida': 'eudocima-phalonia',
#  'lipomelia-subusta': 'carriola-thyridophora',
#  'lithosiini-genera-spp': 'prooedema-inscisalis',
#  'locastra-muscosalis': 'macrobrochis-gigas',
#  'locharna-strigipennis': 'acherontia-lachesis',
#  'lomographa-inamata': 'Chloroplaga-pallida',
#  'lomographa-spp': 'derambila-spp',
#  'lopharthrum-comprimens': 'lepidoplaga-flavicinctalis',
#  'lophophelma-erionoma': 'coremecis-nigrovittata',
#  'lophophelma-ruficosta': 'spilosomina-genera-spp',
#  'lophophleps-purpurea': 'eupitheciini-genera-spp',
#  'lophosoma-cuprea': 'macrobrochis-gigas',
#  'luxiaria-phyllosaria': 'zeheba-aureata',
#  'luxiaria-spp': 'turnaca-spp',
#  'luxiaria-tephrosaria': 'Luxiaria-hypaphanes',
#  'lygniodes-vampyurs': 'entomogramma-torsa',
#  'lymantria-ampla': 'britha-spp',
#  'lymantria-marginata': 'lymantria-fuliginosa',
#  'lymantria-mathura': 'gastropacha-spp',
#  'lymantria-spp': 'olepa-ricini',
#  'lyssa-zampa': 'ischyja-manlia',
#  'maceda-mansueta': 'maurilia-iconica',
#  'macotasa-nubecula': 'nomophila-noctuella',
#  'macrobrochis-gigas': 'episteme-adulatrix',
#  'macrocilix-maia': 'ourapteryx-spp',
#  'macroglossum-assimilis': 'hyblaea-puera-complex',
#  'macroglossum-bombylans': 'phauda-triadum',
#  'macroglossum-gyrans': 'orgyiini-genera-spp',
#  'macroglossum-sitiene': 'chrysopera-combinans',
#  'mahanta-quadrilinea': 'cnaphalocrocis-rutilalis',
#  'maliattha-erecta': 'thosea-magna',
#  'maliattha-fervens': 'schistophleps-spp',
#  'maliattha-ruptifascia': 'alcanola-tympanistis',
#  'maliattha-signifera': 'progonia-kurosawai',
#  'mangina-argus': 'nepita-conferta',
#  'mangina-syringa': 'mangina-argus',
#  'manoba-tristicta': 'naxidia-punctata',
#  'maruca-amboinalis': 'diaphania-indica',
#  'marumba-dyras': 'thyas-coronata',
#  'maurilia-iconica': 'spilarctia-spp',
#  'mecodina-albodentata': 'larentiinae-genera-spp',
#  'megacorma-obliqua': 'psilogramma-increta',
#  'meganola-nitida': 'digama-marchalii',
#  'metallolophia-taleensis': 'Somatina-densifasciaria',
#  'metanastria-spp': 'gastropacha-spp',
#  'metarbelidae-genera-spp': 'epipaschiinae-genera-spp',
#  'micraloa-spp': 'turnaca-spp',
#  'microblepsis-leucosticta': 'microblepsis-violacea',
#  'microblepsis-violacea': 'callidrepana-patrana',
#  'microloxia-indecretata': 'traminda-mundissima',
#  'microloxia-spp': 'comostola-spp',
#  'micromelalopha-spp': 'eublemma-baccalix',
#  'micronia-aculeata': 'adoxophyes-spp',
#  'microxyla-stipata': 'pseudozarba-spp',
#  'miltochrista-conjunctana': 'siglophora-sanguinolenta',
#  'miltochrista-obsoleta': 'synclera-traducalis',
#  'miltochrista-terminospota': 'asura-miltochrista-group-spp',
#  'miltochrista-undulata': 'eumelea-ludovicata',
#  'miltochrista-undulosa': 'juxtarctia-multiguttata',
#  'mimomiza-cruentaria': 'endocrossis-flavibasalis',
#  'miresa-albipuncta': 'oraesia-emarginata',
#  'miresa-spp': 'argina-astrea',
#  'mixochlora-vittata': 'tanaorhinus-kina',
#  'mocis-frugalis': 'achaea-janata',
#  'mocis-undata': 'chiasmia-spp',
#  'musotiminae-genera-spp': 'eurrhyparodes-tricoloralis',
#  'mustilizans-hepatica': 'orudiza-protheclaria',
#  'naarda-spp': 'amyna-spp',
#  'nacna-malachitis': 'agrius-convolvuli',
#  'narosa-conspersa': 'sameodes-cancellalis',
#  'nausinoe-geometralis': 'sameodes-cancellalis',
#  'nausinoe-perspectata': 'yepcalphis-dilectissima',
#  'negeta-contrariata': 'oglasa-hypenoides',
#  'neocerura-liturata': 'polytela-gloriosae',
#  'neochera-dominia': 'nola-internella-analis-complex',
#  'neogurelca-himachala': 'amplypterus-panopus',
#  'neogurelca-hyas': 'eudocima-materna',
#  'neopheosia-fasciata': 'photoscotosia-amplicata',
#  'nephele-hespera': 'thyas-coronata',
#  'nepita-conferta': 'chalcidica-minea',
#  'netria-multispinae': 'netria-viridescens',
#  'nisaga-simplex': 'theretra-lucasii',
#  'noctuinae-genera-spp': 'phycitinae-genera-spp',
#  'nola-internella-analis-complex': 'chalcoscelides-castaneipars',
#  'nola-taeniata': 'eoophyla-spp',
#  'nolinae-genera-spp': 'syntomoides-imaon',
#  'noorda-blitealis': 'selepa-celtis',
#  'noreia-ajaia': 'ganisa-spp',
#  'notodontella-tenebrosa': 'eriocottidae-genera-spp',
#  'notodontidae-genera-spp': 'macroglossum-corythus',
#  'numenes-siletti': 'pergesa-acteus',
#  'nyctemera-adversata': 'nolinae-genera-spp',
#  'nyctemera-lacticinia': 'nyctemera-adversata',
#  'nygmiini-genera-spp': 'hypocala-subsatura',
#  'oeonistis-entella': 'sesiidae-genera-spp',
#  'oglasa-hypenoides': 'netria-viridescens',
#  'olene-mendosa': 'agrius-convolvuli',
#  'olepa-ricini': 'spirama-spp',
#  'omiodes-spp': 'petelia-spp',
#  'omiodes-surrectalis': 'glyphodes-stolalis',
#  'omiza-miliaria': 'hemithea-spp',
#  'omphisa-anastomosalis': 'crocidolomia-pavonana',
#  'ophiusa-disjungens': 'ophiusa-tirhaca',
#  'ophthalmitis-spp': 'Cusiala-raptaria',
#  'opisthograptis-mimulina': 'hyalobathra-opheltesalis',
#  'opisthograptis-sulphurea': 'asura-miltochrista-group-spp',
#  'oraesia-argyrosigna': 'paralebeda-plagifera',
#  'oraesia-emarginata': 'biston-suppressaria',
#  'oreta-extensa': 'eumelea-spp',
#  'oreta-spp': 'rhesala-spp',
#  'oreta-suffusa': 'striglina-spp',
#  'orgyia-postica': 'spodoptera-litura',
#  'orgyiini-genera-spp': 'bradina-adhaesalis',
#  'orthaga-exvinacea': 'cidariini-genera-spp',
#  'orthobrachia-flavidior': 'thyrididae-genera-spp',
#  'orthocabera-sericea': 'parapoynx-stagnalis',
#  'orthonama-obstipata': 'blasticorhinus-rivulosa',
#  'ortopla-lindsayi': 'deltoplastis-spp',
#  'orudiza-protheclaria': 'poliobotys-ablactalis',
#  'orvasca-subnotata': 'egnasia-ephyrodalis',
#  'ourapteryx-spp': 'hyperythra-lutea',
#  'ovipennis-incompletostriga': 'aberrasine-strigivenata',
#  'oxyodes-scrobiculata': 'acosmeryx-akanshi',
#  'ozarba-punctigera': 'lophoptera-illucida',
#  'ozarba-spp': 'dysodia-spp',
#  'pachyodes-haemataria': 'xanthodes-transversa',
#  'padenia-spp': 'cyana-signa',
#  'padenia-transversa': 'autocharis-amethystina',
#  'pagyda-salvalis': 'artaxa-guttata',
#  'pandesma-spp': 'amata-sperbius',
#  'pangora-matherana': 'creatonotos-gangis-interrupta-complex',
#  'pantana-luteiceps': 'asta-quadrilinea',
#  'paracrama-latimargo': 'ornithospila-avicularia',
#  'paracymoriza-vagalis': 'arichanna-transfasciata',
#  'paralbara-muscularia': 'paralbara-perhamata',
#  'paralbara-perhamata': 'nordstromia-lilacina',
#  'paralebeda-plagifera': 'episparis-exprimens',
#  'parallelia-rigidistria-calefasciens-complex': 'creatonotos-gangis-interrupta-complex',
#  'parallelia-stuposa': 'pericyma-cruegeri',
#  'parapoynx-affinialis': 'dasyboarmia-spp',
#  'parapoynx-bilinealis': 'glyphodes-bivitralis',
#  'parapoynx-crisonalis': 'nolinae-genera-spp',
#  'parapoynx-diminutalis': 'sameodes-cancellalis',
#  'parapoynx-fluctuosalis': 'alcanola-tympanistis',
#  'parapoynx-spp': 'scopula-opicata',
#  'parapoynx-stagnalis': 'pycnarmon-cribrata',
#  'parasa-lepida': 'hypomecis-spp',
#  'parotis-marginata-complex': 'eudocima-hypermnestra',
#  'parotis-spp': 'trabala-spp',
#  'patania-characteristica': 'Chalcidoptera-emissalis',
#  'patania-plagiatalis': 'omiodes-indicata',
#  'penicillifera-apicalis': 'parapoynx-stagnalis',
#  'peratophyga-hyalinata': 'coremecis-nigrovittata',
#  'pergesa-acteus': 'amata-elongata',
#  'pericyma-albidens': 'erebus-hieroglyphica',
#  'pericyma-cruegeri': 'cidariini-genera-spp',
#  'pericyma-glaucinans': 'blasticorhinus-rivulosa',
#  'pericyma-spp': 'condica-spp',
#  'perina-nuda': 'hypopyra-spp',
#  'petelia-immaculata': 'anticarsia-irrorata',
#  'petelia-spp': 'cleora-spp',
#  'phalacra-vidhisara': 'scopula-emissaria',
#  'phalera-combusta': 'ophiusa-tirhaca',
#  'phalera-spp': 'sufetula-spp',
#  'phazaca-spp': 'actias-selene',
#  'phocoderma-velutina': 'alphaea-imbuta',
#  'photoscotosia-spp': 'progonia-kurosawai',
#  'phycitinae-genera-spp': 'sterrhinae-genera-spp',
#  'phycodes-radiata': 'vamuna-remelana',
#  'phyllodes-eyndhovii': 'theretra-boisduvalii',
#  'pida-spp': 'perina-nuda',
#  'pidorus-glaucopis': 'macrobrochis-gigas',
#  'piesmopoda-semilutea': 'phauda-triadum',
#  'pindara-illibata': 'artena-dotata',
#  'pingasa-lariaria': 'euchromius-ocellea',
#  'pingasa-spp': 'ericeia-spp',
#  'plagodis-inustaria': 'dierna-patibulum',
#  'plecoptera-spp': 'micronia-aculeata',
#  'plusiinae-genera-spp': 'orgyiini-genera-spp',
#  'plutella-xylostella': 'oraesia-emarginata',
#  'plutodes-transmutata': 'agnidra-discispilaria',
#  'poaphilini-genera-spp': 'spoladea-recurvalis',
#  'poliobotys-ablactalis': 'ptychopseustis-spp',
#  'polydesma-boarmoides': 'boarmiini-genera-spp',
#  'polytela-gloriosae': 'acherontia-lachesis',
#  'polythlipta-divaricata': 'biston-contectaria',
#  'problepsis-spp': 'nyctemera-coleta',
#  'problepsis-vulgaris': 'problepsis-albidior',
#  'procridinae-genera-spp': 'zygaenidae-genera-spp',
#  'progonia-oileusalis': 'ptychopseustis-spp',
#  'prophantis-adusta': 'achrosis-rufescens',
#  'protonoceras-capitalis': 'boletobiinae-genera-spp',
#  'protuliocnemis-biplagiata': 'eucyclodes-sanguilineata',
#  'pseudoblabes-oophora': 'hyblaea-puera-complex',
#  'pseudomiza-leucogonia': 'siglophora-ferreilutea',
#  'pseudosphetta-moorei': 'cassephyra-cyanosticta',
#  'pseudozarba-spp': 'britha-spp',
#  'psilalcis-albibasis': 'biston-suppressaria',
#  'psilalcis-breta': 'cusiala-boarmoides',
#  'psilochira-lineata': 'arctornis-l-nigrum',
#  'psilogramma-increta': 'auchmis-inextricata',
#  'psilogramma-spp': 'xyleutes-persona',
#  'psilogramma-vates': 'chiasmia-eleonora',
#  'psimada-quadripennis': 'helicoverpa-armigera',
#  'pterotopteryx-spilodesma': 'eurrhyparodes-bracteolalis',
#  'ptisciana-seminivea': 'psilogramma-increta',
#  'ptychopseustis-spp': 'dolgoma-angulifera',
#  'pycnarmon-cribrata': 'scythropiodes-spp',
#  'pygospila-costiflexalis': 'nacoleia-commixta',
#  'pygospila-tyres': 'abraxas-spp',
#  'pyloetis-mimosae': 'stathmopoda-spp',
#  'pyralidae-genera-spp': 'bocana-manifestalis',
#  'pyralis-manihotalis': 'ectropidia-shoreae',
#  'pyralis-pictalis': 'digama-marchalii',
#  'pyrausta-spp': 'idaea-spp',
#  'pyrrhia-umbra': 'anomis-flava',
#  'radara-subcupralis': 'orybina-flaviplaga',
#  'radhica-rosea': 'thespea-bicolor',
#  'rajendra-biguttata': 'dysphania-nelera',
#  'ramadasa-pavo': 'gazalina-apsara',
#  'ramila-acciusalis': 'problepsis-vulgaris',
#  'rapdalus-pardicolor': 'boarmiini-genera-spp',
#  'rehimena-phrynealis': 'eudocima-salaminia',
#  'rhagastis-castor': 'parotis-marginata-complex',
#  'rhagastis-olivacea': 'ophiusa-tirhaca',
#  'rhectothyris-gratiosalis': 'leptomiza-calcearia',
#  'rhesala-spp': 'ozarba-spp',
#  'rhimphalea-trogusalis': 'diasemiopsis-ramburialis',
#  'rhodophaea-actiosella': 'eriocottidae-genera-spp',
#  'rinaca-cidosa': 'hyposidra-talaca',
#  'rinaca-simla': 'cricula-agria',
#  'rinaca-thibeta': 'mocis-undata',
#  'rivula-bioculalis': 'carea-angulata',
#  'rivula-spp': 'naarda-spp',
#  'rusicada-spp': 'pyrausta-spp',
#  'sacada-discinota': 'penicillaria-simplex',
#  'sacada-spp': 'spirama-spp',
#  'sameodes-cancellalis': 'noctuinae-genera-spp',
#  'sarcinodes-aequilinearia': 'chloroglyphica-variegata',
#  'sarobela-litterata': 'hippotion-celerio',
#  'sauris-spp': 'naarda-spp',
#  'schistophleps-spp': 'cnaphalocrocis-spp',
#  'sciorista-assignatalis': 'botyodes-diniasalis',
#  'scirpophaga-incertulas': 'antheraea-assamensis',
#  'scopelodes-spp': 'digama-insulana',
#  'scopula-cuneilinea': 'Pingasa-rubicunda',
#  'scopula-ferrilineata': 'biston-bengaliaria',
#  'scopula-fibulata': 'comibaena-spp',
#  'scythropiodes-spp': 'cephonodes-hylas',
#  'selepa-celtis': 'selepa-spp',
#  'selepa-spp': 'archips-spp',
#  'serrodes-campana': 'ecliptopera-dissecta',
#  'sesiidae-genera-spp': 'nyctemera-lacticinia',
#  'siccia-spotoptera': 'amata-sperbius',
#  'siccia-spp': 'Ecpyrrhorrhoe-spp',
#  'siccia-taprobanis': 'oxymacaria-palliata',
#  'sinarella-discisigna': 'cidariini-genera-spp',
#  'singara-diversalis': 'cricula-trifenestrata',
#  'sinna-extrema': 'argina-astrea',
#  'sirinopteryx-rufivinctata': 'microloxia-indecretata',
#  'somatina-anthophilata': 'pterophoridae-genera-spp',
#  'somatina-omicraria': 'scopula-pulchellata',
#  'somena-scintillans': 'mocis-undata',
#  'soritia-pulchella': 'balataea-spp',
#  'spataliini-genera-spp': 'creatonotos-transiens',
#  'sphenarches-anisodactyla': 'omphisa-anastomosalis',
#  'sphingomorpha-chlorea': 'aedia-leucomelas-complex',
#  'sphingonaepiopsis-pumilio': 'thysanoplusia-orichalcea',
#  'sphrageidus-spp': 'euproctis-lunata',
#  'spilarctia-comma': 'vamuna-remelana',
#  'spilarctia-spp': 'trabala-spp',
#  'spilosoma-spp': 'amerila-eugenia',
#  'spilosomina-genera-spp': 'crambidae-genera-spp',
#  'spirama-spp': 'artaxa-spp',
#  'spodoptera-litura': 'macroglossum-sitiene',
#  'spoladea-recurvalis': 'orgyiini-genera-spp',
#  'stauropus-alternus': 'achaea-janata',
#  'stauropus-thiaucourti': 'acantholipes-trajecta',
#  'sterrhinae-genera-spp': 'poliobotys-ablactalis',
#  'striglina-scitaria': 'maurilia-iconica',
#  'striglina-spp': 'nygmia-icilia',
#  'suana-concolor': 'trilocha-varians',
#  'syllepte-bipartalis': 'omiodes-indicata',
#  'syllepte-sellalis': 'theretra-lucasii',
#  'syllepte-straminalis': 'synclera-traducalis',
#  'sympis-rufibasis': 'theretra-nessus',
#  'synclera-traducalis': 'conogethes-spp',
#  'syngamia-latimarginalis': 'lopharthrum-comprimens',
#  'syntomoides-imaon': 'agassiziella-picalis',
#  'syntypistis-comatus': 'scopariinae-genera-spp',
#  'sypnoides-pannosa': 'achrosis-incitata-complex',
#  'talanga-sexpunctalis': 'pyrausta-phoenicealis',
#  'tamba-spp': 'ericeia-spp',
#  'tanaorhinus-reciprocata': 'aplochlora-dentisignata',
#  'tatobotys-biannulalis': 'siccia-spotoptera',
#  'teldenia-vestigiata': 'micronia-aculeata',
#  'teleclita-centristicta': 'lymantria-fuliginosa',
#  'teleclita-strigata': 'bacotoma-violata',
#  'termioptycha-albifurcalis': 'epipaschiinae-genera-spp',
#  'tetragonus-catamitus': 'helicoverpa-armigera',
#  'teuloma-nebulosa': 'nepita-conferta',
#  'thaumetopoea-cheela': 'chlumetia-transversa',
#  'theretra-boisduvalii': 'marumba-cristata',
#  'theretra-clotho': 'theretra-lucasii',
#  'theretra-lucasii': 'thyas-coronata',
#  'theretra-shendurneensis': 'westermannia-triangularis',
#  'theretra-sumatrensis': 'rhagastis-confusa',
#  'thespea-bicolor': 'comibaena-spp',
#  'thinopteryx-crocoptera': 'tridrepana-albonotata',
#  'thosea-spp': 'amyna-spp',
#  'thyas-coronata': 'olene-mendosa',
#  'thyatira-batis': 'phalera-spp',
#  'thymistida-spp': 'pandesma-spp',
#  'thyrididae-genera-spp': 'gazalina-chrysolopha',
#  'thysanoidma-stellata': 'paradiopa-postfusca',
#  'thysanoplusia-orichalcea': 'xenochroa-chlorostigma',
#  'thysanoplusia-reticulata': 'eriocottidae-genera-spp',
#  'thysanoplusia-spp': 'orvasca-subnotata',
#  'timandra-correspondens': 'pelagodes-thalassodes-spp',
#  'timora-sanguinolenta': 'cheromettia-apicata',
#  'tiracola-plagiata': 'olene-mendosa',
#  'tiracola-spp': 'athetis-spp',
#  'tonica-niviferana': 'phazaca-theclata',
#  'tortricidae-genera-spp': 'Tympanistes-testacea',
#  'trabala-spp': 'parasa-lepida',
#  'trachea-auriplena': 'chrysodeixis-spp',
#  'traminda-aventiaria': 'cephonodes-picus',
#  'traminda-mundissima': 'chlorozancla-falcatus',
#  'trichoplusia-ni': 'thyatira-batis',
#  'trichopterigia-spp': 'conogethes-spp',
#  'tridrepana-flava': 'botyodes-asialis',
#  'trigonodes-hyppasia': 'padenia-transversa',
#  'trilocha-varians': 'crocidolomia-spp',
#  'trischalis-subaurana': 'pyralidae-genera-spp',
#  'trypanophora-semihyalina': 'asura-miltochrista-group-spp',
#  'tyana-chloroleuca': 'agathia-incudaria',
#  'ulopeza-semivialis': 'crocidophora-fasciata',
#  'utetheisa-spp': 'lymantria-spp',
#  'vamuna-bipars': 'plecoptera-spp',
#  'vamuna-remelana': 'comostola-inops',
#  'westermannia-superba': 'Pseudargyria-parallelus',
#  'xandrames-dholaria': 'coremecis-nigrovittata',
#  'xandrames-latiferaria': 'boarmiini-genera-spp',
#  'xanthodes-albago': 'euproctis-lunata',
#  'xanthodes-transversa': 'tetragonus-catamitus',
#  'xanthorhoe-saturata': 'boarmiini-genera-spp',
#  'xanthorhoe-spp': 'calluga-costalis',
#  'xenochroa-biviata': 'euproctis-plagiata',
#  'xenoplia-maculata': 'siccia-taprobanis',
#  'xyleutes-ramamurthyi': 'macrobrochis-prasena',
#  'zamarada-spp': 'chiasmia-nora',
#  'zeuzerini-genera-spp': 'alcanola-tympanistis',
#  'zitha-torridalis': 'ercheia-cyllaria'}

# %% [markdown]
# # Train & Test again

# %%
train(model_data, 20, f"{dataset_dir}/checkpoint_latest.pth")
# Out:
# Epoch    1 /   20  | Train Loss: 1.7439 Acc: 0.5875  | Val Loss: 23.1811 Acc: 0.0003  | Elapsed time: 0:04:25.660752
# Epoch    2 /   20  | Train Loss: 1.7487 Acc: 0.5862  | Val Loss: 23.3453 Acc: 0.0002  | Elapsed time: 0:09:05.312824
# Epoch    3 /   20  | Train Loss: 1.7470 Acc: 0.5880  | Val Loss: 23.2512 Acc: 0.0002  | Elapsed time: 0:13:43.395756
# Epoch    4 /   20  | Train Loss: 1.7415 Acc: 0.5876  | Val Loss: 23.2180 Acc: 0.0003  | Elapsed time: 0:18:21.717836
# Epoch    5 /   20  | Train Loss: 1.7465 Acc: 0.5901  | Val Loss: 23.3627 Acc: 0.0002  | Elapsed time: 0:23:03.262890
# Epoch    6 /   20  | Train Loss: 1.7485 Acc: 0.5852  | Val Loss: 23.3329 Acc: 0.0002  | Elapsed time: 0:27:42.845197
# Epoch    7 /   20  | Train Loss: 1.7438 Acc: 0.5876  | Val Loss: 23.1874 Acc: 0.0002  | Elapsed time: 0:32:23.790829
# Epoch    8 /   20  | Train Loss: 1.7379 Acc: 0.5911  | Val Loss: 23.3091 Acc: 0.0002  | Elapsed time: 0:37:07.961059
# Epoch    9 /   20  | Train Loss: 1.7421 Acc: 0.5890  | Val Loss: 23.3658 Acc: 0.0002  | Elapsed time: 0:41:50.797557
# Epoch   10 /   20  | Train Loss: 1.7437 Acc: 0.5880  | Val Loss: 23.3902 Acc: 0.0002  | Elapsed time: 0:46:26.846942
# Epoch   11 /   20  | Train Loss: 1.7418 Acc: 0.5890  | Val Loss: 23.2469 Acc: 0.0002  | Elapsed time: 0:51:02.383148
# Epoch   12 /   20  | Train Loss: 1.7447 Acc: 0.5864  | Val Loss: 23.2394 Acc: 0.0002  | Elapsed time: 0:55:39.942604
# Epoch   13 /   20  | Train Loss: 1.7399 Acc: 0.5904  | Val Loss: 23.1530 Acc: 0.0002  | Elapsed time: 1:00:19.571930
# Epoch   14 /   20  | Train Loss: 1.7355 Acc: 0.5905  | Val Loss: 23.1626 Acc: 0.0002  | Elapsed time: 1:04:58.021731
# Epoch   15 /   20  | Train Loss: 1.7479 Acc: 0.5877  | Val Loss: 23.3176 Acc: 0.0002  | Elapsed time: 1:09:33.461275
# Epoch   16 /   20  | Train Loss: 1.7450 Acc: 0.5877  | Val Loss: 23.1709 Acc: 0.0002  | Elapsed time: 1:14:11.524665
# Epoch   17 /   20  | Train Loss: 1.7441 Acc: 0.5884  | Val Loss: 23.2568 Acc: 0.0002  | Elapsed time: 1:18:47.814235
# Epoch   18 /   20  | Train Loss: 1.7384 Acc: 0.5904  | Val Loss: 23.3427 Acc: 0.0002  | Elapsed time: 1:23:27.817703
# Epoch   19 /   20  | Train Loss: 1.7455 Acc: 0.5884  | Val Loss: 23.3484 Acc: 0.0002  | Elapsed time: 1:28:08.059101
# Epoch   20 /   20  | Train Loss: 1.7405 Acc: 0.5872  | Val Loss: 23.2812 Acc: 0.0002  | Elapsed time: 1:32:48.872200

# %%
shutil.copy(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/checkpoint_{int(time.time())}.pth")
# Out:
# 'insect-dataset/moth/checkpoint_1737807164.pth'

# %%
test(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/test")
# Out:
# Accuracy: 804 / 2105 -> 38.19%
# Elapsed time: 0:00:15.555013
# ----------
# Failures:
# {'Aiteta-spp': 'banisia-spp',
#  'Alcis-periphracta': 'dasyboarmia-spp',
#  'Apha-floralis': 'Gunda-spp',
#  'Boeotarcha-martinalis': 'oxaenanus-brontesalis',
#  'Calamotropha-corticellus': 'westermannia-superba',
#  'Calletaera-obliquata': 'Luxiaria-hypaphanes',
#  'Callopistria-pulchrilinea': 'dudusa-sphingiformis',
#  'Carea-obsolescens': 'oxymacaria-palliata',
#  'Chalcosiopsis-variata': 'Mosopia-kononenkoi',
#  'Charitoprepes-lubricosa': 'crambidae-genera-spp',
#  'Chloroplaga-pallida': 'Somatina-densifasciaria',
#  'Chusaris-spp': 'rhesala-spp',
#  'Comibaena-biplaga': 'poliobotys-ablactalis',
#  'Cusiala-raptaria': 'cleora-alienaria',
#  'Cusiala-spp': 'phalera-spp',
#  'Daplasa-irrorata': 'aegocera-venulia',
#  'Ecpyrrhorrhoe-spp': 'perina-nuda',
#  'Floridasura-tricolor': 'Moorasura-inflexa',
#  'Goniocraspidum-ennomoide': 'lasiocampidae-genera-spp',
#  'Harutaea-flavizona': 'heterostegane-spp',
#  'Hyperythra-swinhoei': 'herpetogramma-spp',
#  'Hypolamprus-bastialis': 'parapoynx-stagnalis',
#  'Lamprosema-spp': 'digama-marchalii',
#  'Luxiaria-hypaphanes': 'krananda-semihyalina',
#  'Meganola-major': 'Athetis-bremusa',
#  'Metacosmesis-laxeuta': 'hypeninae-genera-spp',
#  'Miltochrista-spp': 'nepita-conferta',
#  'Moorasura-gloriosa': 'Moorasura-inflexa',
#  'Mosopia-kononenkoi': 'daddala-lucilla-complex',
#  'Orothalassodes-hypocrites': 'pelagodes-thalassodes-spp',
#  'Perixera-illepidaria': 'eupterote-patula',
#  'Petavia-attenuata': 'euproctis-plagiata',
#  'Pingasa-rubicunda': 'dysphania-percota',
#  'Protuliocnemis-castalaria': 'linguisaccus-subhyalina',
#  'Psilalcis-conspicuata': 'Luxiaria-mitorrhaphes',
#  'Rhodoneura-fimbriata': 'notarcha-aurolinealis',
#  'Rhodoneura-lobulata': 'syngamia-falsidicalis',
#  'Spodoptera-frugiperda': 'Pectinophora-gossypiella',
#  'Striatella-nigralba': 'problepsis-spp',
#  'Tambana-subflava': 'dolbina-manjunatha',
#  'Teleclita-grisea': 'lophoptera-spp',
#  'abraxas-spp': 'micraloa-spp',
#  'acantholipes-circumdata': 'acmeshachia-gigantea',
#  'acantholipes-trajecta': 'trigonodes-hyppasia',
#  'achaea-janata': 'hypsopygia-spp',
#  'achaea-serva': 'scopula-opicata',
#  'achelura-bifasciata': 'lymantria-similis',
#  'acherontia-lachesis': 'spodoptera-litura',
#  'acherontia-styx': 'callopistria-spp',
#  'achrosis-intexta': 'endotricha-spp',
#  'achrosis-rondelaria': 'herpetogramma-spp',
#  'achrosis-spp': 'mocis-undata',
#  'acontia-crocata': 'macrocilix-maia',
#  'acontia-marmoralis': 'pseudoadites-frigida',
#  'acontia-spp': 'miresa-spp',
#  'acosmeryx-akanshi': 'psilogramma-increta',
#  'acosmeryx-anceus': 'acosmeryx-pseudonaga',
#  'actias-parasinensis': 'callambulyx-poecilus',
#  'actias-selene': 'arctornis-spp',
#  'adisura-spp': 'Rhynchina-spp',
#  'adoxophyes-spp': 'hastina-pluristrigata',
#  'aegocera-venulia': 'tonica-niviferana',
#  'agalope-hyalina': 'abraxas-spp',
#  'agassiziella-picalis': 'diaphania-indica',
#  'agathia-lycaenaria': 'Comibaena-biplaga',
#  'agrioglypta-eurytusalis': 'cirrhochrista-pulchellalis',
#  'agrius-convolvuli': 'hypena-laceratalis',
#  'agrotera-basinotata': 'crambinae-genera-spp',
#  'alcanola-tympanistis': 'talanga-sexpunctalis',
#  'alcis-perspicuata': 'ectropidia-shoreae',
#  'alcis-spp': 'cleora-spp',
#  'aloa-lactinea': 'actias-selene',
#  'aloa-neoaloa-spp': 'vamuna-remelana',
#  'amata-cyssea': 'amata-passalis',
#  'amata-elongata': 'glyphodes-bicolor',
#  'amata-extensa': 'oeonistis-spp',
#  'amata-passalis': 'nepita-conferta',
#  'amata-sperbius': 'spilarctia-spp',
#  'amblychia-pardicelata': 'biston-suppressaria',
#  'ambulyx-belli': 'asota-caricae',
#  'ambulyx-liturata': 'theretra-clotho',
#  'ambulyx-moorei': 'calesia-haemorrhoa',
#  'amerila-astreus': 'brunia-antica',
#  'amerila-eugenia': 'digama-marchalii',
#  'ammatho-cuneonotatus': 'thinopteryx-nebulosa',
#  'ammatho-spp': 'anomis-flava',
#  'amyna-spp': 'ozarba-spp',
#  'anabasis-obliquifasciella': 'phycitinae-genera-spp',
#  'anadevidia-peponis': 'eudocima-homaena',
#  'andraca-trilochoides': 'orvasca-subnotata',
#  'angonyx-krishna': 'ambulyx-moorei',
#  'angonyx-testacea': 'pergesa-acteus',
#  'anisoneura-aluco': 'spodoptera-litura',
#  'anomis-flava': 'agrotis-ipsilon',
#  'antheraea-assamensis': 'epipleminae-genera-spp',
#  'antheraea-frithi': 'plutodes-exquisita',
#  'antheraea-paphia': 'mocis-undata',
#  'anticarsia-irrorata': 'eupterote-patula',
#  'antigastra-catalaunalis': 'creatonotos-transiens',
#  'antipercnia-belluaria': 'zeuzerini-genera-spp',
#  'aphendala-spp': 'nola-taeniata',
#  'archaeoattacus-edwardsii': 'macroglossum-gyrans',
#  'archiplutodes-prasina': 'polynesia-sunandava',
#  'archips-spp': 'idaea-spp',
#  'arcte-polygrapha': 'erebus-ephesperis',
#  'arctioblepsis-rubida': 'plutodes-transmutata',
#  'arctornis-spp': 'abraxas-spp',
#  'areas-galactina': 'pterophoridae-genera-spp',
#  'argina-astrea': 'utetheisa-spp',
#  'argonestis-flammans': 'cheromettia-apicata',
#  'argyrocosma-inductaria': 'ornithospila-avicularia',
#  'arichanna-jaguarinaria': 'pachyodes-haemataria',
#  'arichanna-schnitzleri': 'nausinoe-perspectata',
#  'arna-bipunctapex': 'rhagastis-olivacea',
#  'aroa-campbelli': 'orgyia-postica',
#  'aroa-spp': 'Aiteta-spp',
#  'artaxa-spp': 'earias-spp',
#  'arthroschista-hilaralis': 'comostola-laesaria',
#  'artona-quadrimaculata': 'hyblaea-puera-complex',
#  'ascotis-spp': 'cleora-spp',
#  'asota-caricae': 'earias-vittella',
#  'asota-ficus': 'cyana-spp',
#  'asota-plana': 'abraxas-spp',
#  'asta-quadrilinea': 'bastilla-arcuata',
#  'astygisa-spp': 'lygniodes-spp',
#  'asura-miltochrista-group-spp': 'siglophora-sanguinolenta',
#  'atacira-melanephra': 'sinarella-discisigna',
#  'athetis-delecta': 'calliteara-spp',
#  'atkinsonia-clerodendronella': 'lasiocampidae-genera-spp',
#  'attacus-taprobanis': 'petavia-erycinoides',
#  'attatha-ino': 'allata-spp',
#  'atteva-fabriciella': 'acherontia-lachesis',
#  'autoba-silicula': 'hypomecis-spp',
#  'autocharis-fessalis': 'vamuna-maculata',
#  'auzata-semipavonaria': 'drepanidae-genera-spp',
#  'avatha-discolor': 'asta-quadrilinea',
#  'avatha-leksawasdi': 'elophila-spp',
#  'azygophleps-scalaris': 'creatonotos-transiens',
#  'bamra-albicola': 'lymantria-spp',
#  'baniana-semilugens': 'endotricha-ruminalis',
#  'banisia-spp': 'Teinoptila-spp',
#  'barsaurea-phaeoxanthia': 'ovipennis-flavivenosa',
#  'barsine-genera-group-spp': 'hypochrosis-hyadaria-complex',
#  'barsine-group-spp': 'nygmiini-genera-spp',
#  'bastilla-acuta': 'bastilla-crameri',
#  'bastilla-conficiens': 'chalciope-mygdon',
#  'bastilla-crameri': 'trilocha-varians',
#  'bastilla-simillima': 'erebus-macrops',
#  'beara-spp': 'rhesala-spp',
#  'berta-spp': 'cleora-spp',
#  'bertula-abjudicalis': 'spoladea-recurvalis',
#  'bharetta-cinnamomea': 'amblychia-angeronaria',
#  'bireta-longivitta': 'olene-mendosa',
#  'biston-bengaliaria': 'biston-contectaria',
#  'biston-strigaria': 'chlororithra-fea',
#  'biston-suppressaria': 'lassaba-albidaria',
#  'blasticorhinus-rivulosa': 'pericyma-glaucinans',
#  'boarmiini-genera-spp': 'phycitinae-genera-spp',
#  'bocchoris-inspersalis': 'plusiinae-genera-spp',
#  'bocula-spp': 'ozarba-spp',
#  'botyodes-asialis': 'omiodes-indicata',
#  'botyodes-principalis': 'sciorista-assignatalis',
#  'bradina-adhaesalis': 'orgyiini-genera-spp',
#  'bradina-diagonalis': 'bradina-admixtalis',
#  'brahmaea-hearseyi': 'glyphodes-caesalis',
#  'brenthia-spp': 'spirama-spp',
#  'britha-pactalis': 'digama-insulana',
#  'britha-spp': 'gesonia-spp',
#  'brunia-antica': 'Tamba-lala',
#  'calesia-fuscicorpus': 'calesia-dasypterus',
#  'calesia-haemorrhoa': 'eudocima-homaena',
#  'calesia-stillifera': 'gonodontis-spp',
#  'callambulyx-rubricosa': 'hippotion-celerio',
#  'callidrepana-argenteola': 'sirinopteryx-rufivinctata',
#  'callidrepana-patrana': 'agnidra-discispilaria',
#  'callindra-equitalis': 'chrysodeixis-spp',
#  'calliteara-complicata': 'perciana-marmorea',
#  'calliteara-horsfieldii': 'oxymacaria-palliata',
#  'calliteara-spp': 'arctornis-spp',
#  'callopistria-minuta': 'spodoptera-litura',
#  'callopistria-repleta': 'xandrames-dholaria',
#  'callyna-semivitta': 'rajendra-biguttata',
#  'calyptra-spp': 'selepa-spp',
#  'camptoloma-binotatum': 'nygmiini-genera-spp',
#  'campylotes-histrionicus': 'aglaomorpha-plagiata',
#  'canucha-specularis': 'hydatocapnia-spp',
#  'carea-angulata': 'maurilia-iconica',
#  'casama-vilis': 'garella-ruficirra',
#  'cechetra-lineosa': 'antheraea-paphia',
#  'cechetra-scotti': 'pergesa-acteus',
#  'celenna-festivaria': 'eudocima-salaminia',
#  'cephonodes-hylas': 'chasmina-candida',
#  'cephonodes-spp': 'padenia-transversa',
#  'cerynea-igniaria': 'anoba-polyspila',
#  'cerynea-punctilinealis': 'helicoverpa-armigera',
#  'cerynea-spp': 'ericeia-spp',
#  'ceryx-diptera': 'aloa-lactinea',
#  'chabula-acamasalis': 'brahmaea-wallichii',
#  'chadisra-bipars': 'olene-mendosa',
#  'chadisra-spp': 'condica-spp',
#  'chalcosia-diana': 'vamuna-remelana',
#  'chamaita-nympha': 'parapoynx-stagnalis',
#  'chasmina-spp': 'sphrageidus-spp',
#  'chiasmia-eleonora': 'isturgia-disputaria',
#  'chiasmia-fidoniata': 'biston-suppressaria',
#  'chiasmia-spp': 'achaea-serva',
#  'chilena-similis': 'carea-angulata',
#  'chilkasa-falcata': 'artaxa-guttata',
#  'chlororithra-fea': 'erebus-macrops',
#  'chlumetia-spp': 'feliniopsis-spp',
#  'chlumetia-transversa': 'sameodes-cancellalis',
#  'chorodna-adumbrata': 'agnidra-discispilaria',
#  'chorodna-strixaria': 'chiasmia-fidoniata',
#  'chorsia-mollicula': 'maliattha-separata',
#  'chrysocraspeda-abhadraca': 'blepharoctenucha-virescens',
#  'chrysocraspeda-faganaria': 'orphanostigma-abruptalis',
#  'chrysocraspeda-spp': 'endotricha-ruminalis',
#  'chrysodeixis-eriosoma': 'chabulina-onychinalis',
#  'chrysodeixis-spp': 'idaea-macrospila',
#  'chrysorabdia-bivitta': 'Paraona-splendens',
#  'cidariini-genera-spp': 'lithosiini-genera-spp',
#  'cirrhochrista-fumipalpis': 'creatonotos-transiens',
#  'clanidopsis-exusta': 'arctioblepsis-rubida',
#  'clanis-bilineata': 'olene-mendosa',
#  'clanis-phalaris': 'kunugia-lineata',
#  'clelea-sapphirina': 'episteme-adulatrix',
#  'cleora-alienaria': 'ophthalmitis-spp',
#  'cleora-fraterna': 'metoeca-foedalis',
#  'clostera-fulgurita': 'lymantria-grandis',
#  'clostera-restitura': 'hyposidra-talaca',
#  'cnaphalocrocis-patnalis': 'cnaphalocrocis-rutilalis',
#  'cnaphalocrocis-rutilalis': 'agassiziella-fuscifusale',
#  'comibaena-albimarginata': 'linguisaccus-subhyalina',
#  'comibaena-cassidara': 'argyrocosma-inductaria',
#  'comibaena-spp': 'comostola-spp',
#  'comostola-spp': 'comostola-inops',
#  'condica-spp': 'feliniopsis-spp',
#  'conogethes-punctiferalis': 'eurrhyparodes-tricoloralis',
#  'conogethes-semifascialis-complex': 'pachynoa-spilosomoides-complex',
#  'conogethes-spp': 'nepita-conferta',
#  'corgatha-dictaria': 'anticarsia-irrorata',
#  'corymica-deducta': 'heliothis-peltigera',
#  'corymica-spp': 'parasa-lepida',
#  'crambidae-genera-spp': 'hypeninae-genera-spp',
#  'crambinae-genera-spp': 'ammatho-cuneonotatus',
#  'creatonotos-transiens': 'crambinae-genera-spp',
#  'cretonia-spp': 'condica-spp',
#  'cricula-trifenestrata': 'haritalodes-derogata',
#  'crocidolomia-luteolalis': 'indarbela-tetraonis',
#  'cruxoruza-reticulata': 'dichocrocis-definita',
#  'ctenoplusia-albostriata': 'epipleminae-genera-spp',
#  'ctenoplusia-placida': 'spataliini-genera-spp',
#  'ctenoplusia-tarassota': 'noctuinae-genera-spp',
#  'curoba-sangarida': 'spodoptera-litura',
#  'cusiala-boarmoides': 'psilalcis-breta',
#  'cyana-adita': 'cyana-signa',
#  'cyana-detrita': 'lymantria-spp',
#  'cyana-gazella': 'lepidoptera-0',
#  'cyana-peregrina': 'epiplema-himala',
#  'cyana-perornata': 'tinolius-hypsana',
#  'cyana-signa': 'cyana-spp',
#  'cyana-spp': 'utetheisa-spp',
#  'cyclidia-rectificata': 'micronia-aculeata',
#  'cyclidia-substigmaria': 'chiasmia-emersaria',
#  'cyclodes-omma': 'digama-marchalii',
#  'cyclosia-latipennis': 'macrobrochis-gigas',
#  'cyclosia-midamia': 'carea-angulata',
#  'cyclosia-papilionaris': 'macrobrochis-gigas',
#  'cyclothea-disjuncta': 'traminda-aventiaria',
#  'cydalima-laticostalis': 'crambinae-genera-spp',
#  'cydalima-spp': 'abraxas-spp',
#  'cypa-enodis': 'theretra-alecto',
#  'dalima-intricata': 'herochroma-spp',
#  'dalima-truncataria': 'scopula-emissaria',
#  'daphnis-nerii': 'mocis-undata',
#  'decetia-spp': 'ligdia-coctata',
#  'degia-spp': 'tisis-spp',
#  'deilephila-rivularis': 'thysanoplusia-spp',
#  'deroca-inconclusa': 'pycnarmon-cribrata',
#  'diaphania-indica': 'plutella-xylostella',
#  'diasemia-spp': 'eoophyla-spp',
#  'dichocrocis-definita': 'haritalodes-derogata',
#  'dichromia-quadralis': 'eudocima-phalonia',
#  'dichromia-sagitta': 'spodoptera-litura',
#  'dichromia-spp': 'hydrillodes-spp',
#  'digama-hearseyana': 'cephonodes-hylas',
#  'dindicodes-crocina': 'cephonodes-hylas',
#  'discoglypha-locupletata': 'chrysocraspeda-faganaria',
#  'drepanidae-genera-spp': 'cyclidia-substigmaria',
#  'dudusa-sphingiformis': 'neogurelca-himachala',
#  'dudusa-synopla': 'spodoptera-litura',
#  'dura-alba': 'ericeia-spp',
#  'dyrzela-plagiata': 'eupterote-undata',
#  'dysgonia-latifascia': 'parallelia-stuposa',
#  'dysgonia-torrida': 'achaea-janata',
#  'dysodia-spp': 'bocula-spp',
#  'dysphania-percota': 'cyclosia-latipennis',
#  'earias-cupreoviridis': 'eustrotia-marginata',
#  'earias-flavida': 'trabala-vishnou',
#  'earias-vittella': 'gesonia-spp',
#  'ecliptopera-dissecta': 'odontopera-kametaria',
#  'ecliptopera-rectilinea': 'alphaea-imbuta',
#  'ecliptopera-substituta': 'paracymoriza-vagalis',
#  'ectropis-spp': 'mocis-undata',
#  'egens-egens': 'tetragonus-catamitus',
#  'egnasia-accingalis': 'syntomoides-imaon',
#  'egnasia-ephyrodalis': 'Calletaera-postvittata',
#  'electrophaes-spp': 'callopistria-rivularis',
#  'eligma-narcissus': 'agrius-convolvuli',
#  'elusa-spp': 'fodina-stola',
#  'endoclita-malabaricus': 'hyblaea-puera-complex',
#  'endotricha-olivacealis': 'Piletocera-flexiguttalis',
#  'endotricha-ruminalis': 'talanga-sexpunctalis',
#  'endotricha-spp': 'trilocha-varians',
#  'enispa-elataria': 'ruttellerona-spp',
#  'ennominae-genera-spp': 'arichanna-transectata',
#  'entomogramma-fautrix': 'chiasmia-emersaria',
#  'entomogramma-torsa': 'ourapteryx-marginata',
#  'eoophyla-spp': 'manulea-spp',
#  'epicopeia-polydora': 'curoba-sangarida',
#  'epicrocis-spp': 'cania-sericea',
#  'epipagis-peritalis': 'synclera-traducalis',
#  'epiparbattia-gloriosalis': 'pachynoa-spilosomoides-complex',
#  'epipaschiinae-genera-spp': 'achrosis-incitata-complex',
#  'episothalma-robustaria': 'argyrocosma-inductaria',
#  'episparis-liturata': 'lacera-procellosa',
#  'ercheia-cyllaria': 'noorda-blitealis',
#  'erebus-ephesperis': 'chiasmia-eleonora',
#  'erebus-macrops': 'metanastria-spp',
#  'eressa-confinis': 'eressa-spp',
#  'ericeia-inangulata': 'heterostegane-urbica',
#  'ericeia-pertendens': 'Luxiaria-hypaphanes',
#  'ericeia-spp': 'cleora-spp',
#  'eriocottidae-genera-spp': 'phycitinae-genera-spp',
#  'ernolatia-moorei': 'problepsis-deliaria',
#  'eterusia-aedea': 'Mimeusemia-ceylonica',
#  'eterusia-raja': 'selepa-spp',
#  'eublemma-baccalix': 'nolinae-genera-spp',
#  'eublemma-dimidialis': 'eublemma-accedens',
#  'eublemma-olivacea': 'orvasca-subnotata',
#  'eublemma-quadrapex': 'entomogramma-torsa',
#  'eublemma-semirufa': 'helicoverpa-armigera',
#  'euchromia-polymena': 'Nephelomilta-suffusa',
#  'euchromius-ocellea': 'lithosiini-genera-spp',
#  'euclasta-spp': 'arsacia-rectalis',
#  'eucyclodes-divapala-complex': 'pelagodes-thalassodes-spp',
#  'eucyclodes-picturata': 'calindoea-argentalis',
#  'eucyclodes-semialba': 'rhimphalea-trogusalis',
#  'eucyclodes-textilis': 'comostola-inops',
#  'eudocima-homaena': 'barsine-group-spp',
#  'eudocima-hypermnestra': 'notodontidae-genera-spp',
#  'eudocima-materna': 'aethaloessa-calidalis',
#  'eudocima-phalonia': 'crocidolomia-pavonana',
#  'eudocima-salaminia': 'tanaoctenia-haliaria',
#  'eudocima-spp': 'daphnis-nerii',
#  'euhampsonia-niveiceps': 'endocrossis-flavibasalis',
#  'eupitheciini-genera-spp': 'chundana-emarginata',
#  'euproctis-hampsoni': 'plotheia-decrescens',
#  'euproctis-leithiana': 'nygmiini-genera-spp',
#  'euproctis-magna': 'thyas-coronata',
#  'euproctis-plagiata': 'gastropacha-spp',
#  'eupterote-gardneri': 'thinopteryx-nebulosa',
#  'eupterote-spp': 'achaea-janata',
#  'eupterote-undata': 'hyposidra-talaca',
#  'eurrhyparodes-bracteolalis': 'archaeoattacus-edwardsii',
#  'euteliidae-genera-spp': 'paracymoriza-rivularis',
#  'euthrix-laeta': 'miresa-spp',
#  'fascellina-chromataria': 'traminda-mundissima',
#  'fascellina-plagiata': 'laelia-exclamationis',
#  'fascellina-porphyreofusa': 'parotis-marginata-complex',
#  'fentonia-baibarana': 'psilogramma-vates',
#  'filodes-fulvidorsalis': 'cephonodes-hylas',
#  'gabala-polyspilalis': 'nyctemera-coleta',
#  'galleria-mellonella': 'hydriris-ornatalis',
#  'ganisa-spp': 'ericeia-spp',
#  'garaeus-apicata': 'agnidra-vinacea',
#  'gastropacha-spp': 'euproctis-varia',
#  'gaurena-florens': 'arichanna-sparsa',
#  'gaurena-florescens': 'brahmaea-hearseyi',
#  'gazalina-chrysolopha': 'drepanidae-genera-spp',
#  'gelechiidae-genera-spp': 'hyblaea-puera-complex',
#  'gesonia-spp': 'ischyja-spp',
#  'glycythyma-chrysorycta': 'cnaphalocrocis-trebiusalis',
#  'glyphodes-caesalis': 'eucyclodes-gavissima',
#  'glyphodes-crithealis': 'nausinoe-geometralis',
#  'glyphodes-stolalis': 'pygospila-tyres',
#  'gnophos-spp': 'pingasa-spp',
#  'goniorhynchus-gratalis': 'uncobotyodes-patulalis',
#  'gonodontis-clelia': 'thyrididae-genera-spp',
#  'gonodontis-spp': 'hyposidra-talaca',
#  'grammodes-geometrica': 'pterophoridae-genera-spp',
#  'grammodes-stolida': 'daphnis-hypothous',
#  'gunda-ochracea': 'rectipalpula-billeti',
#  'habrosyne-violacea': 'creatonotos-gangis-interrupta-complex',
#  'hadennia-spp': 'bastilla-arcuata',
#  'haritalodes-derogata': 'Dichocrocis-bistrigalis',
#  'helicoverpa-armigera': 'lithosiini-genera-spp',
#  'helicoverpa-assulta': 'egnasia-accingalis',
#  'heliothis-peltigera': 'corymica-deducta',
#  'hellula-undalis': 'digama-insulana',
#  'hemonia-orbiferana': 'callyna-monoleuca',
#  'hendecasis-duplifascialis': 'pelagodes-thalassodes-spp',
#  'heortia-vitessoides': 'dysphania-percota',
#  'herpetogramma-basalis': 'crambidae-genera-spp',
#  'herpetogramma-spp': 'orudiza-protheclaria',
#  'heterostegane-urbica': 'hastina-pluristrigata',
#  'heterothera-spp': 'athetis-delecta',
#  'himala-argentea': 'gazalina-apsara',
#  'hipoepa-biasalis': 'attonda-adspersa',
#  'hipoepa-fractalis': 'euthrix-inobtrusa',
#  'hippotion-celerio': 'spoladea-recurvalis',
#  'hippotion-rosetta': 'thyas-coronata',
#  'hippotion-spp': 'clanis-titan',
#  'histia-flabellicornis': 'leucostola-argyrosticta',
#  'homaea-clathrum': 'pygospila-tyres',
#  'hulodes-caranea': 'hyposidra-talaca',
#  'hyalobathra-miniosalis': 'stigmatophora-roseivena',
#  'hyalobathra-phoenicozona': 'cnaphalocrocis-medinalis',
#  'hyblaea-puera-complex': 'macroglossum-bombylans',
#  'hydrillodes-spp': 'carea-angulata',
#  'hydrorybina-polusalis': 'helicoverpa-armigera',
#  'hyles-livornica': 'daphnis-nerii',
#  'hymenia-perspectalis': 'erebus-hieroglyphica',
#  'hypena-iconicalis': 'lymantria-incerta',
#  'hypena-laceratalis': 'orgyiini-genera-spp',
#  'hypena-obacerralis': 'eudocima-homaena',
#  'hypeninae-genera-spp': 'noctuinae-genera-spp',
#  'hypersypnoides-constellata': 'epipaschiinae-genera-spp',
#  'hyperythra-lutea': 'artaxa-guttata',
#  'hypocala-deflorata': 'scopula-emissaria',
#  'hypocala-subsatura': 'gastropacha-spp',
#  'hypochrosis-abstractaria': 'craspediopsis-bimaculata',
#  'hypochrosis-flavifusata': 'thysanoplusia-orichalcea',
#  'hypochrosis-hyadaria-complex': 'Herpetogramma-rudis%20species-group',
#  'hypochrosis-iris': 'agnidra-vinacea',
#  'hypochrosis-sternaria': 'dichromia-quadralis',
#  'hypolamprus-angulalis': 'discoglypha-aureifloris',
#  'hypomecis-cineracea': 'Hypomecis-tamilensis',
#  'hypomecis-separata': 'psilalcis-breta',
#  'hypomecis-spp': 'naxidia-irrorata',
#  'hypomecis-transcissa': 'psilalcis-breta',
#  'hypopyra-meridionalis': 'fascellina-chromataria',
#  'hypopyra-spp': 'lygniodes-spp',
#  'hyposidra-infixaria': 'zurobata-vacillans',
#  'hyposidra-spp': 'lygniodes-spp',
#  'hyposidra-talaca': 'zitha-torridalis',
#  'hypospila-bolinoides': 'endotricha-ruminalis',
#  'hypsopygia-spp': 'plecoptera-recta',
#  'idaea-costiguttata': 'erebus-ephesperis',
#  'idaea-spp': 'luxiaria-spp',
#  'idaea-violacea': 'maruca-vitrata',
#  'idiochlora-spp': 'parotis-spp',
#  'ilema-chloroptera': 'habrosyne-fraterna',
#  'ischyja-manlia': 'mocis-undata',
#  'ischyja-spp': 'spirama-spp',
#  'isocentris-filalis': 'gesonia-spp',
#  'isturgia-disputaria': 'spoladea-recurvalis',
#  'janseodes-melanospila': 'Aeolanthes-rhodochrysa',
#  'juxtarctia-multiguttata': 'pachyodes-haemataria',
#  'katha-conformis': 'asota-caricae',
#  'krananda-semihyalina': 'amblychia-angeronaria',
#  'kunugia-lineata': 'manulea-spp',
#  'labdia-spp': 'cyana-spp',
#  'lacera-noctilio': 'aporodes-floralis',
#  'laelia-exclamationis': 'chasmina-judicata',
#  'lamoria-spp': 'degia-spp',
#  'lamprosema-tampiusalis': 'eupitheciini-genera-spp',
#  'langia-zenzeroides': 'creatonotos-gangis-interrupta-complex',
#  'lepidoptera-0': 'baorisa-hieroglyphica',
#  'leucania-yu': 'Ecpyrrhorrhoe-spp',
#  'leucoma-clara': 'arctornis-spp',
#  'ligdia-coctata': 'psyra-cuneata',
#  'limacodinae-genera-spp': 'xenochroa-chlorostigma',
#  'liparopsis-postalbida': 'eudocima-phalonia',
#  'lipomelia-subusta': 'oraesia-emarginata',
#  'lithosiini-genera-spp': 'prooedema-inscisalis',
#  'locastra-muscosalis': 'pyralidae-genera-spp',
#  'locharna-strigipennis': 'acherontia-lachesis',
#  'lomographa-inamata': 'nygmiini-genera-spp',
#  'lomographa-spp': 'derambila-spp',
#  'lopharthrum-comprimens': 'lepidoplaga-flavicinctalis',
#  'lophophelma-erionoma': 'gasterocome-pannosaria',
#  'lophophelma-ruficosta': 'cirrhochrista-brizoalis',
#  'lophophleps-purpurea': 'eupitheciini-genera-spp',
#  'lophosoma-cuprea': 'macrobrochis-gigas',
#  'luxiaria-phyllosaria': 'zeheba-aureata',
#  'luxiaria-spp': 'turnaca-spp',
#  'luxiaria-tephrosaria': 'Luxiaria-hypaphanes',
#  'lygniodes-vampyurs': 'entomogramma-torsa',
#  'lymantria-ampla': 'britha-spp',
#  'lymantria-marginata': 'zeuzera-multistrigata',
#  'lymantria-mathura': 'oraesia-emarginata',
#  'lymantria-sobrina': 'psilogramma-discistriga',
#  'lymantria-spp': 'olepa-ricini',
#  'lyssa-zampa': 'attacus-atlas',
#  'maceda-mansueta': 'ramadasa-pavo',
#  'macotasa-nubecula': 'syntomoides-imaon',
#  'macrobrochis-gigas': 'episteme-adulatrix',
#  'macrocilix-maia': 'ourapteryx-spp',
#  'macroglossum-assimilis': 'hyblaea-puera-complex',
#  'macroglossum-bombylans': 'asura-miltochrista-group-spp',
#  'macroglossum-gyrans': 'plusiinae-genera-spp',
#  'macroglossum-sitiene': 'chrysopera-combinans',
#  'mahanta-quadrilinea': 'cnaphalocrocis-rutilalis',
#  'maliattha-erecta': 'ramadasa-pavo',
#  'maliattha-fervens': 'schistophleps-spp',
#  'maliattha-ruptifascia': 'alcanola-tympanistis',
#  'maliattha-signifera': 'progonia-kurosawai',
#  'mangina-argus': 'nepita-conferta',
#  'mangina-syringa': 'mangina-argus',
#  'manoba-tristicta': 'naxidia-punctata',
#  'maruca-amboinalis': 'diaphania-indica',
#  'marumba-dyras': 'thyas-coronata',
#  'marumba-saishiuana': 'theretra-oldenlandiae',
#  'maurilia-iconica': 'ophiusa-tirhaca',
#  'mecodina-albodentata': 'larentiinae-genera-spp',
#  'megacorma-obliqua': 'psilogramma-increta',
#  'meganola-nitida': 'digama-marchalii',
#  'metallolophia-taleensis': 'Somatina-densifasciaria',
#  'metanastria-spp': 'gastropacha-spp',
#  'metarbelidae-genera-spp': 'epipaschiinae-genera-spp',
#  'micraloa-spp': 'turnaca-spp',
#  'microblepsis-leucosticta': 'entomogramma-fautrix',
#  'microblepsis-violacea': 'callidrepana-patrana',
#  'microloxia-indecretata': 'geometrinae-genera-spp',
#  'microloxia-spp': 'comostola-spp',
#  'micromelalopha-spp': 'noctuinae-genera-spp',
#  'micronia-aculeata': 'adoxophyes-spp',
#  'microxyla-stipata': 'pseudozarba-spp',
#  'miltochrista-conjunctana': 'siglophora-sanguinolenta',
#  'miltochrista-obsoleta': 'synclera-traducalis',
#  'miltochrista-terminospota': 'asura-miltochrista-group-spp',
#  'miltochrista-undulata': 'miltochrista-dharma',
#  'miltochrista-undulosa': 'juxtarctia-multiguttata',
#  'mimomiza-cruentaria': 'endocrossis-flavibasalis',
#  'miresa-albipuncta': 'oraesia-emarginata',
#  'miresa-spp': 'argina-astrea',
#  'mixochlora-vittata': 'tanaorhinus-kina',
#  'mocis-frugalis': 'achaea-janata',
#  'mocis-undata': 'chiasmia-spp',
#  'musotiminae-genera-spp': 'eurrhyparodes-tricoloralis',
#  'mustilizans-hepatica': 'orudiza-protheclaria',
#  'naarda-spp': 'amyna-spp',
#  'nacna-malachitis': 'agrius-convolvuli',
#  'narosa-conspersa': 'sameodes-cancellalis',
#  'nausinoe-geometralis': 'sameodes-cancellalis',
#  'nausinoe-perspectata': 'yepcalphis-dilectissima',
#  'negeta-contrariata': 'orvasca-subnotata',
#  'neocerura-liturata': 'cyclosia-papilionaris',
#  'neogurelca-himachala': 'amplypterus-panopus',
#  'neogurelca-hyas': 'eudocima-materna',
#  'neopheosia-fasciata': 'photoscotosia-amplicata',
#  'nephele-hespera': 'thyas-coronata',
#  'nepita-conferta': 'chalcidica-minea',
#  'netria-multispinae': 'netria-viridescens',
#  'nisaga-simplex': 'theretra-lucasii',
#  'noctuinae-genera-spp': 'phycitinae-genera-spp',
#  'nola-internella-analis-complex': 'pterophoridae-genera-spp',
#  'nola-taeniata': 'eoophyla-spp',
#  'nolinae-genera-spp': 'syntomoides-imaon',
#  'noorda-blitealis': 'selepa-celtis',
#  'noreia-ajaia': 'ganisa-spp',
#  'notodontella-tenebrosa': 'eriocottidae-genera-spp',
#  'notodontidae-genera-spp': 'macroglossum-corythus',
#  'numenes-siletti': 'pergesa-acteus',
#  'nyctemera-adversata': 'agrotera-basinotata',
#  'nyctemera-lacticinia': 'nyctemera-adversata',
#  'nygmiini-genera-spp': 'hypocala-subsatura',
#  'oeonistis-entella': 'sesiidae-genera-spp',
#  'oglasa-hypenoides': 'netria-viridescens',
#  'olene-mendosa': 'agrius-convolvuli',
#  'olepa-ricini': 'spirama-spp',
#  'omiodes-spp': 'petelia-spp',
#  'omiodes-surrectalis': 'glyphodes-bicolor',
#  'omiza-miliaria': 'hemithea-spp',
#  'omphisa-anastomosalis': 'crocidolomia-pavonana',
#  'ophiusa-disjungens': 'ophiusa-tirhaca',
#  'ophthalmitis-spp': 'Cusiala-raptaria',
#  'opisthograptis-mimulina': 'hyalobathra-opheltesalis',
#  'opisthograptis-sulphurea': 'asura-miltochrista-group-spp',
#  'oraesia-argyrosigna': 'paralebeda-plagifera',
#  'oraesia-emarginata': 'biston-suppressaria',
#  'oreta-extensa': 'eupterote-spp',
#  'oreta-spp': 'rhesala-spp',
#  'oreta-suffusa': 'eupterote-spp',
#  'orgyia-postica': 'spodoptera-litura',
#  'orgyiini-genera-spp': 'bradina-adhaesalis',
#  'orthaga-exvinacea': 'cidariini-genera-spp',
#  'orthobrachia-flavidior': 'thyrididae-genera-spp',
#  'orthocabera-sericea': 'cyclidia-substigmaria',
#  'orthonama-obstipata': 'blasticorhinus-rivulosa',
#  'ortopla-lindsayi': 'deltoplastis-spp',
#  'orudiza-protheclaria': 'poliobotys-ablactalis',
#  'orvasca-subnotata': 'egnasia-ephyrodalis',
#  'ourapteryx-spp': 'micronia-aculeata',
#  'ovipennis-incompletostriga': 'aberrasine-strigivenata',
#  'oxyodes-scrobiculata': 'acosmeryx-akanshi',
#  'ozarba-punctigera': 'lophoptera-illucida',
#  'ozarba-spp': 'dysodia-spp',
#  'pachyodes-haemataria': 'areas-galactina',
#  'padenia-spp': 'cyana-signa',
#  'padenia-transversa': 'autocharis-amethystina',
#  'pagyda-salvalis': 'artaxa-guttata',
#  'pandesma-spp': 'amata-sperbius',
#  'pangora-matherana': 'creatonotos-gangis-interrupta-complex',
#  'pantana-luteiceps': 'asta-quadrilinea',
#  'paracrama-latimargo': 'ornithospila-avicularia',
#  'paracymoriza-vagalis': 'arichanna-transfasciata',
#  'paralbara-muscularia': 'paralbara-perhamata',
#  'paralbara-perhamata': 'nordstromia-lilacina',
#  'paralebeda-plagifera': 'peratostega-deletaria',
#  'parallelia-rigidistria-calefasciens-complex': 'creatonotos-gangis-interrupta-complex',
#  'parallelia-stuposa': 'pericyma-cruegeri',
#  'parapoynx-affinialis': 'dasyboarmia-spp',
#  'parapoynx-bilinealis': 'glyphodes-bivitralis',
#  'parapoynx-crisonalis': 'nolinae-genera-spp',
#  'parapoynx-diminutalis': 'sameodes-cancellalis',
#  'parapoynx-fluctuosalis': 'termioptycha-albifurcalis',
#  'parapoynx-spp': 'scopula-opicata',
#  'parapoynx-stagnalis': 'pycnarmon-cribrata',
#  'parasa-lepida': 'mocis-undata',
#  'parotis-marginata-complex': 'eudocima-hypermnestra',
#  'parotis-spp': 'trabala-spp',
#  'patania-characteristica': 'Chalcidoptera-emissalis',
#  'patania-plagiatalis': 'omiodes-indicata',
#  'penicillifera-apicalis': 'parapoynx-stagnalis',
#  'peratophyga-hyalinata': 'coremecis-nigrovittata',
#  'pergesa-acteus': 'amata-elongata',
#  'pericyma-albidens': 'erebus-hieroglyphica',
#  'pericyma-cruegeri': 'cidariini-genera-spp',
#  'pericyma-glaucinans': 'blasticorhinus-rivulosa',
#  'pericyma-spp': 'condica-spp',
#  'perina-nuda': 'hypopyra-spp',
#  'petelia-immaculata': 'Luxiaria-hypaphanes',
#  'petelia-spp': 'cleora-spp',
#  'phalacra-vidhisara': 'scopula-emissaria',
#  'phalera-combusta': 'ophiusa-tirhaca',
#  'phalera-spp': 'sufetula-spp',
#  'phazaca-spp': 'actias-selene',
#  'phocoderma-velutina': 'alphaea-imbuta',
#  'photoscotosia-spp': 'progonia-kurosawai',
#  'phycitinae-genera-spp': 'sterrhinae-genera-spp',
#  'phycodes-radiata': 'vamuna-remelana',
#  'phyllodes-eyndhovii': 'euchromia-polymena',
#  'pida-spp': 'perina-nuda',
#  'pidorus-glaucopis': 'macrobrochis-gigas',
#  'piesmopoda-semilutea': 'phauda-triadum',
#  'pindara-illibata': 'artena-dotata',
#  'pingasa-lariaria': 'euchromius-ocellea',
#  'pingasa-spp': 'ericeia-spp',
#  'plagodis-inustaria': 'helicoverpa-armigera',
#  'plecoptera-spp': 'micronia-aculeata',
#  'plusiinae-genera-spp': 'orgyiini-genera-spp',
#  'plutella-xylostella': 'oraesia-emarginata',
#  'plutodes-transmutata': 'agnidra-discispilaria',
#  'poaphilini-genera-spp': 'macroglossum-gyrans',
#  'poliobotys-ablactalis': 'ptychopseustis-spp',
#  'polydesma-boarmoides': 'eupitheciini-genera-spp',
#  'polytela-gloriosae': 'acherontia-lachesis',
#  'problepsis-spp': 'nyctemera-coleta',
#  'problepsis-vulgaris': 'problepsis-albidior',
#  'procridinae-genera-spp': 'zygaenidae-genera-spp',
#  'progonia-oileusalis': 'ptychopseustis-spp',
#  'prophantis-adusta': 'eudocima-materna',
#  'protonoceras-capitalis': 'boletobiinae-genera-spp',
#  'protuliocnemis-biplagiata': 'eucyclodes-sanguilineata',
#  'pseudoblabes-oophora': 'hyblaea-puera-complex',
#  'pseudomiza-leucogonia': 'siglophora-ferreilutea',
#  'pseudosphetta-moorei': 'cassephyra-cyanosticta',
#  'pseudozarba-spp': 'britha-spp',
#  'psilalcis-albibasis': 'biston-suppressaria',
#  'psilalcis-breta': 'cusiala-boarmoides',
#  'psilochira-lineata': 'arctornis-l-nigrum',
#  'psilogramma-increta': 'auchmis-inextricata',
#  'psilogramma-spp': 'xyleutes-persona',
#  'psilogramma-vates': 'chiasmia-eleonora',
#  'psimada-quadripennis': 'helicoverpa-armigera',
#  'pterotopteryx-spilodesma': 'eurrhyparodes-bracteolalis',
#  'ptisciana-seminivea': 'psilogramma-increta',
#  'ptychopseustis-spp': 'dolgoma-angulifera',
#  'pycnarmon-cribrata': 'scythropiodes-spp',
#  'pygospila-costiflexalis': 'nacoleia-commixta',
#  'pygospila-tyres': 'abraxas-spp',
#  'pyloetis-mimosae': 'stathmopoda-spp',
#  'pyralidae-genera-spp': 'bocana-manifestalis',
#  'pyralis-manihotalis': 'ectropidia-shoreae',
#  'pyralis-pictalis': 'digama-marchalii',
#  'pyrausta-spp': 'scopula-spp',
#  'pyrrhia-umbra': 'anomis-flava',
#  'radara-subcupralis': 'orybina-flaviplaga',
#  'radhica-rosea': 'thespea-bicolor',
#  'rajendra-biguttata': 'dysphania-nelera',
#  'ramadasa-pavo': 'gazalina-apsara',
#  'ramila-acciusalis': 'problepsis-vulgaris',
#  'rapdalus-pardicolor': 'boarmiini-genera-spp',
#  'rehimena-phrynealis': 'eudocima-salaminia',
#  'rhagastis-castor': 'parotis-marginata-complex',
#  'rhagastis-olivacea': 'ophiusa-tirhaca',
#  'rhectothyris-gratiosalis': 'syngamia-falsidicalis',
#  'rhesala-spp': 'ozarba-spp',
#  'rhimphalea-trogusalis': 'diasemiopsis-ramburialis',
#  'rhodophaea-actiosella': 'eriocottidae-genera-spp',
#  'rinaca-cidosa': 'hyposidra-talaca',
#  'rinaca-simla': 'cricula-agria',
#  'rinaca-thibeta': 'maruca-vitrata',
#  'rivula-bioculalis': 'carea-angulata',
#  'rivula-spp': 'naarda-spp',
#  'rusicada-spp': 'pyrausta-spp',
#  'sacada-discinota': 'sacada-pallescens',
#  'sacada-spp': 'spirama-spp',
#  'sameodes-cancellalis': 'noctuinae-genera-spp',
#  'sarcinodes-aequilinearia': 'chloroglyphica-variegata',
#  'sarobela-litterata': 'hippotion-celerio',
#  'sauris-spp': 'acontia-spp',
#  'schistophleps-spp': 'cnaphalocrocis-spp',
#  'sciorista-assignatalis': 'botyodes-diniasalis',
#  'scirpophaga-incertulas': 'antheraea-assamensis',
#  'scopelodes-spp': 'digama-insulana',
#  'scopula-cuneilinea': 'Pingasa-rubicunda',
#  'scopula-ferrilineata': 'biston-bengaliaria',
#  'scopula-fibulata': 'comibaena-spp',
#  'scythropiodes-spp': 'cephonodes-hylas',
#  'selepa-celtis': 'selepa-spp',
#  'selepa-spp': 'archips-spp',
#  'serrodes-campana': 'ecliptopera-dissecta',
#  'sesiidae-genera-spp': 'maliattha-ruptifascia',
#  'siccia-spotoptera': 'oxymacaria-palliata',
#  'siccia-spp': 'Ecpyrrhorrhoe-spp',
#  'siccia-taprobanis': 'oxymacaria-palliata',
#  'sinarella-discisigna': 'cidariini-genera-spp',
#  'singara-diversalis': 'cricula-trifenestrata',
#  'sinna-extrema': 'argina-astrea',
#  'sirinopteryx-rufivinctata': 'palpita-annulifer-complex',
#  'somatina-anthophilata': 'pterophoridae-genera-spp',
#  'somatina-omicraria': 'scopula-pulchellata',
#  'somena-scintillans': 'mocis-undata',
#  'soritia-pulchella': 'oeonistis-entella',
#  'spataliini-genera-spp': 'creatonotos-transiens',
#  'sphenarches-anisodactyla': 'omphisa-anastomosalis',
#  'sphingomorpha-chlorea': 'aedia-leucomelas-complex',
#  'sphingonaepiopsis-pumilio': 'thysanoplusia-orichalcea',
#  'sphrageidus-spp': 'aplochlora-vivilaca',
#  'spilarctia-comma': 'vamuna-remelana',
#  'spilarctia-spp': 'trabala-spp',
#  'spilosoma-spp': 'amerila-eugenia',
#  'spilosomina-genera-spp': 'holocryptis-erubescens',
#  'spirama-spp': 'ischyja-manlia',
#  'spodoptera-litura': 'macroglossum-sitiene',
#  'spoladea-recurvalis': 'orgyiini-genera-spp',
#  'stauropus-alternus': 'hypena-laceratalis',
#  'stauropus-thiaucourti': 'acantholipes-trajecta',
#  'sterrhinae-genera-spp': 'cyclidia-substigmaria',
#  'striglina-scitaria': 'maurilia-iconica',
#  'striglina-spp': 'nygmia-icilia',
#  'suana-concolor': 'trilocha-varians',
#  'syllepte-bipartalis': 'omiodes-indicata',
#  'syllepte-sellalis': 'theretra-lucasii',
#  'syllepte-straminalis': 'synclera-traducalis',
#  'sympis-rufibasis': 'theretra-nessus',
#  'synclera-traducalis': 'haritalodes-derogata',
#  'syngamia-latimarginalis': 'lopharthrum-comprimens',
#  'syntomoides-imaon': 'boarmiini-genera-spp',
#  'syntypistis-comatus': 'scopariinae-genera-spp',
#  'sypnoides-pannosa': 'achrosis-incitata-complex',
#  'talanga-sexpunctalis': 'pyrausta-phoenicealis',
#  'tamba-spp': 'mocis-undata',
#  'tanaorhinus-reciprocata': 'aplochlora-dentisignata',
#  'tatobotys-biannulalis': 'siccia-spotoptera',
#  'teldenia-vestigiata': 'micronia-aculeata',
#  'teleclita-centristicta': 'lymantria-fuliginosa',
#  'teleclita-strigata': 'bacotoma-violata',
#  'terastia-egialealis': 'daphnis-hypothous',
#  'termioptycha-albifurcalis': 'epipaschiinae-genera-spp',
#  'tetragonus-catamitus': 'helicoverpa-armigera',
#  'teuloma-nebulosa': 'nepita-conferta',
#  'thaumetopoea-cheela': 'chlumetia-transversa',
#  'theretra-boisduvalii': 'marumba-cristata',
#  'theretra-clotho': 'ambulyx-liturata',
#  'theretra-lucasii': 'thyas-coronata',
#  'theretra-shendurneensis': 'westermannia-triangularis',
#  'theretra-sumatrensis': 'macroglossum-sitiene',
#  'thespea-bicolor': 'comibaena-spp',
#  'thinopteryx-crocoptera': 'tridrepana-albonotata',
#  'thosea-spp': 'amyna-spp',
#  'thyas-coronata': 'olene-mendosa',
#  'thyatira-batis': 'phalera-spp',
#  'thymistida-spp': 'pandesma-spp',
#  'thyrididae-genera-spp': 'gazalina-chrysolopha',
#  'thysanoidma-stellata': 'paradiopa-postfusca',
#  'thysanoplusia-orichalcea': 'xenochroa-chlorostigma',
#  'thysanoplusia-reticulata': 'eriocottidae-genera-spp',
#  'thysanoplusia-spp': 'orvasca-subnotata',
#  'timandra-correspondens': 'pelagodes-thalassodes-spp',
#  'timora-sanguinolenta': 'cheromettia-apicata',
#  'tiracola-plagiata': 'olene-mendosa',
#  'tiracola-spp': 'athetis-spp',
#  'tonica-niviferana': 'phazaca-theclata',
#  'tortricidae-genera-spp': 'Tympanistes-testacea',
#  'trabala-spp': 'parasa-lepida',
#  'trachea-auriplena': 'chrysodeixis-spp',
#  'traminda-aventiaria': 'cephonodes-picus',
#  'traminda-mundissima': 'callidrepana-patrana',
#  'trichoplusia-ni': 'thyatira-batis',
#  'trichopterigia-spp': 'conogethes-spp',
#  'tridrepana-flava': 'botyodes-asialis',
#  'trigonodes-hyppasia': 'padenia-transversa',
#  'trilocha-varians': 'crocidolomia-spp',
#  'trischalis-subaurana': 'pyralidae-genera-spp',
#  'trypanophora-semihyalina': 'asura-miltochrista-group-spp',
#  'tyana-chloroleuca': 'agathia-incudaria',
#  'ulopeza-semivialis': 'crocidophora-fasciata',
#  'utetheisa-spp': 'lymantria-spp',
#  'vamuna-bipars': 'plecoptera-spp',
#  'vamuna-remelana': 'comostola-inops',
#  'westermannia-superba': 'Pseudargyria-parallelus',
#  'xandrames-dholaria': 'coremecis-nigrovittata',
#  'xandrames-latiferaria': 'boarmiini-genera-spp',
#  'xanthodes-albago': 'nygmiini-genera-spp',
#  'xanthodes-transversa': 'tetragonus-catamitus',
#  'xanthorhoe-saturata': 'boarmiini-genera-spp',
#  'xanthorhoe-spp': 'calluga-costalis',
#  'xenochroa-biviata': 'euproctis-plagiata',
#  'xenoplia-maculata': 'siccia-taprobanis',
#  'xyleutes-ramamurthyi': 'macrobrochis-prasena',
#  'zamarada-spp': 'chiasmia-nora',
#  'zeuzerini-genera-spp': 'alcanola-tympanistis',
#  'zitha-torridalis': 'ercheia-cyllaria'}

# %%
predict_top_k(Path(f"{dataset_dir}/test_000/antheraea-paphia.jpg"), model_data, 5)
# Out:
# {'antheraea-paphia': 0.3467530608177185,
#  'tibetanja-tagoroides': 0.12467645108699799,
#  'gastropacha-spp': 0.11187088489532471,
#  'hyposidra-talaca': 0.07221446186304092,
#  'cricula-trifenestrata': 0.04722161963582039}

# %%
predict_top_k(Path(f"{dataset_dir}/test_000/angonyx-krishna.jpg"), model_data, 5)
# Out:
# {'ambulyx-moorei': 0.09101460874080658,
#  'deilephila-elpenor': 0.06724270433187485,
#  'theretra-alecto': 0.05991685017943382,
#  'theretra-clotho': 0.0594797246158123,
#  'parasa-lepida': 0.05015980079770088}

# %%
predict_top_k(Path(f"{dataset_dir}/test_000/angonyx-krishna-2.jpg"), model_data, 5)
# Out:
# {'angonyx-krishna': 0.5652188658714294,
#  'parasa-lepida': 0.11934609711170197,
#  'nephele-hespera': 0.08489922434091568,
#  'mocis-frugalis': 0.06565359234809875,
#  'theretra-clotho': 0.037341922521591187}

# %% [markdown]
# # Again

# %%
if os.path.exists(f"{dataset_dir}/test_001"):
    shutil.rmtree(f"{dataset_dir}/test_001")
if os.path.exists(f"{dataset_dir}/val_001"):
    shutil.rmtree(f"{dataset_dir}/val_001")
if os.path.exists(f"{dataset_dir}/train_001"):
    shutil.rmtree(f"{dataset_dir}/train_001")
    
split_data_for_train_and_val(f"{dataset_dir}/clean-data", f"{dataset_dir}/test_001", f"{dataset_dir}/val_001", f"{dataset_dir}/train_001", 0.1, 0.2, 4)
# Out:
# Class count: 3048
# Training data count: 30594
# Validation data count: 8168
# Test data count: 4046

# %%
model_data = init_model_for_training(f'{dataset_dir}/train_001', f'{dataset_dir}/val_001', 32)
model_data['model'].fc = torch.nn.Linear(512, 3047)
model_data['model'] = model_data['model'].to("cuda:0")
model_data['model'].load_state_dict(torch.load(f"{dataset_dir}/checkpoint_latest.pth", weights_only=False))
train(model_data, 10, f"{dataset_dir}/checkpoint_latest.pth")
shutil.copy(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/checkpoint_{int(time.time())}.pth")
# Out:
# Epoch    1 /   10  | Train Loss: 7.8600 Acc: 0.0264  | Val Loss: 8.9647 Acc: 0.0004  | Elapsed time: 0:04:12.757773
# Epoch    2 /   10  | Train Loss: 7.2571 Acc: 0.0568  | Val Loss: 9.3002 Acc: 0.0002  | Elapsed time: 0:08:29.751477
# Epoch    3 /   10  | Train Loss: 6.9978 Acc: 0.0824  | Val Loss: 10.1264 Acc: 0.0001  | Elapsed time: 0:12:46.166905
# Epoch    4 /   10  | Train Loss: 6.7195 Acc: 0.1084  | Val Loss: 10.0348 Acc: 0.0001  | Elapsed time: 0:17:05.766331
# Epoch    5 /   10  | Train Loss: 6.4070 Acc: 0.1428  | Val Loss: 10.7305 Acc: 0.0004  | Elapsed time: 0:21:22.545590
# Epoch    6 /   10  | Train Loss: 6.1008 Acc: 0.1749  | Val Loss: 11.0124 Acc: 0.0000  | Elapsed time: 0:25:59.090695
# Epoch    7 /   10  | Train Loss: 5.8054 Acc: 0.2071  | Val Loss: 11.8888 Acc: 0.0000  | Elapsed time: 0:30:34.954839
# Epoch    8 /   10  | Train Loss: 5.2650 Acc: 0.2680  | Val Loss: 12.3435 Acc: 0.0000  | Elapsed time: 0:34:53.345911
# Epoch    9 /   10  | Train Loss: 5.1117 Acc: 0.2837  | Val Loss: 12.1553 Acc: 0.0000  | Elapsed time: 0:39:15.085288
# Epoch   10 /   10  | Train Loss: 5.0294 Acc: 0.2911  | Val Loss: 12.2672 Acc: 0.0000  | Elapsed time: 0:43:37.380434
# 'insect-dataset/moth/checkpoint_1737811902.pth'

# %%
test(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/test")
# Out:
# Accuracy: 643 / 2105 -> 30.55%
# Elapsed time: 0:00:15.620167
# ----------
# Failures:
# {'Aiteta-spp': 'plecoptera-spp',
#  'Alcis-periphracta': 'alcis-perspicuata',
#  'Boeotarcha-martinalis': 'ozarba-bipars',
#  'Calamotropha-corticellus': 'acontia-marmoralis',
#  'Calletaera-obliquata': 'Luxiaria-hypaphanes',
#  'Callopistria-pulchrilinea': 'areas-galactina',
#  'Carea-obsolescens': 'Luxiaria-hypaphanes',
#  'Chalcosiopsis-variata': 'Macrobrochis-flavicincta',
#  'Charitoprepes-lubricosa': 'hypertrocta-posticalis',
#  'Chloroplaga-pallida': 'Chalcosiopsis-variata',
#  'Chusaris-spp': 'stenoloba-glaucescens',
#  'Comibaena-biplaga': 'anticarsia-irrorata',
#  'Cusiala-raptaria': 'cleora-spp',
#  'Cusiala-spp': 'idaea-violacea',
#  'Daplasa-irrorata': 'speiredonia-mutabilis',
#  'Endotricha-luteogrisalis': 'syntypistis-pallidifascia',
#  'Eugraptoblemma-rosealis': 'callabraxas-amanda',
#  'Floridasura-tricolor': 'barsine-group-spp',
#  'Goniocraspidum-ennomoide': 'nola-internella-analis-complex',
#  'Harutaea-flavizona': 'biston-suppressaria',
#  'Herochroma-elaearia': 'chiasmia-fidoniata',
#  'Hyperythra-swinhoei': 'cnaphalocrocis-spp',
#  'Hypolamprus-bastialis': 'parapoynx-stagnalis',
#  'Lamprosema-spp': 'nolinae-genera-spp',
#  'Meganola-major': 'lymantria-spp',
#  'Metacosmesis-laxeuta': 'callopistria-maillardi',
#  'Moorasura-gloriosa': 'argonestis-flammans',
#  'Mosopia-kononenkoi': 'acantholipes-trajecta',
#  'Orothalassodes-hypocrites': 'ghoria-albocinerea',
#  'Perixera-illepidaria': 'ramila-spp',
#  'Petavia-attenuata': 'achaea-janata',
#  'Pingasa-rubicunda': 'ariola-coelisigna',
#  'Protuliocnemis-castalaria': 'achrosis-incitata-complex',
#  'Psilalcis-conspicuata': 'fascellina-porphyreofusa',
#  'Pterodecta-felderi': 'trabala-vishnou',
#  'Rhodoneura-fimbriata': 'Rhodoneura-lobulata',
#  'Rhodoneura-lobulata': 'thysanoplusia-intermixta',
#  'Rhynchina-spp': 'spilarctia-spp',
#  'Spodoptera-frugiperda': 'eudocima-salaminia',
#  'Striatella-nigralba': 'Somatina-densifasciaria',
#  'Tambana-subflava': 'neocerura-liturata',
#  'Telchines-vialis': 'Lemaireia-himalayana',
#  'Teleclita-grisea': 'plecoptera-spp',
#  'abraxas-spp': 'Ecpyrrhorrhoe-spp',
#  'acantholipes-circumdata': 'hypeninae-genera-spp',
#  'acantholipes-trajecta': 'spoladea-recurvalis',
#  'achaea-janata': 'chiasmia-spp',
#  'achaea-serva': 'chiasmia-spp',
#  'achelura-bifasciata': 'neoherpa-spp',
#  'acherontia-lachesis': 'spodoptera-litura',
#  'achrosis-intexta': 'stenoloba-glaucescens',
#  'achrosis-rondelaria': 'heterolocha-falconaria',
#  'achrosis-spp': 'mocis-undata',
#  'acontia-crocata': 'actias-selene',
#  'acontia-marmoralis': 'acantholipes-trajecta',
#  'acontia-spp': 'trabala-spp',
#  'acosmeryx-akanshi': 'acosmeryx-pseudonaga',
#  'acosmeryx-pseudonaga': 'creatonotos-transiens',
#  'acosmeryx-sericeus': 'acherontia-lachesis',
#  'actias-maenas': 'amata-passalis',
#  'adisura-spp': 'athetis-spp',
#  'adoxophyes-spp': 'Miltochrista-spp',
#  'aegocera-venulia': 'amata-cyssea',
#  'aethaloessa-calidalis': 'ambulyx-moorei',
#  'aetholix-flavibasalis': 'ariolica-pulchella',
#  'agalope-hyalina': 'omiodes-milvinalis',
#  'agassiziella-picalis': 'glyphodes-bivitralis',
#  'aglaomorpha-plagiata': 'areas-galactina',
#  'agrius-convolvuli': 'mocis-undata',
#  'agrotera-basinotata': 'creatonotos-transiens',
#  'alcanola-tympanistis': 'panilla-dispila',
#  'alcis-perspicuata': 'chorodna-metaphaearia',
#  'alcis-variegata': 'cleora-spp',
#  'allata-spp': 'Ecpyrrhorrhoe-spp',
#  'aloa-neoaloa-spp': 'bombycinae-genera-spp',
#  'alphaea-impleta': 'amata-passalis',
#  'amata-cyssea': 'amata-passalis',
#  'amata-elongata': 'spodoptera-spp',
#  'amata-extensa': 'amata-cyssea',
#  'amata-passalis': 'Miltochrista-spp',
#  'amata-sperbius': 'micronia-aculeata',
#  'amata-spp': 'amata-cyssea',
#  'amblychia-pardicelata': 'biston-suppressaria',
#  'ambulyx-belli': 'eretmocera-impactella',
#  'ambulyx-liturata': 'stenoloba-glaucescens',
#  'amerila-eugenia': 'conolophia-nigripuncta',
#  'ammatho-cuneonotatus': 'longipennis-longipennis',
#  'ammatho-spp': 'Miltochrista-spp',
#  'amraica-recursaria': 'psilogramma-discistriga',
#  'amyna-spp': 'panilla-dispila',
#  'anabasis-obliquifasciella': 'spodoptera-litura',
#  'anadevidia-peponis': 'hypochrosis-baenzigeri',
#  'analyta-diaphana': 'amata-sperbius',
#  'andraca-trilochoides': 'cyclothea-disjuncta',
#  'anereuthina-renosa': 'stenoloba-glaucescens',
#  'angonyx-krishna': 'marumba-nympha',
#  'angonyx-testacea': 'achrosis-incitata-complex',
#  'anisephyra-ocularia': 'eupterote-spp',
#  'anisoneura-aluco': 'acherontia-lachesis',
#  'anomis-flava': 'campylotes-desgodinsi',
#  'antheraea-assamensis': 'trigonodes-hyppasia',
#  'antheraea-paphia': 'attacus-taprobanis',
#  'anticarsia-irrorata': 'Luxiaria-hypaphanes',
#  'anticrates-anticlina': 'Lemyra-rhodophila',
#  'antigastra-catalaunalis': 'xandrames-dholaria',
#  'aphendala-spp': 'omiodes-milvinalis',
#  'apocalypsis-velox': 'acherontia-lachesis',
#  'archaeoattacus-edwardsii': 'eudocima-materna',
#  'archiplutodes-prasina': 'lymantria-grandis',
#  'archips-spp': 'Ecpyrrhorrhoe-spp',
#  'arcte-polygrapha': 'spodoptera-spp',
#  'arctioblepsis-rubida': 'areas-galactina',
#  'arctornis-spp': 'abraxas-spp',
#  'areas-galactina': 'gandhara-typica',
#  'argina-astrea': 'omiodes-milvinalis',
#  'argyrocosma-inductaria': 'comibaena-cassidara',
#  'arichanna-jaguarinaria': 'parotis-marginata-complex',
#  'arichanna-schnitzleri': 'paralbara-perhamata',
#  'arichanna-transfasciata': 'mellea-taeniata',
#  'arna-bipunctapex': 'anomis-mesogona',
#  'aroa-campbelli': 'eudocima-spp',
#  'aroa-spp': 'idaea-spp',
#  'artaxa-spp': 'acontia-spp',
#  'artona-quadrimaculata': 'psilogramma-vates',
#  'ascotis-spp': 'cleora-spp',
#  'asota-caricae': 'mocis-frugalis',
#  'asota-ficus': 'cyana-spp',
#  'asota-plana': 'abraxas-spp',
#  'asota-venalba': 'asota-plana',
#  'asta-quadrilinea': 'omiodes-milvinalis',
#  'astygisa-spp': 'banisia-spp',
#  'ataboruza-divisa': 'marasmia-poeyalis',
#  'atacira-melanephra': 'barsine-roseata',
#  'athetis-delecta': 'achaea-janata',
#  'athetis-spp': 'Ecpyrrhorrhoe-spp',
#  'atkinsonia-clerodendronella': 'eurrhyparodes-bracteolalis',
#  'attacus-taprobanis': 'acherontia-styx',
#  'atteva-fabriciella': 'mocis-undata',
#  'autoba-silicula': 'chiasmia-spp',
#  'autocharis-fessalis': 'elophila-spp',
#  'auzata-semipavonaria': 'perizoma-albofasciata',
#  'avatha-discolor': 'achaea-janata',
#  'avatha-leksawasdi': 'spirama-spp',
#  'azygophleps-scalaris': 'phyllodes-eyndhovii',
#  'bamra-albicola': 'agrotis-ipsilon',
#  'baniana-semilugens': 'udea-ferrugalis',
#  'banisia-spp': 'amata-sperbius',
#  'barsaurea-phaeoxanthia': 'chiasmia-eleonora',
#  'barsine-genera-group-spp': 'asura-miltochrista-group-spp',
#  'barsine-group-spp': 'barsine-roseata',
#  'bastilla-acuta': 'artena-dotata',
#  'bastilla-conficiens': 'pyrosis-fulviplaga',
#  'bastilla-crameri': 'chalcoscelides-castaneipars',
#  'bastilla-simillima': 'eurrhyparodes-tricoloralis',
#  'beara-spp': 'lebeda-nobilis',
#  'bepea-tranquillalis': 'acantholipes-trajecta',
#  'berta-spp': 'cleora-spp',
#  'bertula-abjudicalis': 'pseudozarba-spp',
#  'bharetta-cinnamomea': 'ethmia-spp',
#  'bireta-longivitta': 'artaxa-guttata',
#  'biston-bengaliaria': 'bivincula-kalikotei',
#  'biston-regalis': 'abraxas-spp',
#  'biston-strigaria': 'biston-suppressaria',
#  'biston-suppressaria': 'chiasmia-fidoniata',
#  'blasticorhinus-rivulosa': 'arthroschista-hilaralis',
#  'boarmiini-genera-spp': 'phycitinae-genera-spp',
#  'bocchoris-inspersalis': 'lymantria-plumbalis',
#  'bocula-spp': 'archips-spp',
#  'botyodes-asialis': 'pagyda-salvalis',
#  'botyodes-principalis': 'namangana-cashmirensis',
#  'bradina-adhaesalis': 'phyllodes-eyndhovii',
#  'bradina-admixtalis': 'marasmia-poeyalis',
#  'bradina-diagonalis': 'parapoynx-stagnalis',
#  'brahmaea-hearseyi': 'glyphodes-caesalis',
#  'brenthia-spp': 'omiodes-milvinalis',
#  'britha-pactalis': 'cnaphalocrocis-patnalis',
#  'britha-spp': 'pachynoa-spilosomoides-complex',
#  'brithys-crini': 'perina-nuda',
#  'brunia-antica': 'macroglossum-sitiene',
#  'caeneressa-diaphana': 'aglaomorpha-plagiata',
#  'calamotropha-latella': 'leucania-spp',
#  'caldubotys-caldusalis': 'eumelea-ludovicata',
#  'calesia-dasypterus': 'plusiinae-genera-spp',
#  'calesia-fuscicorpus': 'plusiinae-genera-spp',
#  'calesia-haemorrhoa': 'theretra-oldenlandiae',
#  'calesia-stillifera': 'eretmocera-impactella',
#  'callambulyx-rubricosa': 'macroglossum-sitiene',
#  'callidrepana-argenteola': 'tridrepana-flava',
#  'callidrepana-patrana': 'Lemaireia-himalayana',
#  'callindra-equitalis': 'stauroplitis-apicalis',
#  'calliteara-complicata': 'analyta-diaphana',
#  'calliteara-grotei': 'omiodes-milvinalis',
#  'calliteara-horsfieldii': 'Luxiaria-hypaphanes',
#  'calliteara-spp': 'pitama-spp',
#  'callopistria-minuta': 'squamosa-ocellata',
#  'callopistria-repleta': 'omiodes-milvinalis',
#  'callopistria-spp': 'elophila-spp',
#  'callyna-semivitta': 'eudocima-phalonia',
#  'calyptra-spp': 'syntypistis-pallidifascia',
#  'camptoloma-binotatum': 'xanthodes-transversa',
#  'campylotes-histrionicus': 'dysphania-militaris',
#  'canucha-specularis': 'scopula-fibulata',
#  'carea-albopurpurea': 'carea-angulata',
#  'carea-angulata': 'acria-ceramitis',
#  'casama-vilis': 'campylotes-desgodinsi',
#  'cechetra-lineosa': 'theretra-lucasii',
#  'cechetra-scotti': 'theretra-lucasii',
#  'celenna-festivaria': 'macroglossum-corythus',
#  'cephonodes-hylas': 'acherontia-lachesis',
#  'cephonodes-spp': 'endotricha-spp',
#  'cerynea-igniaria': 'Ozarba-hypenoides',
#  'cerynea-punctilinealis': 'helicoverpa-armigera',
#  'cerynea-spp': 'ericeia-spp',
#  'ceryx-diptera': 'amata-cyssea',
#  'chabula-acamasalis': 'episteme-nipalensis',
#  'chadisra-bipars': 'perizoma-albofasciata',
#  'chadisra-spp': 'chiasmia-spp',
#  'chalcidica-minea': 'amata-passalis',
#  'chalciope-mygdon': 'achrosis-incitata-complex',
#  'chalcoscelides-castaneipars': 'nola-internella-analis-complex',
#  'chalcosia-diana': 'lymantria-grandis',
#  'chamaita-nympha': 'arctornis-spp',
#  'chasmina-candida': 'barsine-roseata',
#  'chasmina-spp': 'hemithea-spp',
#  'cheromettia-apicata': 'Miltochrista-spp',
#  'chiasmia-eleonora': 'risoba-obstructa',
#  'chiasmia-fidoniata': 'hypomecis-transcissa',
#  'chiasmia-nora': 'sinna-floralis',
#  'chiasmia-spp': 'idaea-violacea',
#  'chilena-similis': 'achaea-janata',
#  'chilkasa-falcata': 'eupterote-spp',
#  'chlororithra-fea': 'utetheisa-spp',
#  'chlumetia-spp': 'chalcoscelides-castaneipars',
#  'chlumetia-transversa': 'yashmakia-erythra',
#  'choreutis-euclista': 'abrostola-anophioides',
#  'chorodna-adumbrata': 'agnidra-discispilaria',
#  'chorodna-metaphaearia': 'amblychia-angeronaria',
#  'chorodna-strixaria': 'chiasmia-fidoniata',
#  'chorsia-mollicula': 'alcis-variegata',
#  'chrysocraspeda-abhadraca': 'mellea-taeniata',
#  'chrysocraspeda-faganaria': 'macroglossum-sitiene',
#  'chrysocraspeda-spp': 'chabulina-tenera',
#  'chrysodeixis-eriosoma': 'traminda-mundissima',
#  'chrysodeixis-spp': 'chiasmia-spp',
#  'chrysorabdia-bivitta': 'areas-galactina',
#  'cidariini-genera-spp': 'lithosiini-genera-spp',
#  'cirrhochrista-brizoalis': 'areas-galactina',
#  'cirrhochrista-fumipalpis': 'creatonotos-transiens',
#  'cirrhochrista-pulchellalis': 'alcanola-tympanistis',
#  'clanidopsis-exusta': 'stenoloba-glaucescens',
#  'clanis-bilineata': 'ambulyx-ochracea',
#  'clanis-phalaris': 'theretra-lucasii',
#  'clelea-sapphirina': 'herdonia-osacesalis',
#  'cleora-alienaria': 'cleora-spp',
#  'cleora-fraterna': 'cleora-spp',
#  'clostera-fulgurita': 'achaea-janata',
#  'clostera-pallida': 'anomis-involuta',
#  'clostera-restitura': 'idiochlora-spp',
#  'cnaphalocrocis-medinalis': 'macroglossum-sitiene',
#  'cnaphalocrocis-patnalis': 'cnaphalocrocis-rutilalis',
#  'cnaphalocrocis-rutilalis': 'cnaphalocrocis-medinalis',
#  'comibaena-albimarginata': 'achrosis-incitata-complex',
#  'comibaena-spp': 'pyloetis-mimosae',
#  'comostola-inops': 'traminda-mundissima',
#  'comostola-spp': 'comibaena-spp',
#  'comparmustilia-sphingiformis': 'antheraea-paphia',
#  'condica-spp': 'olepa-ricini',
#  'conogethes-punctiferalis': 'xandrames-latiferaria',
#  'conogethes-semifascialis-complex': 'notodontella-tenebrosa',
#  'corgatha-albicinctalis': 'phycodes-radiata',
#  'corgatha-dictaria': 'anticarsia-irrorata',
#  'corymica-deducta': 'acontia-marmoralis',
#  'corymica-spp': 'neomusotima-conspurcatalis',
#  'crambidae-genera-spp': 'noctuinae-genera-spp',
#  'cretonia-spp': 'condica-spp',
#  'cricula-trifenestrata': 'Dichocrocis-bistrigalis',
#  'crithote-spp': 'condica-spp',
#  'crocidolomia-luteolalis': 'lobobasis-niveimaculata',
#  'cruxoruza-reticulata': 'panilla-dispila',
#  'ctenoplusia-albostriata': 'crocidolomia-pavonana',
#  'ctenoplusia-placida': 'pyrinioides-sinuosus',
#  'ctenoplusia-tarassota': 'cnaphalocrocis-spp',
#  'curoba-sangarida': 'pygospila-tyres',
#  'cusiala-boarmoides': 'biston-suppressaria',
#  'cyana-adita': 'aloa-lactinea',
#  'cyana-gazella': 'ariolica-superba',
#  'cyana-peregrina': 'lepidoptera-0',
#  'cyana-perornata': 'cyana-bellissima',
#  'cyana-signa': 'cyana-spp',
#  'cyclidia-rectificata': 'cyclidia-substigmaria',
#  'cyclidia-substigmaria': 'chiasmia-emersaria',
#  'cyclodes-omma': 'elophila-spp',
#  'cyclosia-latipennis': 'areas-galactina',
#  'cyclosia-midamia': 'achaea-janata',
#  'cyclosia-papilionaris': 'dysphania-percota',
#  'cyclothea-disjuncta': 'comibaena-cassidara',
#  'cydalima-laticostalis': 'macrocilix-mysticata',
#  'cypa-enodis': 'panilla-dispila',
#  'dalima-intricata': 'longipennis-longipennis',
#  'dalima-truncataria': 'chiasmia-emersaria',
#  'daphnis-nerii': 'spirama-spp',
#  'dasychira-postfusca': 'creatonotos-transiens',
#  'decetia-spp': 'chiasmia-spp',
#  'degia-spp': 'amyna-spp',
#  'deilephila-rivularis': 'ostrinia-spp',
#  'diaphania-indica': 'plutella-xylostella',
#  'diasemia-accalis': 'elophila-spp',
#  'diasemia-spp': 'elophila-spp',
#  'diasemiopsis-ramburialis': 'panilla-dispila',
#  'dichocrocis-definita': 'exelastis-atomosa',
#  'dichromia-quadralis': 'acherontia-styx',
#  'dichromia-sagitta': 'achaea-janata',
#  'dichromia-spp': 'hypeninae-genera-spp',
#  'digama-hearseyana': 'marasmia-poeyalis',
#  'digama-marchalii': 'calliteara-horsfieldii',
#  'dindicodes-crocina': 'acherontia-lachesis',
#  'discoglypha-locupletata': 'chrysocraspeda-spp',
#  'drepanidae-genera-spp': 'Eupterote-primularis',
#  'dudusa-sphingiformis': 'areas-galactina',
#  'dudusa-synopla': 'elophila-spp',
#  'dura-alba': 'Ecpyrrhorrhoe-spp',
#  'dyrzela-plagiata': 'acria-ceramitis',
#  'dysallacta-negatalis': 'areas-galactina',
#  'dysgonia-latifascia': 'achaea-janata',
#  'dysgonia-torrida': 'daphnis-nerii',
#  'dysodia-spp': 'artena-dotata',
#  'dysphania-nelera': 'pterogonia-cardinalis',
#  'dysphania-percota': 'diomea-lignicolora',
#  'earias-cupreoviridis': 'leucinodes-orbonalis',
#  'earias-flavida': 'trabala-vishnou',
#  'earias-vittella': 'mocis-frugalis',
#  'ecliptopera-dissecta': 'terastia-egialealis',
#  'ecliptopera-fulvotincta': 'eurrhyparodes-bracteolalis',
#  'ecliptopera-rectilinea': 'panilla-dispila',
#  'ecliptopera-substituta': 'hypochrosis-baenzigeri',
#  'ectropis-spp': 'idaea-spp',
#  'edosa-spp': 'areas-galactina',
#  'egens-egens': 'teulisna-tumida',
#  'egnasia-accingalis': 'syntypistis-spp',
#  'egnasia-ephyrodalis': 'patania-scinisalis',
#  'elaphria-conjugata': 'Ecpyrrhorrhoe-spp',
#  'electrophaes-spp': 'nolinae-genera-spp',
#  'eligma-narcissus': 'lymantria-plumbalis',
#  'elophila-spp': 'spirama-spp',
#  'elusa-spp': 'anoba-spp',
#  'endoclita-malabaricus': 'creatonotos-transiens',
#  'endotricha-mesenterialis': 'panilla-dispila',
#  'endotricha-olivacealis': 'endotricha-spp',
#  'endotricha-ruminalis': 'endotricha-spp',
#  'endotricha-spp': 'syntypistis-pallidifascia',
#  'enispa-elataria': 'perisyntrocha-ossealis',
#  'ennominae-genera-spp': 'eupitheciini-genera-spp',
#  'entomogramma-fautrix': 'chiasmia-emersaria',
#  'entomogramma-torsa': 'traminda-mundissima',
#  'eoophyla-spp': 'Miltochrista-spp',
#  'epicopeia-polydora': 'episteme-adulatrix',
#  'epicrocis-spp': 'lipomelia-subusta',
#  'epipagis-peritalis': 'marasmia-poeyalis',
#  'epiparbattia-gloriosalis': 'pingasa-rufofasciata',
#  'epipaschiinae-genera-spp': 'notodontidae-genera-spp',
#  'episothalma-robustaria': 'traminda-mundissima',
#  'episparis-liturata': 'eudocima-spp',
#  'ercheia-cyllaria': 'panilla-dispila',
#  'erebus-macrops': 'eretmocera-impactella',
#  'eressa-confinis': 'eressa-spp',
#  'ericeia-inangulata': 'drepanidae-genera-spp',
#  'ericeia-pertendens': 'Luxiaria-hypaphanes',
#  'ericeia-spp': 'petelia-spp',
#  'eriocottidae-genera-spp': 'hypeninae-genera-spp',
#  'ernolatia-moorei': 'stathmopoda-theoris',
#  'etanna-breviuscula': 'spodoptera-litura',
#  'eterusia-aedea': 'areas-galactina',
#  'eterusia-raja': 'spirama-spp',
#  'eublemma-accedens': 'hyperythra-lutea',
#  'eublemma-baccalix': 'saptha-cypridia',
#  'eublemma-dimidialis': 'Ecpyrrhorrhoe-spp',
#  'eublemma-olivacea': 'luceria-spp',
#  'eublemma-quadrapex': 'singara-diversalis',
#  'eublemma-semirufa': 'pyrausta-phoenicealis',
#  'euchromia-polymena': 'Nephelomilta-suffusa',
#  'euchromius-ocellea': 'amata-sperbius',
#  'euclasta-spp': 'archips-spp',
#  'eucyclodes-divapala-complex': 'nola-internella-analis-complex',
#  'eucyclodes-picturata': 'radhica-flavovittata',
#  'eucyclodes-semialba': 'antheraea-assamensis',
#  'eucyclodes-textilis': 'hemithea-spp',
#  'eudocima-homaena': 'elophila-spp',
#  'eudocima-hypermnestra': 'macroglossum-sitiene',
#  'eudocima-materna': 'eudocima-spp',
#  'eudocima-phalonia': 'squamosa-ocellata',
#  'eudocima-salaminia': 'trabala-spp',
#  'eudocima-spp': 'daplasa-postincisa',
#  'euhampsonia-niveiceps': 'areas-galactina',
#  'euproctis-hampsoni': 'platyja-ciacula',
#  'euproctis-leithiana': 'hyperythra-lutea',
#  'euproctis-magna': 'achaea-janata',
#  'euproctis-plagiata': 'eupterote-mollifera',
#  'eupterote-gardneri': 'perizoma-albofasciata',
#  'eupterote-patula': 'traminda-mundissima',
#  'eupterote-spp': 'omiodes-maculicostalis',
#  'eupterote-undata': 'erebus-hieroglyphica',
#  'eurrhyparodes-tricoloralis': 'conogethes-spp',
#  'euteliidae-genera-spp': 'cidariini-genera-spp',
#  'euthrix-laeta': 'asota-caricae',
#  'fascellina-chromataria': 'traminda-mundissima',
#  'fascellina-plagiata': 'eumorphobotys-spp',
#  'fascellina-porphyreofusa': 'macroglossum-bombylans',
#  'feliniopsis-spp': 'hyles-gallii',
#  'fentonia-baibarana': 'psilogramma-vates',
#  'filodes-fulvidorsalis': 'nevrina-procopia',
#  'fodina-pallula': 'achaea-janata',
#  'gabala-polyspilalis': 'pygospila-tyres',
#  'galleria-mellonella': 'lobobasis-niveimaculata',
#  'ganisa-spp': 'petelia-spp',
#  'garaeus-apicata': 'lebeda-nobilis',
#  'gastropacha-spp': 'barsine-group-spp',
#  'gaurena-florens': 'omiodes-milvinalis',
#  'gaurena-florescens': 'callindra-principalis',
#  'gazalina-chrysolopha': 'oxacme-marginata',
#  'gelechiidae-genera-spp': 'crambinae-genera-spp',
#  'gesonia-spp': 'idaea-amplipennis',
#  'glycythyma-chrysorycta': 'fascellina-porphyreofusa',
#  'glyphodes-actorionalis': 'areas-galactina',
#  'glyphodes-crithealis': 'phyllodes-eyndhovii',
#  'glyphodes-spp': 'glyphodes-bicolor',
#  'glyphodes-stolalis': 'paralbara-perhamata',
#  'gnophos-spp': 'idaea-spp',
#  'goniorhynchus-gratalis': 'egnasia-accingalis',
#  'gonoclostera-aurosigna': 'achrosis-incitata-complex',
#  'gonodontis-clelia': 'syntypistis-comatus',
#  'gonodontis-spp': 'chiasmia-spp',
#  'grammodes-geometrica': 'eudocima-salaminia',
#  'grammodes-stolida': 'stauroplitis-apicalis',
#  'gunda-ochracea': 'ophiusa-tirhaca',
#  'habrosyne-violacea': 'creatonotos-gangis-interrupta-complex',
#  'hadennia-spp': 'plecoptera-spp',
#  'haritalodes-derogata': 'acherontia-lachesis',
#  'hastina-pluristrigata': 'anisoneura-aluco',
#  'helicoverpa-armigera': 'cnaphalocrocis-medinalis',
#  'helicoverpa-assulta': 'autocharis-fessalis',
#  'heliothis-peltigera': 'eupterote-spp',
#  'hellula-undalis': 'dindicodes-apicalis',
#  'hemonia-orbiferana': 'heterolocha-falconaria',
#  'hemonia-rotundata': 'hyposidra-talaca',
#  'hendecasis-duplifascialis': 'antheraea-paphia',
#  'heortia-vitessoides': 'mellea-taeniata',
#  'herminiinae-genera-spp': 'eupitheciini-genera-spp',
#  'herpetogramma-basalis': 'parapsestis-lichenea',
#  'herpetogramma-licarsisalis': 'herpetogramma-spp',
#  'herpetogramma-spp': 'plusiinae-genera-spp',
#  'heterostegane-urbica': 'heterostegane-subtessellata',
#  'heterothera-spp': 'stathmopoda-theoris',
#  'himala-argentea': 'lymantria-todara',
#  'hipoepa-biasalis': 'achaea-janata',
#  'hipoepa-fractalis': 'achaea-janata',
#  'hippotion-celerio': 'stenoloba-glaucescens',
#  'hippotion-rosetta': 'squamosa-ocellata',
#  'hippotion-spp': 'theretra-lucasii',
#  'histia-flabellicornis': 'nyctemera-adversata',
#  'homaea-clathrum': 'pygospila-tyres',
#  'hulodes-caranea': 'parallelia-stuposa',
#  'hyalobathra-miniosalis': 'loboschiza-koenigiana',
#  'hyalobathra-phoenicozona': 'eustroma-aurigena',
#  'hyblaea-puera-complex': 'eustroma-aurigena',
#  'hydrillodes-spp': 'hyles-gallii',
#  'hydrorybina-polusalis': 'helicoverpa-armigera',
#  'hyles-livornica': 'daphnis-nerii',
#  'hymenia-perspectalis': 'traminda-mundissima',
#  'hymenoptychis-sordida': 'crocidolomia-pavonana',
#  'hypena-iconicalis': 'hypeninae-genera-spp',
#  'hypena-laceratalis': 'hydriris-ornatalis',
#  'hypena-obacerralis': 'syntypistis-spp',
#  'hypeninae-genera-spp': 'crambidae-genera-spp',
#  'hypersypnoides-constellata': 'mellea-taeniata',
#  'hyperythra-lutea': 'ophiusa-tirhaca',
#  'hypocala-deflorata': 'barsine-roseata',
#  'hypocala-subsatura': 'eudocima-phalonia',
#  'hypochrosis-abstractaria': 'traminda-mundissima',
#  'hypochrosis-flavifusata': 'miltochrista-obsoleta',
#  'hypochrosis-hyadaria-complex': 'heterothera-consimilis',
#  'hypochrosis-iris': 'diphtherocome-pallida',
#  'hypochrosis-sternaria': 'achaea-serva',
#  'hypomecis-cineracea': 'chiasmia-fidoniata',
#  'hypomecis-separata': 'cleora-fraterna',
#  'hypomecis-spp': 'idaea-violacea',
#  'hypomecis-transcissa': 'chiasmia-fidoniata',
#  'hypopyra-meridionalis': 'tyana-callichlora',
#  'hypopyra-spp': 'idaea-amplipennis',
#  'hyposidra-aquilaria': 'hyposidra-talaca',
#  'hyposidra-infixaria': 'zythos-avellanea',
#  'hyposidra-spp': 'fascellina-rectimarginata',
#  'hyposidra-talaca': 'anisoneura-aluco',
#  'hypospila-bolinoides': 'artena-dotata',
#  'hypsopygia-spp': 'lipomelia-subusta',
#  'idaea-costiguttata': 'erebus-hieroglyphica',
#  'idaea-spp': 'Ecpyrrhorrhoe-spp',
#  'idiochlora-spp': 'Ecpyrrhorrhoe-spp',
#  'ilema-chloroptera': 'lymantria-spp',
#  'indiania-eccentropis': 'epiplema-fuscifrons',
#  'ischyja-manlia': 'achaea-janata',
#  'ischyja-spp': 'petelia-spp',
#  'isocentris-filalis': 'erpis-macularis',
#  'isturgia-disputaria': 'spoladea-recurvalis',
#  'isturgia-spp': 'thyrassia-penangae',
#  'janseodes-melanospila': 'eugnathia-pictipennis',
#  'juxtarctia-multiguttata': 'siccia-taprobanis',
#  'katha-conformis': 'asota-caricae',
#  'krananda-semihyalina': 'metanastria-hyrtaca',
#  'kunugia-lineata': 'archips-spp',
#  'labdia-spp': 'lacera-spp',
#  'lacera-noctilio': 'elophila-spp',
#  'laelia-exclamationis': 'barsine-roseata',
#  'lamoria-spp': 'athetis-spp',
#  'lamprosema-tampiusalis': 'eurrhyparodes-bracteolalis',
#  'langia-zenzeroides': 'eustroma-aurigena',
#  'leucania-spp': 'areas-galactina',
#  'leucania-yu': 'Ecpyrrhorrhoe-spp',
#  'leucinodes-orbonalis': 'plutella-xylostella',
#  'leucoma-clara': 'arctornis-spp',
#  'leucostola-argyrosticta': 'abraxas-spp',
#  'ligdia-coctata': 'chiasmia-spp',
#  'limacodinae-genera-spp': 'barsine-genera-group-spp',
#  'liparopsis-postalbida': 'Ecpyrrhorrhoe-spp',
#  'lipomelia-subusta': 'attacus-taprobanis',
#  'lissoblemma-lunuliferata': 'traminda-mundissima',
#  'lithosiopsis-torsivena': 'polydesma-boarmoides',
#  'loboschiza-koenigiana': 'barsine-genera-group-spp-0',
#  'locastra-muscosalis': 'trichophysetis-hampsoni',
#  'locharna-strigipennis': 'areas-galactina',
#  'lomographa-inamata': 'Sesapa-dentifascia',
#  'lomographa-spp': 'chamaita-neuropteroides',
#  'lopharthrum-comprimens': 'xandrames-latiferaria',
#  'lophophelma-erionoma': 'boarmiini-genera-spp',
#  'lophophelma-ruficosta': 'phyllodes-eyndhovii',
#  'lophophleps-phoenicoptera': 'entomogramma-mediocris',
#  'lophophleps-purpurea': 'amblychia-angeronaria',
#  'lophosoma-cuprea': 'linguisaccus-subhyalina',
#  'luxiaria-phyllosaria': 'Luxiaria-hypaphanes',
#  'luxiaria-spp': 'idaea-spp',
#  'luxiaria-tephrosaria': 'drepanidae-genera-spp',
#  'lygniodes-vampyurs': 'apona-shevaroyensis',
#  'lymantria-ampla': 'achaea-janata',
#  'lymantria-incerta': 'acherontia-styx',
#  'lymantria-lepcha': 'barsine-roseata',
#  'lymantria-mathura': 'barsine-group-spp',
#  'lymantria-semicincta': 'asota-canaraica',
#  'lymantria-similis': 'entomogramma-mediocris',
#  'lymantria-sobrina': 'polydesma-boarmoides',
#  'lymantria-spp': 'olepa-ricini',
#  'lymantria-todara': 'areas-galactina',
#  'lyssa-zampa': 'spirama-spp',
#  'macariini-genera-spp': 'choreutis-spp',
#  'maceda-mansueta': 'hypeninae-genera-spp',
#  'macotasa-nubecula': 'creatonotos-transiens',
#  'macrobrochis-gigas': 'dysphania-percota',
#  'macrocilix-maia': 'macrocilix-mysticata',
#  'macroglossum-assimilis': 'cechenena-helops',
#  'macroglossum-bombylans': 'macroglossum-sitiene',
#  'macroglossum-gyrans': 'erebus-glaucopis',
#  'macroglossum-sitiene': 'psilogramma-vates',
#  'mahanta-quadrilinea': 'Ecpyrrhorrhoe-spp',
#  'maliattha-erecta': 'anomis-involuta',
#  'maliattha-fervens': 'Sesapa-dentifascia',
#  'maliattha-ruptifascia': 'agrioglypta-eurytusalis',
#  'maliattha-signifera': 'paralbara-perhamata',
#  'mangina-argus': 'nepita-conferta',
#  'mangina-syringa': 'squamosa-ocellata',
#  'maruca-amboinalis': 'maruca-vitrata',
#  'marumba-cristata': 'marumba-dyras',
#  'marumba-dyras': 'achaea-janata',
#  'marumba-spectabilis': 'marumba-dyras',
#  'maurilia-iconica': 'siglophora-haematica',
#  'mecodina-albodentata': 'patania-caletoralis',
#  'megacorma-obliqua': 'acherontia-lachesis',
#  'meganola-nitida': 'dindicodes-apicalis',
#  'melinaria-pseudorepanda': 'elophila-spp',
#  'melittia-spp': 'trabala-spp',
#  'mellea-taeniata': 'Microselene-mesostipa',
#  'menophra-subplagiata': 'acantholipes-circumdata',
#  'mesoptila-melanolopha': 'patania-caletoralis',
#  'metallolophia-taleensis': 'areas-galactina',
#  'metanastria-spp': 'stenoloba-glaucescens',
#  'metarbelidae-genera-spp': 'epipaschiinae-genera-spp',
#  'micraloa-spp': 'spilarctia-spp',
#  'microblepsis-leucosticta': 'antheraea-paphia',
#  'microblepsis-violacea': 'Luxiaria-hypaphanes',
#  'microloxia-indecretata': 'traminda-mundissima',
#  'microloxia-spp': 'comibaena-spp',
#  'micromelalopha-spp': 'nygmiini-genera-spp',
#  'micronia-aculeata': 'eurrhyparodes-bracteolalis',
#  'microxyla-stipata': 'stathmopoda-theoris',
#  'miltochrista-conjunctana': 'miltochrista-obsoleta',
#  'miltochrista-dharma': 'miltochrista-undulata',
#  'miltochrista-undulata': 'asota-producta',
#  'miltochrista-undulosa': 'miltochrista-obsoleta',
#  'mimomiza-cruentaria': 'pingasa-subviridis',
#  'miresa-albipuncta': 'acherontia-lachesis',
#  'miresa-spp': 'perizoma-albofasciata',
#  'mixochlora-vittata': 'traminda-mundissima',
#  'mocis-frugalis': 'achaea-janata',
#  'mocis-undata': 'spirama-spp',
#  'musotiminae-genera-spp': 'pyralis-manihotalis',
#  'mustilizans-hepatica': 'scopelodes-sericea',
#  'mythimna-separata': 'Ecpyrrhorrhoe-spp',
#  'naarda-spp': 'artena-dotata',
#  'nacna-malachitis': 'nyctemera-coleta',
#  'nannoarctia-dentata': 'marumba-irata',
#  'narosa-conspersa': 'sameodes-cancellalis',
#  'nausinoe-perspectata': 'eudocima-salaminia',
#  'negeta-contrariata': 'dysgonia-latifascia',
#  'neocerura-liturata': 'areas-galactina',
#  'neochera-dominia': 'lyssa-zampa',
#  'neogurelca-himachala': 'anabasis-obliquifasciella',
#  'neogurelca-hyas': 'macroglossum-sitiene',
#  'neopheosia-fasciata': 'mellea-taeniata',
#  'nephele-hespera': 'antheraea-paphia',
#  'netria-multispinae': 'leucophlebia-emittens',
#  'nisaga-simplex': 'Ecpyrrhorrhoe-spp',
#  'noctuinae-genera-spp': 'phycitinae-genera-spp',
#  'nola-taeniata': 'omiodes-milvinalis',
#  'noorda-blitealis': 'traminda-mundissima',
#  'noorda-spp': 'elophila-spp',
#  'noreia-ajaia': 'traminda-mundissima',
#  'notodontella-tenebrosa': 'creatonotos-transiens',
#  'notodontella-viridinota': 'ochropleura-costalis',
#  'notodontidae-genera-spp': 'eupitheciini-genera-spp',
#  'notonagemia-analis': 'tridrepana-albonotata',
#  'numenes-siletti': 'glyphodes-bivitralis',
#  'nyctemera-adversata': 'cirrhochrista-pulchellalis',
#  'nyctemera-lacticinia': 'lymantria-concolor',
#  'nygmia-icilia': 'barsine-group-spp',
#  'nygmiini-genera-spp': 'noctuinae-genera-spp',
#  'oeonistis-entella': 'amata-cyssea',
#  'oglasa-hypenoides': 'cnaphalocrocis-spp',
#  'olene-mendosa': 'agrius-convolvuli',
#  'olepa-ricini': 'amata-cyssea',
#  'omiodes-spp': 'ambulyx-ochracea',
#  'omiodes-surrectalis': 'naarda-spp',
#  'omiza-miliaria': 'traminda-mundissima',
#  'omphisa-anastomosalis': 'thysanoplusia-orichalcea',
#  'ophiusa-disjungens': 'ophiusa-tirhaca',
#  'ophthalmitis-spp': 'somera-viridifusca',
#  'opisthograptis-mimulina': 'lymantria-grandis',
#  'opisthograptis-sulphurea': 'lymantria-grandis',
#  'oraesia-argyrosigna': 'eudocima-spp',
#  'oraesia-emarginata': 'eudocima-spp',
#  'oreta-extensa': 'cricula-spp',
#  'oreta-griseotincta': 'hyalobathra-aequalis',
#  'oreta-spp': 'perina-nuda',
#  'oreta-suffusa': 'acantholipes-trajecta',
#  'orgyia-postica': 'achaea-janata',
#  'orgyiini-genera-spp': 'nolinae-genera-spp',
#  'orthaga-exvinacea': 'laspeyria-excisa',
#  'orthobrachia-flavidior': 'barsine-roseata',
#  'orthonama-obstipata': 'eressa-aperiens',
#  'ortopla-lindsayi': 'amata-sperbius',
#  'orudiza-protheclaria': 'mimeusemia-peshwa',
#  'orvasca-subnotata': 'barsine-roseata',
#  'ourapteryx-spp': 'nebula-homophana',
#  'ovipennis-incompletostriga': 'miresa-spp',
#  'oxyodes-scrobiculata': 'creatonotos-transiens',
#  'ozarba-punctigera': 'loxaspilates-spp',
#  'ozarba-spp': 'acantholipes-trajecta',
#  'ozola-spp': 'egnasia-accingalis',
#  'pachyodes-haemataria': 'areas-galactina',
#  'padenia-spp': 'spilarctia-spp',
#  'padenia-transversa': 'macroglossum-corythus',
#  'pagyda-salvalis': 'artaxa-guttata',
#  'palpita-annulifer-complex': 'risoba-obstructa',
#  'pandesma-spp': 'achaea-janata',
#  'pangora-matherana': 'areas-galactina',
#  'pantana-luteiceps': 'ambulyx-ochracea',
#  'paracrama-latimargo': 'ornithospila-avicularia',
#  'paracymoriza-aurantialis': 'arichanna-flavinigra',
#  'paracymoriza-vagalis': 'mellea-taeniata',
#  'paralbara-muscularia': 'calesia-haemorrhoa',
#  'paralbara-perhamata': 'Luxiaria-hypaphanes',
#  'paralebeda-plagifera': 'areas-galactina',
#  'parallelia-rigidistria-calefasciens-complex': 'creatonotos-gangis-interrupta-complex',
#  'parallelia-stuposa': 'achaea-janata',
#  'parapholodes-fuliginea': 'scopula-fibulata',
#  'parapoynx-affinialis': 'chiasmia-fidoniata',
#  'parapoynx-bilinealis': 'antheraea-paphia',
#  'parapoynx-crisonalis': 'phyllodes-eyndhovii',
#  'parapoynx-diminutalis': 'parapoynx-fluctuosalis',
#  'parapoynx-fluctuosalis': 'eurrhyparodes-bracteolalis',
#  'parapoynx-spp': 'parapoynx-stagnalis',
#  'parasa-lepida': 'achaea-janata',
#  'pardomima-amyntusalis': 'theretra-lucasii',
#  'parotis-marginata-complex': 'macroglossum-sitiene',
#  'parotis-spp': 'spilarctia-spp',
#  'patania-characteristica': 'pyrausta-phoenicealis',
#  'patania-iopasalis': 'patania-scinisalis',
#  'patania-plagiatalis': 'conogethes-spp',
#  'penicillifera-apicalis': 'creatonotos-transiens',
#  'peratophyga-hyalinata': 'boarmiini-genera-spp',
#  'pergesa-acteus': 'hyposidra-aquilaria',
#  'pericyma-albidens': 'acherontia-lachesis',
#  'pericyma-cruegeri': 'chiasmia-emersaria',
#  'pericyma-glaucinans': 'cerynea-spp',
#  'pericyma-spp': 'condica-spp',
#  'perina-nuda': 'trabala-vishnou',
#  'perisyntrocha-ossealis': 'hellula-undalis',
#  'petelia-immaculata': 'antheraea-paphia',
#  'petelia-spp': 'chiasmia-spp',
#  'phalacra-vidhisara': 'Luxiaria-hypaphanes',
#  'phalera-combusta': 'artaxa-guttata',
#  'phalera-spp': 'elophila-spp',
#  'phazaca-spp': 'actias-selene',
#  'phazaca-theclata': 'amata-sperbius',
#  'phocoderma-velutina': 'lymantria-plumbalis',
#  'photoscotosia-spp': 'harutalcis-vialis',
#  'phycitinae-genera-spp': 'crambinae-genera-spp',
#  'phycodes-radiata': 'phyllodes-eyndhovii',
#  'phyllodes-eyndhovii': 'ophiusa-tirhaca',
#  'pida-spp': 'Ecpyrrhorrhoe-spp',
#  'pidorus-glaucopis': 'nyctemera-hampsoni',
#  'piesmopoda-semilutea': 'creatonotos-transiens',
#  'pindara-illibata': 'artena-dotata',
#  'pingasa-lariaria': 'ostrinia-spp',
#  'pingasa-spp': 'chiasmia-spp',
#  'plagodis-inustaria': 'imaus-munda',
#  'plecoptera-spp': 'pyrausta-spp',
#  'plusiinae-genera-spp': 'stauroplitis-apicalis',
#  'plusiodonta-coelonota': 'callopistria-rivularis',
#  'plutella-xylostella': 'antheraea-paphia',
#  'plutodes-transmutata': 'Lemaireia-himalayana',
#  'poaphilini-genera-spp': 'stauroplitis-apicalis',
#  'poliobotys-ablactalis': 'autocharis-amethystina',
#  'polydesma-boarmoides': 'metallaxis-semipurpurascens',
#  'polynesia-sunandava': 'polynesia-truncapex',
#  'polytela-gloriosae': 'acherontia-lachesis',
#  'polythlipta-divaricata': 'stenoloba-glaucescens',
#  'problepsis-deliaria': 'ptisciana-seminivea',
#  'problepsis-spp': 'nyctemera-coleta',
#  'problepsis-vulgaris': 'creatonotos-transiens',
#  'prophantis-adusta': 'eudocima-hypermnestra',
#  'protonoceras-capitalis': 'analyta-diaphana',
#  'protuliocnemis-biplagiata': 'achrosis-incitata-complex',
#  'pseudoblabes-oophora': 'eudocima-spp',
#  'pseudojana-incandescens': 'achrosis-incitata-complex',
#  'pseudomiza-leucogonia': 'trabala-spp',
#  'pseudosphetta-moorei': 'amblychia-angeronaria',
#  'pseudozarba-spp': 'risoba-obstructa',
#  'psilalcis-albibasis': 'antheraea-paphia',
#  'psilalcis-breta': 'spodoptera-litura',
#  'psilochira-lineata': 'barsine-roseata',
#  'psilogramma-increta': 'lymantria-plumbalis',
#  'psilogramma-spp': 'mellea-taeniata',
#  'psilogramma-vates': 'eudocima-spp',
#  'psimada-quadripennis': 'marumba-nympha',
#  'pterotopteryx-spilodesma': 'eurrhyparodes-bracteolalis',
#  'ptisciana-seminivea': 'eustroma-aurantiaria',
#  'ptychopseustis-spp': 'nygmiini-genera-spp',
#  'pycnarmon-cribrata': 'parapoynx-stagnalis',
#  'pycnarmon-meritalis': 'parapoynx-stagnalis',
#  'pygospila-tyres': 'amata-passalis',
#  'pyloetis-mimosae': 'Promalactis-spp',
#  'pyralidae-genera-spp': 'saptha-cypridia',
#  'pyralis-manihotalis': 'glyphodes-orbiferalis',
#  'pyralis-pictalis': 'dindicodes-apicalis',
#  'pyrausta-spp': 'idiochlora-spp',
#  'pyrrhia-umbra': 'anomis-flava',
#  'radara-subcupralis': 'achaea-janata',
#  'radhica-rosea': 'tyana-spp',
#  'rajendra-biguttata': 'lymantria-plumbalis',
#  'ramadasa-pavo': 'lymantria-grandis',
#  'ramila-acciusalis': 'autocharis-amethystina',
#  'rapdalus-pardicolor': 'xandrames-dholaria',
#  'rehimena-phrynealis': 'chiasmia-eleonora',
#  'rhagastis-albomarginatus': 'creatonotos-gangis-interrupta-complex',
#  'rhagastis-castanea': 'ambulyx-ochracea',
#  'rhagastis-castor': 'areas-galactina',
#  'rhagastis-olivacea': 'dichocrocis-festivalis',
#  'rhectothyris-gratiosalis': 'endotricha-spp',
#  'rhesala-spp': 'archips-spp',
#  'rhimphalea-trogusalis': 'acmeshachia-gigantea',
#  'rhodometra-sacraria': 'Ecpyrrhorrhoe-spp',
#  'rhodophaea-actiosella': 'areas-galactina',
#  'rinaca-cidosa': 'sarbanissa-insocia',
#  'rinaca-simla': 'attacus-atlas',
#  'rinaca-thibeta': 'anambulyx-elwesi',
#  'rivula-bioculalis': 'rusicada-spp',
#  'rivula-spp': 'pyrausta-spp',
#  'rusicada-spp': 'acria-ceramitis',
#  'sacada-discinota': 'Prosaris-pernigralis',
#  'sacada-spp': 'nepita-conferta',
#  'sagariphora-magnificalis': 'ischnurges-luteomarginalis',
#  'sameodes-cancellalis': 'areas-galactina',
#  'samia-canningii': 'attacus-taprobanis',
#  'sarcinodes-aequilinearia': 'condate-purpurea',
#  'sarobela-litterata': 'acherontia-styx',
#  'sauris-spp': 'archips-spp',
#  'schistophleps-spp': 'nolinae-genera-spp',
#  'sciorista-assignatalis': 'hyalobathra-phoenicozona',
#  'scirpophaga-incertulas': 'tridrepana-postica',
#  'scopelodes-spp': 'erpis-macularis',
#  'scopula-caesaria': 'perizoma-albofasciata',
#  'scopula-cuneilinea': 'Sesapa-dentifascia',
#  'scopula-ferrilineata': 'menophra-translineata',
#  'scopula-fibulata': 'traminda-mundissima',
#  'scopula-opicata': 'idaea-spp',
#  'scopula-pedilata': 'macrocilix-mysticata',
#  'scopula-spp': 'arctornis-spp',
#  'scythropiodes-spp': 'macroglossum-sitiene',
#  'selepa-celtis': 'Ecpyrrhorrhoe-spp',
#  'selepa-spp': 'siccia-spp',
#  'serrodes-campana': 'photoscotosia-spp',
#  'sesiidae-genera-spp': 'phycitinae-genera-spp',
#  'siccia-guttulosana': 'siccia-taprobanis',
#  'siccia-spotoptera': 'ditrigona-idaeoides',
#  'siccia-spp': 'Ecpyrrhorrhoe-spp',
#  'siccia-taprobanis': 'barsine-roseata',
#  'sinarella-discisigna': 'acantholipes-trajecta',
#  'singara-diversalis': 'thosea-magna',
#  'sinna-extrema': 'asota-ficus',
#  'sirinopteryx-rufivinctata': 'lymantria-grandis',
#  'somatina-anthophilata': 'creatonotos-transiens',
#  'somatina-omicraria': 'ptisciana-seminivea',
#  'somena-scintillans': 'mocis-undata',
#  'soritia-pulchella': 'amata-passalis',
#  'spataliini-genera-spp': 'areas-galactina',
#  'sphenarches-anisodactyla': 'eustroma-aurigena',
#  'sphingomorpha-chlorea': 'elophila-spp',
#  'sphingonaepiopsis-pumilio': 'chrysocraspeda-faganaria',
#  'sphrageidus-spp': 'comibaena-spp',
#  'spilarctia-comma': 'leucinodella-leucostola',
#  'spilarctia-spp': 'bombycinae-genera-spp',
#  'spilosoma-spp': 'spilarctia-spp',
#  'spilosomina-genera-spp': 'macroglossum-corythus',
#  'spodoptera-litura': 'squamosa-ocellata',
#  'spoladea-recurvalis': 'lipomelia-subusta',
#  'stathmopoda-spp': 'phyllodes-eyndhovii',
#  'stauropus-alternus': 'eressa-aperiens',
#  'stauropus-thiaucourti': 'polydesma-boarmoides',
#  'sterrhinae-genera-spp': 'crambinae-genera-spp',
#  'streblote-siva': 'mocis-frugalis',
#  'striglina-scitaria': 'scopula-emissaria',
#  'striglina-spp': 'perizoma-albofasciata',
#  'suana-concolor': 'artena-dotata',
#  'syllepte-bipartalis': 'endocrossis-flavibasalis',
#  'syllepte-sellalis': 'noorda-blitealis',
#  'syllepte-straminalis': 'haritalodes-derogata',
#  'synclera-traducalis': 'conogethes-spp',
#  'syntomoides-imaon': 'phyllodes-eyndhovii',
#  'syntypistis-comatus': 'nolinae-genera-spp',
#  'syntypistis-pallidifascia': 'hypena-laceratalis',
#  'sypnoides-pannosa': 'achrosis-incitata-complex',
#  'talanga-sexpunctalis': 'miltochrista-obsoleta',
#  'tamba-spp': 'Ecpyrrhorrhoe-spp',
#  'tanaorhinus-reciprocata': 'traminda-mundissima',
#  'tanaorhinus-viridiluteatus': 'ghoria-albocinerea',
#  'tasta-micaceata': 'plusiodonta-coelonota',
#  'tatobotys-biannulalis': 'cnaphalocrocis-trebiusalis',
#  'teldenia-vestigiata': 'scopula-pulchellata',
#  'teleclita-centristicta': 'psilogramma-vates',
#  'teleclita-strigata': 'omiodes-milvinalis',
#  'terastia-egialealis': 'acherontia-styx',
#  'termioptycha-albifurcalis': 'hypertrocta-posticalis',
#  'tetragonus-catamitus': 'pyrausta-phoenicealis',
#  'teuloma-nebulosa': 'nepita-conferta',
#  'thaumetopoea-cheela': 'trabala-spp',
#  'theretra-boisduvalii': 'theretra-lucasii',
#  'theretra-clotho': 'marumba-spectabilis',
#  'theretra-lucasii': 'achaea-janata',
#  'theretra-shendurneensis': 'macroglossum-sitiene',
#  'theretra-sumatrensis': 'stenoloba-glaucescens',
#  'thespea-bicolor': 'agathia-laetata',
#  'thinopteryx-crocoptera': 'eumelea-ludovicata',
#  'thosea-spp': 'Ecpyrrhorrhoe-spp',
#  'thyas-coronata': 'theretra-lucasii',
#  'thyatira-batis': 'omiodes-milvinalis',
#  'thymistida-spp': 'achaea-janata',
#  'thyrassia-subcordata': 'dysphania-percota',
#  'thyrididae-genera-spp': 'boarmiini-genera-spp',
#  'thysanoidma-stellata': 'dysmilichia-calamistrata',
#  'thysanoplusia-orichalcea': 'acherontia-styx',
#  'thysanoplusia-reticulata': 'anabasis-obliquifasciella',
#  'thysanoplusia-spp': 'nygmiini-genera-spp',
#  'timandra-correspondens': 'ghoria-albocinerea',
#  'timora-sanguinolenta': 'cricula-trifenestrata',
#  'tiracola-plagiata': 'achaea-janata',
#  'tiracola-spp': 'athetis-spp',
#  'tisis-spp': 'athetis-spp',
#  'titulcia-eximia': 'eurrhyparodes-bracteolalis',
#  'tonica-niviferana': 'eustroma-aurantiaria',
#  'tortricidae-genera-spp': 'noctuinae-genera-spp',
#  'trabala-spp': 'parotis-spp',
#  'trachea-auriplena': 'elophila-spp',
#  'traminda-aventiaria': 'traminda-mundissima',
#  'traminda-mundissima': 'nola-taeniata',
#  'trichoplusia-ni': 'elophila-spp',
#  'trichopterigia-spp': 'conogethes-spp',
#  'tridrepana-flava': 'botyodes-asialis',
#  'tridrepana-fulvata': 'lymantria-grandis',
#  'tridrepana-spp': 'eupterote-spp',
#  'trigonodes-hyppasia': 'mimeusemia-peshwa',
#  'trilocha-varians': 'euproctis-marginata',
#  'triphosa-spp': 'Tethea-albicosta',
#  'trischalis-subaurana': 'heterolocha-falconaria',
#  'trypanophora-semihyalina': 'areas-galactina',
#  'tyana-chloroleuca': 'areas-galactina',
#  'tyana-spp': 'miresa-spp',
#  'ulopeza-semivialis': 'diphtherocome-pallida',
#  'utetheisa-spp': 'agathia-spp',
#  'vamuna-bipars': 'macrocilix-mysticata',
#  'vamuna-remelana': 'lymantria-grandis',
#  'westermannia-superba': 'creatonotos-transiens',
#  'xandrames-dholaria': 'panilla-dispila',
#  'xandrames-latiferaria': 'Macrobrochis-flavicincta',
#  'xanthodes-albago': 'hyperythra-lutea',
#  'xanthodes-transversa': 'pyrausta-phoenicealis',
#  'xanthorhoe-saturata': 'chiasmia-fidoniata',
#  'xanthorhoe-spp': 'ariola-coelisigna',
#  'xenochroa-biviata': 'Xenochroa-xanthia',
#  'xenoplia-maculata': 'lymantria-todara',
#  'xyleutes-persona': 'spodoptera-litura',
#  'xyleutes-ramamurthyi': 'stauroplitis-apicalis',
#  'zamarada-spp': 'chiasmia-spp',
#  'zeuzerini-genera-spp': 'nygmiini-genera-spp',
#  'zitha-tactilis': 'lebeda-nobilis',
#  'zitha-torridalis': 'nepita-conferta'}

# %%
test(f"{dataset_dir}/checkpoint_latest.pth", f"{dataset_dir}/test_001")
# Out:
# Accuracy: 983 / 4046 -> 24.30%
# Elapsed time: 0:00:52.197689
# ----------
# Failures:
# {'Acygnatha-nigripuncta': 'areas-galactina',
#  'Addaea-trimeronalis': 'nola-taeniata',
#  'Aeolanthes-rhodochrysa': 'macroglossum-sitiene',
#  'Alcis-periphracta': 'alcis-variegata',
#  'Alophogaster-rubribasis': 'pidorus-glaucopis',
#  'Borbotana-nivifascia': 'erpis-macularis',
#  'Calamotropha-spp': 'autocharis-amethystina',
#  'Calletaera-obliquata': 'Luxiaria-hypaphanes',
#  'Callopistria-pulchrilinea': 'areas-galactina',
#  'Cassephyra-lamprosticta': 'boarmiini-genera-spp',
#  'Chalcophaedra-zuleika': 'campylotes-histrionicus',
#  'Chalcosiopsis-variata': 'Macrobrochis-flavicincta',
#  'Chorodna-creataria': 'zythos-avellanea',
#  'Chusaris-spp': 'naarda-spp',
#  'Comibaena-biplaga': 'Rivula-simulatrix',
#  'Cusiala-spp': 'chiasmia-xanthonora',
#  'Cyclosiella-dulcicula': 'hyperythra-lutea',
#  'Cystidia-indrasana': 'omiodes-milvinalis',
#  'Dichromia-indicatalis': 'Tarsolepis-malayana',
#  'Ecpyrrhorrhoe-damastesalis': 'amblychia-angeronaria',
#  'Endotricha-luteogrisalis': 'syntypistis-pallidifascia',
#  'Fascionycta-fasciata': 'photoscotosia-spp',
#  'Harutaea-flavizona': 'biston-suppressaria',
#  'Herochroma-elaearia': 'stigmatophora-inanis',
#  'Heterolocha-spp': 'stauroplitis-apicalis',
#  'Hyperythra-swinhoei': 'traminda-mundissima',
#  'Idaea-falcipennis': 'nolinae-genera-spp',
#  'Lemyra-rhodophila': 'phaiogramma-discessa',
#  'Leucinodes-melanopalis': 'areas-galactina',
#  'Leucoblepsis-excisa': 'euclasta-spp',
#  'Luxiaria-hypaphanes': 'chiasmia-eleonora',
#  'Macrobrochis-flavicincta': 'areas-galactina',
#  'Meganola-major': 'lymantria-spp',
#  'Miltochrista-spp': 'spilarctia-spp',
#  'Monema-coralina': 'macrocilix-mysticata',
#  'Mosara-apicalis': 'Sarbanissa-spp',
#  'Mosopia-magniplaga': 'comostola-pyrrhogona',
#  'Nola-spp': 'siccia-spp',
#  'Opula-mollis': 'dalima-patularia',
#  'Pantura-rufifrons': 'spirama-spp',
#  'Peribona-venosa': 'pyrosis-fulviplaga',
#  'Pilipectus-cyclopis': 'diomea-lignicolora',
#  'Pingasa-chlora': 'chiasmia-xanthonora',
#  'Pingasa-rubicunda': 'chiasmia-emersaria',
#  'Rhodoneura-fimbriata': 'areas-galactina',
#  'Rhynchina-spp': 'trisula-variegata',
#  'Risoba-prominens': 'lymantria-mathura',
#  'Risoba-vialis': 'elophila-scitalis',
#  'Sarbanissa-spp': 'chalcoscelides-castaneipars',
#  'Sasunaga-tenebrosa': 'Metaschalis-disrupta',
#  'Scopelodes-kwangtungensis': 'achrosis-incitata-complex',
#  'Scopelodes-venosa': 'epiplema-fuscifrons',
#  'Synegiodes-diffusifascia-obliquifascia-group': 'Herpetogramma-rudis%20species-group',
#  'Tamba-lala': 'chiasmia-spp',
#  'Teinoptila-spp': 'Eulocastra-excisa',
#  'Telchines-vialis': 'enispa-elataria',
#  'Teleclita-grisea': 'lymantria-spp',
#  'Tethea-albicosta': 'arichanna-spp',
#  'Teulisna-spp': 'lacera-spp',
#  'Teulisna-unicornuta': 'Promalactis-spp',
#  'Tinissa-indica': 'metoeca-foedalis',
#  'Tropacme-cupreimargo': 'ochropleura-costalis',
#  'Ziridava-rubridisca': 'hydriris-ornatalis',
#  'aberrasine-strigivenata': 'ammatho-cuneonotatus',
#  'abraxas-spp': 'asota-caricae',
#  'acantholipes-circumdata': 'pyrausta-phoenicealis',
#  'acantholipes-spp': 'acantholipes-trajecta',
#  'acantholipes-trajecta': 'eterusia-raja',
#  'achaea-janata': 'artena-dotata',
#  'achaea-serva': 'chiasmia-spp',
#  'achelura-bifasciata': 'lymantria-grisea',
#  'acherontia-lachesis': 'acherontia-styx',
#  'acherontia-styx': 'acherontia-lachesis',
#  'achrosis-incitata-complex': 'eudocima-salaminia',
#  'achrosis-pyrrhularia': 'lymantria-obfuscata',
#  'achrosis-rondelaria': 'heterolocha-falconaria',
#  'achrosis-spp': 'idaea-amplipennis',
#  'acmeshachia-gigantea': 'grammodes-geometrica',
#  'acontia-crocata': 'anomis-involuta',
#  'acontia-nitidula': 'achaea-janata',
#  'acosmeryx-naga': 'acherontia-lachesis',
#  'acosmeryx-omissa': 'acherontia-lachesis',
#  'acosmeryx-pseudonaga': 'creatonotos-transiens',
#  'acosmeryx-sericeus': 'acherontia-styx',
#  'acropteris-ciniferaria': 'chiasmia-emersaria',
#  'acropteris-iphiata': 'chiasmia-emersaria',
#  'acropteris-striataria': 'lymantria-grandis',
#  'actias-parasinensis': 'antheraea-paphia',
#  'actias-rhodopneuma': 'trigonodes-hyppasia',
#  'actias-selene': 'arctornis-spp',
#  'adisura-spp': 'Ecpyrrhorrhoe-spp',
#  'adixoa-trizonata': 'amata-cyssea',
#  'adoxophyes-spp': 'nepita-conferta',
#  'aedia-leucomelas-complex': 'eurrhyparodes-bracteolalis',
#  'aegocera-venulia': 'tasta-micaceata',
#  'aergina-fumosa': 'Rivula-curvifera',
#  'aergina-hilaris': 'parasa-lepida',
#  'aethaloessa-calidalis': 'ambulyx-ochracea',
#  'aetholix-flavibasalis': 'enispa-elataria',
#  'agassiziella-picalis': 'agathodes-ostentalis',
#  'agathia-laetata': 'agathia-spp',
#  'agathia-lycaenaria': 'agathia-spp',
#  'agathodes-ostentalis': 'trigonodes-hyppasia',
#  'aglaomorpha-plagiata': 'areas-galactina',
#  'aglaopus-industa': 'anticarsia-irrorata',
#  'agnidra-discispilaria': 'Eugraptoblemma-pictalis',
#  'agrioglypta-itysalis': 'glyphodes-bicolor',
#  'agrius-convolvuli': 'achaea-janata',
#  'agrotera-basinotata': 'Miltochrista-spp',
#  'agrotera-scissalis': 'eoophyla-spp',
#  'agrotis-biconica': 'syntypistis-spp',
#  'agrotis-spp': 'Ecpyrrhorrhoe-spp',
#  'aiteta-musculina': 'anomis-involuta',
#  'alcanola-speideli': 'calliteara-horsfieldii',
#  'alcis-albifera': 'eretmocera-impactella',
#  'alcis-perspicuata': 'astygisa-orbapicalis',
#  'alcis-spp': 'cleora-spp',
#  'allata-spp': 'Ecpyrrhorrhoe-spp',
#  'aloa-lactinea': 'eudocima-hypermnestra',
#  'aloa-neoaloa-spp': 'spilarctia-spp',
#  'alphaea-florescens': 'adites-pseudohilaris',
#  'alphaea-impleta': 'spirama-spp',
#  'altha-nivea': 'abraxas-spp',
#  'altha-subnotata': 'theretra-oldenlandiae',
#  'alucitidae-genera-spp': 'epipleminae-genera-spp',
#  'amata-bicincta': 'amata-cyssea',
#  'amata-compta': 'amata-passalis',
#  'amata-cyssea': 'amata-passalis',
#  'amata-elongata': 'amata-cyssea',
#  'amata-extensa': 'euthrix-laeta',
#  'amata-passalis': 'eressa-confinis',
#  'amata-sperbius': 'chiasmia-spp',
#  'amata-spp': 'amata-cyssea',
#  'amblychia-pardicelata': 'chiasmia-fidoniata',
#  'ambulyx-aglaia': 'ambulyx-ochracea',
#  'ambulyx-belli': 'eretmocera-impactella',
#  'ambulyx-moorei': 'theretra-lucasii',
#  'amerila-astreus': 'achaea-janata',
#  'amerila-eugenia': 'ovipennis-incompletostriga',
#  'amplypterus-panopus': 'ambulyx-moorei',
#  'amraica-recursaria': 'chiasmia-fidoniata',
#  'amyna-axis': 'phalacra-spp',
#  'amyna-spp': 'hypochrosis-flavifusata',
#  'anadevidia-peponis': 'eudocima-spp',
#  'anambulyx-elwesi': 'trigonodes-hyppasia',
#  'anarsia-spp': 'archips-spp',
#  'angonyx-testacea': 'traminda-mundissima',
#  'anisephyra-ocularia': 'eumelea-ludovicata',
#  'anisoneura-aluco': 'acherontia-lachesis',
#  'anoba-polyspila': 'daphnis-nerii',
#  'anomis-flava': 'campylotes-desgodinsi',
#  'anomis-involuta': 'acherontia-lachesis',
#  'anomis-mesogona': 'Sesapa-dentifascia',
#  'anonychia-grisea': 'chiasmia-emersaria',
#  'antheraea-assamensis': 'antheraea-paphia',
#  'antheraea-helferi': 'antheraea-paphia',
#  'antheraea-paphia': 'thyas-coronata',
#  'antheraea-roylei': 'actias-parasinensis',
#  'anticarsia-irrorata': 'eupterote-spp',
#  'anticrates-anticlina': 'argonestis-flammans',
#  'antigastra-catalaunalis': 'corgatha-atrimargo',
#  'antipercnia-belluaria': 'metapercnia-ductaria',
#  'aphendala-spp': 'omiodes-milvinalis',
#  'aplochlora-vivilaca': 'autocharis-fessalis',
#  'apocalypsis-velox': 'lymantria-plumbalis',
#  'apoheterolocha-patalata': 'oreta-griseotincta',
#  'apona-shevaroyensis': 'Heterospila-nigripalpis',
#  'aporandria-specularia': 'comibaena-cassidara',
#  'aporodes-floralis': 'elophila-spp',
#  'apsarasa-radians': 'aglaomorpha-plagiata',
#  'araeopteron-proleuca': 'locastra-crassipennis',
#  'archaeoattacus-edwardsii': 'chrysodeixis-permissa',
#  'archigargetta-viridigrisea': 'chiasmia-eleonora',
#  'archips-spp': 'athetis-spp',
#  'arcte-coerula': 'spirama-spp',
#  'arcte-polygrapha': 'squamosa-ocellata',
#  'arctelene-arcuata': 'ammatho-cuneonotatus',
#  'arctiini-genera-spp': 'lymantria-todara',
#  'arctornis-marginata': 'Ecpyrrhorrhoe-spp',
#  'arctornis-spp': 'scopula-spp',
#  'argina-astrea': 'dysphania-militaris',
#  'argonestis-flammans': 'Arctelene-rubricosa',
#  'arichanna-flavinigra': 'acherontia-lachesis',
#  'arichanna-sparsa': 'alcis-spp',
#  'arichanna-transfasciata': 'areas-galactina',
#  'ariola-coelisigna': 'parasa-lepida',
#  'ariolica-pulchella': 'nyctemera-coleta',
#  'arna-bipunctapex': 'exelastis-atomosa',
#  'aroa-spp': 'idaea-spp',
#  'arsacia-rectalis': 'maliattha-quadripartita',
#  'artena-dotata': 'mocis-frugalis',
#  'artena-submira': 'electrophaes-spp',
#  'arthroschista-hilaralis': 'cydalima-laticostalis',
#  'ascotis-spp': 'cleora-spp',
#  'asota-caricae': 'asota-plaginota',
#  'asota-ficus': 'asota-spp',
#  'asota-heliconia': 'asota-plaginota',
#  'asota-paphos': 'asota-caricae',
#  'asota-plana': 'arctornis-spp',
#  'asota-producta': 'Miltochrista-spp',
#  'asota-sericea': 'nepita-conferta',
#  'asota-spp': 'Ecpyrrhorrhoe-spp',
#  'asota-venalba': 'asota-plana',
#  'asta-quadrilinea': 'stenoloba-glaucescens',
#  'astygisa-hollowayi': 'anticarsia-irrorata',
#  'astygisa-spp': 'Apha-floralis',
#  'ataboruza-divisa': 'psilogramma-vates',
#  'atacira-melanephra': 'elophila-spp',
#  'athetis-delecta': 'prooedema-inscisalis',
#  'athetis-spp': 'amyna-spp',
#  'attacus-atlas': 'erebus-ephesperis',
#  'attacus-taprobanis': 'antheraea-paphia',
#  'attatha-regalis': 'abraxas-spp',
#  'atteva-niveigutta': 'indarbela-tetraonis',
#  'autoba-silicula': 'fascellina-porphyreofusa',
#  'autocharis-amethystina': 'areas-galactina',
#  'autocharis-fessalis': 'orvasca-subnotata',
#  'auzata-semipavonaria': 'eressa-multigutta',
#  'auzatellodes-hyalinata': 'amblychia-angeronaria',
#  'auzea-arenosa': 'somera-viridifusca',
#  'auzea-rufifrontata': 'chiasmia-fidoniata',
#  'avatha-discolor': 'elophila-spp',
#  'avatha-leksawasdi': 'elophila-spp',
#  'axylia-dispalata': 'acherontia-styx',
#  'axylia-renalis': 'allata-spp',
#  'axylia-triseriata': 'pygospila-tyres',
#  'bacotoma-violata': 'amblychia-angeronaria',
#  'balataea-spp': 'amata-passalis',
#  'baniana-semilugens': 'antitrisuloides-catocalina',
#  'banisia-spp': 'archips-spp',
#  'baradesa-omissa': 'eudocima-spp',
#  'baroa-punctivaga': 'maliattha-vialis-complex',
#  'barsine-genera-group-spp': 'barsine-group-spp',
#  'barsine-group-spp': 'lipomelia-subusta',
#  'barsine-linga': 'spirama-spp',
#  'barsine-roseata': 'acherontia-styx',
#  'bastilla-absentimacula': 'traminda-mundissima',
#  'bastilla-arcuata': 'acantholipes-trajecta',
#  'bastilla-crameri': 'artena-dotata',
#  'bastilla-joviana': 'fossia-punicea',
#  'bastilla-praetermissa': 'acantholipes-trajecta',
#  'bastilla-simillima': 'hypeninae-genera-spp',
#  'beana-terminigera': 'andala-unifascia',
#  'beara-dichromella': 'omiodes-milvinalis',
#  'beara-spp': 'Ecpyrrhorrhoe-spp',
#  'belippa-horrida': 'archips-spp',
#  'bepea-tranquillalis': 'lobobasis-niveimaculata',
#  'berta-annulifera': 'hemithea-spp',
#  'berta-chrysolineata': 'parapoynx-stagnalis',
#  'bertula-abjudicalis': 'spoladea-recurvalis',
#  'bharetta-cinnamomea': 'creatonotos-transiens',
#  'bireta-longivitta': 'eupterote-spp',
#  'birthamoides-junctura': 'panilla-dispila',
#  'biston-betularia': 'pyralis-manihotalis',
#  'biston-contectaria': 'cyclidia-substigmaria',
#  'biston-panterinaria': 'ascotis-spp',
#  'biston-regalis': 'achaea-janata',
#  'biston-spp': 'elophila-spp',
#  'biston-strigaria': 'biston-suppressaria',
#  'biston-suppressaria': 'bivincula-kalikotei',
#  'blasticorhinus-rivulosa': 'lymantria-todara',
#  'blastobasis-spp': 'eublemma-olivacea',
#  'boarmiini-genera-spp': 'noctuinae-genera-spp',
#  'bocana-manifestalis': 'traminda-mundissima',
#  'bocchoris-inspersalis': 'cypa-enodis',
#  'bocula-spp': 'eudocima-spp',
#  'boletobiinae-genera-spp': 'herminiinae-genera-spp',
#  'bombycinae-genera-spp': 'arcyophora-icterica',
#  'bombyx-huttoni': 'traminda-mundissima',
#  'botyodes-diniasalis': 'laspeyria-excisa',
#  'bradina-adhaesalis': 'phocoderma-velutina',
#  'bradina-admixtalis': 'marasmia-poeyalis',
#  'bradina-diagonalis': 'diaphania-indica',
#  'bradina-spp': 'ommatophora-luminosa',
#  'brahmaea-hearseyi': 'acherontia-lachesis',
#  'brahmaea-wallichii': 'pyralis-manihotalis',
#  'brenthia-spp': 'elophila-spp',
#  'brihaspa-atrostigmella': 'macrocilix-mysticata',
#  'britha-pactalis': 'Ecpyrrhorrhoe-spp',
#  'britha-spp': 'Ecpyrrhorrhoe-spp',
#  'brithys-crini': 'jodis-delicatula',
#  'brunia-antica': 'daphnis-nerii',
#  'brunia-gibonica': 'spilarctia-spp',
#  'buzara-onelia': 'idaea-violacea',
#  'caduca-albopunctata': 'alcis-spp',
#  'caissa-spp': 'spilarctia-spp',
#  'calamotropha-latella': 'Chalcosiopsis-variata',
#  'calesia-dasypterus': 'traminda-mundissima',
#  'calesia-fuscicorpus': 'bradina-diagonalis',
#  'calesia-haemorrhoa': 'omiza-spp',
#  'calesia-spp': 'banisia-spp',
#  'calesia-stillifera': 'eretmocera-impactella',
#  'calguia-defiguralis': 'callopistria-spp',
#  'calindoea-argentalis': 'Pilipectus-cyclopis',
#  'callambulyx-junonia': 'marumba-nympha',
#  'callambulyx-poecilus': 'daphnis-nerii',
#  'callambulyx-rubricosa': 'acosmeryx-sericeus',
#  'calletaera-subexpressa': 'chiasmia-emersaria',
#  'callidarsine-callida': 'argonestis-flammans',
#  'callidrepana-gemina': 'tridrepana-postica',
#  'callidrepana-patrana': 'trichopterigia-spp',
#  'callindra-equitalis': 'mabra-eryxalis',
#  'callindra-principalis': 'aglaomorpha-plagiata',
#  'calliteara-grotei': 'elophila-spp',
#  'calliteara-horsfieldii': 'Ozarba-hypenoides',
#  'calliteara-spp': 'agrius-convolvuli',
#  'callopistria-maillardi': 'digama-marchalii',
#  'callopistria-placodoides': 'psilotagma-pictaria',
#  'callopistria-repleta': 'callopistria-spp',
#  'callopistria-rivularis': 'miaromima-cornucopia',
#  'callopistria-spp': 'panilla-dispila',
#  'calluga-costalis': 'Leuroperna-sera',
#  'callyna-costiplaga': 'anomis-involuta',
#  'callyna-jugaria': 'artena-dotata',
#  'calonola-ectrocta': 'siccia-spp',
#  'calyptra-pseudobicolor': 'neochera-marmorea',
#  'calyptra-spp': 'chiasmia-spp',
#  'campylotes-histrionicus': 'aglaomorpha-plagiata',
#  'cania-sericea': 'chiasmia-eleonora',
#  'cania-spp': 'cyana-spp',
#  'canucha-specularis': 'scopula-fibulata',
#  'carea-angulata': 'Miltochrista-spp',
#  'carea-varipes': 'plusiodonta-coelonota',
#  'casama-vilis': 'campylotes-desgodinsi',
#  'cassephyra-cyanosticta': 'psimada-quadripennis',
#  'catoria-sublavaria': 'erebus-hieroglyphica',
#  'cechenena-helops': 'cechetra-minor',
#  'celenna-festivaria': 'eucyclodes-picturata',
#  'celerena-divisa': 'dysphania-percota',
#  'cephonodes-hylas': 'cephonodes-picus',
#  'cephonodes-spp': 'trabala-viridana',
#  'cerberonoton-rubescens': 'rhagastis-albomarginatus',
#  'cerynea-punctilinealis': 'eressa-aperiens',
#  'cerynea-spp': 'idaea-amplipennis',
#  'chabula-acamasalis': 'nausinoe-geometralis',
#  'chabula-telphusalis': 'agrioglypta-itysalis',
#  'chabulina-onychinalis': 'traminda-mundissima',
#  'chadisra-bipars': 'acontia-nitidula',
#  'chalcidica-minea': 'amata-passalis',
#  'chalciope-mygdon': 'parapoynx-stagnalis',
#  'chalcoscelides-castaneipars': 'ischnurges-luteomarginalis',
#  'chamaita-nympha': 'arctornis-spp',
#  'chandica-quadripennis': 'eudocima-phalonia',
#  'chasmina-candida': 'Pantura-rufifrons',
#  'chasmina-judicata': 'barsine-roseata',
#  'chasmina-spp': 'arctornis-spp',
#  'cheromettia-apicata': 'areas-galactina',
#  'chiasmia-eleonora': 'stauroplitis-apicalis',
#  'chiasmia-emersaria': 'hyposidra-talaca',
#  'chiasmia-fidoniata': 'acontia-marmoralis',
#  'chiasmia-nora': 'chiasmia-spp',
#  'chiasmia-spp': 'Petelia-riobearia',
#  'chiasmia-xanthonora': 'photoscotosia-spp',
#  'chilena-similis': 'mocis-frugalis',
#  'chilkasa-falcata': 'eupterote-spp',
#  'chloroglyphica-variegata': 'hemonia-rotundata',
#  'chlororithra-fea': 'utetheisa-spp',
#  'chlumetia-spp': 'alcis-variegata',
#  'choreutis-spp': 'endotricha-spp',
#  'chorodna-fulgurita': 'chiasmia-eleonora',
#  'chorodna-metaphaearia': 'barsine-roseata',
#  'chorodna-moorei': 'lymantria-plumbalis',
#  'chorodna-spp': 'Pagyda-lustralis',
#  'chorodna-strixaria': 'menophra-translineata',
#  'chorsia-albiscripta': 'exsula-victrix',
#  'chorsia-mollicula': 'alcis-variegata',
#  'chrysodeixis-eriosoma': 'antheraea-paphia',
#  'chrysodeixis-spp': 'acherontia-lachesis',
#  'chrysopera-combinans': 'artona-quadrimaculata',
#  'chrysorabdia-viridata': 'acherontia-lachesis',
#  'churinga-rufifrons': 'ammatho-spp',
#  'cidariini-genera-spp': 'lithosiini-genera-spp',
#  'cirrhochrista-brizoalis': 'lepidoptera-0',
#  'cirrhochrista-fumipalpis': 'cirrhochrista-brizoalis',
#  'cirrhochrista-pulchellalis': 'cirrhochrista-semibrunnea',
#  'cispia-punctifascia': 'crinocraspeda-torrida',
#  'cladarctia-quadriramosa': 'areas-galactina',
#  'clanidopsis-exusta': 'stenoloba-glaucescens',
#  'clanis-bilineata': 'ophthalmitis-xanthypochlora',
#  'clanis-phalaris': 'thyas-coronata',
#  'cleora-fraterna': 'cleora-spp',
#  'cleora-spp': 'clethrophora-gonophora',
#  'clostera-pallida': 'fodina-stola',
#  'clostera-restitura': 'cyana-divakara',
#  'clostera-spp': 'Sarbanissa-spp',
#  'cnaphalocrocis-medinalis': 'cnaphalocrocis-trebiusalis',
#  'cnaphalocrocis-patnalis': 'cnaphalocrocis-medinalis',
#  'cnaphalocrocis-rutilalis': 'heterostegane-tritocampsis',
#  'cnaphalocrocis-spp': 'herpetogramma-spp',
#  'comibaena-albimarginata': 'varmina-indica',
#  'comibaena-attenuata': 'argyrocosma-inductaria',
#  'comibaena-cassidara': 'argyrocosma-inductaria',
#  'comibaena-fuscidorsata': 'comibaena-cassidara',
#  'comibaena-integranota': 'argyrocosma-inductaria',
#  'comibaena-spp': 'erpis-macularis',
#  'comibaena-striataria': 'traminda-mundissima',
#  'comibaenini-genera-spp': 'geometrinae-genera-spp',
#  'comostola-chlorargyra': 'achrosis-incitata-complex',
#  'comostola-inops': 'traminda-mundissima',
#  'comostola-laesaria': 'comostola-spp',
#  'comostola-spp': 'lissoblemma-lunuliferata',
#  'comostola-turgescens': 'comostola-pyrrhogona',
#  'comparmustilia-sphingiformis': 'trigonodes-hyppasia',
#  'condica-spp': 'elophila-spp',
#  'conogethes-punctiferalis': 'cnaphalocrocis-spp',
#  'conogethes-spp': 'Miltochrista-spp',
#  'conservula-indica': 'nordstromia-bicostata',
#  'coptobasis-spp': 'hyles-gallii',
#  'coremecis-nigrovittata': 'boarmiini-genera-spp',
#  'corgatha-costipicta': 'rhimphalea-trogusalis',
#  'corgatha-dictaria': 'attonda-adspersa',
#  'corymica-deducta': 'antheraea-paphia',
#  'corymica-spp': 'eupterote-spp',
#  'cosmia-restituta': 'chalcoscelides-castaneipars',
#  'cotachena-pubescens': 'hydriris-ornatalis',
#  'cotachena-spp': 'crambidae-genera-spp',
#  'crambidae-genera-spp': 'sterrhinae-genera-spp',
#  'crambinae-genera-spp': 'notodontidae-genera-spp',
#  'creatonotos-transiens': 'areas-galactina',
#  'cricula-agria': 'artena-dotata',
#  'cricula-andrei': 'pyrrhia-umbra',
#  'cricula-trifenestrata': 'antheraea-helferi',
#  'crithote-spp': 'artaxa-spp',
#  'crocidolomia-pavonana': 'acontia-marmoralis',
#  'crocidophora-fasciata': 'parotis-spp',
#  'cruxoruza-decorata': None,
#  'cruxoruza-reticulata': 'bradina-diagonalis',
#  'cryptophlebia-ombrodelta': 'spodoptera-litura',
#  'ctenoplusia-albostriata': 'lymantria-plumbalis',
#  'culasta-indecisa': 'epiparbattia-gloriosalis',
#  'curoba-sangarida': 'egnasia-accingalis',
#  'cusiala-boarmoides': 'hypomecis-transcissa',
#  'cyana-adita': 'cyana-spp',
#  'cyana-arama': 'aloa-lactinea',
#  'cyana-coccinea': 'cyana-bellissima',
#  'cyana-detrita': 'demonarosa-rufotessellata',
#  'cyana-dudgeoni': 'lepidoptera-0',
#  'cyana-gelida': 'asota-ficus',
#  'cyana-perornata': 'cyana-bellissima',
#  'cyana-puella': 'cyana-spp',
#  'cyana-spp': 'agathia-spp',
#  'cyclidia-rectificata': 'cyclidia-substigmaria',
#  'cyclidia-substigmaria': 'ozarba-mallarba',
#  'cyclosia-latipennis': 'lymantria-concolor',
#  'cyclosia-panthona': 'hyposidra-talaca',
#  'cyclosia-papilionaris': 'dysphania-percota',
#  'cydalima-laticostalis': 'rhodoprasina-floralis',
#  'cydalima-spp': 'cymatophoropsis-sinuata',
#  'cynaeda-dichroalis': 'panilla-dispila',
#  'cypa-enodis': 'achaea-janata',
#  'daddala-lucilla-complex': 'psilotagma-pictaria',
#  'dalima-metachromata': 'chorodna-moorei',
#  'dalima-schistacearia': 'traminda-mundissima',
#  'daphnis-nerii': 'eurrhyparodes-bracteolalis',
#  'daplasa-postincisa': 'Eupterote-primularis',
#  'dasyboarmia-spp': 'Darisa-lampasaria',
#  'decetia-subobscurata': 'traminda-mundissima',
#  'degia-spp': 'athetis-spp',
#  'deilephila-rivularis': 'ambulyx-ochracea',
#  'derambila-dentifera': 'parasa-darma',
#  'derambila-spp': 'arctornis-spp',
#  'deroca-inconclusa': 'attacus-taprobanis',
#  'diaphania-indica': 'theretra-lucasii',
#  'diasemia-accalis': 'eurrhyparodes-tricoloralis',
#  'diasemia-spp': 'elophila-spp',
#  'diasemiopsis-ramburialis': 'panilla-dispila',
#  'dichocrocis-definita': 'herpetogramma-phaeopteralis',
#  'dichocrocis-rigidalis': 'synclera-tibialis',
#  'dichocrocis-zebralis': 'nevrina-procopia',
#  'dichromia-pullata': 'eudocima-spp',
#  'dichromia-quadralis': 'eudocima-phalonia',
#  'diduga-spp': 'trabala-spp',
#  'dierna-patibulum': 'achaea-janata',
#  'dierna-strigata': 'mocis-frugalis',
#  'digama-fasciata': 'calliteara-horsfieldii',
#  'digama-hearseyana': 'nordstromia-bicostata',
#  'digama-insulana': 'naxa-textilis',
#  'digama-marchalii': 'orvasca-subnotata',
#  'dindicodes-apicalis': 'biston-suppressaria',
#  'dindicodes-crocina': 'acherontia-lachesis',
#  'diomea-lignicolora': 'antheraea-paphia',
#  'discoglypha-aureifloris': 'chrysocraspeda-iole',
#  'dixoa-albatalis': 'trisula-variegata',
#  'dolbina-inexacta': 'hypeninae-genera-spp',
#  'dolbina-manjunatha': 'acherontia-lachesis',
#  'dolgoma-angulifera': 'barsine-roseata',
#  'doloessa-viridis': 'trabala-spp',
#  'dooabia-viridata': 'biston-suppressaria',
#  'drepana-dispilata': 'hyposidra-talaca',
#  'drepana-pallida': 'anticarsia-irrorata',
#  'dudua-aprobola': 'idaea-violacea',
#  'dudusa-sphingiformis': 'tasta-micaceata',
#  'dudusa-synopla': 'chrysopera-combinans',
#  'duomitus-ceramica': 'spodoptera-litura',
#  'dura-alba': 'pachynoa-spilosomoides-complex',
#  'dyrzela-plagiata': 'athetis-spp',
#  'dysaethria-quadricaudata': 'cnaphalocrocis-trebiusalis',
#  'dysallacta-negatalis': 'pygospila-tyres',
#  'dysgonia-latifascia': 'achaea-janata',
#  'dysgonia-torrida': 'spoladea-recurvalis',
#  'dysodia-spp': 'plecoptera-spp',
#  'dysphania-militaris': 'dysphania-percota',
#  'dysphania-nelera': 'lymantria-plumbalis',
#  'dysphania-palmyra': 'maruca-vitrata',
#  'earias-cupreoviridis': 'barsine-roseata',
#  'earias-flavida': 'spilarctia-spp',
#  'earias-insulana': 'ecliptopera-muscicolor',
#  'earias-spp': 'Ecpyrrhorrhoe-spp',
#  'earias-vittella': 'anomis-flava',
#  'ecliptopera-dissecta': 'panilla-dispila',
#  'ecliptopera-muscicolor': 'hypeninae-genera-spp',
#  'ecliptopera-rectilinea': 'elophila-spp',
#  'ecliptopera-substituta': 'ecliptopera-triangulifera',
#  'ecliptopera-triangulifera': 'cerynea-igniaria',
#  'ectropidia-shoreae': 'elophila-spp',
#  'ectropis-spp': 'chiasmia-spp',
#  'edosa-spp': 'archips-spp',
#  'egens-egens': 'asota-ficus',
#  'egnasia-ephyrodalis': 'exelastis-atomosa',
#  'elcysma-ziroensis': 'calliteara-horsfieldii',
#  'elibia-dolichoides': 'marumba-dyras',
#  'eligma-narcissus': 'dysphania-percota',
#  'elophila-scitalis': 'idaea-amplipennis',
#  'elophila-spp': 'pygospila-tyres',
#  'elusa-spp': 'athetis-spp',
#  'endoclita-malabaricus': 'eudocima-salaminia',
#  'endoclita-spp': 'blasticorhinus-varius',
#  'endocrossis-flavibasalis': 'cidariini-genera-spp',
#  'endotricha-ruminalis': 'areas-galactina',
#  'endotricha-spp': 'pyrausta-spp',
#  'enispa-elataria': 'archips-spp',
#  'enispa-rosellaria': 'stenoloba-glaucescens',
#  'enispa-rosellus': 'conolophia-nigripuncta',
#  'ennominae-genera-spp': 'noctuinae-genera-spp',
#  'entomogramma-fautrix': 'chiasmia-emersaria',
#  'entomopteryx-obliquilinea': 'antheraea-paphia',
#  'eois-dissimilis': 'idaea-spp',
#  'eoophyla-spp': 'barsine-roseata',
#  'epicopeia-polydora': 'nyctemera-hampsoni',
#  'epicrocis-oegnusalis': 'eudocima-phalonia',
#  'epicrocis-spp': 'lipomelia-subusta',
#  'epipagis-peritalis': 'elophila-spp',
#  'epiparbattia-gloriosalis': 'asura-miltochrista-group-spp',
#  'epipaschiinae-genera-spp': 'eupitheciini-genera-spp',
#  'epiplema-reticulata': 'amblychia-angeronaria',
#  'epiplema-ruptaria': 'parapoynx-stagnalis',
#  'epipleminae-genera-spp': 'herminiinae-genera-spp',
#  'episparis-costistriga': 'harutalcis-atrostipata',
#  'episparis-liturata': 'plusiodonta-coelonota',
#  'episparis-tortuosalis': 'stenoloba-glaucescens',
#  'episteme-adulatrix': 'dysphania-percota',
#  'ercheia-cyllaria': 'conogethes-punctiferalis',
#  'erebus-albicincta': 'hyposidra-talaca',
#  'erebus-caprimulgus': 'chiasmia-spp',
#  'erebus-gemmans': 'erebus-macrops',
#  'erebus-hieroglyphica': 'pitama-spp',
#  'erebus-macrops': 'olepa-ricini',
#  'eressa-confinis': 'amata-cyssea',
#  'eressa-multigutta': 'amata-cyssea',
#  'eretmocera-impactella': 'eurrhyparodes-bracteolalis',
#  'ericeia-inangulata': 'helicoverpa-armigera',
#  'ericeia-spp': 'chiasmia-spp',
#  'eriocottidae-genera-spp': 'eupitheciini-genera-spp',
#  'ernolatia-moorei': 'palpifer-sexnotatus',
#  'etanna-breviuscula': 'spoladea-recurvalis',
#  'eterusia-aedea': 'eudocima-hypermnestra',
#  'ethmia-spp': 'chrysorabdia-bivitta',
#  'etiella-zinckenella': 'theretra-lucasii',
#  'eublemma-abrupta': 'Pingasa-rubicunda',
#  'eublemma-accedens': 'comibaenini-genera-spp',
#  'eublemma-baccalix': 'saptha-cypridia',
#  'eublemma-quadrapex': 'teulisna-tumida',
#  'eublemma-rivula': 'Athetis-bremusa',
#  'eublemma-roseana': 'creatonotos-transiens',
#  'eublemma-scitula': 'macroglossum-sitiene',
#  'eublemma-spp': 'barsine-roseata',
#  'euchromia-polymena': 'linguisaccus-subhyalina',
#  'euchromius-ocellea': 'eugnathia-pictipennis',
#  'euclasta-spp': 'archips-spp',
#  'eucyclodes-discipennata': 'patania-caletoralis',
#  'eucyclodes-divapala-complex': 'nola-internella-analis-complex',
#  'eucyclodes-gavissima': 'orthospila-tigrina',
#  'eucyclodes-picturata': 'maruca-vitrata',
#  'eucyclodes-sanguilineata': 'agathia-incudaria',
#  'eucyclodes-semialba': 'trigonodes-hyppasia',
#  'eucyclodes-textilis': 'autocharis-amethystina',
#  'eudocima-cajeta': 'acherontia-styx',
#  'eudocima-homaena': 'Tarsolepis-malayana',
#  'eudocima-hypermnestra': 'xandrames-latiferaria',
#  'eudocima-materna': 'ataboruza-stragulata',
#  'eudocima-phalonia': 'stenoloba-glaucescens',
#  'eudocima-salaminia': 'traminda-mundissima',
#  'eudocima-sikhimensis': 'eudocima-spp',
#  'eudocima-spp': 'achaea-janata',
#  'eulocastra-argentifrons': 'creatonotos-transiens',
#  'eumelea-atomata': 'eumelea-ludovicata',
#  'eumelea-ludovicata': 'panilla-dispila',
#  'eumelea-spp': 'exelastis-atomosa',
#  'eumeta-variegata': 'amata-sperbius',
#  'eupanacra-mydon': 'acherontia-lachesis',
#  'eupitheciini-genera-spp': 'crambidae-genera-spp',
#  'euproctis-leithiana': 'naxa-textilis',
#  'euproctis-lunata': 'spilarctia-spp',
#  'euproctis-madana': 'lymantria-detersa',
#  'euproctis-plagiata': 'stenoloba-glaucescens',
#  'euproctis-varia': 'ozarba-spp',
#  'eupterote-gardneri': 'traminda-mundissima',
#  'eupterote-spp': 'idaea-amplipennis',
#  'eupterote-undata': 'tridrepana-fulvata',
#  'eurrhyparodes-tricoloralis': 'conolophia-nigripuncta',
#  'eustroma-inextricata': 'synclera-traducalis',
#  'eustrotia-marginata': 'Ecpyrrhorrhoe-spp',
#  'euteliidae-genera-spp': 'cidariini-genera-spp',
#  'euthrix-decisa': 'artena-dotata',
#  'euthrix-laeta': 'achaea-janata',
#  'evergestis-forficalis': 'pyrausta-phoenicealis',
#  'evonima-plagiola': 'duomitus-ceramica',
#  'exelastis-atomosa': 'parapoynx-stagnalis',
#  'exsula-victrix': 'daplasa-postincisa',
#  'fascellina-chromataria': 'fascellina-rectimarginata',
#  'fascellina-plagiata': 'areas-galactina',
#  'filodes-fulvidorsalis': 'stauroplitis-apicalis',
#  'fodina-pallula': 'eressa-spp',
#  'formofentonia-orbifer': 'pyrausta-phoenicealis',
#  'fossia-punicea': 'nepita-conferta',
#  'gabala-argentata': 'campylotes-desgodinsi',
#  'gangarides-rufinus': 'cyclosia-midamia',
#  'gangarides-vittipalpis': 'argonestis-flammans',
#  'ganisa-spp': 'banisia-spp',
#  'garaeus-apicata': 'nacoleia-spp',
#  'garaeus-specularis': 'attacus-taprobanis',
#  'gasterocome-pannosaria': 'mellea-taeniata',
#  'gastropacha-spp': 'nolinae-genera-spp',
#  'gaurena-florens': 'omiodes-milvinalis',
#  'gaurena-florescens': 'areas-galactina',
#  'gazalina-apsara': 'chiasmia-emersaria',
#  'gazalina-chrysolopha': 'bombycinae-genera-spp',
#  'geometra-flavifrontaria': 'comibaenini-genera-spp',
#  'geometrinae-genera-spp': 'crambinae-genera-spp',
#  'gesonia-spp': 'Ecpyrrhorrhoe-spp',
#  'ginshachia-gemmifera': 'eurrhyparodes-tricoloralis',
#  'glanycus-insolitus': 'exelastis-atomosa',
#  'glauconoe-deductalis': 'parapoynx-stagnalis',
#  'glycythyma-chrysorycta': 'areas-galactina',
#  'glyphodes-actorionalis': 'areas-galactina',
#  'glyphodes-bicolor': 'pingasa-ruginaria',
#  'glyphodes-bivitralis': 'acherontia-lachesis',
#  'glyphodes-caesalis': 'helicoverpa-armigera',
#  'glyphodes-canthusalis': 'mellea-taeniata',
#  'glyphodes-crithealis': 'phyllodes-eyndhovii',
#  'glyphodes-minimalis': 'glyphodes-bivitralis',
#  'glyphodes-pyloalis-complex': 'Ptyomaxia-syntaractis',
#  'glyphodes-spp': 'rhodophaea-actiosella',
#  'glyphodes-stolalis': 'analyta-diaphana',
#  'gnophos-spp': 'petelia-spp',
#  'goniocraspedon-mistura': 'artona-quadrimaculata',
#  'goniorhynchus-gratalis': 'liparopsis-postalbida',
#  'gonodontis-clelia': 'Sesapa-dentifascia',
#  'gonodontis-spp': 'chiasmia-spp',
#  'grammodes-geometrica': 'areas-galactina',
#  'gunda-ochracea': 'omiodes-milvinalis',
#  'gynautocera-papilionaria': 'rivula-basalis',
#  'hadennia-spp': 'condica-spp',
#  'hamodes-propitia': 'harutalcis-atrostipata',
#  'haritalodes-derogata': 'ecliptopera-triangulifera',
#  'harutalcis-vialis': 'bocana-manifestalis',
#  'hastina-caeruleolineata': 'hyposidra-talaca',
#  'hastina-pluristrigata': 'Sasunaga-tenebrosa',
#  'helicoverpa-armigera': 'cnaphalocrocis-medinalis',
#  'heliothis-peltigera': 'hyperythra-lutea',
#  'hellula-undalis': 'achaea-janata',
#  'hemichloridia-euprepia': 'patania-caletoralis',
#  'hemiscopis-suffusalis': 'eressa-aperiens',
#  'hemithea-spp': 'parotis-spp',
#  'hendecasis-duplifascialis': 'macroglossum-sitiene',
#  'heortia-vitessoides': 'panilla-dispila',
#  'herdonia-thaiensis': 'dindicodes-apicalis',
#  'herminiinae-genera-spp': 'crambinae-genera-spp',
#  'herochroma-ochreipicta': 'traminda-mundissima',
#  'herochroma-spp': 'somera-viridifusca',
#  'herpetogramma-basalis': 'platycerota-homoema',
#  'herpetogramma-cynaralis': 'hypolamprus-angulalis',
#  'herpetogramma-licarsisalis': 'chrysocraspeda-faganaria',
#  'herpetogramma-spp': 'nygmiini-genera-spp',
#  'hesudra-divisa': 'attatha-ino',
#  'heterolocha-falconaria': 'lymantria-grandis',
#  'heterostegane-spp': 'barsine-group-spp',
#  'heterostegane-tritocampsis': 'Microcalicha-melanosticta',
#  'heterostegane-urbica': 'heterostegane-subtessellata',
#  'heterothera-consimilis': 'xandrames-dholaria',
#  'heterothera-spp': 'pyrausta-spp',
#  'himala-argentea': 'spirama-spp',
#  'hindothosea-cervina': 'barsine-roseata',
#  'hipoepa-biasalis': 'achaea-janata',
#  'hipoepa-fractalis': 'dysgonia-latifascia',
#  'hippotion-celerio': 'macroglossum-sitiene',
#  'hippotion-rosetta': 'theretra-lucasii',
#  'hippotion-spp': 'Rivula-curvifera',
#  'histia-flabellicornis': 'chiasmia-spp',
#  'hodebertia-testalis': 'bradina-diagonalis',
#  'holocryptis-erubescens': 'risoba-obstructa',
#  'homaea-clathrum': 'alcis-variegata',
#  'homodes-spp': 'archips-spp',
#  'homona-spp': 'archips-spp',
#  'hulodes-caranea': 'artena-dotata',
#  'hyalobathra-coenostolalis': 'lobogonodes-multistriata',
#  'hyalobathra-miniosalis': 'loboschiza-koenigiana',
#  'hyblaea-puera-complex': 'eustroma-aurigena',
#  'hydatocapnia-spp': 'heterostegane-spp',
#  'hydrelia-ornata': 'antheraea-paphia',
#  'hydrillodes-spp': 'crambinae-genera-spp',
#  'hydriris-ornatalis': 'eressa-aperiens',
#  'hydrorybina-polusalis': 'mocis-frugalis',
#  'hymenoptychis-sordida': 'crocidolomia-pavonana',
#  'hypena-conscitalis': 'omiodes-milvinalis',
#  'hypena-laceratalis': 'cechenena-helops',
#  'hypena-obacerralis': 'nordstromia-bicostata',
#  'hypeninae-genera-spp': 'noctuinae-genera-spp',
#  'hypersypnoides-constellata': 'mellea-taeniata',
#  'hypertrocta-posticalis': 'acherontia-lachesis',
#  'hyperythra-lutea': 'eupterote-spp',
#  'hypocala-deflorata': 'leucinodella-leucostola',
#  'hypocala-subsatura': 'egnasia-ephyrodalis',
#  'hypochrosis-flavifusata': 'antheraea-paphia',
#  'hypochrosis-hyadaria-complex': 'hyblaea-puera-complex',
#  'hypochrosis-iris': 'pseudozarba-spp',
#  'hypolamprus-angulalis': 'entomogramma-mediocris',
#  'hypolamprus-spp': 'pyralis-manihotalis',
#  'hypomecis-cineracea': 'creatonotos-transiens',
#  'hypomecis-separata': 'ectropis-spp',
#  'hypomecis-spp': 'idaea-violacea',
#  'hypomecis-transcissa': 'acontia-marmoralis',
#  'hypopyra-meridionalis': 'traminda-mundissima',
#  'hypopyra-spp': 'calesia-stillifera',
#  'hyposada-hydrocampata': 'polydesma-boarmoides',
#  'hyposidra-aquilaria': 'erebus-hieroglyphica',
#  'hyposidra-infixaria': 'erebus-hieroglyphica',
#  'hyposidra-spp': 'artena-dotata',
#  'hyposidra-talaca': 'eudocima-spp',
#  'hyposidra-violescens': 'stenoloba-glaucescens',
#  'hypospila-bolinoides': 'eterusia-raja',
#  'hypsopygia-nigrivitta': 'marasmia-poeyalis',
#  'hypsopygia-spp': 'endotricha-spp',
#  'hysterura-multifaria': 'paralbara-perhamata',
#  'idaea-amplipennis': 'Luxiaria-hypaphanes',
#  'idaea-craspedota': 'drepanidae-genera-spp',
#  'idaea-gemmaria': 'conolophia-nigripuncta',
#  'idaea-spp': 'petelia-spp',
#  'idaea-vacillata': 'psilogramma-discistriga',
#  'idiochlora-spp': 'Ecpyrrhorrhoe-spp',
#  'ilema-chloroptera': 'olepa-ricini',
#  'imma-mylias': 'archips-spp',
#  'immidae-genera-spp': 'areas-galactina',
#  'indarbela-tetraonis': 'nausinoe-geometralis',
#  'iotaphora-iridicolor': 'barsine-roseata',
#  'iragoides-crispa': 'dysgonia-latifascia',
#  'iridoplecta-ferrifera': 'scopula-pulchellata',
#  'ischnurges-luteomarginalis': 'chrysocraspeda-faganaria',
#  'ischyja-manlia': 'mocis-frugalis',
#  'ischyja-spp': 'banisia-spp',
#  'isocentris-filalis': 'trabala-vishnou',
#  'isturgia-disputaria': 'lymantria-plumbalis',
#  'isturgia-spp': 'naarda-spp',
#  'janseodes-melanospila': 'areas-galactina',
#  'jodis-spp': 'alcis-spp',
#  'juxtarctia-multiguttata': 'areas-galactina',
#  'karana-gemmifera': 'pygospila-tyres',
#  'krananda-semihyalina': 'Luxiaria-hypaphanes',
#  'labdia-spp': 'archips-spp',
#  'lacera-procellosa': 'hyposidra-talaca',
#  'laciniodes-plurilinearia': 'chiasmia-fidoniata',
#  'laelia-exclamationis': 'Ecpyrrhorrhoe-spp',
#  'lamoria-spp': 'archips-spp',
#  'lamprosema-tampiusalis': 'cnaphalocrocis-trebiusalis',
#  'langia-zenzeroides': 'nola-internella-analis-complex',
#  'lantanophaga-pusillidactylus': 'nola-internella-analis-complex',
#  'larentiinae-genera-spp': 'eupitheciini-genera-spp',
#  'lasiocampidae-genera-spp': 'asura-miltochrista-group-spp',
#  'laspeyria-viridicincta': 'Luxiaria-hypaphanes',
#  'lassaba-albidaria': 'antipercnia-belluaria',
#  'lebeda-nobilis': 'achaea-janata',
#  'lecithoceridae-genera-spp': 'pterophoridae-genera-spp',
#  'leucania-loreyi': 'spodoptera-litura',
#  'leucania-spp': 'scopula-spp',
#  'leucania-yu': 'amyna-spp',
#  'leucinodes-orbonalis': 'olepa-ricini',
#  'leucoma-clara': 'arctornis-spp',
#  'leucostola-argyrosticta': 'agrioglypta-eurytusalis',
#  'limacodinae-genera-spp': 'pterophoridae-genera-spp',
#  'liparopsis-postalbida': 'Macrobrochis-flavicincta',
#  'lipomelia-subusta': 'eurrhyparodes-tricoloralis',
#  'lista-spp': 'crocidolomia-luteolalis',
#  'lithosiini-genera-spp': 'nygmiini-genera-spp',
#  'loboschiza-spp': 'nepita-conferta',
#  'locastra-muscosalis': 'lymantria-plumbalis',
#  'loepa-spp': 'longipennis-longipennis',
#  'lophophelma-erionoma': 'boarmiini-genera-spp',
#  'lophophelma-iterans': 'cyclodes-omma',
#  'lophophleps-purpurea': 'chrysocraspeda-iole',
#  'lophoptera-illucida': 'acantholipes-trajecta',
#  'lophoptera-spp': 'paralbara-perhamata',
#  'lophosoma-cuprea': 'daphnis-nerii',
#  'luxiaria-emphatica': 'Luxiaria-hypaphanes',
#  'luxiaria-phyllosaria': 'Luxiaria-hypaphanes',
#  'luxiaria-spp': 'chiasmia-spp',
#  'lygniodes-hypoleuca': 'habrosyne-spp',
#  'lygropia-distorta': 'arichanna-spp',
#  'lymantria-ampla': 'panilla-dispila',
#  'lymantria-aryama': 'acherontia-styx',
#  'lymantria-bivittata': 'omiodes-milvinalis',
#  'lymantria-concolor': 'asota-heliconia',
#  'lymantria-detersa': 'callopistria-spp',
#  'lymantria-fuliginosa': 'lymantria-concolor',
#  'lymantria-grandis': 'heterolocha-falconaria',
#  'lymantria-incerta': 'panilla-dispila',
#  'lymantria-lepcha': 'lymantria-todara',
#  'lymantria-marginata': 'pyralis-manihotalis',
#  'lymantria-mathura': 'manulea-spp',
#  'lymantria-semicincta': 'psilogramma-vates',
#  'lymantria-serva': 'acherontia-styx',
#  'lymantria-similis': 'lymantria-todara',
#  'lymantria-spp': 'asota-caricae',
#  'lymantria-todara': 'nycteola-spp',
#  'lyssa-zampa': 'spirama-spp',
#  'macariini-genera-spp': 'boarmiini-genera-spp',
#  'maceda-mansueta': 'nola-taeniata',
#  'macohasa-orientalis': 'naxa-textilis',
#  'macotasa-nubecula': 'creatonotos-transiens',
#  'macrauzata-fenestraria': 'macrobrochis-prasena',
#  'macrobrochis-albifascia': 'nannoarctia-dentata',
#  'macrobrochis-gigas': 'eudocima-salaminia',
#  'macrobrochis-pallens': 'lipomelia-subusta',
#  'macrobrochis-prasena': 'areas-galactina',
#  'macroglossum-belis': 'ambulyx-moorei',
#  'macroglossum-bombylans': 'macroglossum-sitiene',
#  'macroglossum-corythus': 'photoscotosia-spp',
#  'macroglossum-gyrans': 'areas-galactina',
#  'macroglossum-particolor': 'hydrelia-bicolorata',
#  'macroglossum-sitiene': 'creatonotos-transiens',
#  'macroglossum-spp': 'stenoloba-glaucescens',
#  'mahanta-quadrilinea': 'garaeus-apicata',
#  'maliattha-fervens': 'Sesapa-dentifascia',
#  'maliattha-lativitta': 'pitama-spp',
#  'maliattha-quadripartita': 'eucyclodes-picturata',
#  'maliattha-ruptifascia': 'agrioglypta-eurytusalis',
#  'maliattha-separata': 'parapoynx-stagnalis',
#  'maliattha-signifera': 'spodoptera-litura',
#  'mangina-argus': 'leucania-spp',
#  'mangina-syringa': 'digama-marchalii',
#  'manulea-spp': 'achaea-serva',
#  'marasmia-poeyalis': 'parapoynx-stagnalis',
#  'marasmia-trapezalis': 'traminda-mundissima',
#  'maruca-amboinalis': 'hyperlopha-cristifera',
#  'maruca-vitrata': 'spoladea-recurvalis',
#  'marumba-cristata': 'eudocima-spp',
#  'marumba-dyras': 'artena-dotata',
#  'marumba-irata': 'ambulyx-moorei',
#  'marumba-nympha': 'Ecpyrrhorrhoe-spp',
#  'marumba-spectabilis': 'callambulyx-rubricosa',
#  'maurilia-iconica': 'theretra-lucasii',
#  'maxates-spp': 'luxiaria-spp',
#  'maxates-thetydaria': 'heterolocha-falconaria',
#  'maxates-veninotata': 'hemithea-spp',
#  'mecodina-albodentata': 'patania-caletoralis',
#  'mecodina-diastriga': 'erebus-hieroglyphica',
#  'megacorma-obliqua': 'lymantria-mathura',
#  'meganola-nitida': 'calliteara-horsfieldii',
#  'meganola-tomkovichi': 'acantholipes-trajecta',
#  'melanthia-catenaria': 'lymantria-mathura',
#  'melinaria-pseudorepanda': 'elophila-spp',
#  'melittia-spp': 'antitrisuloides-catocalina',
#  'mellea-taeniata': 'Microselene-mesostipa',
#  'menophra-decorata': 'bivincula-kalikotei',
#  'meroctena-tullalis': 'patania-scinisalis',
#  'mesoleuca-costipannaria': 'endotricha-mesenterialis',
#  'mesoptila-melanolopha': 'parapoynx-fluctuosalis',
#  'metallolophia-opalina': 'chiasmia-emersaria',
#  'metallolophia-taleensis': 'fascellina-porphyreofusa',
#  'metanastria-hyrtaca': 'erebus-glaucopis',
#  'metanastria-spp': 'achaea-janata',
#  'metapercnia-ductaria': 'antipercnia-belluaria',
#  'metoeca-foedalis': 'stenoloba-glaucescens',
#  'microblepsis-leucosticta': 'thysanoptyx-sordida',
#  'microblepsis-violacea': 'creatonotos-transiens',
#  'microloxia-indecretata': 'traminda-mundissima',
#  'micromelalopha-spp': 'nolinae-genera-spp',
#  'micronia-aculeata': 'milleria-adalifa',
#  'microxyla-stipata': 'olepa-ricini',
#  'miltochrista-dharma': 'areas-galactina',
#  'miltochrista-obsoleta': 'conogethes-spp',
#  'miltochrista-semifascia': 'miltochrista-obsoleta',
#  'miltochrista-undulata': 'endocrossis-flavibasalis',
#  'miltochrista-undulosa': 'miltochrista-obsoleta',
#  'mimomiza-cruentaria': 'sinobirma-bouyeri',
#  'miresa-bracteata': 'miresa-spp',
#  'miresa-spp': 'brunia-antica',
#  'mocis-discios': 'mocis-frugalis',
#  'mocis-frugalis': 'achaea-janata',
#  'mocis-undata': 'daphnis-nerii',
#  'monocerotesa-connexa': 'cnaphalocrocis-trebiusalis',
#  'monopis-spp': 'Sarbanissa-spp',
#  'mustilia-falcipennis': 'spaniocentra-spp',
#  'mustilizans-hepatica': 'eumelea-atomata',
#  'mythimna-separata': 'Ecpyrrhorrhoe-spp',
#  'naarda-spp': 'elophila-spp',
#  'nacna-malachitis': 'dysphania-percota',
#  'nagiella-quadrimaculalis': 'chrysocraspeda-faganaria',
#  'nannoarctia-dentata': 'marumba-irata',
#  'narosa-conspersa': 'conolophia-nigripuncta',
#  'narosa-spp': 'asota-ficus',
#  'nausinoe-geometralis': 'parapoynx-fluctuosalis',
#  'nausinoe-perspectata': 'pyralis-manihotalis',
#  'naxa-textilis': 'parapoynx-stagnalis',
#  'negeta-contrariata': 'achaea-janata',
#  'nemophora-scitulella': 'lobobasis-niveimaculata',
#  'neobotyodes-crocopteralis': 'stenoloba-glaucescens',
#  'neocerura-liturata': 'lymantria-todara',
#  'neochera-marmorea': 'macrobrochis-gigas',
#  'neodrymonia-elisabethae': 'fascellina-porphyreofusa',
#  'neogurelca-hyas': 'achaea-janata',
#  'neopheosia-fasciata': 'theretra-silhetensis',
#  'nephele-hespera': 'Ecpyrrhorrhoe-spp',
#  'nepita-conferta': 'amata-passalis',
#  'netria-spp': 'Ecpyrrhorrhoe-spp',
#  'netria-viridescens': 'asota-canaraica',
#  'nisaga-simplex': 'nygmia-icilia',
#  'noctuinae-genera-spp': 'crambinae-genera-spp',
#  'nola-internella-analis-complex': 'achrosis-incitata-complex',
#  'nola-lucidalis': 'siccia-spp',
#  'nolinae-genera-spp': 'stauroplitis-apicalis',
#  'nomophila-noctuella': 'analyta-diaphana',
#  'noorda-blitealis': 'idaea-violacea',
#  'noorda-spp': 'hippotion-spp',
#  'nordstromia-bicostata': 'achaea-janata',
#  'nosophora-spp': 'trachea-auriplena',
#  'notarcha-aurolinealis': 'Chalcosiopsis-variata',
#  'nothomiza-costalis': 'plutodes-costatus',
#  'notodontella-tenebrosa': 'creatonotos-transiens',
#  'notodontella-viridinota': 'ethmia-spp',
#  'notodontidae-genera-spp': 'eupitheciini-genera-spp',
#  'notonagemia-analis': 'nyctemera-adversata',
#  'nudaria-fasciata': 'aporodes-floralis',
#  'numenes-siletti': 'daphnis-nerii',
#  'nyctemera-adversata': 'pidorus-glaucopis',
#  'nyctemera-arctata': 'lymantria-plumbalis',
#  'nyctemera-carissima': 'asota-heliconia',
#  'nyctemera-coleta': 'nyctemera-adversata',
#  'nyctemera-lacticinia': 'agrioglypta-eurytusalis',
#  'nycteola-spp': 'comibaena-spp',
#  'nygmia-icilia': 'panilla-dispila',
#  'nygmia-plana': 'angonyx-krishna',
#  'nygmiini-genera-spp': 'boarmiini-genera-spp',
#  'nymphicula-blandialis': 'ethmia-spp',
#  'odonestis-bheroba': 'barsine-group-spp',
#  'odontodes-aleuca': 'theretra-suffusa',
#  'odontopera-bilinearia': 'hemaris-saundersii',
#  'oenospila-flavifusata': 'indarbela-tetraonis',
#  'oeonistis-entella': 'eusabena-miltochristalis',
#  'oeonistis-spp': 'antitrisuloides-catocalina',
#  'olene-mendosa': 'agrius-convolvuli',
#  'olepa-ricini': 'chiasmia-spp',
#  'omiodes-indicata': 'marasmia-poeyalis',
#  'omiodes-milvinalis': 'marasmia-poeyalis',
#  'omiodes-spp': 'eressa-spp',
#  'omiodes-surrectalis': 'Luxiaria-hypaphanes',
#  'omiza-miliaria': 'acolutha-spp',
#  'ommatophora-luminosa': 'chiasmia-spp',
#  'omphisa-anastomosalis': 'crocidolomia-pavonana',
#  'ophiusa-spp': 'artena-dotata',
#  'ophiusa-tirhaca': 'eupterote-spp',
#  'ophiusa-trapezium': 'pyralis-manihotalis',
#  'ophthalmitis-spp': 'cleora-fraterna',
#  'opisthograptis-moelleri': 'chiasmia-spp',
#  'oporophylla-ustulata': 'acosmeryx-pseudonaga',
#  'opsyra-chalcoela': 'idaea-macrospila',
#  'oraesia-argyrosigna': 'eudocima-spp',
#  'oraesia-emarginata': 'traminda-mundissima',
#  'oreta-extensa': 'orgyia-postica',
#  'oreta-griseotincta': 'achaea-serva',
#  'oreta-sanguinea': 'Lemaireia-himalayana',
#  'oreta-suffusa': 'pyrausta-phoenicealis',
#  'orgyia-postica': 'ornithospila-lineata',
#  'orgyiini-genera-spp': 'nolinae-genera-spp',
#  'orothalassodes-aptifimbria': 'hemonia-rotundata',
#  'orphanostigma-abruptalis': 'theretra-lucasii',
#  'orphnophanes-eucerusalis': 'chiasmia-spp',
#  'orthaga-exvinacea': 'attacus-taprobanis',
#  'orthonama-obstipata': 'glyphodes-canthusalis',
#  'ortopla-lindsayi': 'elophila-spp',
#  'orudiza-protheclaria': 'berta-spp',
#  'orvasca-subnotata': 'dysgonia-latifascia',
#  'orybina-flaviplaga': 'panilla-dispila',
#  'ourapteryx-marginata': 'lymantria-grandis',
#  'ovipennis-incompletostriga': 'macroglossum-sitiene',
#  'oxaenanus-brontesalis': 'Macrobrochis-flavicincta',
#  'oxymacaria-palliata': 'pyrausta-phoenicealis',
#  'oxymacaria-temeraria': 'nola-taeniata',
#  'oxyodes-scrobiculata': 'creatonotos-transiens',
#  'ozarba-punctigera': 'pyrausta-spp',
#  'ozarba-spp': 'archips-spp',
#  'ozola-falcipennis': 'lymantria-plumbalis',
#  'ozola-spp': 'athetis-spp',
#  'pachynoa-sabelialis': 'amata-elongata',
#  'pachyodes-haemataria': 'areas-galactina',
#  'padenia-spp': 'macroglossum-corythus',
#  'padenia-transversa': 'Miltochrista-spp',
#  'pagyda-auroralis': None,
#  'pagyda-salvalis': 'asota-caricae',
#  'palpita-annulifer-complex': 'callabraxas-amanda',
#  'palpita-spp': 'Ecpyrrhorrhoe-spp',
#  'pandesma-spp': 'ghoria-albocinerea',
#  'pangora-matherana': 'udea-renalis',
#  'pantydia-metaphaea': 'achaea-janata',
#  'pantydia-metaspila': 'hyposidra-talaca',
#  'paracymoriza-aurantialis': 'mellea-taeniata',
#  'paracymoriza-rivularis': 'chabulina-onychinalis',
#  'paracymoriza-vagalis': 'chabulina-tenera',
#  'paralbara-muscularia': 'Luxiaria-hypaphanes',
#  'paralebeda-plagifera': 'lymantria-mathura',
#  'parallelia-rigidistria-calefasciens-complex': 'creatonotos-gangis-interrupta-complex',
#  'parallelia-stuposa': 'pygospila-tyres',
#  'paramaxates-spp': 'herochroma-spp',
#  'parapholodes-fuliginea': 'scopula-fibulata',
#  'parapoynx-affinialis': 'parapoynx-fluctuosalis',
#  'parapoynx-crisonalis': 'parapoynx-fluctuosalis',
#  'parapoynx-diminutalis': 'nausinoe-geometralis',
#  'parapoynx-fluctuosalis': 'parapoynx-diminutalis',
#  'parapoynx-spp': 'lipomelia-subusta',
#  'parapoynx-stagnalis': 'barsine-roseata',
#  'parasa-lepida': 'parasynegia-pluristriaria',
#  'parasa-pastoralis': 'hypeninae-genera-spp',
#  'pardomima-amyntusalis': 'conogethes-punctiferalis',
#  'pareuchaetes-pseudoinsulata': 'ischnurges-luteomarginalis',
#  'parotis-marginata-complex': 'eurrhyparodes-bracteolalis',
#  'parotis-spp': 'agathia-spp',
#  'patania-balteata': 'archiplutodes-prasina',
#  'patania-iopasalis': 'asota-caricae',
#  'patania-obfuscalis': 'patania-scinisalis',
#  'patania-scinisalis': 'orvasca-subnotata',
#  'pelagodes-thalassodes-spp': 'lecithoceridae-genera-spp',
#  'penicillaria-jocosatrix': 'acosmeryx-pseudonaga',
#  'peratophyga-hyalinata': 'amblychia-angeronaria',
#  'perciana-marmorea': 'paralbara-perhamata',
#  'pergesa-acteus': 'antheraea-paphia',
#  'pericyma-albidens': 'namangana-cashmirensis',
#  'pericyma-cruegeri': 'eustroma-aurigena',
#  'pericyma-glaucinans': 'dysgonia-latifascia',
#  'pericyma-spp': 'alcis-spp',
#  'pericyma-umbrina': 'erebus-hieroglyphica',
#  'peridea-sikkima': 'squamosa-ocellata',
#  'perina-nuda': 'spoladea-recurvalis',
#  'perizoma-maculata': 'nyctemera-adversata',
#  'petavia-erycinoides': 'ochropleura-costalis',
#  'petelia-spp': 'stenopsestis-alternata',
#  'phalacra-vidhisara': 'hyposidra-talaca',
#  'phalera-spp': 'acherontia-styx',
#  'phalga-sinuosa': 'samea-castoralis',
#  'phauda-triadum': 'areas-galactina',
#  'phazaca-spp': 'idaea-spp',
#  'phazaca-theclata': 'Ecpyrrhorrhoe-spp',
#  'phlogophora-albovittata': 'areas-galactina',
#  'phocoderma-velutina': 'notonagemia-analis',
#  'photoscotosia-spp': 'stauroplitis-apicalis',
#  'phycitinae-genera-spp': 'noctuinae-genera-spp',
#  'phycodes-radiata': 'phyllodes-eyndhovii',
#  'phycodes-spp': 'pygospila-tyres',
#  'pida-apicalis': 'eurrhyparodes-bracteolalis',
#  'pida-patrana': 'spirama-spp',
#  'pida-spp': 'Ecpyrrhorrhoe-spp',
#  'pidorus-circe': 'banisia-spp',
#  'pidorus-glaucopis': 'thyas-coronata',
#  'piesmopoda-semilutea': 'areas-galactina',
#  'pindara-illibata': 'artena-dotata',
#  'pingasa-lariaria': 'barsine-roseata',
#  'pingasa-rufofasciata': 'leucania-spp',
#  'pingasa-ruginaria': 'chiasmia-emersaria',
#  'pingasa-spp': 'arctornis-spp',
#  'pitama-lativitta': 'nyctemera-coleta',
#  'pitama-spp': 'areas-galactina',
#  'platyjionia-mediorufa': 'Chalcosiopsis-variata',
#  'plecoptera-recta': 'stauroplitis-apicalis',
#  'plecoptera-spp': 'Rivula-curvifera',
#  'plusiinae-genera-spp': 'nygmiini-genera-spp',
#  'plusiodonta-coelonota': 'crocidolomia-spp',
#  'plusiopalpa-adrasta': 'acherontia-lachesis',
#  'plutella-xylostella': 'phyllodes-eyndhovii',
#  'plutodes-exquisita': 'zitha-spp',
#  'plutodes-flavescens': 'argonestis-flammans',
#  'plutodes-transmutata': 'antitrisuloides-catocalina',
#  'poaphilini-genera-spp': 'stenoloba-glaucescens',
#  'poliobotys-ablactalis': 'euclasta-spp',
#  'polydesma-boarmoides': 'boarmiini-genera-spp',
#  'polyptychus-trilineatus': 'achrosis-incitata-complex',
#  'polytela-gloriosae': 'dysphania-percota',
#  'polythlipta-divaricata': 'glyphodes-bivitralis',
#  'prionodonta-amethystina': 'Scopelodes-kwangtungensis',
#  'problepsis-deliaria': 'ptisciana-seminivea',
#  'problepsis-spp': 'chiasmia-spp',
#  'problepsis-vulgaris': 'scopula-pulchellata',
#  'progonia-oileusalis': 'Luxiaria-hypaphanes',
#  'prospalta-leucospila': 'paralbara-perhamata',
#  'protonoceras-capitalis': 'analyta-diaphana',
#  'protuliocnemis-biplagiata': 'achrosis-incitata-complex',
#  'protuliocnemis-partita': 'comibaena-attenuata',
#  'pseudoadites-frigida': 'pseudojana-incandescens',
#  'pseudoblabes-oophora': 'phyllodes-eyndhovii',
#  'pseudojana-incandescens': 'Macrobrochis-flavicincta',
#  'pseudomiza-leucogonia': 'pyrausta-phoenicealis',
#  'pseudozarba-spp': 'endotricha-spp',
#  'psilalcis-albibasis': 'chiasmia-fidoniata',
#  'psilalcis-breta': 'hypomecis-transcissa',
#  'psilalcis-pallidaria': 'cleora-fraterna',
#  'psilalcis-spp': 'cleora-spp',
#  'psilochira-lineata': 'psilogramma-vates',
#  'psilogramma-discistriga': 'lymantria-mathura',
#  'psilogramma-renneri': 'boarmiini-genera-spp',
#  'psilogramma-vates': 'leucophlebia-emittens',
#  'psimada-quadripennis': 'areas-galactina',
#  'pterocyclophora-pictimargo': 'ghoria-albocinerea',
#  'pterogonia-episcopalis': 'acosmeryx-pseudonaga',
#  'pterothysanus-laticilia': 'omiodes-milvinalis',
#  'ptisciana-seminivea': 'creatonotos-transiens',
#  'ptychopseustis-spp': 'nygmiini-genera-spp',
#  'pycnarmon-abraxalis': 'parapoynx-stagnalis',
#  'pycnarmon-cribrata': 'parapoynx-stagnalis',
#  'pycnarmon-jaguaralis': 'chabulina-tenera',
#  'pycnarmon-lactiferalis': 'egnasia-accingalis',
#  'pycnarmon-meritalis': 'chrysorabdia-viridata',
#  'pygospila-costiflexalis': 'pygospila-tyres',
#  'pyloetis-mimosae': 'Promalactis-spp',
#  'pyralidae-genera-spp': 'noctuinae-genera-spp',
#  'pyralis-fumipennis': 'cnaphalocrocis-spp',
#  'pyralis-manihotalis': 'spoladea-recurvalis',
#  'pyralis-pictalis': 'perina-nuda',
#  'pyrausta-phoenicealis': 'ischnurges-luteomarginalis',
#  'pyrausta-spp': 'amyna-spp',
#  'pyrosis-undulosa': 'acosmeryx-pseudonaga',
#  'pyrrhia-umbra': 'anomis-flava',
#  'rachia-striata': 'artena-dotata',
#  'radhica-rosea': 'aroa-spp',
#  'rajendra-biguttata': 'lymantria-plumbalis',
#  'ramadasa-pavo': 'thyas-coronata',
#  'ramila-acciusalis': 'autocharis-amethystina',
#  'ramila-spp': 'Ecpyrrhorrhoe-spp',
#  'raparna-ochreipennis': 'heterostegane-subtessellata',
#  'rectipalpula-billeti': 'sympis-rufibasis',
#  'rehimena-phrynealis': 'acantholipes-trajecta',
#  'relluna-nurella': 'spilarctia-spp',
#  'rhagastis-albomarginatus': 'creatonotos-gangis-interrupta-complex',
#  'rhagastis-castanea': 'acherontia-lachesis',
#  'rhagastis-castor': 'sesiidae-genera-spp',
#  'rhagastis-confusa': 'marumba-dyras',
#  'rhagastis-olivacea': 'dichocrocis-festivalis',
#  'rhagastis-velata': 'achaea-janata',
#  'rhagoba-octomaculalis': 'panilla-dispila',
#  'rhesala-spp': 'archips-spp',
#  'rhimphalea-ochalis': 'polythlipta-divaricata',
#  'rhimphalea-trogusalis': 'areas-galactina',
#  'rhodinia-newara': 'antheraea-paphia',
#  'rhodometra-sacraria': 'Ecpyrrhorrhoe-spp',
#  'rhodophaea-actiosella': 'anabasis-obliquifasciella',
#  'rhodostrophia-spp': 'barsine-roseata',
#  'rhombophylla-edentata': 'eressa-multigutta',
#  'rinaca-anna': 'achaea-janata',
#  'rinaca-cidosa': 'spirama-spp',
#  'rinaca-lindia': 'idaea-violacea',
#  'rinaca-simla': 'risoba-obstructa',
#  'risoba-obstructa': 'elophila-spp',
#  'risoba-repugnans': 'spoladea-recurvalis',
#  'rivula-spp': 'idaea-spp',
#  'rusicada-spp': 'plecoptera-spp',
#  'ruttellerona-spp': 'pyralis-manihotalis',
#  'sacada-spp': 'endoclita-spp',
#  'sagariphora-magnificalis': 'agathodes-ostentalis',
#  'samea-castoralis': 'marasmia-poeyalis',
#  'sameodes-cancellalis': 'nausinoe-geometralis',
#  'sameodes-pictalis': 'areas-galactina',
#  'samia-canningii': 'maruca-vitrata',
#  'sarbanissa-catacoloides': 'Sarbanissa-spp',
#  'sarbanissa-insocia': 'chalcoscelides-castaneipars',
#  'sarcinodes-restitutaria': 'pyralis-manihotalis',
#  'sarobela-litterata': 'spoladea-recurvalis',
#  'schistophleps-bipuncta': 'traminda-mundissima',
#  'schistophleps-spp': 'nolinae-genera-spp',
#  'scirpophaga-incertulas': 'psilogramma-vates',
#  'scirpophaga-spp': 'tridrepana-postica',
#  'scopelodes-sericea': 'Ecpyrrhorrhoe-spp',
#  'scopelodes-spp': 'disasuridia-spp',
#  'scopelodes-testacea': 'fascellina-porphyreofusa',
#  'scopula-divisaria': 'chiasmia-emersaria',
#  'scopula-emissaria': 'nola-taeniata',
#  'scopula-ferrilineata': 'areas-galactina',
#  'scopula-fibulata': 'cleora-fraterna',
#  'scopula-opicata': 'acropteris-iphiata',
#  'scopula-pedilata': 'achaea-janata',
#  'scopula-pulchellata': 'chiasmia-emersaria',
#  'scopula-spp': 'spilarctia-spp',
#  'scythropiodes-spp': 'nolinae-genera-spp',
#  'selepa-celtis': 'achaea-janata',
#  'selepa-spp': 'aquis-orbicularis',
#  'serrodes-partita': 'achaea-janata',
#  'sesiidae-genera-spp': 'areas-galactina',
#  'siccia-guttulosana': 'lymantria-todara',
#  'siccia-sagittifera': 'lymantria-todara',
#  'siccia-spotoptera': 'barsine-roseata',
#  'siccia-spp': 'Ecpyrrhorrhoe-spp',
#  'siccia-taprobanis': 'lymantria-todara',
#  'siccia-tenebrosa': 'elophila-spp',
#  'sidyma-apicalis': 'hyposidra-talaca',
#  'siglophora-sanguinolenta': 'hypolamprus-angulalis',
#  'simplicia-spp': 'syntypistis-pallidifascia',
#  'sinarella-discisigna': 'agrioglypta-zelimalis',
#  'singara-diversalis': 'pyralis-manihotalis',
#  'sinna-floralis': 'chiasmia-spp',
#  'sirinopteryx-rufivinctata': 'lymantria-grandis',
#  'smerinthus-kindermannii': 'chrysocraspeda-faganaria',
#  'somatina-omicraria': 'xandrames-dholaria',
#  'somena-scintillans': 'helicoverpa-armigera',
#  'somena-similis': 'panilla-dispila',
#  'soritia-pulchella': 'amata-passalis',
#  'spaniocentra-spp': 'pygospila-tyres',
#  'spataliini-genera-spp': 'lithosiini-genera-spp',
#  'speiredonia-obscura': 'areas-galactina',
#  'sphenarches-anisodactyla': 'cnaphalocrocis-trebiusalis',
#  'sphingomorpha-chlorea': 'cnaphalocrocis-medinalis',
#  'sphrageidus-spp': 'ghoria-albocinerea',
#  'spilarctia-comma': 'theretra-lucasii',
#  'spilarctia-spp': 'cnaphalocrocis-spp',
#  'spilosoma-spp': 'spilarctia-spp',
#  'spilosomina-genera-spp': 'lymantria-plumbalis',
#  'spirama-spp': 'elaphria-conjugata',
#  'spodoptera-exigua': 'chiasmia-emersaria',
#  'spodoptera-litura': 'plutella-xylostella',
#  'spodoptera-spp': 'erpis-macularis',
#  'spoladea-recurvalis': 'spodoptera-litura',
#  'squamosa-ocellata': 'creatonotos-transiens',
#  'stathmopoda-spp': 'phyllodes-eyndhovii',
#  'stathmopoda-theoris': 'orvasca-subnotata',
#  'stauropus-alternus': 'acherontia-lachesis',
#  'stauropus-spp': 'amata-sperbius',
#  'stauropus-thiaucourti': 'phyllodes-eyndhovii',
#  'sterrhinae-genera-spp': 'herminiinae-genera-spp',
#  'stictane-obliquilinea': 'parapoynx-stagnalis',
#  'stigmatophora-inanis': 'miltochrista-obsoleta',
#  'stigmatophora-palmata': 'areas-galactina',
#  'streblote-siva': 'samea-castoralis',
#  'striglina-scitaria': 'Heterolocha-spp',
#  'striglina-spp': 'amyna-spp',
#  'suana-concolor': 'pyrinioides-sinuosus',
#  'sufetula-spp': 'chiasmia-spp',
#  'suhela-alboflavalis': 'agrioglypta-itysalis',
#  'syllepte-bipartalis': 'epiplema-bicaudata',
#  'syllepte-gastralis': 'amata-cyssea',
#  'syllepte-nigriflava': 'thosea-magna',
#  'syllepte-sellalis': 'noorda-blitealis',
#  'syllepte-straminalis': 'pyralis-manihotalis',
#  'sympis-rufibasis': 'isocentris-filalis',
#  'synclera-spp': 'conogethes-spp',
#  'synclera-tibialis': 'panilla-dispila',
#  'synclera-traducalis': 'phyllodes-eyndhovii',
#  'synegiodes-histrionaria': 'amblychia-angeronaria',
#  'synegiodes-sanguinaria': 'chrysocraspeda-faganaria',
#  'syngamia-falsidicalis': 'hypomecis-fulvosparsa',
#  'syngamia-latimarginalis': 'hypertrocta-posticalis',
#  'syntomini-genera-spp': 'syntomoides-imaon',
#  'syntomoides-imaon': 'areas-galactina',
#  'syntypistis-spp': 'marumba-irata',
#  'sypnoides-cyanivitta': 'hyposidra-talaca',
#  'sypnoides-pannosa': 'achrosis-incitata-complex',
#  'talanga-sexpunctalis': 'autocharis-amethystina',
#  'tamba-spp': 'Ecpyrrhorrhoe-spp',
#  'tanaoctenia-haliaria': 'ornithospila-avicularia',
#  'tanaorhinus-reciprocata': 'lissoblemma-lunuliferata',
#  'tanaorhinus-viridiluteatus': 'ghoria-albocinerea',
#  'targallodes-vittalba': 'pyrausta-spp',
#  'tarsolepis-fulgurifera': 'areas-galactina',
#  'tasta-micaceata': 'pitama-lativitta',
#  'tathorhynchus-exsiccata': 'crambinae-genera-spp',
#  'tatobotys-biannulalis': 'marasmia-poeyalis',
#  'teldenia-spp': 'problepsis-vulgaris',
#  'teldenia-vestigiata': 'scopula-pulchellata',
#  'teleclita-centristicta': 'photoscotosia-spp',
#  'terastia-egialealis': 'acherontia-styx',
#  'termioptycha-albifurcalis': 'areas-galactina',
#  'tetragonus-catamitus': 'hypertrocta-posticalis',
#  'teulisna-karena': 'stauroplitis-apicalis',
#  'teulisna-tumida': 'Sarbanissa-spp',
#  'theretra-alecto': 'theretra-lucasii',
#  'theretra-boisduvalii': 'acosmeryx-omissa',
#  'theretra-clotho': 'actias-parasinensis',
#  'theretra-gnoma': 'euthrix-laeta',
#  'theretra-lucasii': 'stenoloba-glaucescens',
#  'theretra-nessus': 'hydrelia-bicolorata',
#  'theretra-oldenlandiae': 'cnaphalocrocis-medinalis',
#  'theretra-pallicosta': 'panilla-dispila',
#  'theretra-shendurneensis': 'achrosis-incitata-complex',
#  'theretra-silhetensis': 'chiasmia-eleonora',
#  'theretra-suffusa': 'theretra-nessus',
#  'thespea-bicolor': 'theretra-lucasii',
#  'thinopteryx-crocoptera': 'antheraea-paphia',
#  'thyas-coronata': 'theretra-lucasii',
#  'thyas-honesta': 'artena-dotata',
#  'thyas-juno': 'artena-dotata',
#  'thyatira-batis': 'thyrassia-penangae',
#  'thyrassia-aurodisca': 'episteme-adulatrix',
#  'thyrassia-subcordata': 'calliteara-angulata',
#  'thyrididae-genera-spp': 'chrysocraspeda-spp',
#  'thysanoplusia-intermixta': 'panilla-dispila',
#  'thysanoplusia-orichalcea': 'macroglossum-sitiene',
#  'thysanoplusia-reticulata': 'hydrelia-bicolorata',
#  'thysanoplusia-spp': 'nygmiini-genera-spp',
#  'thysanoptyx-tetragona': 'areas-galactina',
#  'timandra-convectaria': 'hyalobathra-phoenicozona',
#  'timandra-correspondens': 'fascellina-porphyreofusa',
#  'timandra-ruptilinea': 'traminda-mundissima',
#  'timandra-spp': 'spilarctia-spp',
#  'tinolius-eburneigutta': 'Ecpyrrhorrhoe-spp',
#  'tinolius-quadrimaculatus': 'miltochrista-terminospota',
#  'tiracola-aureata': 'hyperythra-lutea',
#  'tiracola-plagiata': 'Ecpyrrhorrhoe-spp',
#  'tisis-spp': 'egnasia-accingalis',
#  'toccolosida-rubriceps': 'fodina-stola',
#  'tonica-niviferana': 'polythlipta-euroalis',
#  'tortricidae-genera-spp': 'noctuinae-genera-spp',
#  'trabala-spp': 'spirama-spp',
#  'trabala-vishnou': 'artaxa-guttata',
#  'trachea-auriplena': 'ecliptopera-rectilinea',
#  'traminda-aventiaria': 'traminda-mundissima',
#  'traminda-mundissima': 'creatonotos-transiens',
#  'trichoplusia-ni': 'elophila-spp',
#  'tridrepana-albonotata': 'trigonodes-hyppasia',
#  'tridrepana-fulvata': 'pyralis-manihotalis',
#  'tridrepana-spp': 'eupterote-spp',
#  'trigonodes-hyppasia': 'areas-galactina',
#  'trilocha-varians': 'trisula-variegata',
#  'triphosa-spp': 'naarda-spp',
#  'trotocraspeda-divaricata': 'areas-galactina',
#  'trypanophora-semihyalina': 'herpetogramma-licarsisalis',
#  'tyana-callichlora': 'comibaena-fuscidorsata',
#  'tyana-chloroleuca': 'phyllodes-eyndhovii',
#  'tyloptera-bella': 'chiasmia-xanthonora',
#  'tyspanodes-fascialis': 'oxacme-marginata',
#  'tyspanodes-linealis': 'idaea-violacea',
#  'udea-ferrugalis': 'asota-caricae',
#  'udea-spp': 'amyna-spp',
#  'ulopeza-semivialis': 'endotricha-spp',
#  'uncobotyodes-patulalis': 'traminda-mundissima',
#  'urapteroides-astheniata': 'lymantria-grandis',
#  'utetheisa-pulchelloides': 'indarbela-tetraonis',
#  'utetheisa-spp': 'siccia-spp',
#  'utetheisa-varians': 'nyctemera-adversata',
#  'vamuna-bipars': 'achaea-janata',
#  'vamuna-maculata': 'Miltochrista-spp',
#  'vamuna-remelana': 'lymantria-grandis',
#  'westermannia-superba': 'creatonotos-transiens',
#  'westermannia-triangularis': 'xandrames-latiferaria',
#  'xandrames-albofasciata': 'eudocima-phalonia',
#  'xandrames-dholaria': 'erebus-glaucopis',
#  'xanthodes-transversa': 'nola-taeniata',
#  'xanthorhoe-saturata': 'menophra-translineata',
#  'xanthorhoe-spp': 'pyralis-manihotalis',
#  'xenochroa-biviata': 'nepita-conferta',
#  'xenoplia-maculata': 'chabulina-tenera',
#  'xestia-c-nigrum': 'neurois-atrovirens',
#  'xestia-spp': 'panilla-dispila',
#  'xyleutes-persona': 'psilogramma-vates',
#  'xyleutes-strix': 'elophila-spp',
#  'xylophylla-punctifascia': 'cerynea-spp',
#  'yashmakia-erythra': 'Luxiaria-hypaphanes',
#  'yepcalphis-dilectissima': 'acherontia-styx',
#  'zamarada-spp': 'agathia-spp',
#  'zeheba-aureata': 'luceria-spp',
#  'zeuzera-multistrigata': 'lymantria-concolor',
#  'zeuzerini-genera-spp': 'phycitinae-genera-spp',
#  'zitha-tactilis': 'pyrausta-spp',
#  'zitha-torridalis': 'spodoptera-spp',
#  'zurobata-vacillans': 'hyalobathra-aequalis',
#  'zygaenidae-genera-spp': 'plutodes-subcaudata',
#  'zythos-avellanea': 'Microselene-mesostipa'}

# %% [markdown]
# # No... Its not working... 24% is too low

# %% [markdown]
# ### Problems identified
# 1. not having correct train/eval mode before operation gives rong results
# 2. model need to be saved with rest of the parameters, at least class to index mapping
# 3. new class names needs to appended correctly before retraining same model with more classes
