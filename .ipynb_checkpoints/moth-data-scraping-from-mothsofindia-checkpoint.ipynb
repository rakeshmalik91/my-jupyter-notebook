# %%
# !pip install torch torchvision
# !pip install matplotlib pandas scikit-learn
# !pip install pillow
# !pip install opencv-python

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
dataset_dir = "insect-dataset/moth"

# %% [markdown]
# # Scrape https://www.mothsofindia.org for moths dataset

# %%
website_url = "https://www.mothsofindia.org"
initial_path = "/lepidoptera"
first_page = 0
last_page = 145

batch_size = 3
max_workers = 50
page_timeout = 120
image_timeout = 30

ignore_image_regex = r"^(imgs10|.*webheader.*)\.png$"
skip_downloaded_species = False

# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor

# %%
def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

# %%
def download_image(img_url, output_dir):
    try:
        img_data = requests.get(img_url, timeout=image_timeout).content
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name)
        with open(img_path, 'wb') as file:
            file.write(img_data)
        return True
    except Exception as e:
        # print(f"{log_header()}{e}")
        return False

# %%
def scrape_images(url, output_dir):
    try:
        print(f"{log_header()}    Scraping URL: {url}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        success_cnt = 0
        failure_cnt = 0
        already_downloaded_cnt = 0
        for img in img_tags:
            img_url = img.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if os.path.exists(f"{output_dir}/{img_name}"):
                    already_downloaded_cnt = already_downloaded_cnt + 1
                    continue
                if download_image(img_url, output_dir):
                    success_cnt = success_cnt + 1
                else:
                    failure_cnt = failure_cnt + 1
        print(f"{log_header()}      Downloaded {success_cnt}(+{already_downloaded_cnt}) / {success_cnt+already_downloaded_cnt+failure_cnt} image(s) in {output_dir}")
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

# %%
def crawl(base_url, root, output_dir):
    try:
        url = urljoin(base_url, root)
        print(f"{log_header()}Crawling URL: {url}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            img_url = img.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                species_path = img.parent.parent.get('href')
                species_dir = output_dir+species_path
                if not (skip_downloaded_species and os.path.exists(species_dir) and os.path.isdir(species_dir) and os.listdir(species_dir)):
                    scrape_images(urljoin(base_url, species_path), species_dir)
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl_in_batch(batch_start):
    print(f"Starting batch from page {batch_start} on thread {threading.current_thread().name}")
    for page in range(batch_start, min(batch_start+batch_size, last_page+1), 1):
        crawl(website_url, f"{initial_path}?page={page}", f"{dataset_dir}/data")

# %%
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(crawl_in_batch, batch_start) for batch_start in range(first_page, last_page+1, batch_size)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")

print("Scraping completed!")
# Out:
# Starting batch from page 0 on thread ThreadPoolExecutor-0_0
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=0
# Starting batch from page 3 on thread ThreadPoolExecutor-0_1
# [ ThreadPoolExecutor-0_1   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=3
# Starting batch from page 6 on thread ThreadPoolExecutor-0_2
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=6
# Starting batch from page 9 on thread ThreadPoolExecutor-0_3
# [ ThreadPoolExecutor-0_3   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=9
# Starting batch from page 12 on thread ThreadPoolExecutor-0_4
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=12
# Starting batch from page 15 on thread ThreadPoolExecutor-0_5
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=15
# Starting batch from page 18 on thread ThreadPoolExecutor-0_6
# [ ThreadPoolExecutor-0_6   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=18
# Starting batch from page 21 on thread ThreadPoolExecutor-0_7
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=21
# Starting batch from page 24 on thread ThreadPoolExecutor-0_8
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=24
# Starting batch from page 27 on thread ThreadPoolExecutor-0_9
# [ ThreadPoolExecutor-0_9   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=27
# Starting batch from page 30 on thread ThreadPoolExecutor-0_10
# [ ThreadPoolExecutor-0_10  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=30
# Starting batch from page 33 on thread ThreadPoolExecutor-0_11
# [ ThreadPoolExecutor-0_11  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=33
# Starting batch from page 36 on thread ThreadPoolExecutor-0_12
# [ ThreadPoolExecutor-0_12  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=36
# Starting batch from page 39 on thread ThreadPoolExecutor-0_13
# [ ThreadPoolExecutor-0_13  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=39
# Starting batch from page 42 on thread ThreadPoolExecutor-0_14
# [ ThreadPoolExecutor-0_14  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=42
# Starting batch from page 45 on thread ThreadPoolExecutor-0_15
# [ ThreadPoolExecutor-0_15  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=45
# Starting batch from page 48 on thread ThreadPoolExecutor-0_16
# [ ThreadPoolExecutor-0_16  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=48
# Starting batch from page 51 on thread ThreadPoolExecutor-0_17
# [ ThreadPoolExecutor-0_17  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=51
# Starting batch from page 54 on thread ThreadPoolExecutor-0_18
# [ ThreadPoolExecutor-0_18  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=54
# Starting batch from page 57 on thread ThreadPoolExecutor-0_19
# [ ThreadPoolExecutor-0_19  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=57
# Starting batch from page 60 on thread ThreadPoolExecutor-0_20
# [ ThreadPoolExecutor-0_20  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=60
# Starting batch from page 63 on thread ThreadPoolExecutor-0_21
# [ ThreadPoolExecutor-0_21  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=63
# Starting batch from page 66 on thread ThreadPoolExecutor-0_22
# [ ThreadPoolExecutor-0_22  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=66
# Starting batch from page 69 on thread ThreadPoolExecutor-0_23
# [ ThreadPoolExecutor-0_23  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=69
# Starting batch from page 72 on thread ThreadPoolExecutor-0_24
# [ ThreadPoolExecutor-0_24  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=72
# Starting batch from page 75 on thread ThreadPoolExecutor-0_25
# [ ThreadPoolExecutor-0_25  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=75
# Starting batch from page 78 on thread ThreadPoolExecutor-0_26
# [ ThreadPoolExecutor-0_26  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=78
# Starting batch from page 81 on thread ThreadPoolExecutor-0_27
# [ ThreadPoolExecutor-0_27  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=81
# Starting batch from page 84 on thread ThreadPoolExecutor-0_28
# [ ThreadPoolExecutor-0_28  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=84
# Starting batch from page 87 on thread ThreadPoolExecutor-0_29
# [ ThreadPoolExecutor-0_29  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=87
# Starting batch from page 90 on thread ThreadPoolExecutor-0_30
# [ ThreadPoolExecutor-0_30  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=90
# Starting batch from page 93 on thread ThreadPoolExecutor-0_31
# [ ThreadPoolExecutor-0_31  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=93
# Starting batch from page 96 on thread ThreadPoolExecutor-0_32
# [ ThreadPoolExecutor-0_32  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=96
# Starting batch from page 99 on thread ThreadPoolExecutor-0_33
# [ ThreadPoolExecutor-0_33  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=99
# Starting batch from page 102 on thread ThreadPoolExecutor-0_34
# [ ThreadPoolExecutor-0_34  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=102
# Starting batch from page 105 on thread ThreadPoolExecutor-0_35
# [ ThreadPoolExecutor-0_35  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=105
# Starting batch from page 108 on thread ThreadPoolExecutor-0_36
# [ ThreadPoolExecutor-0_36  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=108
# Starting batch from page 111 on thread ThreadPoolExecutor-0_37
# [ ThreadPoolExecutor-0_37  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=111
# Starting batch from page 114 on thread ThreadPoolExecutor-0_38
# [ ThreadPoolExecutor-0_38  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=114
# Starting batch from page 117 on thread ThreadPoolExecutor-0_39
# [ ThreadPoolExecutor-0_39  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=117
# Starting batch from page 120 on thread ThreadPoolExecutor-0_40
# [ ThreadPoolExecutor-0_40  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=120
# Starting batch from page 123 on thread ThreadPoolExecutor-0_41
# [ ThreadPoolExecutor-0_41  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=123
# Starting batch from page 126 on thread ThreadPoolExecutor-0_42
# [ ThreadPoolExecutor-0_42  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=126
# Starting batch from page 129 on thread ThreadPoolExecutor-0_43
# [ ThreadPoolExecutor-0_43  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=129
# Starting batch from page 132 on thread ThreadPoolExecutor-0_44
# [ ThreadPoolExecutor-0_44  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=132
# Starting batch from page 135 on thread ThreadPoolExecutor-0_45
# [ ThreadPoolExecutor-0_45  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=135
# Starting batch from page 138 on thread ThreadPoolExecutor-0_46
# [ ThreadPoolExecutor-0_46  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=138
# Starting batch from page 141 on thread ThreadPoolExecutor-0_47
# [ ThreadPoolExecutor-0_47  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=141
# Starting batch from page 144 on thread ThreadPoolExecutor-0_48
# [ ThreadPoolExecutor-0_48  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=144
# [ ThreadPoolExecutor-0_37  ]      Scraping URL: https://www.mothsofindia.org/pantydia-metaspila
# [ ThreadPoolExecutor-0_22  ]      Scraping URL: https://www.mothsofindia.org/diomea-lignicolora
# [ ThreadPoolExecutor-0_34  ]      Scraping URL: https://www.mothsofindia.org/striglina-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/syllepte-cometa
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.mothsofindia.org/euthrix-inobtrusa
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/mudaria-leprosa
# [ ThreadPoolExecutor-0_26  ]      Scraping URL: https://www.mothsofindia.org/lobogonodes-porphyriata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.mothsofindia.org/eupanacra-busiris
# [ ThreadPoolExecutor-0_46  ]      Scraping URL: https://www.mothsofindia.org/Pseudargyria-parallelus
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/arichanna-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/idiochlora-spp
# [ ThreadPoolExecutor-0_11  ]      Scraping URL: https://www.mothsofindia.org/oxyodes-scrobiculata
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/anoratha-costalis
# [ ThreadPoolExecutor-0_31  ]      Scraping URL: https://www.mothsofindia.org/liparopsis-postalbida
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/alcis-maculata
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/arichanna-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/calliteara-spp
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/mudaria-leprosa
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/decetia-numicusaria
# [ ThreadPoolExecutor-0_20  ]      Scraping URL: https://www.mothsofindia.org/leucania-yu
# [ ThreadPoolExecutor-0_42  ]      Scraping URL: https://www.mothsofindia.org/Eois-plicata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.mothsofindia.org/fodina-pallula
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/calindoea-argentalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.mothsofindia.org/synegiodes-sanguinaria
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/paramaxates-taiwana
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/chamaita-nympha
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/chamaesphecia-xanthosticta
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/asota-tortuosa
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/albara-reversaria
# [ ThreadPoolExecutor-0_41  ]      Scraping URL: https://www.mothsofindia.org/Speiredonia-cymosema
# [ ThreadPoolExecutor-0_19  ]      Scraping URL: https://www.mothsofindia.org/gadirtha-pulchra
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/Eulocastra-excisa
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/orthobrachia-flavidior
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/arichanna-transectata
# [ ThreadPoolExecutor-0_17  ]      Scraping URL: https://www.mothsofindia.org/scopula-mecysma
# [ ThreadPoolExecutor-0_3   ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/asota-tortuosa
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/episparis-exprimens
# [ ThreadPoolExecutor-0_44  ]      Scraping URL: https://www.mothsofindia.org/Siccia-amnaea
# [ ThreadPoolExecutor-0_25  ]      Scraping URL: https://www.mothsofindia.org/speiredonia-mutabilis
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.mothsofindia.org/anomis-flava
# [ ThreadPoolExecutor-0_21  ]      Scraping URL: https://www.mothsofindia.org/trichoplusia-ni
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/nepita-conferta
# [ ThreadPoolExecutor-0_18  ]      Scraping URL: https://www.mothsofindia.org/mimochroa-albifrons
# [ ThreadPoolExecutor-0_26  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/lobogonodes-porphyriata
# [ ThreadPoolExecutor-0_26  ]      Scraping URL: https://www.mothsofindia.org/clostera-anachoreta
# [ ThreadPoolExecutor-0_31  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/liparopsis-postalbida
# [ ThreadPoolExecutor-0_31  ]      Scraping URL: https://www.mothsofindia.org/athetis-delecta
# [ ThreadPoolExecutor-0_10  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/euthrix-inobtrusa
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.mothsofindia.org/daddala-lucilla-complex
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/anoratha-costalis
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/chilo-partellus
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+16) / 17 image(s) in insect-dataset/moth/data/decetia-numicusaria
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/targallodes-vittalba
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+22) / 23 image(s) in insect-dataset/moth/data/calliteara-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/menophra-spp
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/chilo-partellus
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/namangana-cashmirensis
# [ ThreadPoolExecutor-0_37  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/pantydia-metaspila
# [ ThreadPoolExecutor-0_37  ]      Scraping URL: https://www.mothsofindia.org/atkinsonia-clerodendronella
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+20) / 21 image(s) in insect-dataset/moth/data/calindoea-argentalis
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/pachynoa-thoosalis
# [ ThreadPoolExecutor-0_20  ]        Downloaded 0(+52) / 53 image(s) in insect-dataset/moth/data/leucania-yu
# [ ThreadPoolExecutor-0_20  ]      Scraping URL: https://www.mothsofindia.org/glyphodes-orbiferalis
# [ ThreadPoolExecutor-0_17  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/scopula-mecysma
# [ ThreadPoolExecutor-0_17  ]      Scraping URL: https://www.mothsofindia.org/pericyma-umbrina
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/chamaesphecia-xanthosticta
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/agnidra-specularia
# [ ThreadPoolExecutor-0_48  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/arichanna-transectata
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/rinaca-zuleika
# [ ThreadPoolExecutor-0_15  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/orthobrachia-flavidior
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/ctenoplusia-albostriata
# [ ThreadPoolExecutor-0_19  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/gadirtha-pulchra
# [ ThreadPoolExecutor-0_19  ]      Scraping URL: https://www.mothsofindia.org/adites-pseudohilaris
# [ ThreadPoolExecutor-0_6   ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/synegiodes-sanguinaria
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.mothsofindia.org/platyja-umbrina
# [ ThreadPoolExecutor-0_3   ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/episparis-exprimens
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/cyclidia-substigmaria
# [ ThreadPoolExecutor-0_21  ]        Downloaded 0(+13) / 14 image(s) in insect-dataset/moth/data/trichoplusia-ni
# [ ThreadPoolExecutor-0_21  ]      Scraping URL: https://www.mothsofindia.org/eulocastra-argentifrons
# [ ThreadPoolExecutor-0_28  ]        Downloaded 0(+38) / 39 image(s) in insect-dataset/moth/data/chamaita-nympha
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/hypertrocta-posticalis
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/targallodes-vittalba
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/demonarosa-rufotessellata
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/namangana-cashmirensis
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/endotricha-olivacealis
# [ ThreadPoolExecutor-0_8   ]        Downloaded 0(+60) / 61 image(s) in insect-dataset/moth/data/anomis-flava
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.mothsofindia.org/hypocala-deflorata
# [ ThreadPoolExecutor-0_10  ]        Downloaded 0(+38) / 39 image(s) in insect-dataset/moth/data/daddala-lucilla-complex
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.mothsofindia.org/clostera-fulgurita
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/pachynoa-thoosalis
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/psilalcis-albibasis
# [ ThreadPoolExecutor-0_31  ]        Downloaded 0(+26) / 27 image(s) in insect-dataset/moth/data/athetis-delecta
# [ ThreadPoolExecutor-0_31  ]      Scraping URL: https://www.mothsofindia.org/scopula-insolata
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/demonarosa-rufotessellata
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/oreta-insignis
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+36) / 37 image(s) in insect-dataset/moth/data/endotricha-olivacealis
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/hypolamprus-emblicalis
# [ ThreadPoolExecutor-0_6   ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/platyja-umbrina
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.mothsofindia.org/daphnis-hypothous
# [ ThreadPoolExecutor-0_21  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/eulocastra-argentifrons
# [ ThreadPoolExecutor-0_21  ]      Scraping URL: https://www.mothsofindia.org/serrodes-partita
# [ ThreadPoolExecutor-0_48  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/rinaca-zuleika
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/hallicarnia-albipectus
# [ ThreadPoolExecutor-0_28  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/hypertrocta-posticalis
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/canucha-miranda
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/agnidra-specularia
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/ecliptopera-substituta
# [ ThreadPoolExecutor-0_48  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/hallicarnia-albipectus
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/herimba-atkinsoni
# [ ThreadPoolExecutor-0_48  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/herimba-atkinsoni
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/alcis-arisema
# [ ThreadPoolExecutor-0_10  ]        Downloaded 0(+23) / 24 image(s) in insect-dataset/moth/data/clostera-fulgurita
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.mothsofindia.org/netria-multispinae
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/hypolamprus-emblicalis
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/manulea-spp
# [ ThreadPoolExecutor-0_31  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/scopula-insolata
# [ ThreadPoolExecutor-0_31  ]      Scraping URL: https://www.mothsofindia.org/eois-phaneroscia
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/psilalcis-albibasis
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/eurrhyparodes-bracteolalis
# [ ThreadPoolExecutor-0_6   ]        Downloaded 0(+24) / 25 image(s) in insect-dataset/moth/data/daphnis-hypothous
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.mothsofindia.org/rhagastis-olivacea
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/ecliptopera-substituta
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/diphtherocome-fasciata
# [ ThreadPoolExecutor-0_6   ]        Downloaded 0(+15) / 16 image(s) in insect-dataset/moth/data/rhagastis-olivacea
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.mothsofindia.org/rhagastis-gloriosa
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+22) / 23 image(s) in insect-dataset/moth/data/manulea-spp
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/euproctis-madana
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+73) / 74 image(s) in insect-dataset/moth/data/eurrhyparodes-bracteolalis
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/homodes-crocea
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/diphtherocome-fasciata
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/diphtherocome-pallida
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/homodes-crocea
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/siglophora-ferreilutea
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/alcis-maculata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/epiplema-himala
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/siglophora-ferreilutea
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/agathia-lycaenaria
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+32) / 33 image(s) in insect-dataset/moth/data/agathia-lycaenaria
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/padenia-transversa
# [ ThreadPoolExecutor-0_7   ]        Downloaded 0(+5) / 6 image(s) in insect-dataset/moth/data/eupanacra-busiris
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.mothsofindia.org/haritalodes-derogata
# [ ThreadPoolExecutor-0_41  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/Speiredonia-cymosema
# [ ThreadPoolExecutor-0_41  ]      Scraping URL: https://www.mothsofindia.org/Tambana-subflava
# [ ThreadPoolExecutor-0_41  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/Tambana-subflava
# [ ThreadPoolExecutor-0_41  ]      Scraping URL: https://www.mothsofindia.org/Xenotrachea-albidisca
# [ ThreadPoolExecutor-0_4   ]        Downloaded 0(+48) / 49 image(s) in insect-dataset/moth/data/fodina-pallula
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.mothsofindia.org/odontocraspis-hasora
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+31) / 32 image(s) in insect-dataset/moth/data/padenia-transversa
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/tiruvaca-subcostalis
# [ ThreadPoolExecutor-0_13  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/tiruvaca-subcostalis
# [ ThreadPoolExecutor-0_13  ]      Scraping URL: https://www.mothsofindia.org/comostola-pyrrhogona
# [ ThreadPoolExecutor-0_4   ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/odontocraspis-hasora
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.mothsofindia.org/polytela-gloriosae
# [ ThreadPoolExecutor-0_42  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Eois-plicata
# [ ThreadPoolExecutor-0_42  ]      Scraping URL: https://www.mothsofindia.org/Centronaxa-orthostigialis
# [ ThreadPoolExecutor-0_34  ]        Downloaded 0(+51) / 52 image(s) in insect-dataset/moth/data/striglina-spp
# [ ThreadPoolExecutor-0_34  ]      Scraping URL: https://www.mothsofindia.org/striglina-scitaria
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+36) / 37 image(s) in insect-dataset/moth/data/idiochlora-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/hyposidra-spp
# [ ThreadPoolExecutor-0_25  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/speiredonia-mutabilis
# [ ThreadPoolExecutor-0_25  ]      Scraping URL: https://www.mothsofindia.org/parallelia-calefaciens
# [ ThreadPoolExecutor-0_4   ]        Downloaded 0(+81) / 82 image(s) in insect-dataset/moth/data/polytela-gloriosae
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.mothsofindia.org/chasmina-candida
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/albara-reversaria
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/pidorus-albifascia
# [ ThreadPoolExecutor-0_34  ]        Downloaded 0(+19) / 20 image(s) in insect-dataset/moth/data/striglina-scitaria
# [ ThreadPoolExecutor-0_34  ]      Scraping URL: https://www.mothsofindia.org/ozarba-venata
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+38) / 39 image(s) in insect-dataset/moth/data/hyposidra-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/abaciscus-spp
# [ ThreadPoolExecutor-0_25  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/parallelia-calefaciens
# [ ThreadPoolExecutor-0_25  ]      Scraping URL: https://www.mothsofindia.org/blasticorhinus-varius
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+16) / 17 image(s) in insect-dataset/moth/data/menophra-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/polythlipta-euroalis
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/pidorus-albifascia
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/chalcosia-diana
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/abaciscus-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/naranga-diffusa
# [ ThreadPoolExecutor-0_25  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/blasticorhinus-varius
# [ ThreadPoolExecutor-0_25  ]      Scraping URL: https://www.mothsofindia.org/baroa-punctivaga
# [ ThreadPoolExecutor-0_20  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/glyphodes-orbiferalis
# [ ThreadPoolExecutor-0_20  ]      Scraping URL: https://www.mothsofindia.org/eublemma-dimidialis
# [ ThreadPoolExecutor-0_46  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/Pseudargyria-parallelus
# [ ThreadPoolExecutor-0_46  ]      Scraping URL: https://www.mothsofindia.org/Stericta-divitalis
# [ ThreadPoolExecutor-0_46  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Stericta-divitalis
# [ ThreadPoolExecutor-0_46  ]      Scraping URL: https://www.mothsofindia.org/Adrapsa-geometroides
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/chalcosia-diana
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/neoreta-olga
# [ ThreadPoolExecutor-0_46  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Adrapsa-geometroides
# [ ThreadPoolExecutor-0_46  ]      Scraping URL: https://www.mothsofindia.org/Ecliptopera-postpallida
# [ ThreadPoolExecutor-0_20  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/eublemma-dimidialis
# [ ThreadPoolExecutor-0_20  ]      Scraping URL: https://www.mothsofindia.org/ambulyx-aglaia
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/neoreta-olga
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/thosea-magna
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/thosea-magna
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/eurrhyparodes-tricoloralis
# [ ThreadPoolExecutor-0_19  ]        Downloaded 0(+24) / 25 image(s) in insect-dataset/moth/data/adites-pseudohilaris
# [ ThreadPoolExecutor-0_19  ]      Scraping URL: https://www.mothsofindia.org/gazalina-apsara
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/diphtherocome-pallida
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/perizoma-albofasciata
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/perizoma-albofasciata
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/odontopera-bilinearia
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/epiplema-himala
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/acosmeryx-naga
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/odontopera-bilinearia
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/odontopera-heydena
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+25) / 26 image(s) in insect-dataset/moth/data/acosmeryx-naga
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/thinopteryx-crocoptera
# [ ThreadPoolExecutor-0_28  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/canucha-miranda
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/laelia-litura
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+30) / 31 image(s) in insect-dataset/moth/data/thinopteryx-crocoptera
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/pseudeuchlora-kafebera
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/odontopera-heydena
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/eumelea-atomata
# [ ThreadPoolExecutor-0_7   ]        Downloaded 0(+86) / 87 image(s) in insect-dataset/moth/data/haritalodes-derogata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.mothsofindia.org/striatella-pluma
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/eumelea-atomata
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/ginshachia-gemmifera
# [ ThreadPoolExecutor-0_7   ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/striatella-pluma
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.mothsofindia.org/callabraxas-amanda
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/ginshachia-gemmifera
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/hippotion-rosetta
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/naranga-diffusa
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/turnaca-spp
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/oreta-insignis
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/hemistola-ornata
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+22) / 23 image(s) in insect-dataset/moth/data/turnaca-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/epicrocis-spp
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+38) / 39 image(s) in insect-dataset/moth/data/eurrhyparodes-tricoloralis
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/bastilla-praetermissa
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+42) / 43 image(s) in insect-dataset/moth/data/epicrocis-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/synegiodes-hyriaria
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/synegiodes-hyriaria
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/omiodes-spp
# [ ThreadPoolExecutor-0_19  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/gazalina-apsara
# [ ThreadPoolExecutor-0_19  ]      Scraping URL: https://www.mothsofindia.org/sataspes-infernalis
# [ ThreadPoolExecutor-0_19  ]        Downloaded 0(+11) / 12 image(s) in insect-dataset/moth/data/sataspes-infernalis
# [ ThreadPoolExecutor-0_19  ]      Scraping URL: https://www.mothsofindia.org/uncobotyodes-patulalis
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/pseudeuchlora-kafebera
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/utetheisa-varians
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+30) / 31 image(s) in insect-dataset/moth/data/hippotion-rosetta
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/blepharoctenucha-virescens
# [ ThreadPoolExecutor-0_28  ]        Downloaded 0(+26) / 27 image(s) in insect-dataset/moth/data/laelia-litura
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/stigmatophora-strigivenata
# [ ThreadPoolExecutor-0_9   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_9   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=28
# [ ThreadPoolExecutor-0_32  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_32  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=97
# [ ThreadPoolExecutor-0_35  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_35  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=106
# [ ThreadPoolExecutor-0_29  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_29  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=88
# [ ThreadPoolExecutor-0_22  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_22  ]      Scraping URL: https://www.mothsofindia.org/herpetogramma-licarsisalis
# [ ThreadPoolExecutor-0_28  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/stigmatophora-strigivenata
# [ ThreadPoolExecutor-0_28  ]      Scraping URL: https://www.mothsofindia.org/herdonia-osacesalis
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/blepharoctenucha-virescens
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/varmina-indica
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.mothsofindia.org/pseudomicronia-advocataria
# [ ThreadPoolExecutor-0_32  ]      Scraping URL: https://www.mothsofindia.org/problepsis-spp
# [ ThreadPoolExecutor-0_35  ]      Scraping URL: https://www.mothsofindia.org/oeonistis-entella
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/varmina-indica
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/odontopera-bivittaria
# [ ThreadPoolExecutor-0_22  ]        Downloaded 0(+29) / 30 image(s) in insect-dataset/moth/data/herpetogramma-licarsisalis
# [ ThreadPoolExecutor-0_22  ]      Scraping URL: https://www.mothsofindia.org/herpetogramma-phaeopteralis
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/hemistola-ornata
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/stictane-fractilinea
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/stictane-fractilinea
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/termioptycha-albifurcalis
# [ ThreadPoolExecutor-0_9   ]        Downloaded 0(+36) / 37 image(s) in insect-dataset/moth/data/pseudomicronia-advocataria
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.mothsofindia.org/acontia-lucida
# [ ThreadPoolExecutor-0_35  ]        Downloaded 0(+19) / 20 image(s) in insect-dataset/moth/data/oeonistis-entella
# [ ThreadPoolExecutor-0_35  ]      Scraping URL: https://www.mothsofindia.org/oeonistis-spp
# [ ThreadPoolExecutor-0_23  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_23  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=70
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/bastilla-praetermissa
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/sphinx-oberthueri
# [ ThreadPoolExecutor-0_33  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/comostola-meritaria
# [ ThreadPoolExecutor-0_23  ]      Scraping URL: https://www.mothsofindia.org/ilema-chloroptera
# [ ThreadPoolExecutor-0_16  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/odontopera-bivittaria
# [ ThreadPoolExecutor-0_16  ]      Scraping URL: https://www.mothsofindia.org/artena-submira
# [ ThreadPoolExecutor-0_5   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=16
# [ ThreadPoolExecutor-0_27  ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/termioptycha-albifurcalis
# [ ThreadPoolExecutor-0_27  ]      Scraping URL: https://www.mothsofindia.org/rhodoprasina-floralis
# [ ThreadPoolExecutor-0_35  ]        Downloaded 0(+43) / 44 image(s) in insect-dataset/moth/data/oeonistis-spp
# [ ThreadPoolExecutor-0_35  ]      Scraping URL: https://www.mothsofindia.org/locastra-crassipennis
# [ ThreadPoolExecutor-0_45  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/Numenes-flagrans
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+11) / 12 image(s) in insect-dataset/moth/data/comostola-meritaria
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/archigargetta-viridigrisea
# [ ThreadPoolExecutor-0_23  ]        Downloaded 0(+50) / 51 image(s) in insect-dataset/moth/data/ilema-chloroptera
# [ ThreadPoolExecutor-0_23  ]      Scraping URL: https://www.mothsofindia.org/neogurelca-himachala
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+5) / 6 image(s) in insect-dataset/moth/data/sphinx-oberthueri
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/ambulyx-ochracea
# [ ThreadPoolExecutor-0_0   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/diaphania-indica
# [ ThreadPoolExecutor-0_30  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_30  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=91
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.mothsofindia.org/dichocrocis-zebralis
# [ ThreadPoolExecutor-0_26  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_26  ]      Scraping URL: https://www.mothsofindia.org/parapholodes-fuliginea
# [ ThreadPoolExecutor-0_35  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/locastra-crassipennis
# [ ThreadPoolExecutor-0_35  ]      Scraping URL: https://www.mothsofindia.org/omiodes-maculicostalis
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/archigargetta-viridigrisea
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/camadena-vespertilionis
# [ ThreadPoolExecutor-0_30  ]      Scraping URL: https://www.mothsofindia.org/microloxia-indecretata
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+32) / 33 image(s) in insect-dataset/moth/data/ambulyx-ochracea
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/eupanacra-sinuata
# [ ThreadPoolExecutor-0_36  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/epipleminae-genera-spp
# [ ThreadPoolExecutor-0_36  ]        Downloaded 1(+87) / 89 image(s) in insect-dataset/moth/data/epipleminae-genera-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/phazaca-spp
# [ ThreadPoolExecutor-0_5   ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/dichocrocis-zebralis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.mothsofindia.org/neochera-dominia
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+111) / 112 image(s) in insect-dataset/moth/data/diaphania-indica
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/theretra-nessus
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/camadena-vespertilionis
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/rhesala-spp
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+5) / 6 image(s) in insect-dataset/moth/data/eupanacra-sinuata
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/ampelophaga-khasiana
# [ ThreadPoolExecutor-0_30  ]        Downloaded 0(+43) / 44 image(s) in insect-dataset/moth/data/microloxia-indecretata
# [ ThreadPoolExecutor-0_30  ]      Scraping URL: https://www.mothsofindia.org/metallaxis-semipurpurascens
# [ ThreadPoolExecutor-0_5   ]        Downloaded 0(+28) / 29 image(s) in insect-dataset/moth/data/neochera-dominia
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.mothsofindia.org/chalciope-mygdon
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+83) / 84 image(s) in insect-dataset/moth/data/rhesala-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/lymantria-nussi
# [ ThreadPoolExecutor-0_2   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=7
# [ ThreadPoolExecutor-0_12  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/ampelophaga-khasiana
# [ ThreadPoolExecutor-0_12  ]      Scraping URL: https://www.mothsofindia.org/dierna-patibulum
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/lymantria-nussi
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/derambila-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.mothsofindia.org/thyas-coronata
# [ ThreadPoolExecutor-0_14  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_14  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=43
# [ ThreadPoolExecutor-0_8   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.mothsofindia.org/miltochrista-obsoleta
# [ ThreadPoolExecutor-0_3   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/cyclidia-rectificata
# [ ThreadPoolExecutor-0_14  ]      Scraping URL: https://www.mothsofindia.org/clanis-phalaris
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+13) / 14 image(s) in insect-dataset/moth/data/derambila-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/amerila-spp
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+26) / 27 image(s) in insect-dataset/moth/data/amerila-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/amyna-spp
# [ ThreadPoolExecutor-0_40  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_40  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=121
# [ ThreadPoolExecutor-0_18  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_18  ]      Scraping URL: https://www.mothsofindia.org/maruca-amboinalis
# [ ThreadPoolExecutor-0_47  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_47  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=142
# [ ThreadPoolExecutor-0_3   ]        Downloaded 0(+32) / 33 image(s) in insect-dataset/moth/data/cyclidia-rectificata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/anonychia-grisea
# [ ThreadPoolExecutor-0_40  ]      Scraping URL: https://www.mothsofindia.org/artaxa-vitellina
# [ ThreadPoolExecutor-0_48  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_48  ]      Scraping URL: https://www.mothsofindia.org/eupterotidae-genera-spp
# [ ThreadPoolExecutor-0_47  ]      Scraping URL: https://www.mothsofindia.org/Doloessa-constellata
# [ ThreadPoolExecutor-0_3   ]        Downloaded 0(+19) / 20 image(s) in insect-dataset/moth/data/anonychia-grisea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.mothsofindia.org/gynautocera-papilionaria
# [ ThreadPoolExecutor-0_40  ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/artaxa-vitellina
# [ ThreadPoolExecutor-0_40  ]      Scraping URL: https://www.mothsofindia.org/jodis-delicatula
# [ ThreadPoolExecutor-0_31  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_31  ]      Scraping URL: https://www.mothsofindia.org/laspeyria-olivata
# [ ThreadPoolExecutor-0_18  ]        Downloaded 0(+40) / 41 image(s) in insect-dataset/moth/data/maruca-amboinalis
# [ ThreadPoolExecutor-0_18  ]      Scraping URL: https://www.mothsofindia.org/tonica-niviferana
# [ ThreadPoolExecutor-0_1   ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/utetheisa-varians
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.mothsofindia.org/chorodna-fulgurita
# [ ThreadPoolExecutor-0_47  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/Doloessa-constellata
# [ ThreadPoolExecutor-0_47  ]      Scraping URL: https://www.mothsofindia.org/adrapsa-abnormalis
# [ ThreadPoolExecutor-0_24  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_24  ]  Crawling URL: https://www.mothsofindia.org/lepidoptera?page=73
# [ ThreadPoolExecutor-0_40  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/jodis-delicatula
# [ ThreadPoolExecutor-0_40  ]      Scraping URL: https://www.mothsofindia.org/tathorhynchus-exsiccata
# [ ThreadPoolExecutor-0_18  ]        Downloaded 0(+49) / 50 image(s) in insect-dataset/moth/data/tonica-niviferana
# [ ThreadPoolExecutor-0_18  ]      Scraping URL: https://www.mothsofindia.org/iridoplecta-ferrifera
# [ ThreadPoolExecutor-0_40  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/tathorhynchus-exsiccata
# [ ThreadPoolExecutor-0_40  ]      Scraping URL: https://www.mothsofindia.org/janseodes-melanospila
# [ ThreadPoolExecutor-0_47  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/adrapsa-abnormalis
# [ ThreadPoolExecutor-0_47  ]      Scraping URL: https://www.mothsofindia.org/anabelcia-nepalensis
# [ ThreadPoolExecutor-0_21  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_21  ]      Scraping URL: https://www.mothsofindia.org/bastilla-simillima
# [ ThreadPoolExecutor-0_47  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/anabelcia-nepalensis
# [ ThreadPoolExecutor-0_47  ]      Scraping URL: https://www.mothsofindia.org/Viridistria-striatovirens
# [ ThreadPoolExecutor-0_21  ]        Downloaded 0(+25) / 26 image(s) in insect-dataset/moth/data/bastilla-simillima
# [ ThreadPoolExecutor-0_21  ]      Scraping URL: https://www.mothsofindia.org/fulgoraecia-melanoleuca
# [ ThreadPoolExecutor-0_10  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.mothsofindia.org/gaurena-aurofasciata
# ...
# [ ThreadPoolExecutor-0_22  ]      Scraping URL: https://www.mothsofindia.org/peratostega-deletaria
# [ ThreadPoolExecutor-0_22  ]        Downloaded 0(+13) / 14 image(s) in insect-dataset/moth/data/peratostega-deletaria
# [ ThreadPoolExecutor-0_22  ]      Scraping URL: https://www.mothsofindia.org/parapsestis-lichenea
# [ ThreadPoolExecutor-0_22  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/parapsestis-lichenea
# [ ThreadPoolExecutor-0_33  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/paracataclysta-fuscalis
# [ ThreadPoolExecutor-0_45  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/Risoba-prominens
# [ ThreadPoolExecutor-0_45  ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/Risoba-prominens
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/Marumba-spp
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/paracataclysta-fuscalis
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/ophiusa-spp
# [ ThreadPoolExecutor-0_36  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/nolinae-genera-spp
# [ ThreadPoolExecutor-0_36  ]        Downloaded 0(+143) / 144 image(s) in insect-dataset/moth/data/nolinae-genera-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/siccia-tenebrosa
# [ ThreadPoolExecutor-0_45  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/Marumba-spp
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/siculifer-bilineatus
# [ ThreadPoolExecutor-0_36  ]        Downloaded 0(+14) / 15 image(s) in insect-dataset/moth/data/siccia-tenebrosa
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/diduga-spp
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+18) / 19 image(s) in insect-dataset/moth/data/ophiusa-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/euclasta-spp
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/gloriana-ornata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/acosmerycoides-harterti
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+69) / 70 image(s) in insect-dataset/moth/data/euclasta-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/abraxas-latizonata
# [ ThreadPoolExecutor-0_36  ]        Downloaded 0(+40) / 41 image(s) in insect-dataset/moth/data/diduga-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/zeuzerini-genera-spp
# [ ThreadPoolExecutor-0_36  ]        Downloaded 0(+45) / 46 image(s) in insect-dataset/moth/data/zeuzerini-genera-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/nacoleia-spp
# [ ThreadPoolExecutor-0_43  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/calonola-ectrocta
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+24) / 25 image(s) in insect-dataset/moth/data/calonola-ectrocta
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/radhica-rosea
# [ ThreadPoolExecutor-0_39  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/metarbelidae-genera-spp
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/radhica-rosea
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Jodis-pallescens
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Jodis-pallescens
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Dysstroma-albiangulata
# [ ThreadPoolExecutor-0_15  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/scirpophaga-incertulas
# [ ThreadPoolExecutor-0_15  ]        Downloaded 0(+72) / 73 image(s) in insect-dataset/moth/data/scirpophaga-incertulas
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/rehimena-phrynealis
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/acosmerycoides-harterti
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/ochrotrigona-triangulifera
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/ochrotrigona-triangulifera
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/craspedortha-porphyria
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Dysstroma-albiangulata
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Oreta-pavaca
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+22) / 23 image(s) in insect-dataset/moth/data/metarbelidae-genera-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/immidae-genera-spp
# [ ThreadPoolExecutor-0_36  ]        Downloaded 0(+26) / 27 image(s) in insect-dataset/moth/data/nacoleia-spp
# [ ThreadPoolExecutor-0_36  ]      Scraping URL: https://www.mothsofindia.org/piesmopoda-semilutea
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/immidae-genera-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/adisura-spp
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+20) / 21 image(s) in insect-dataset/moth/data/adisura-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/proneca-fola
# [ ThreadPoolExecutor-0_38  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/cossidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+16) / 17 image(s) in insect-dataset/moth/data/cossidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/sesiidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+38) / 39 image(s) in insect-dataset/moth/data/sesiidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/gelechiidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+16) / 17 image(s) in insect-dataset/moth/data/gelechiidae-genera-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/ectropidia-spp
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/craspedortha-porphyria
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/baorisa-hieroglyphica
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/proneca-fola
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/ostrinia-spp
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/ostrinia-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/blenina-spp
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/blenina-spp
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/arcyophora-icterica
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/arcyophora-icterica
# [ ThreadPoolExecutor-0_39  ]      Scraping URL: https://www.mothsofindia.org/gadirtha-spp
# [ ThreadPoolExecutor-0_39  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/gadirtha-spp
# [ ThreadPoolExecutor-0_45  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/ecliptopera-zophera
# [ ThreadPoolExecutor-0_33  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/imma-auxobathra
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/imma-auxobathra
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/naxidia-punctata
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/naxidia-punctata
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/diasemiopsis-ramburialis
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/diasemiopsis-ramburialis
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/selepa-spp
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+96) / 97 image(s) in insect-dataset/moth/data/selepa-spp
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/achrosis-spp
# [ ThreadPoolExecutor-0_43  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Luxiaria-hypaphanes
# [ ThreadPoolExecutor-0_36  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_15  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/garaeus-specularis
# [ ThreadPoolExecutor-0_38  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/tyloptera-bella
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/tyloptera-bella
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/triphosa-spp
# [ ThreadPoolExecutor-0_0   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/callambulyx-junonia
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+8) / 9 image(s) in insect-dataset/moth/data/callambulyx-junonia
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/iotaphora-iridicolor
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+47) / 48 image(s) in insect-dataset/moth/data/triphosa-spp
# [ ThreadPoolExecutor-0_38  ]      Scraping URL: https://www.mothsofindia.org/sirinopteryx-spp
# [ ThreadPoolExecutor-0_38  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/sirinopteryx-spp
# [ ThreadPoolExecutor-0_33  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/ophisma-gravata
# [ ThreadPoolExecutor-0_15  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/penicillaria-jocosatrix
# [ ThreadPoolExecutor-0_15  ]        Downloaded 0(+57) / 58 image(s) in insect-dataset/moth/data/penicillaria-jocosatrix
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/ornithospila-submonstrans
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+12) / 13 image(s) in insect-dataset/moth/data/ophisma-gravata
# [ ThreadPoolExecutor-0_33  ]      Scraping URL: https://www.mothsofindia.org/spaniocentra-spp
# [ ThreadPoolExecutor-0_33  ]        Downloaded 0(+11) / 12 image(s) in insect-dataset/moth/data/spaniocentra-spp
# [ ThreadPoolExecutor-0_43  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Doloessa-ochrociliella
# [ ThreadPoolExecutor-0_45  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_45  ]      Scraping URL: https://www.mothsofindia.org/Rhodoneura-glaphyralis
# [ ThreadPoolExecutor-0_45  ]        Downloaded 0(+5) / 6 image(s) in insect-dataset/moth/data/Rhodoneura-glaphyralis
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+2) / 3 image(s) in insect-dataset/moth/data/Doloessa-ochrociliella
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Rivula-simulatrix
# [ ThreadPoolExecutor-0_0   ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/horithyatira-decorata
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/horithyatira-decorata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/ariolica-superba
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/ariolica-superba
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/chlorodontopera-discospilata
# [ ThreadPoolExecutor-0_43  ]        Downloaded 0(+6) / 7 image(s) in insect-dataset/moth/data/Rivula-simulatrix
# [ ThreadPoolExecutor-0_43  ]      Scraping URL: https://www.mothsofindia.org/Diomea-orbifera
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+10) / 11 image(s) in insect-dataset/moth/data/chlorodontopera-discospilata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/palpoctenidia-phoenicosoma
# [ ThreadPoolExecutor-0_15  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out. (read timeout=120)
# [ ThreadPoolExecutor-0_15  ]      Scraping URL: https://www.mothsofindia.org/amblychia-pardicelata
# [ ThreadPoolExecutor-0_15  ]        Downloaded 0(+11) / 12 image(s) in insect-dataset/moth/data/amblychia-pardicelata
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+30) / 31 image(s) in insect-dataset/moth/data/palpoctenidia-phoenicosoma
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/agathia-gemma
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/agathia-gemma
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.mothsofindia.org/doratoptera-nicevillei
# [ ThreadPoolExecutor-0_0   ]        Downloaded 0(+4) / 5 image(s) in insect-dataset/moth/data/doratoptera-nicevillei
# [ ThreadPoolExecutor-0_43  ]  HTTPSConnectionPool(host='www.mothsofindia.org', port=443): Read timed out.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       2     futures = [executor.submit(crawl_in_batch, batch_start) for batch_start in range(first_page, last_page+1, batch_size)]
#       3     for future in futures:
# ----> 4         print(f"Thread completed with result {future.result()}")
#       6 print("Scraping completed!")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(f"{dataset_dir}/data").iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
    if not os.listdir(species_dir):
        os.rmdir(species_dir)
        print(f"Empty folder {species_dir} removed")

# %% [markdown]
# # ZIP the data

# %%
import shutil
import time
import datetime

shutil.make_archive(f"{dataset_dir}/data_{int(time.time())}", 'zip', f"{dataset_dir}/data")
# Out:
# 'D:\\Projects\\my-jupyter-notebook\\insect-dataset\\moth\\data_1737815141.zip'
