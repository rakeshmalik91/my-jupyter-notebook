# %%
# !pip install torch torchvision
# !pip install matplotlib pandas scikit-learn
# !pip install pillow
# !pip install opencv-python

# %% [markdown]
# # Scrape https://www.ifoundbutterflies.org for butterfly dataset

# %%
dataset_dir = "insect-dataset/butterfly"

website_url = "https://www.ifoundbutterflies.org"
initial_path = "/lepidoptera"
first_page = 0
last_page = 53

batch_size = 5
max_workers = 50
page_timeout = 120
image_timeout = 30

ignore_image_regex = r"^(imgs10|.*(boimobileapp|butterfliesofurbangreeneries|webheader|headerlogo|WPA-[IVX]+).*)\.(png|jpg|jpeg)$"
skip_downloaded_species = False

early_stage_suffix = '-early'

# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def download_image(img_url, output_dir):
    try:
        img_data = requests.get(img_url, timeout=image_timeout).content
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name)
        with open(img_path, 'wb') as file:
            file.write(img_data)
        return True
    except Exception as e:
        # print(f"{log_header()}{e}")
        return False

def has_parent_with_prop(tag, prop, value, max_parents):
    parent = tag
    for i in range(0, max_parents):
        parent = parent.parent
        if parent.get(prop) == value:
            return True
    return False
    
def scrape_images(url, output_dir):
    try:
        print(f"{log_header()}    Scraping URL: {url}")
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        success_cnt = 0
        failure_cnt = 0
        already_downloaded_cnt = 0
        for img in img_tags:
            img_url = img.get('src')
            if has_parent_with_prop(img, 'id', 'laraval', 5):
                # larval host plants photo
                # print (f"Ignoring larval host plants image {img_url}")
                continue
            class_suffix = ''
            if has_parent_with_prop(img, 'id', 'early', 6):
                # early stages
                # print (f"Found early stages image {img_url}")
                class_suffix = early_stage_suffix
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if os.path.exists(f"{output_dir}{class_suffix}/{img_name}"):
                    already_downloaded_cnt = already_downloaded_cnt + 1
                    continue
                if not os.path.exists(output_dir+class_suffix):
                    os.makedirs(output_dir+class_suffix)
                if download_image(img_url, output_dir+class_suffix):
                    success_cnt = success_cnt + 1
                else:
                    failure_cnt = failure_cnt + 1
        if success_cnt > 0:
            print(f"{log_header()}      Downloaded {success_cnt}(+{already_downloaded_cnt}) / {success_cnt+already_downloaded_cnt+failure_cnt} image(s) in {output_dir}")
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl(base_url, root, output_dir):
    try:
        url = urljoin(base_url, root)
        print(f"{log_header()}Crawling URL: {url}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            img_url = img.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                # print (f"Found image {img_url}")
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                species_path = img.parent.parent.get('href')
                species_dir = output_dir+species_path.lower()
                if not (skip_downloaded_species and os.path.exists(species_dir) and os.path.isdir(species_dir) and os.listdir(species_dir)):
                    scrape_images(urljoin(base_url, species_path), species_dir)
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl_in_batch(batch_start):
    print(f"Starting batch from page {batch_start} on thread {threading.current_thread().name}")
    for page in range(batch_start, min(batch_start+batch_size, last_page+1), 1):
        crawl(website_url, f"{initial_path}?page={page}", f"{dataset_dir}/data")

# %%
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(crawl_in_batch, batch_start) for batch_start in range(first_page, last_page+1, batch_size)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")

print("Scraping completed!")
# Out:
# Starting batch from page 0 on thread ThreadPoolExecutor-0_0
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=0
# Starting batch from page 5 on thread ThreadPoolExecutor-0_1
# [ ThreadPoolExecutor-0_1   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=5
# Starting batch from page 10 on thread ThreadPoolExecutor-0_2
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=10
# Starting batch from page 15 on thread ThreadPoolExecutor-0_3
# [ ThreadPoolExecutor-0_3   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=15
# Starting batch from page 20 on thread ThreadPoolExecutor-0_4
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=20
# Starting batch from page 25 on thread ThreadPoolExecutor-0_5
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=25
# Starting batch from page 30 on thread ThreadPoolExecutor-0_6
# [ ThreadPoolExecutor-0_6   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=30
# Starting batch from page 35 on thread ThreadPoolExecutor-0_7
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=35
# Starting batch from page 40 on thread ThreadPoolExecutor-0_8
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=40
# Starting batch from page 45 on thread ThreadPoolExecutor-0_9
# [ ThreadPoolExecutor-0_9   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=45
# Starting batch from page 50 on thread ThreadPoolExecutor-0_10
# [ ThreadPoolExecutor-0_10  ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=50
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/papilio-slateri
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/mycalesis-suaveolens
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/seseria-dohertyi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/tanaecia-lepidea
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/badamia-exclamationis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/ticherra-acte
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-andamanicus
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/udaspes-folus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/plebejus-samudra
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-bifasciata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/faunis-canens
# [ ThreadPoolExecutor-0_5   ]        Downloaded 1(+1) / 3 image(s) in insect-dataset/butterfly/data/charaxes-andamanicus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-aristogiton
# [ ThreadPoolExecutor-0_8   ]        Downloaded 9(+6) / 16 image(s) in insect-dataset/butterfly/data/mycalesis-suaveolens
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/mycalesis-subdita
# [ ThreadPoolExecutor-0_3   ]        Downloaded 11(+2) / 14 image(s) in insect-dataset/butterfly/data/plebejus-samudra
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-ariana
# [ ThreadPoolExecutor-0_2   ]        Downloaded 28(+2) / 31 image(s) in insect-dataset/butterfly/data/seseria-dohertyi
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/seseria-sambara
# [ ThreadPoolExecutor-0_5   ]        Downloaded 35(+1) / 37 image(s) in insect-dataset/butterfly/data/charaxes-aristogiton
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-arja
# [ ThreadPoolExecutor-0_7   ]        Downloaded 42(+3) / 46 image(s) in insect-dataset/butterfly/data/faunis-canens
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/faunis-eumeus
# [ ThreadPoolExecutor-0_3   ]        Downloaded 32(+4) / 37 image(s) in insect-dataset/butterfly/data/polyommatus-ariana
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-dux
# [ ThreadPoolExecutor-0_3   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/polyommatus-dux
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-janetae
# [ ThreadPoolExecutor-0_9   ]        Downloaded 52(+2) / 55 image(s) in insect-dataset/butterfly/data/papilio-slateri
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/papilio-xuthus
# [ ThreadPoolExecutor-0_3   ]        Downloaded 1(+1) / 3 image(s) in insect-dataset/butterfly/data/polyommatus-janetae
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-pseuderos
# [ ThreadPoolExecutor-0_9   ]        Downloaded 2(+0) / 3 image(s) in insect-dataset/butterfly/data/papilio-xuthus
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/meandrusa-lachinus
# [ ThreadPoolExecutor-0_3   ]        Downloaded 5(+3) / 9 image(s) in insect-dataset/butterfly/data/polyommatus-pseuderos
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-spp2
# [ ThreadPoolExecutor-0_8   ]        Downloaded 49(+3) / 53 image(s) in insect-dataset/butterfly/data/mycalesis-subdita
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/mycalesis-visala
# [ ThreadPoolExecutor-0_4   ]        Downloaded 82(+5) / 88 image(s) in insect-dataset/butterfly/data/ticherra-acte
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/araotes-lapithis
# [ ThreadPoolExecutor-0_7   ]        Downloaded 38(+2) / 41 image(s) in insect-dataset/butterfly/data/faunis-eumeus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/stichophthalma-camadeva
# [ ThreadPoolExecutor-0_4   ]        Downloaded 12(+2) / 15 image(s) in insect-dataset/butterfly/data/araotes-lapithis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/artipe-eryx
# [ ThreadPoolExecutor-0_4   ]        Downloaded 9(+2) / 12 image(s) in insect-dataset/butterfly/data/artipe-eryx
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/bindahara-moorei
# [ ThreadPoolExecutor-0_5   ]        Downloaded 74(+4) / 79 image(s) in insect-dataset/butterfly/data/charaxes-arja
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-bernardus
# [ ThreadPoolExecutor-0_9   ]        Downloaded 56(+2) / 59 image(s) in insect-dataset/butterfly/data/meandrusa-lachinus
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/meandrusa-payeni
# [ ThreadPoolExecutor-0_2   ]        Downloaded 83(+1) / 85 image(s) in insect-dataset/butterfly/data/seseria-sambara
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-cohaerens
# [ ThreadPoolExecutor-0_2   ]        Downloaded 11(+0) / 12 image(s) in insect-dataset/butterfly/data/tagiades-cohaerens
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-gana
# [ ThreadPoolExecutor-0_0   ]        Downloaded 144(+0) / 145 image(s) in insect-dataset/butterfly/data/badamia-exclamationis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/bibasis-mahintha
# [ ThreadPoolExecutor-0_3   ]        Downloaded 79(+6) / 86 image(s) in insect-dataset/butterfly/data/polyommatus-spp2
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/polyommatus-stoliczkana
# [ ThreadPoolExecutor-0_0   ]        Downloaded 2(+2) / 5 image(s) in insect-dataset/butterfly/data/bibasis-mahintha
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/bibasis-sena
# [ ThreadPoolExecutor-0_1   ]        Downloaded 146(+0) / 147 image(s) in insect-dataset/butterfly/data/udaspes-folus
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/unkana-ambasa
# [ ThreadPoolExecutor-0_7   ]        Downloaded 65(+0) / 66 image(s) in insect-dataset/butterfly/data/stichophthalma-camadeva
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/stichophthalma-nurinissa
# [ ThreadPoolExecutor-0_6   ]        Downloaded 159(+0) / 160 image(s) in insect-dataset/butterfly/data/tanaecia-lepidea
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-asura
# [ ThreadPoolExecutor-0_1   ]        Downloaded 16(+0) / 17 image(s) in insect-dataset/butterfly/data/unkana-ambasa
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/zographetus-ogygia
# [ ThreadPoolExecutor-0_7   ]        Downloaded 12(+2) / 15 image(s) in insect-dataset/butterfly/data/stichophthalma-nurinissa
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/stichophthalma-sparta
# [ ThreadPoolExecutor-0_3   ]        Downloaded 26(+2) / 29 image(s) in insect-dataset/butterfly/data/polyommatus-stoliczkana
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-aluta
# [ ThreadPoolExecutor-0_0   ]        Downloaded 28(+3) / 32 image(s) in insect-dataset/butterfly/data/bibasis-sena
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-amara
# [ ThreadPoolExecutor-0_7   ]        Downloaded 7(+2) / 10 image(s) in insect-dataset/butterfly/data/stichophthalma-sparta
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/thaumantis-diores
# [ ThreadPoolExecutor-0_10  ]        Downloaded 169(+0) / 170 image(s) in insect-dataset/butterfly/data/abisara-bifasciata
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-burnii
# [ ThreadPoolExecutor-0_10  ]        Downloaded 2(+2) / 5 image(s) in insect-dataset/butterfly/data/abisara-burnii
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-chela
# [ ThreadPoolExecutor-0_9   ]        Downloaded 68(+1) / 70 image(s) in insect-dataset/butterfly/data/meandrusa-payeni
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/teinopalpus-imperialis
# [ ThreadPoolExecutor-0_8   ]        Downloaded 149(+2) / 152 image(s) in insect-dataset/butterfly/data/mycalesis-visala
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neope-armandii
# [ ThreadPoolExecutor-0_8   ]        Downloaded 6(+3) / 10 image(s) in insect-dataset/butterfly/data/neope-armandii
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neope-bhadra
# [ ThreadPoolExecutor-0_3   ]        Downloaded 46(+3) / 50 image(s) in insect-dataset/butterfly/data/prosotas-aluta
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-bhutea
# [ ThreadPoolExecutor-0_9   ]        Downloaded 30(+4) / 35 image(s) in insect-dataset/butterfly/data/teinopalpus-imperialis
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/atrophaneura-aidoneus
# [ ThreadPoolExecutor-0_10  ]        Downloaded 43(+4) / 48 image(s) in insect-dataset/butterfly/data/abisara-chela
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-echerius
# [ ThreadPoolExecutor-0_4   ]        Downloaded 120(+6) / 127 image(s) in insect-dataset/butterfly/data/bindahara-moorei
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/bindahara-phocides
# [ ThreadPoolExecutor-0_6   ]        Downloaded 68(+6) / 75 image(s) in insect-dataset/butterfly/data/athyma-asura
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-cama
# [ ThreadPoolExecutor-0_4   ]        Downloaded 20(+2) / 23 image(s) in insect-dataset/butterfly/data/bindahara-phocides
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/deudorix-epijarbas
# [ ThreadPoolExecutor-0_9   ]        Downloaded 23(+3) / 27 image(s) in insect-dataset/butterfly/data/atrophaneura-aidoneus
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/atrophaneura-varuna
# [ ThreadPoolExecutor-0_0   ]        Downloaded 73(+0) / 74 image(s) in insect-dataset/butterfly/data/burara-amara
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-anadi
# [ ThreadPoolExecutor-0_8   ]        Downloaded 29(+2) / 32 image(s) in insect-dataset/butterfly/data/neope-bhadra
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neope-pulaha
# [ ThreadPoolExecutor-0_10  ]        Downloaded 26(+1) / 28 image(s) in insect-dataset/butterfly/data/abisara-echerius
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-fylla
# [ ThreadPoolExecutor-0_3   ]        Downloaded 32(+3) / 36 image(s) in insect-dataset/butterfly/data/prosotas-bhutea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-dubiosa
# [ ThreadPoolExecutor-0_1   ]        Downloaded 87(+0) / 88 image(s) in insect-dataset/butterfly/data/zographetus-ogygia
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/zographetus-satwa
# [ ThreadPoolExecutor-0_0   ]        Downloaded 10(+0) / 11 image(s) in insect-dataset/butterfly/data/burara-anadi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-gomata
# [ ThreadPoolExecutor-0_7   ]        Downloaded 97(+2) / 100 image(s) in insect-dataset/butterfly/data/thaumantis-diores
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/thauria-aliris
# [ ThreadPoolExecutor-0_5   ]        Downloaded 159(+0) / 160 image(s) in insect-dataset/butterfly/data/charaxes-bernardus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-bharata
# [ ThreadPoolExecutor-0_7   ]        Downloaded 4(+4) / 9 image(s) in insect-dataset/butterfly/data/thauria-aliris
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-caudata
# [ ThreadPoolExecutor-0_2   ]        Downloaded 157(+2) / 160 image(s) in insect-dataset/butterfly/data/tagiades-gana
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-japetus
# [ ThreadPoolExecutor-0_8   ]        Downloaded 47(+2) / 50 image(s) in insect-dataset/butterfly/data/neope-pulaha
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neope-pulahina
# [ ThreadPoolExecutor-0_1   ]        Downloaded 50(+0) / 51 image(s) in insect-dataset/butterfly/data/zographetus-satwa
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/baorini-baorini-spp
# [ ThreadPoolExecutor-0_8   ]        Downloaded 4(+4) / 9 image(s) in insect-dataset/butterfly/data/neope-pulahina
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neope-yama
# [ ThreadPoolExecutor-0_9   ]        Downloaded 63(+0) / 64 image(s) in insect-dataset/butterfly/data/atrophaneura-varuna
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-crassipes
# [ ThreadPoolExecutor-0_6   ]        Downloaded 75(+2) / 78 image(s) in insect-dataset/butterfly/data/athyma-cama
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-inara
# [ ThreadPoolExecutor-0_9   ]        Downloaded 11(+0) / 12 image(s) in insect-dataset/butterfly/data/byasa-crassipes
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-dasarada
# [ ThreadPoolExecutor-0_8   ]        Downloaded 32(+3) / 36 image(s) in insect-dataset/butterfly/data/neope-yama
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/orinoma-damaris
# [ ThreadPoolExecutor-0_0   ]        Downloaded 101(+0) / 102 image(s) in insect-dataset/butterfly/data/burara-gomata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-harisa
# [ ThreadPoolExecutor-0_10  ]        Downloaded 119(+0) / 120 image(s) in insect-dataset/butterfly/data/abisara-fylla
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/abisara-neophron
# [ ThreadPoolExecutor-0_9   ]        Downloaded 46(+5) / 52 image(s) in insect-dataset/butterfly/data/byasa-dasarada
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-latreillei
# [ ThreadPoolExecutor-0_4   ]        Downloaded 146(+4) / 151 image(s) in insect-dataset/butterfly/data/deudorix-epijarbas
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-damona
# [ ThreadPoolExecutor-0_9   ]        Downloaded 15(+2) / 18 image(s) in insect-dataset/butterfly/data/byasa-latreillei
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-plutonius
# [ ThreadPoolExecutor-0_4   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/rapala-damona
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-dieneces
# [ ThreadPoolExecutor-0_3   ]        Downloaded 151(+0) / 152 image(s) in insect-dataset/butterfly/data/prosotas-dubiosa
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-lutea
# [ ThreadPoolExecutor-0_9   ]        Downloaded 12(+1) / 14 image(s) in insect-dataset/butterfly/data/byasa-plutonius
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-polla
# [ ThreadPoolExecutor-0_10  ]        Downloaded 40(+2) / 43 image(s) in insect-dataset/butterfly/data/abisara-neophron
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/taxila-haquinus
# [ ThreadPoolExecutor-0_4   ]        Downloaded 19(+2) / 22 image(s) in insect-dataset/butterfly/data/rapala-dieneces
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-iarbus
# [ ThreadPoolExecutor-0_3   ]        Downloaded 13(+3) / 17 image(s) in insect-dataset/butterfly/data/prosotas-lutea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-nora
# [ ThreadPoolExecutor-0_7   ]        Downloaded 134(+1) / 136 image(s) in insect-dataset/butterfly/data/elymnias-caudata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-hypermnestra
# [ ThreadPoolExecutor-0_8   ]        Downloaded 82(+1) / 84 image(s) in insect-dataset/butterfly/data/orinoma-damaris
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/orsotriaena-medus
# [ ThreadPoolExecutor-0_9   ]        Downloaded 18(+6) / 25 image(s) in insect-dataset/butterfly/data/byasa-polla
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/byasa-polyeuctes
# [ ThreadPoolExecutor-0_1   ]        Downloaded 121(+3) / 125 image(s) in insect-dataset/butterfly/data/baorini-baorini-spp
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/baoris-chapmani
# [ ThreadPoolExecutor-0_0   ]        Downloaded 75(+0) / 76 image(s) in insect-dataset/butterfly/data/burara-harisa
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-jaina
# [ ThreadPoolExecutor-0_5   ]        Downloaded 147(+0) / 148 image(s) in insect-dataset/butterfly/data/charaxes-bharata
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-delphis
# [ ThreadPoolExecutor-0_1   ]        Downloaded 30(+0) / 31 image(s) in insect-dataset/butterfly/data/baoris-chapmani
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/baoris-farri
# [ ThreadPoolExecutor-0_10  ]        Downloaded 50(+3) / 54 image(s) in insect-dataset/butterfly/data/taxila-haquinus
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-adonira
# [ ThreadPoolExecutor-0_5   ]        Downloaded 29(+0) / 30 image(s) in insect-dataset/butterfly/data/charaxes-delphis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-dolon
# [ ThreadPoolExecutor-0_2   ]        Downloaded 177(+1) / 179 image(s) in insect-dataset/butterfly/data/tagiades-japetus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-litigiosa
# [ ThreadPoolExecutor-0_6   ]        Downloaded 171(+1) / 173 image(s) in insect-dataset/butterfly/data/athyma-inara
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-jina
# [ ThreadPoolExecutor-0_5   ]        Downloaded 47(+0) / 48 image(s) in insect-dataset/butterfly/data/charaxes-dolon
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-eudamippus
# [ ThreadPoolExecutor-0_6   ]        Downloaded 47(+3) / 51 image(s) in insect-dataset/butterfly/data/athyma-jina
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-kanwa
# [ ThreadPoolExecutor-0_9   ]        Downloaded 117(+6) / 124 image(s) in insect-dataset/butterfly/data/byasa-polyeuctes
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/losaria-coon
# [ ThreadPoolExecutor-0_10  ]        Downloaded 80(+3) / 84 image(s) in insect-dataset/butterfly/data/dodona-adonira
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-deodata
# [ ThreadPoolExecutor-0_9   ]        Downloaded 6(+2) / 9 image(s) in insect-dataset/butterfly/data/losaria-coon
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/losaria-rhodifer
# [ ThreadPoolExecutor-0_10  ]        Downloaded 4(+0) / 5 image(s) in insect-dataset/butterfly/data/dodona-deodata
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-dipoea
# [ ThreadPoolExecutor-0_7   ]        Downloaded 132(+2) / 135 image(s) in insect-dataset/butterfly/data/elymnias-hypermnestra
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-malelas
# [ ThreadPoolExecutor-0_8   ]        Downloaded 137(+0) / 138 image(s) in insect-dataset/butterfly/data/orsotriaena-medus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/paralasa-kalinda
# [ ThreadPoolExecutor-0_3   ]        Downloaded 141(+2) / 144 image(s) in insect-dataset/butterfly/data/prosotas-nora
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-noreia
# [ ThreadPoolExecutor-0_4   ]        Downloaded 154(+2) / 157 image(s) in insect-dataset/butterfly/data/rapala-iarbus
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-lankana
# [ ThreadPoolExecutor-0_6   ]        Downloaded 25(+2) / 28 image(s) in insect-dataset/butterfly/data/athyma-kanwa
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-opalina
# [ ThreadPoolExecutor-0_8   ]        Downloaded 8(+2) / 11 image(s) in insect-dataset/butterfly/data/paralasa-kalinda
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/paralasa-mani
# [ ThreadPoolExecutor-0_9   ]        Downloaded 24(+1) / 26 image(s) in insect-dataset/butterfly/data/losaria-rhodifer
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/pachliopta-aristolochiae
# [ ThreadPoolExecutor-0_8   ]        Downloaded 14(+6) / 21 image(s) in insect-dataset/butterfly/data/paralasa-mani
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/paralasa-shallada
# [ ThreadPoolExecutor-0_0   ]        Downloaded 162(+0) / 163 image(s) in insect-dataset/butterfly/data/burara-jaina
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-oedipodea
# [ ThreadPoolExecutor-0_8   ]        Downloaded 15(+3) / 19 image(s) in insect-dataset/butterfly/data/paralasa-shallada
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/paroeneis-pumilus
# [ ThreadPoolExecutor-0_10  ]        Downloaded 62(+2) / 65 image(s) in insect-dataset/butterfly/data/dodona-dipoea
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-durga
# [ ThreadPoolExecutor-0_8   ]        Downloaded 11(+3) / 15 image(s) in insect-dataset/butterfly/data/paroeneis-pumilus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/pseudochazara-lehana
# [ ThreadPoolExecutor-0_4   ]        Downloaded 61(+4) / 66 image(s) in insect-dataset/butterfly/data/rapala-lankana
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-manea
# [ ThreadPoolExecutor-0_8   ]        Downloaded 6(+1) / 8 image(s) in insect-dataset/butterfly/data/pseudochazara-lehana
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ragadia-crisilda
# [ ThreadPoolExecutor-0_1   ]        Downloaded 178(+0) / 179 image(s) in insect-dataset/butterfly/data/baoris-farri
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/baoris-pagana
# [ ThreadPoolExecutor-0_5   ]        Downloaded 114(+1) / 116 image(s) in insect-dataset/butterfly/data/charaxes-eudamippus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-kahruba
# [ ThreadPoolExecutor-0_2   ]        Downloaded 162(+1) / 164 image(s) in insect-dataset/butterfly/data/tagiades-litigiosa
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-menaka
# [ ThreadPoolExecutor-0_6   ]        Downloaded 70(+3) / 74 image(s) in insect-dataset/butterfly/data/athyma-opalina
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-orientalis
# [ ThreadPoolExecutor-0_0   ]        Downloaded 52(+0) / 53 image(s) in insect-dataset/butterfly/data/burara-oedipodea
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/burara-vasutana
# [ ThreadPoolExecutor-0_8   ]        Downloaded 21(+21) / 43 image(s) in insect-dataset/butterfly/data/ragadia-crisilda
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ragadia-crito
# [ ThreadPoolExecutor-0_1   ]        Downloaded 26(+0) / 27 image(s) in insect-dataset/butterfly/data/baoris-pagana
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/baoris-unicolor
# [ ThreadPoolExecutor-0_5   ]        Downloaded 28(+4) / 33 image(s) in insect-dataset/butterfly/data/charaxes-kahruba
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-marmax
# [ ThreadPoolExecutor-0_8   ]        Downloaded 20(+4) / 25 image(s) in insect-dataset/butterfly/data/ragadia-crito
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/rhaphicera-moorei
# [ ThreadPoolExecutor-0_1   ]        Downloaded 14(+3) / 18 image(s) in insect-dataset/butterfly/data/baoris-unicolor
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/borbo-bevani
# [ ThreadPoolExecutor-0_3   ]        Downloaded 118(+1) / 120 image(s) in insect-dataset/butterfly/data/prosotas-noreia
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/prosotas-pia
# [ ThreadPoolExecutor-0_7   ]        Downloaded 131(+6) / 138 image(s) in insect-dataset/butterfly/data/elymnias-malelas
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-nesaea
# [ ThreadPoolExecutor-0_0   ]        Downloaded 59(+0) / 60 image(s) in insect-dataset/butterfly/data/burara-vasutana
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/choaspes-benjaminii
# [ ThreadPoolExecutor-0_3   ]        Downloaded 20(+3) / 24 image(s) in insect-dataset/butterfly/data/prosotas-pia
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/pseudophilotes-vicrama
# [ ThreadPoolExecutor-0_8   ]        Downloaded 32(+3) / 36 image(s) in insect-dataset/butterfly/data/rhaphicera-moorei
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/rhaphicera-satricus
# [ ThreadPoolExecutor-0_2   ]        Downloaded 76(+3) / 80 image(s) in insect-dataset/butterfly/data/tagiades-menaka
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tagiades-parra
# [ ThreadPoolExecutor-0_3   ]        Downloaded 8(+3) / 12 image(s) in insect-dataset/butterfly/data/pseudophilotes-vicrama
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/pseudozizeeria-maha
# [ ThreadPoolExecutor-0_6   ]        Downloaded 75(+5) / 81 image(s) in insect-dataset/butterfly/data/athyma-orientalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-perius
# [ ThreadPoolExecutor-0_10  ]        Downloaded 98(+6) / 105 image(s) in insect-dataset/butterfly/data/dodona-durga
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-egeon
# [ ThreadPoolExecutor-0_9   ]        Downloaded 149(+0) / 150 image(s) in insect-dataset/butterfly/data/pachliopta-aristolochiae
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/pachliopta-hector
# [ ThreadPoolExecutor-0_7   ]        Downloaded 36(+0) / 37 image(s) in insect-dataset/butterfly/data/elymnias-nesaea
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-obnubila
# [ ThreadPoolExecutor-0_7   ]        Downloaded 3(+1) / 5 image(s) in insect-dataset/butterfly/data/elymnias-obnubila
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-panthera
# [ ThreadPoolExecutor-0_8   ]        Downloaded 19(+3) / 23 image(s) in insect-dataset/butterfly/data/rhaphicera-satricus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-adolphei
# [ ThreadPoolExecutor-0_2   ]        Downloaded 19(+2) / 22 image(s) in insect-dataset/butterfly/data/tagiades-parra
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/tapena-thwaitesi
# [ ThreadPoolExecutor-0_7   ]        Downloaded 3(+3) / 7 image(s) in insect-dataset/butterfly/data/elymnias-panthera
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-patna
# [ ThreadPoolExecutor-0_5   ]        Downloaded 73(+3) / 77 image(s) in insect-dataset/butterfly/data/charaxes-marmax
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-moori
# [ ThreadPoolExecutor-0_8   ]        Downloaded 18(+3) / 22 image(s) in insect-dataset/butterfly/data/telinga-adolphei
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-davisoni
# [ ThreadPoolExecutor-0_1   ]        Downloaded 83(+0) / 84 image(s) in insect-dataset/butterfly/data/borbo-bevani
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/borbo-cinnara
# [ ThreadPoolExecutor-0_10  ]        Downloaded 49(+4) / 54 image(s) in insect-dataset/butterfly/data/dodona-egeon
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-eugenes
# [ ThreadPoolExecutor-0_0   ]        Downloaded 68(+0) / 69 image(s) in insect-dataset/butterfly/data/choaspes-benjaminii
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/choaspes-furcata
# [ ThreadPoolExecutor-0_8   ]        Downloaded 19(+1) / 21 image(s) in insect-dataset/butterfly/data/telinga-davisoni
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=41
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-heri
# [ ThreadPoolExecutor-0_5   ]        Downloaded 33(+5) / 39 image(s) in insect-dataset/butterfly/data/charaxes-moori
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-narcaeus
# [ ThreadPoolExecutor-0_4   ]        Downloaded 157(+0) / 158 image(s) in insect-dataset/butterfly/data/rapala-manea
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-melida
# [ ThreadPoolExecutor-0_7   ]        Downloaded 45(+3) / 49 image(s) in insect-dataset/butterfly/data/elymnias-patna
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-peali
# [ ThreadPoolExecutor-0_4   ]        Downloaded 2(+0) / 3 image(s) in insect-dataset/butterfly/data/rapala-melida
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-nissa
# [ ThreadPoolExecutor-0_8   ]        Downloaded 19(+4) / 24 image(s) in insect-dataset/butterfly/data/telinga-heri
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-lepcha
# [ ThreadPoolExecutor-0_5   ]        Downloaded 28(+1) / 30 image(s) in insect-dataset/butterfly/data/charaxes-narcaeus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-psaphon
# [ ThreadPoolExecutor-0_7   ]        Downloaded 26(+5) / 32 image(s) in insect-dataset/butterfly/data/elymnias-peali
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-penanga
# [ ThreadPoolExecutor-0_8   ]        Downloaded 18(+3) / 22 image(s) in insect-dataset/butterfly/data/telinga-lepcha
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-malsara
# [ ThreadPoolExecutor-0_0   ]        Downloaded 45(+0) / 46 image(s) in insect-dataset/butterfly/data/choaspes-furcata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/choaspes-choaspes-spp
# [ ThreadPoolExecutor-0_7   ]        Downloaded 26(+6) / 33 image(s) in insect-dataset/butterfly/data/elymnias-penanga
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/elymnias-vasudeva
# [ ThreadPoolExecutor-0_2   ]        Downloaded 121(+2) / 124 image(s) in insect-dataset/butterfly/data/tapena-thwaitesi
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-acuta
# [ ThreadPoolExecutor-0_0   ]        Downloaded 37(+2) / 40 image(s) in insect-dataset/butterfly/data/choaspes-choaspes-spp
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/choaspes-stigmata
# [ ThreadPoolExecutor-0_8   ]        Downloaded 42(+5) / 48 image(s) in insect-dataset/butterfly/data/telinga-malsara
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-malsarida
# [ ThreadPoolExecutor-0_7   ]        Downloaded 21(+3) / 25 image(s) in insect-dataset/butterfly/data/elymnias-vasudeva
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/cyllogenes-janetae
# [ ThreadPoolExecutor-0_3   ]        Downloaded 143(+0) / 144 image(s) in insect-dataset/butterfly/data/pseudozizeeria-maha
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/shijimia-moorei
# [ ThreadPoolExecutor-0_10  ]        Downloaded 103(+2) / 106 image(s) in insect-dataset/butterfly/data/dodona-eugenes
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-longicaudata
# [ ThreadPoolExecutor-0_9   ]        Downloaded 151(+5) / 157 image(s) in insect-dataset/butterfly/data/pachliopta-hector
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/pachliopta-pandiyana
# [ ThreadPoolExecutor-0_0   ]        Downloaded 20(+0) / 21 image(s) in insect-dataset/butterfly/data/choaspes-stigmata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/choaspes-xanthopogon
# [ ThreadPoolExecutor-0_4   ]        Downloaded 94(+2) / 97 image(s) in insect-dataset/butterfly/data/rapala-nissa
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-pheretima
# [ ThreadPoolExecutor-0_7   ]        Downloaded 16(+3) / 20 image(s) in insect-dataset/butterfly/data/cyllogenes-janetae
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/cyllogenes-suradeva
# [ ThreadPoolExecutor-0_10  ]        Downloaded 7(+1) / 9 image(s) in insect-dataset/butterfly/data/dodona-longicaudata
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/dodona-ouida
# [ ThreadPoolExecutor-0_7   ]        Downloaded 4(+4) / 9 image(s) in insect-dataset/butterfly/data/cyllogenes-suradeva
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/melanitis-leda
# [ ThreadPoolExecutor-0_0   ]        Downloaded 7(+0) / 8 image(s) in insect-dataset/butterfly/data/choaspes-xanthopogon
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-anura
# [ ThreadPoolExecutor-0_3   ]        Downloaded 23(+3) / 27 image(s) in insect-dataset/butterfly/data/shijimia-moorei
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/talicada-nyseus
# [ ThreadPoolExecutor-0_6   ]        Downloaded 176(+2) / 179 image(s) in insect-dataset/butterfly/data/athyma-perius
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-pravara
# [ ThreadPoolExecutor-0_8   ]        Downloaded 54(+4) / 59 image(s) in insect-dataset/butterfly/data/telinga-malsarida
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-mestra
# [ ThreadPoolExecutor-0_0   ]        Downloaded 32(+0) / 33 image(s) in insect-dataset/butterfly/data/hasora-anura
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-badra
# [ ThreadPoolExecutor-0_1   ]        Downloaded 182(+0) / 183 image(s) in insect-dataset/butterfly/data/borbo-cinnara
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/caltoris-aurociliata
# [ ThreadPoolExecutor-0_1   ]        Downloaded 1(+1) / 3 image(s) in insect-dataset/butterfly/data/caltoris-aurociliata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/caltoris-canaraica
# [ ThreadPoolExecutor-0_8   ]        Downloaded 21(+0) / 22 image(s) in insect-dataset/butterfly/data/telinga-mestra
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-misenus
# [ ThreadPoolExecutor-0_10  ]        Downloaded 53(+4) / 58 image(s) in insect-dataset/butterfly/data/dodona-ouida
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/stiboges-nymphidia
# [ ThreadPoolExecutor-0_9   ]        Downloaded 66(+3) / 70 image(s) in insect-dataset/butterfly/data/pachliopta-pandiyana
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/troides-aeacus
# [ ThreadPoolExecutor-0_8   ]        Downloaded 12(+3) / 16 image(s) in insect-dataset/butterfly/data/telinga-misenus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-nicotia
# [ ThreadPoolExecutor-0_10  ]        Downloaded 21(+2) / 24 image(s) in insect-dataset/butterfly/data/stiboges-nymphidia
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/zemeros-flegyas
# [ ThreadPoolExecutor-0_6   ]        Downloaded 61(+3) / 65 image(s) in insect-dataset/butterfly/data/athyma-pravara
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-punctata
# [ ThreadPoolExecutor-0_6   ]        Downloaded 10(+2) / 13 image(s) in insect-dataset/butterfly/data/athyma-punctata
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-ranga
# [ ThreadPoolExecutor-0_5   ]        Downloaded 177(+0) / 178 image(s) in insect-dataset/butterfly/data/charaxes-psaphon
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-schreiber
# [ ThreadPoolExecutor-0_9   ]        Downloaded 44(+4) / 49 image(s) in insect-dataset/butterfly/data/troides-aeacus
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/troides-helena
# [ ThreadPoolExecutor-0_8   ]        Downloaded 32(+4) / 37 image(s) in insect-dataset/butterfly/data/telinga-nicotia
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/telinga-oculus
# [ ThreadPoolExecutor-0_4   ]        Downloaded 128(+4) / 133 image(s) in insect-dataset/butterfly/data/rapala-pheretima
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-rectivitta
# [ ThreadPoolExecutor-0_2   ]        Downloaded 149(+1) / 151 image(s) in insect-dataset/butterfly/data/curetis-acuta
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-bulis
# [ ThreadPoolExecutor-0_4   ]        Downloaded 6(+1) / 8 image(s) in insect-dataset/butterfly/data/rapala-rectivitta
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-refulgens
# [ ThreadPoolExecutor-0_4   ]        Downloaded 1(+1) / 3 image(s) in insect-dataset/butterfly/data/rapala-refulgens
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-selira
# [ ThreadPoolExecutor-0_5   ]        Downloaded 47(+3) / 51 image(s) in insect-dataset/butterfly/data/charaxes-schreiber
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/charaxes-solon
# [ ThreadPoolExecutor-0_3   ]        Downloaded 142(+1) / 144 image(s) in insect-dataset/butterfly/data/talicada-nyseus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/tarucus-ananda
# [ ThreadPoolExecutor-0_1   ]        Downloaded 111(+0) / 112 image(s) in insect-dataset/butterfly/data/caltoris-canaraica
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/caltoris-kumara
# [ ThreadPoolExecutor-0_7   ]        Downloaded 162(+0) / 163 image(s) in insect-dataset/butterfly/data/melanitis-leda
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/melanitis-phedima
# [ ThreadPoolExecutor-0_8   ]        Downloaded 47(+21) / 69 image(s) in insect-dataset/butterfly/data/telinga-oculus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ypthima-affectata
# [ ThreadPoolExecutor-0_4   ]        Downloaded 37(+2) / 40 image(s) in insect-dataset/butterfly/data/rapala-selira
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-suffusa
# [ ThreadPoolExecutor-0_8   ]        Downloaded 7(+7) / 15 image(s) in insect-dataset/butterfly/data/ypthima-affectata
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ypthima-asterope
# [ ThreadPoolExecutor-0_4   ]        Downloaded 13(+0) / 14 image(s) in insect-dataset/butterfly/data/rapala-suffusa
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-tara
# [ ThreadPoolExecutor-0_0   ]        Downloaded 168(+0) / 169 image(s) in insect-dataset/butterfly/data/hasora-badra
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-chromus
# [ ThreadPoolExecutor-0_2   ]        Downloaded 82(+1) / 84 image(s) in insect-dataset/butterfly/data/curetis-bulis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-saronis
# [ ThreadPoolExecutor-0_4   ]        Downloaded 22(+3) / 26 image(s) in insect-dataset/butterfly/data/rapala-tara
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/rapala-varuna
# [ ThreadPoolExecutor-0_9   ]        Downloaded 100(+6) / 107 image(s) in insect-dataset/butterfly/data/troides-helena
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/troides-minos
# [ ThreadPoolExecutor-0_10  ]        Downloaded 143(+2) / 146 image(s) in insect-dataset/butterfly/data/zemeros-flegyas
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/graphium-agamemnon
# [ ThreadPoolExecutor-0_2   ]        Downloaded 30(+4) / 35 image(s) in insect-dataset/butterfly/data/curetis-saronis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-siva
# [ ThreadPoolExecutor-0_6   ]        Downloaded 153(+2) / 156 image(s) in insect-dataset/butterfly/data/athyma-ranga
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-rufula
# [ ThreadPoolExecutor-0_6   ]        Downloaded 11(+1) / 13 image(s) in insect-dataset/butterfly/data/athyma-rufula
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/athyma-selenophora
# [ ThreadPoolExecutor-0_5   ]        Downloaded 150(+3) / 154 image(s) in insect-dataset/butterfly/data/charaxes-solon
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/prothoe-franck
# [ ThreadPoolExecutor-0_8   ]        Downloaded 123(+4) / 128 image(s) in insect-dataset/butterfly/data/ypthima-asterope
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ypthima-avanta
# [ ThreadPoolExecutor-0_5   ]        Downloaded 3(+1) / 5 image(s) in insect-dataset/butterfly/data/prothoe-franck
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/chersonesia-intermedia
# [ ThreadPoolExecutor-0_3   ]        Downloaded 153(+4) / 158 image(s) in insect-dataset/butterfly/data/tarucus-ananda
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/tarucus-balkanica
# [ ThreadPoolExecutor-0_2   ]        Downloaded 71(+5) / 77 image(s) in insect-dataset/butterfly/data/curetis-siva
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-curetis-spp
# [ ThreadPoolExecutor-0_7   ]        Downloaded 149(+2) / 152 image(s) in insect-dataset/butterfly/data/melanitis-phedima
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=36
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/melanitis-zitenius
# [ ThreadPoolExecutor-0_8   ]        Downloaded 14(+3) / 18 image(s) in insect-dataset/butterfly/data/ypthima-avanta
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ypthima-baldus
# [ ThreadPoolExecutor-0_1   ]        Downloaded 171(+5) / 177 image(s) in insect-dataset/butterfly/data/caltoris-kumara
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/caltoris-philippina
# [ ThreadPoolExecutor-0_2   ]        Downloaded 19(+6) / 26 image(s) in insect-dataset/butterfly/data/curetis-curetis-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/curetis-thetis
# [ ThreadPoolExecutor-0_0   ]        Downloaded 155(+0) / 156 image(s) in insect-dataset/butterfly/data/hasora-chromus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-khoda
# [ ThreadPoolExecutor-0_0   ]        Downloaded 1(+1) / 3 image(s) in insect-dataset/butterfly/data/hasora-khoda
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-leucospila
# [ ThreadPoolExecutor-0_0   ]        Downloaded 3(+0) / 4 image(s) in insect-dataset/butterfly/data/hasora-leucospila
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-taminatus
# [ ThreadPoolExecutor-0_5   ]        Downloaded 46(+3) / 50 image(s) in insect-dataset/butterfly/data/chersonesia-intermedia
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/chersonesia-risa
# [ ThreadPoolExecutor-0_10  ]        Downloaded 141(+1) / 143 image(s) in insect-dataset/butterfly/data/graphium-agamemnon
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/burara-spp2
# [ ThreadPoolExecutor-0_10  ]        Downloaded 6(+0) / 7 image(s) in insect-dataset/butterfly/data/burara-spp2
# [ ThreadPoolExecutor-0_10  ]      Scraping URL: https://www.ifoundbutterflies.org/hasora-hasora-spp
# ...
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/astictopterus-jama
# [ ThreadPoolExecutor-0_6   ]        Downloaded 78(+1) / 80 image(s) in insect-dataset/butterfly/data/neptis-clinia
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-harita
# [ ThreadPoolExecutor-0_8   ]        Downloaded 46(+2) / 49 image(s) in insect-dataset/butterfly/data/ypthima-ypthimoides
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/zipaetis-saitis
# [ ThreadPoolExecutor-0_1   ]        Downloaded 49(+2) / 52 image(s) in insect-dataset/butterfly/data/pelopidas-subochracea
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/polytremis-discreta
# [ ThreadPoolExecutor-0_2   ]        Downloaded 25(+1) / 27 image(s) in insect-dataset/butterfly/data/logania-distanti
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/miletus-chinensis
# [ ThreadPoolExecutor-0_6   ]        Downloaded 26(+3) / 30 image(s) in insect-dataset/butterfly/data/neptis-harita
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-hylas
# [ ThreadPoolExecutor-0_2   ]        Downloaded 27(+6) / 34 image(s) in insect-dataset/butterfly/data/miletus-chinensis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/spalgis-epius
# [ ThreadPoolExecutor-0_0   ]        Downloaded 60(+0) / 61 image(s) in insect-dataset/butterfly/data/astictopterus-jama
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/baracus-hampsoni
# [ ThreadPoolExecutor-0_8   ]        Downloaded 64(+0) / 65 image(s) in insect-dataset/butterfly/data/zipaetis-saitis
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/zipaetis-scylax
# [ ThreadPoolExecutor-0_1   ]        Downloaded 62(+1) / 64 image(s) in insect-dataset/butterfly/data/polytremis-discreta
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/polytremis-eltola
# [ ThreadPoolExecutor-0_9   ]        Downloaded 151(+0) / 152 image(s) in insect-dataset/butterfly/data/eurema-brigitta
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/eurema-hecabe
# [ ThreadPoolExecutor-0_7   ]        Downloaded 117(+4) / 122 image(s) in insect-dataset/butterfly/data/lethe-drypetis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-dura
# [ ThreadPoolExecutor-0_3   ]        Downloaded 149(+0) / 150 image(s) in insect-dataset/butterfly/data/zizina-otis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/zizula-hylax
# [ ThreadPoolExecutor-0_8   ]        Downloaded 40(+2) / 43 image(s) in insect-dataset/butterfly/data/zipaetis-scylax
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/ethope-himachala
# [ ThreadPoolExecutor-0_4   ]        Downloaded 153(+3) / 157 image(s) in insect-dataset/butterfly/data/zeltus-amasa
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/bullis-buto
# [ ThreadPoolExecutor-0_7   ]        Downloaded 18(+3) / 22 image(s) in insect-dataset/butterfly/data/lethe-dura
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-europa
# [ ThreadPoolExecutor-0_4   ]        Downloaded 6(+2) / 9 image(s) in insect-dataset/butterfly/data/bullis-buto
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/charana-mandarinus
# [ ThreadPoolExecutor-0_0   ]        Downloaded 100(+1) / 102 image(s) in insect-dataset/butterfly/data/baracus-hampsoni
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/baracus-septentrionum
# [ ThreadPoolExecutor-0_0   ]        Downloaded 3(+0) / 4 image(s) in insect-dataset/butterfly/data/baracus-septentrionum
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/baracus-subditus
# [ ThreadPoolExecutor-0_5   ]        Downloaded 195(+3) / 199 image(s) in insect-dataset/butterfly/data/euploea-mulciber
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/euploea-radamanthus
# [ ThreadPoolExecutor-0_4   ]        Downloaded 38(+4) / 43 image(s) in insect-dataset/butterfly/data/charana-mandarinus
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/creon-cleobis
# [ ThreadPoolExecutor-0_0   ]        Downloaded 19(+0) / 20 image(s) in insect-dataset/butterfly/data/baracus-subditus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/creteus-cyrina
# [ ThreadPoolExecutor-0_1   ]        Downloaded 121(+4) / 126 image(s) in insect-dataset/butterfly/data/polytremis-eltola
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/polytremis-lubricans
# [ ThreadPoolExecutor-0_6   ]        Downloaded 159(+0) / 160 image(s) in insect-dataset/butterfly/data/neptis-hylas
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-jumbah
# [ ThreadPoolExecutor-0_2   ]        Downloaded 151(+0) / 152 image(s) in insect-dataset/butterfly/data/spalgis-epius
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/taraka-hamada
# [ ThreadPoolExecutor-0_8   ]        Downloaded 79(+3) / 83 image(s) in insect-dataset/butterfly/data/ethope-himachala
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neorina-hilda
# [ ThreadPoolExecutor-0_9   ]        Downloaded 128(+0) / 129 image(s) in insect-dataset/butterfly/data/eurema-hecabe
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/eurema-laeta
# [ ThreadPoolExecutor-0_0   ]        Downloaded 25(+0) / 26 image(s) in insect-dataset/butterfly/data/creteus-cyrina
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/cupitha-purreea
# [ ThreadPoolExecutor-0_5   ]        Downloaded 53(+2) / 56 image(s) in insect-dataset/butterfly/data/euploea-radamanthus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/euploea-scherzeri
# [ ThreadPoolExecutor-0_5   ]        Downloaded 4(+2) / 7 image(s) in insect-dataset/butterfly/data/euploea-scherzeri
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/euploea-sylvester
# [ ThreadPoolExecutor-0_8   ]        Downloaded 24(+0) / 25 image(s) in insect-dataset/butterfly/data/neorina-hilda
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/neorina-patria
# [ ThreadPoolExecutor-0_8   ]        Downloaded 5(+2) / 8 image(s) in insect-dataset/butterfly/data/neorina-patria
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/penthema-lisarda
# [ ThreadPoolExecutor-0_4   ]        Downloaded 58(+3) / 62 image(s) in insect-dataset/butterfly/data/creon-cleobis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/dacalana-cotys
# [ ThreadPoolExecutor-0_4   ]        Downloaded 11(+2) / 14 image(s) in insect-dataset/butterfly/data/dacalana-cotys
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/dacalana-penicilligera
# [ ThreadPoolExecutor-0_3   ]        Downloaded 144(+0) / 145 image(s) in insect-dataset/butterfly/data/zizula-hylax
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/poritia-hewitsoni
# [ ThreadPoolExecutor-0_2   ]        Downloaded 62(+2) / 65 image(s) in insect-dataset/butterfly/data/taraka-hamada
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/anthene-emolus
# [ ThreadPoolExecutor-0_7   ]        Downloaded 134(+0) / 135 image(s) in insect-dataset/butterfly/data/lethe-europa
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=38
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-gemina
# [ ThreadPoolExecutor-0_8   ]        Downloaded 35(+5) / 41 image(s) in insect-dataset/butterfly/data/penthema-lisarda
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/graphium-agetes
# [ ThreadPoolExecutor-0_7   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/lethe-gemina
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-goalpara
# [ ThreadPoolExecutor-0_1   ]        Downloaded 90(+4) / 95 image(s) in insect-dataset/butterfly/data/polytremis-lubricans
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/hesperia-comma
# [ ThreadPoolExecutor-0_4   ]        Downloaded 33(+3) / 37 image(s) in insect-dataset/butterfly/data/dacalana-penicilligera
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/maneca-bhotea
# [ ThreadPoolExecutor-0_1   ]        Downloaded 9(+0) / 10 image(s) in insect-dataset/butterfly/data/hesperia-comma
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/ochlodes-brahma
# [ ThreadPoolExecutor-0_7   ]        Downloaded 20(+0) / 21 image(s) in insect-dataset/butterfly/data/lethe-goalpara
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-gulnihal
# [ ThreadPoolExecutor-0_4   ]        Downloaded 9(+2) / 12 image(s) in insect-dataset/butterfly/data/maneca-bhotea
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/neocheritra-fabronia
# [ ThreadPoolExecutor-0_0   ]        Downloaded 98(+0) / 99 image(s) in insect-dataset/butterfly/data/cupitha-purreea
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=2
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/erionota-acroleuca
# [ ThreadPoolExecutor-0_4   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/neocheritra-fabronia
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/pratapa-deva
# [ ThreadPoolExecutor-0_7   ]        Downloaded 17(+3) / 21 image(s) in insect-dataset/butterfly/data/lethe-gulnihal
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-isana
# [ ThreadPoolExecutor-0_0   ]        Downloaded 10(+0) / 11 image(s) in insect-dataset/butterfly/data/erionota-acroleuca
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/erionota-apex
# [ ThreadPoolExecutor-0_1   ]        Downloaded 28(+6) / 35 image(s) in insect-dataset/butterfly/data/ochlodes-brahma
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/ochlodes-siva
# [ ThreadPoolExecutor-0_9   ]        Downloaded 135(+1) / 137 image(s) in insect-dataset/butterfly/data/eurema-laeta
# [ ThreadPoolExecutor-0_9   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=47
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/eurema-nilgiriensis
# [ ThreadPoolExecutor-0_8   ]        Downloaded 65(+2) / 68 image(s) in insect-dataset/butterfly/data/graphium-agetes
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.ifoundbutterflies.org/graphium-antiphates
# [ ThreadPoolExecutor-0_1   ]        Downloaded 21(+2) / 24 image(s) in insect-dataset/butterfly/data/ochlodes-siva
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.ifoundbutterflies.org/cephrenes-acalle
# [ ThreadPoolExecutor-0_0   ]        Downloaded 29(+0) / 30 image(s) in insect-dataset/butterfly/data/erionota-apex
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/erionota-thrax
# [ ThreadPoolExecutor-0_3   ]        Downloaded 108(+3) / 112 image(s) in insect-dataset/butterfly/data/poritia-hewitsoni
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/simiskina-phalena
# [ ThreadPoolExecutor-0_6   ]        Downloaded 167(+0) / 168 image(s) in insect-dataset/butterfly/data/neptis-jumbah
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-magadha
# [ ThreadPoolExecutor-0_5   ]        Downloaded 139(+0) / 140 image(s) in insect-dataset/butterfly/data/euploea-sylvester
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/idea-agamarschana
# [ ThreadPoolExecutor-0_3   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/simiskina-phalena
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.ifoundbutterflies.org/amblypodia-anita
# [ ThreadPoolExecutor-0_7   ]        Downloaded 54(+1) / 56 image(s) in insect-dataset/butterfly/data/lethe-isana
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-jalaurida
# [ ThreadPoolExecutor-0_9   ]        Downloaded 36(+2) / 39 image(s) in insect-dataset/butterfly/data/eurema-nilgiriensis
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/eurema-simulatrix
# [ ThreadPoolExecutor-0_5   ]        Downloaded 19(+0) / 20 image(s) in insect-dataset/butterfly/data/idea-agamarschana
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.ifoundbutterflies.org/idea-malabarica
# [ ThreadPoolExecutor-0_0   ]        Downloaded 28(+0) / 29 image(s) in insect-dataset/butterfly/data/erionota-thrax
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.ifoundbutterflies.org/erionota-torus
# [ ThreadPoolExecutor-0_7   ]        Downloaded 6(+1) / 8 image(s) in insect-dataset/butterfly/data/lethe-jalaurida
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-kabrua
# [ ThreadPoolExecutor-0_7   ]        Downloaded 4(+3) / 8 image(s) in insect-dataset/butterfly/data/lethe-kabrua
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-kanjupkula
# [ ThreadPoolExecutor-0_6   ]        Downloaded 34(+1) / 36 image(s) in insect-dataset/butterfly/data/neptis-magadha
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-mahendra
# [ ThreadPoolExecutor-0_9   ]        Downloaded 20(+3) / 24 image(s) in insect-dataset/butterfly/data/eurema-simulatrix
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/eurema-eurema-spp
# [ ThreadPoolExecutor-0_4   ]        Downloaded 93(+3) / 97 image(s) in insect-dataset/butterfly/data/pratapa-deva
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.ifoundbutterflies.org/lepidoptera?page=22
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.ifoundbutterflies.org/pratapa-icetas
# [ ThreadPoolExecutor-0_7   ]        Downloaded 10(+3) / 14 image(s) in insect-dataset/butterfly/data/lethe-kanjupkula
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-kansa
# [ ThreadPoolExecutor-0_6   ]        Downloaded 17(+0) / 18 image(s) in insect-dataset/butterfly/data/neptis-mahendra
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-manasa
# [ ThreadPoolExecutor-0_9   ]        Downloaded 15(+3) / 19 image(s) in insect-dataset/butterfly/data/eurema-eurema-spp
# [ ThreadPoolExecutor-0_9   ]      Scraping URL: https://www.ifoundbutterflies.org/gandaca-harina
# [ ThreadPoolExecutor-0_2   ]        Downloaded 176(+3) / 180 image(s) in insect-dataset/butterfly/data/anthene-emolus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.ifoundbutterflies.org/anthene-lycaenina
# [ ThreadPoolExecutor-0_6   ]        Downloaded 7(+0) / 8 image(s) in insect-dataset/butterfly/data/neptis-manasa
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-melba
# [ ThreadPoolExecutor-0_7   ]        Downloaded 29(+1) / 31 image(s) in insect-dataset/butterfly/data/lethe-kansa
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.ifoundbutterflies.org/lethe-latiaris
# [ ThreadPoolExecutor-0_6   ]        Downloaded 10(+0) / 11 image(s) in insect-dataset/butterfly/data/neptis-melba
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.ifoundbutterflies.org/neptis-miah

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(f"{dataset_dir}/data").iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
    if species_dir.is_dir() and not os.listdir(species_dir):
        os.rmdir(species_dir)
        print(f"Empty folder {species_dir} removed")

# %% [markdown]
# # ZIP the data

# %%
import shutil
import time
import datetime

shutil.make_archive(f"{dataset_dir}/ifoundbutterflies.org.{datetime.datetime.now().strftime("%Y.%m.%d")}", 'zip', f"{dataset_dir}/data")
# Out:
# 'D:\\Projects\\my-jupyter-notebook\\moth-species-identification\\insect-dataset\\butterfly\\ifoundbutterflies.org.2025.02.05.zip'
