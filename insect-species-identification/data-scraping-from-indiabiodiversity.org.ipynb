# %% [markdown]
# # Scrape https://indiabiodiversity.org

# %%
dataset_dir = "insect-dataset/indiabiodiversity"

import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor
from PIL import Image
from pathlib import Path
import requests
import time
import datetime

page_timeout = 120
image_timeout = 30

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

def download_image(img_url, output_dir):
    try:
        # print(f"{log_header()} Downloading {img_url} into {output_dir}")
        # print(f"{log_header()} Downloading {img_url.split("/")[-1].split("?")[0]} into {output_dir.split("/")[-1]}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name.split("?")[0])
        if Path(img_path).is_file() and check_image(img_path):
            # skipping, already downloaded
            return 'EXISTS'
        img_data = requests.get(img_url, timeout=image_timeout).content
        with open(img_path, 'wb') as file:
            file.write(img_data)
        if not check_image(img_path):
            print(f"{log_header()}Removing corrupted image {file}")
            os.remove(Path(img_path))
            return 'FAILURE'
        return 'SUCCESS'
    except Exception as e:
        print(f"{log_header()}{e}")
        return 'FAILURE'

def fetch_json(url, method, headers, params):
    if method == 'get':
        return requests.get(url, headers=headers, params=params).json()
    else:
        return requests.post(url, headers=headers, params=params, json={}).json()

img_base_url = "https://indiabiodiversity.org/files-api/api/get/crop/"
context_map = {
    "OBSERVATION": "observations",
    "SPECIES": "img"
}
headers = {
    "accept": "application/json, text/plain, */*",
}
def scrape(url, method, list_key, img_src_key, get_class_name, params, start_offset=0, step=10, steps_in_batch=100000):
    print(f"{log_header()}Starting scraping from {url} with offset={start_offset}, step={step}, steps_in_batch={steps_in_batch}")
    start_time = time.time()
    total_count = fetch_json(url, method, headers=headers, params=params)['totalCount']
    # print(f"{log_header()}Total count: {total_count}")
    img_cnt = 0
    success_cnt = 0
    failure_cnt = 0
    for offset in range(start_offset, min(total_count, start_offset+step*steps_in_batch), step):
        params['offset'] = f"{offset}"
        response = fetch_json(url, method, headers=headers, params=params)
        for obj in response[list_key]:
            try:
                class_name = get_class_name(obj)
                context_path = context_map[obj['context']] if 'context' in obj else "observations"
                img_url = f"{img_base_url}/{context_path}/{obj[img_src_key]}?h=300"
                target_dir = f"{dataset_dir}/{class_name}"
                download_status = download_image(img_url, target_dir)
                if download_status == 'SUCCESS':
                    success_cnt += 1
                    img_cnt += 1
                elif download_status == 'EXISTS':
                    img_cnt += 1
                else:
                    failure_cnt += 1
            except Exception as e:
                print(f"{log_header()}{e}")
        class_cnt = sum(1 for entry in os.scandir(dataset_dir) if entry.is_dir())
        print(f"{log_header()}Offset: {offset:5} | Success: {success_cnt:5} / {img_cnt:5} | Failure: {failure_cnt:5} | Class count: {class_cnt:5}")
    print(f"{log_header()}Scraping completed in {datetime.timedelta(seconds=(time.time() - start_time))}")

# %%
scrape("https://indiabiodiversity.org/species-api/api/v1/species/list/extended_species/_doc", 'get',
      list_key = 'speciesTiles', img_src_key='reprImage',
      get_class_name = lambda obj: '-'.join(re.sub(r"<i>|</i>.*", "", obj['name']).lower().split(' ')[0:2]),
      params = {
          "view": "grid",
          "max": "16",
          "mediaFilter": "IMAGE",
          "offset": "0",
          "sGroup": "839",
          "sort": "species.lastUpdated",
          "taxon": "70513"
      })
# Out:
# [ MainThread               ]  Starting scraping from https://indiabiodiversity.org/species-api/api/v1/species/list/extended_species/_doc with offset=0, step=10, steps_in_batch=100000
# [ MainThread               ]  Offset:     0 | Success:     0 /    16 | Failure:     0 | Class count:  1275
# [ MainThread               ]  Offset:
# [ MainThread               ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity/celastrina-oreana\\72.jpg'>
# [ MainThread               ]  Offset:   860 | Success:     0 /  1390 | Failure:     2 | Class count:  1275
# [ MainThread               ]  Offset:   870 | Success:     0 /  1406 | Failure:     2 | Class count:  1275
# [ MainThread               ]  Offset:   880 | Success:     0 /  1422 | Failure:     2 | Class count:  1275
# [ MainThread               ]  Offset:   890 | Success:     0 /  1438 | Failure:     2 | Class count:  1275
# [ MainThread               ]  Offset:   900 | Success:     0 /  1454 | Failure:     2 | Class count:  1275
# [ MainThread               ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity/udara-dilecta\\72b.jpg'>
# [ MainThread               ]  Offset:   910 | Success:     0 /  1469 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   920 | Success:     0 /  1485 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   930 | Success:     0 /  1501 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   940 | Success:     0 /  1517 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   950 | Success:     0 /  1533 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   960 | Success:     0 /  1549 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   970 | Success:     0 /  1565 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Offset:   980 | Success:     0 /  1575 | Failure:     3 | Class count:  1275
# [ MainThread               ]  Scraping completed in 0:01:54.409370

# %%
max_workers = 50
step = 8
steps_in_batch = 100

def scrape_observations(offset, step, batch_size):
    scrape("https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc", 'post',
          list_key = 'observationList', img_src_key='reprImageUrl',
          get_class_name = lambda obj: '-'.join(re.sub(r"<i>|</i>.*", "", obj['recoShow']['recoIbp']['scientificName']).lower().split(' ')[0:2]),
          params = {
              "max": "8",
              "mediaFilter": "no_of_images",
              "offset": f"{offset}",
              "sort": "created_on",
              "taxon": "70513"
          },
          start_offset = offset, step = step, steps_in_batch = steps_in_batch)

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(scrape_observations, offset, step, steps_in_batch) for offset in range(0, 72037, step * steps_in_batch)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")
print("All threads completed")
# Out:
# [ ThreadPoolExecutor-0_0   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=0, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_1   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_2   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=1600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_3   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=2400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_4   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=3200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_5   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=4000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_6   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=4800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_7   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=5600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_8   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=6400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_9   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=7200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_10  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=8000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_11  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=8800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_12  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=9600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_13  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=10400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_14  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=11200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_15  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=12000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_16  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=12800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_17  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=13600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_18  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=14400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_19  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=15200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_20  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=16000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_21  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=16800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_22  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=17600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_23  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=18400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_24  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=19200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_25  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=20000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_26  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=20800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_27  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=21600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_28  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=22400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_29  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=23200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_30  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=24000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_31  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=24800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_32  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=25600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_33  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=26400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_34  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=27200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_35  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=28000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_36  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=28800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_37  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=29600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_38  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=30400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_39  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=31200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_40  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=32000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_41  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=32800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_42  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=33600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_43  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=34400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_44  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=35200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_45  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=36000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_46  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=36800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_47  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=37600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_48  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=38400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_49  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=39200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_5   ]  Offset:  4000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_2   ]  Offset:  1600 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_10  ]  Offset:  8000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_16  ]  Offset: 12800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_7   ]  Offset:  5600 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_4   ]  Offset:  3200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_8   ]  Offset:  6400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_14  ]  Offset: 11200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_26  ]  Offset: 20800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_9   ]  Offset:  7200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_6   ]  Offset:  4800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_45  ]  Offset: 36000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_34  ]  Offset: 27200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_41  ]  Offset: 32800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_48  ]  Offset: 38400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_23  ]  Offset: 18400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_3   ]  Offset:  2400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_13  ]  Offset: 10400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_36  ]  Offset: 28800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_49  ]  Offset: 39200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_29  ]  Offset: 23200 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_42  ]  Offset: 33600 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_35  ]  Offset: 28000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_25  ]  Offset: 20000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_30  ]  Offset: 24000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_12  ]  Offset:  9600 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_18  ]  Offset: 14400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_11  ]  Offset:  8800 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_33  ]  Offset: 26400 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_20  ]  Offset: 16000 | Success:     0 /     8 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0
 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_15  ]  Offset: 12016 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_20  ]  Offset: 16016 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_28  ]  Offset: 22416 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_43  ]  Offset: 34416 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_49  ]  Offset: 39216 | Success:     3 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_44  ]  Offset: 35216 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_17  ]  Offset: 13616 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_46  ]  Offset: 36816 | Success:     0 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_48  ]  Offset: 38416 | Success:     5 /    24 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_16  ]  Offset: 12824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_5   ]  Offset:  4024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_10  ]  Offset:  8024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_4   ]  Offset:  3224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_7   ]  Offset:  5624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_41  ]  Offset: 32824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_23  ]  Offset: 18424 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_26  ]  Offset: 20824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_25  ]  Offset: 20024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_42  ]  Offset: 33624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_19  ]  Offset: 15224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_32  ]  Offset: 25624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_6   ]  Offset:  4824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_27  ]  Offset: 21624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_30  ]  Offset: 24024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_29  ]  Offset: 23224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_37  ]  Offset: 29624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_24  ]  Offset: 19224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_31  ]  Offset: 24824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_36  ]  Offset: 28824 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_40  ]  Offset: 32024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_8   ]  Offset:  6424 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_45  ]  Offset: 36024 | Success:     1 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_47  ]  Offset: 37624 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_39  ]  Offset: 31224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_15  ]  Offset: 12024 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_28  ]  Offset: 22424 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_33  ]  Offset: 26424 | Success:     3 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_43  ]  Offset: 34424 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_38  ]  Offset: 30424 | Success:     3 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_34  ]  Offset: 27224 | Success:     3 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_44  ]  Offset: 35224 | Success:     0 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_20  ]  Offset: 16024 | Success:     4 /    32 | Failure:     0 | Class count:  1275
# [ ThreadPoolExecutor-0_21  ]  Offset: 16824 | Success:     6 /    32 | Failure:     0 | Class count:  1276
# [ ThreadPoolExecutor-0_17  ]  Offset: 13624 | Success:     0 /    32 | Failure:     0 | Class count:  1276
# [ ThreadPoolExecutor-0_3   ]  Offset:  2424 | Success:     5 /    32 | Failure:     0 | Class count:  1276
# [ ThreadPoolExecutor-0_0   ]  Offset:     0 | Success:     0 /     8 | Failure:     0 | Class count:  1276
# [ ThreadPoolExecutor-0_46  ]  Offset: 36824 | Success:     0 /    32 | Failure:     0 | Class count:  1276
# [ ThreadPoolExecutor-0_1   ]  Offset:   816 | Success:     8 /    24 | Failure:     0 | Class count:  1277
# [ ThreadPoolExecutor-0_5   ]  Offset:  4032 | Success:     0 /    40 | Failure:     0 | Class count:  1277
# [ ThreadPoolExecutor-0_26  ]  Offset: 20832 | Success:     0 /    40 | Failure:     0 | Class count:  1277
# [ ThreadPoolExecutor-0_42  ]  Offset: 33632 | Success:     0 /    40 | Failure:     0 | Class count:  1277
# [ ThreadPoolExecutor-0_27  ]  Offset: 21632 | Success:     0 /    40 | Failure:     0 | Class count:  1278
# [ ThreadPoolExecutor-0_24  ]  Offset: 19232 | Success:     0 /    40 | Failure:     0 | Class count:  1278
# [ ThreadPoolExecutor-0_29  ]  Offset: 23232 | Success:     0 /    40 | Failure:     0 | Class count:  1278
# [ ThreadPoolExecutor-0_32  ]  Offset: 25632 | Success:     0 /    40 | Failure:     0 | Class count:  1278
# [ ThreadPoolExecutor-0_37  ]  Offset: 29632 | Success:     0 /    40 | Failure:     0 | Class count:  1279
# [ ThreadPoolExecutor-0_28  ]  Offset: 22432 | Success:     0 /    40 | Failure:     0 | Class count:  1281
# [ ThreadPoolExecutor-0_8   ]  Offset:  6432 | Success:     0 /    40 | Failure:     0 | Class count:  1281
# [ ThreadPoolExecutor-0_15  ]  Offset: 12032 | Success:     0 /    40 | Failure:     0 | Class count:  1281
# [ ThreadPoolExecutor-0_16  ]  Offset: 12832 | Success:     2 /    40 | Failure:     0 | Class count:  1282
# [ ThreadPoolExecutor-0_4   ]  Offset:  3232 | Success:     2 /    40 | Failure:     0 | Class count:  1282
# [ ThreadPoolExecutor-0_14  ]  Offset: 11224 | Success:     5 /    32 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_31  ]  Offset: 24832 | Success:     3 /    40 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_43  ]  Offset: 34432 | Success:     0 /    40 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_7   ]  Offset:  5632 | Success:     5 /    40 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_22  ]  Offset: 17624 | Success:     8 /    32 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_6   ]  Offset:  4832 | Success:     5 /    40 | Failure:     0 | Class count:  1285
# [ ThreadPoolExecutor-0_0   ]  Offset:     8 | Success:     0 /    16 | Failure:     0 | Class count:  1286
# [ ThreadPoolExecutor-0_30  ]  Offset: 24032 | Success:     5 /    40 | Failure:     0 | Class count:  1288
# [ ThreadPoolExecutor-0_17  ]  Offset: 13632 | Success:     1 /    40 | Failure:     0 | Class count:  1289
# [ ThreadPoolExecutor-0_44  ]  Offset: 35232 | Success:     3 /    40 | Failure:     0 | Class count:  1291
# [ ThreadPoolExecutor-0_41  ]  Offset: 32832 | Success:     8 /    40 | Failure:     0 | Class count:  1291
# [ ThreadPoolExecutor-0_40  ]  Offset: 32032 | Success:     6 /    40 | Failure:     0 | Class count:  1291
# [ ThreadPoolExecutor-0_11  ]  Offset:  8824 | Success:     6 /    32 | Failure:     0 | Class count:  1291
# [ ThreadPoolExecutor-0_29  ]  Offset: 23240 | Success:     0 /    48 | Failure:     0 | Class count:  1291
# [ ThreadPoolExecutor-0_15  ]  Offset: 12040 | Success:     0 /    48 | Failure:     0 | Class count:  1292
# [ ThreadPoolExecutor-0_0   ]  Offset:    16 | Success:     0 /    24 | Failure:     0 | Class count:  1297
# [ ThreadPoolExecutor-0_18  ]  Offset: 14424 | Success:     8 /    32 | Failure:     0 | Class count:  1297
# [ ThreadPoolExecutor-0_8   ]  Offset:  6440 | Success:     3 /    48 | Failure:     0 | Class count:  1300
# [ ThreadPoolExecutor-0_0   ]  Offset:    24 | Success:     0 /    32 | Failure:     0 | Class count:  1300
# [ ThreadPoolExecutor-0_19  ]  Offset: 15232 | Success:     8 /    40 | Failure:     0 | Class count:  1301
# [ ThreadPoolExecutor-0_13  ]  Offset: 10424 | Success:     8 /    32 | Failure:     0 | Class count:  1302
# [ ThreadPoolExecutor-0_2   ]  Offset:  1624 | Success:     8 /    32 | Failure:     0 | Class count:  1302
# [ ThreadPoolExecutor-0_39  ]  Offset: 31232 | Success:     8 /    40 | Failure:     0 | Class count:  1303
# [ ThreadPoolExecutor-0_45  ]  Offset: 36032 | Success:     9 /    40 | Failure:     0 | Class count:  1303
# [ ThreadPoolExecutor-0_5   ]  Offset:  4040 | Success:     6 /    48 | Failure:     0 | Class count:  1303
# [ ThreadPoolExecutor-0_42  ]  Offset: 33640 | Success:     3 /    48 | Failure:     0 | Class count:  1304
# [ ThreadPoolExecutor-0_21  ]  Offset: 16832 | Success:    14 /    40 | Failure:     0 | Class count:  1304
# [ ThreadPoolExecutor-0_0   ]  Offset:    32 | Success:     0 /    40 | Failure:     0 | Class count:  1304
# [ ThreadPoolExecutor-0_3   ]  Offset:  2432 | Success:    13 /    40 | Failure:     0 | Class count:  1304
# [ ThreadPoolExecutor-0_27  ]  Offset: 21640 | Success:     8 /    48 | Failure:     0 | Class count:  1304
# [ ThreadPoolExecutor-0_47  ]  Offset: 37632 | Success:     8 /    40 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_9   ]  Offset:  7224 | Success:     9 /    32 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_10  ]  Offset:  8032 | Success:     8 /    40 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_33  ]  Offset: 26432 | Success:    11 /    40 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_12  ]  Offset:  9624 | Success:     8 /    32 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_37  ]  Offset: 29640 | Success:     8 /    48 | Failure:     0 | Class count:  1305
# [ ThreadPoolExecutor-0_7   ]  Offset:  5640 | Success:    13 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_40  ]  Offset: 32040 | Success:    14 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_31  ]  Offset: 24840 | Success:    11 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_26  ]  Offset: 20840 | Success:     8 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_16  ]  Offset: 12840 | Success:    10 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_6   ]  Offset:  4840 | Success:    13 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_32  ]  Offset: 25640 | Success:     8 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_23  ]  Offset: 18432 | Success:     8 /    40 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_29  ]  Offset: 23248 | Success:     8 /    56 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_28  ]  Offset: 22440 | Success:     7 /    48 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_20  ]  Offset: 16032 | Success:    12 /    40 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_15  ]  Offset: 12048 | Success:     8 /    56 | Failure:     0 | Class count:  1306
# [ ThreadPoolExecutor-0_25  ]  Offset: 20032 | Success:     8 /    40 | Failure:     0 | Class count:  1307
# [ ThreadPoolExecutor-0_0   ]  Offset:    40 | Success:     0 /    48 | Failure:     0 | Class count:  1307
# [ ThreadPoolExecutor-0_36  ]  Offset: 28832 | Success:     8 /    40 | Failure:     0 | Class count:  1307
# [ ThreadPoolExecutor-0_4   ]  Offset:  3240 | Success:    10 /    48 | Failure:     0 | Class count:  1307
# [ ThreadPoolExecutor-0_48  ]  Offset: 38424 | Success:    13 /    32 | Failure:     0 | Class count:  1307
# [ ThreadPoolExecutor-0_18  ]  Offset: 14432 | Success:    16 /    40 | Failure:     0 | Class count:  1308
# [ ThreadPoolExecutor-0_35  ]  Offset: 28024 | Success:     8 /    32 | Failure:     0 | Class count:  1308
# [ ThreadPoolExecutor-0_43  ]  Offset: 34440 | Success:     8 /    48 | Failure:     0 | Class count:  1308
# [ ThreadPoolExecutor-0_34  ]  Offset: 27232 | Success:    11 /    40 | Failure:     0 | Class count:  1310
# [ ThreadPoolExecutor-0_49  ]  Offset: 39224 | Success:    11 /    32 | Failure:     0 | Class count:  1310
# [ ThreadPoolExecutor-0_19  ]  Offset: 15240 | Success:    16 /    48 | Failure:     0 | Class count:  1311
# [ ThreadPoolExecutor-0_41  ]  Offset: 32840 | Success:    16 /    48 | Failure:     0 | Class count:  1311
# [ ThreadPoolExecutor-0_44  ]  Offset: 35240 | Success:    11 /    48 | Failure:     0 | Class count:  1311
# [ ThreadPoolExecutor-0_38  ]  Offset: 30432 | Success:    11 /    40 | Failure:     0 | Class count:  1312
# [ ThreadPoolExecutor-0_30  ]  Offset: 24040 | Success:    13 /    48 | Failure:     0 | Class count:  1313
# [ ThreadPoolExecutor-0_13  ]  Offset: 10432 | Success:    16 /    40 | Failure:     0 | Class count:  1313
# [ ThreadPoolExecutor-0_39  ]  Offset: 31240 | Success:    16 /    48 | Failure:     0 | Class count:  1313
# [ ThreadPoolExecutor-0_46  ]  Offset: 36832 | Success:     8 /    40 | Failure:     0 | Class count:  1314
# [ ThreadPoolExecutor-0_42  ]  Offset: 33648 | Success:    11 /    56 | Failure:     0 | Class count:  1314
# [ ThreadPoolExecutor-0_14  ]  Offset: 11232 | Success:    13 /    40 | Failure:     0 | Class count:  1314
# [ ThreadPoolExecutor-0_27  ]  Offset: 21648 | Success:    16 /    56 | Failure:     0 | Class count:  1316
# [ ThreadPoolExecutor-0_47  ]  Offset: 37640 | Success:    16 /    48 | Failure:     0 | Class count:  1316
# [ ThreadPoolExecutor-0_17  ]  Offset: 13640 | Success:     9 /    48 | Failure:     0 | Class count:  1319
# [ ThreadPoolExecutor-0_8   ]  Offset:  6448 | Success:    11 /    56 | Failure:     0 | Class count:  1319
# [ ThreadPoolExecutor-0_0   ]  Offset:    48 | Success:     0 /    56 | Failure:     0 | Class count:  1319
# [ ThreadPoolExecutor-0_3   ]  Offset:  2440 | Success:    21 /    48 | Failure:     0 | Class count:  1319
# [ ThreadPoolExecutor-0_5   ]  Offset:  4048 | Success:    14 /    56 | Failure:     0 | Class count:  1321
# [ ThreadPoolExecutor-0_2   ]  Offset:  1632 | Success:    16 /    40 | Failure:     0 | Class count:  1324
# [ ThreadPoolExecutor-0_40  ]  Offset: 32048 | Success:    22 /    56 | Failure:     0 | Class count:  1324
# [ ThreadPoolExecutor-0_37  ]  Offset: 29648 | Success:    16 /    56 | Failure:     0 | Class count:  1325
# [ ThreadPoolExecutor-0_1   ]  Offset:   824 | Success:    16 /    32 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_7   ]  Offset:  5648 | Success:    21 /    56 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_23  ]  Offset: 18440 | Success:    16 /    48 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_26  ]  Offset: 20848 | Success:    16 /    56 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_45  ]  Offset: 36040 | Success:    17 /    48 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_28  ]  Offset: 22448 | Success:    15 /    56 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_29  ]  Offset: 23256 | Success:    16 /    64 | Failure:     0 | Class count:  1326
# [ ThreadPoolExecutor-0_22  ]  Offset: 17632 | Success:    16 /    40 | Failure:     0 | Class count:  1327
# [ ThreadPoolExecutor-0_6   ]  Offset:  4848 | Success:    21 /    56 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_15  ]  Offset: 12056 | Success:    16 /    64 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_24  ]  Offset: 19240 | Success:     8 /    48 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_25  ]  Offset: 20040 | Success:    16 /    48 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_0   ]  Offset:    56 | Success:     0 /    64 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_33  ]  Offset: 26440 | Success:    19 /    48 | Failure:     0 | Class count:  1328
# [ ThreadPoolExecutor-0_11  ]  Offset:  8832 | Success:    14 /    40 | Failure:     0 | Class count:  1330
# [ ThreadPoolExecutor-0_4   ]  Offset:  3248 | Success:    18 /    56 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_43  ]  Offset: 34448 | Success:    16 /    56 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_31  ]  Offset: 24848 | Success:    19 /    56 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_44  ]  Offset: 35248 | Success:    19 /    56 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_38  ]  Offset: 30440 | Success:    19 /    48 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_21  ]  Offset: 16840 | Success:    22 /    48 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_12  ]  Offset:  9632 | Success:    16 /    40 | Failure:     0 | Class count:  1331
# [ ThreadPoolExecutor-0_18  ]  Offset: 14440 | Success:    24 /    48 | Failure:     0 | Class count:  1333
# [ ThreadPoolExecutor-0_48  ]  Offset: 38432 | Success:    21 /    40 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_42  ]  Offset: 33656 | Success:    19 /    64 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_30  ]  Offset: 24048 | Success:    21 /    56 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_36  ]  Offset: 28840 | Success:    16 /    48 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_19  ]  Offset: 15248 | Success:    24 /    56 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_39  ]  Offset: 31248 | Success:    24 /    56 | Failure:     0 | Class count:  1336
# [ ThreadPoolExecutor-0_41  ]  Offset: 32848 | Success:    24 /    56 | Failure:     0 | Class count:  1337
# [ ThreadPoolExecutor-0_20  ]  Offset: 16040 | Success:    20 /    48 | Failure:     0 | Class count:  1337
# [ ThreadPoolExecutor-0_5   ]  Offset:  4056 | Success:    22 /    64 | Failure:     0 | Class count:  1338
# [ ThreadPoolExecutor-0_32  ]  Offset: 25648 | Success:    16 /    56 | Failure:     0 | Class count:  1338
# [ ThreadPoolExecutor-0_13  ]  Offset: 10440 | Success:    24 /    48 | Failure:     0 | Class count:  1339
# [ ThreadPoolExecutor-0_40  ]  Offset: 32056 | Success:    30 /    64 | Failure:     0 | Class count:  1339
# [ ThreadPoolExecutor-0_0   ]  Offset:    64 | Success:     0 /    72 | Failure:     0 | Class count:  1340
# [ ThreadPoolExecutor-0_27  ]  Offset: 21656 | Success:    24 /    64 | Failure:     0 | Class count:  1340
# [ ThreadPoolExecutor-0_9   ]  Offset:  7232 | Success:    17 /    40 | Failure:     0 | Class count:  1340
# [ ThreadPoolExecutor-0_16  ]  Offset: 12848 | Success:    18 /    56 | Failure:     0 | Class count:  1342
# [ ThreadPoolExecutor-0_37  ]  Offset: 29656 | Success:    24 /    64 | Failure:     0 | Class count:  1342
# [ ThreadPoolExecutor-0_47  ]  Offset: 37648 | Success:    24 /    56 | Failure:     0 | Class count:  1343
# [ ThreadPoolExecutor-0_8   ]  Offset:  6456 | Success:    19 /    64 | Failure:     0 | Class count:  1343
# [ ThreadPoolExecutor-0_26  ]  Offset: 20856 | Success:    24 /    64 | Failure:     0 | Class count:  1343
# [ ThreadPoolExecutor-0_14  ]  Offset: 11240 | Success:    21 /    48 | Failure:     0 | Class count:  1344
# [ ThreadPoolExecutor-0_10  ]  Offset:  8040 | Success:    16 /    48 | Failure:     0 | Class count:  1344
# [ ThreadPoolExecutor-0_23  ]  Offset: 18448 | Success:    24 /    56 | Failure:     0 | Class count:  1344
# [ ThreadPoolExecutor-0_17  ]  Offset: 13648 | Success:    17 /    56 | Failure:     0 | Class count:  1345
# [ ThreadPoolExecutor-0_28  ]  Offset: 22456 | Success:    23 /    64 | Failure:     0 | Class count:  1346
# [ ThreadPoolExecutor-0_2   ]  Offset:  1640 | Success:    24 /    48 | Failure:     0 | Class count:  1346
# [ ThreadPoolExecutor-0_29  ]  Offset: 23264 | Success:    24 /    72 | Failure:     0 | Class count:  1346
# [ ThreadPoolExecutor-0_46  ]  Offset: 36840 | Success:    16 /    48 | Failure:     0 | Class count:  1346
# [ ThreadPoolExecutor-0_34  ]  Offset: 27240 | Success:    19 /    48 | Failure:     0 | Class count:  1347
# [ ThreadPoolExecutor-0_6   ]  Offset:  4856 | Success:    29 /    64 | Failure:     0 | Class count:  1347
# [ ThreadPoolExecutor-0_7   ]  Offset:  5656 | Success:    29 /    64 | Failure:     0 | Class count:  1348
# [ ThreadPoolExecutor-0_25  ]  Offset: 20048 | Success:    24 /    56 | Failure:     0 | Class count:  1348
# [ ThreadPoolExecutor-0_15  ]  Offset: 12064 | Success:    24 /    72 | Failure:     0 | Class count:  1348
# [ ThreadPoolExecutor-0_3   ]  Offset:  2448 | Success:    29 /    56 | Failure:     0 | Class count:  1348
# [ ThreadPoolExecutor-0_49  ]  Offset: 39232 | Success:    19 /    40 | Failure:     0 | Class count:  1348
# [ ThreadPoolExecutor-0_22  ]  Offset: 17640 | Success:    24 /    48 | Failure:     0 | Class count:  1349
# [ ThreadPoolExecutor-0_4   ]  Offset:  3256 | Success:    26 /    64 | Failure:     0 | Class count:  1351
# [ ThreadPoolExecutor-0_35  ]  Offset: 28032 | Success:    16 /    40 | Failure:     0 | Class count:  1351
# [ ThreadPoolExecutor-0_43  ]  Offset: 34456 | Success:    24 /    64 | Failure:     0 | Class count:  1353
# [ ThreadPoolExecutor-0_33  ]  Offset: 26448 | Success:    27 /    56 | Failure:     0 | Class count:  1355
# [ ThreadPoolExecutor-0_31  ]  Offset: 24856 | Success:    27 /    64 | Failure:     0 | Class count:  1356
# [ ThreadPoolExecutor-0_44  ]  Offset: 35256 | Success:    27 /    64 | Failure:     0 | Class count:  1356
# [ ThreadPoolExecutor-0_45  ]  Offset: 36048 | Success:    25 /    56 | Failure:     0 | Class count:  1360
# [ ThreadPoolExecutor-0_0   ]  Offset:    72 | Success:     0 /    80 | Failure:     0 | Class count:  1360
# [ ThreadPoolExecutor-0_1   ]  Offset:   832 | Success:    24 /    40 | Failure:     0 | Class count:  1361
# [ ThreadPoolExecutor-0_38  ]  Offset: 30448 | Success:    27 /    56 | Failure:     0 | Class count:  1362
# [ ThreadPoolExecutor-0_12  ]  Offset:  9640 | Success:    24 /    48 | Failure:     0 | Class count:  1362
# [ ThreadPoolExecutor-0_11  ]  Offset:  8840 | Success:    22 /    48 | Failure:     0 | Class count:  1363
# [ ThreadPoolExecutor-0_42  ]  Offset: 33664 | Success:    27 /    72 | Failure:     0 | Class count:  1364
# [ ThreadPoolExecutor-0_40  ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodivers
| Failure:     0 | Class count:  3083
# [ ThreadPoolExecutor-0_23  ]  Offset: 62368 | Success:   743 /   776 | Failure:     0 | Class count:  3083
# [ ThreadPoolExecutor-0_45  ]  Offset: 63048 | Success:   630 /   656 | Failure:     0 | Class count:  3084
# [ ThreadPoolExecutor-0_2   ]  Offset: 64672 | Success:   650 /   679 | Failure:     1 | Class count:  3084
# [ ThreadPoolExecutor-0_36  ]  Offset: 65568 | Success:   736 /   776 | Failure:     0 | Class count:  3084
# [ ThreadPoolExecutor-0_0   ]  Offset: 69544 | Success:   709 /   752 | Failure:     0 | Class count:  3084
# [ ThreadPoolExecutor-0_23  ]  Offset: 62376 | Success:   750 /   784 | Failure:     0 | Class count:  3084
# [ ThreadPoolExecutor-0_36  ]  Offset: 65576 | Success:   744 /   784 | Failure:     0 | Class count:  3085
# [ ThreadPoolExecutor-0_45  ]  Offset: 63056 | Success:   637 /   664 | Failure:     0 | Class count:  3085
# [ ThreadPoolExecutor-0_0   ]  Offset: 69552 | Success:   716 /   760 | Failure:     0 | Class count:  3085
# [ ThreadPoolExecutor-0_36  ]  Offset: 65584 | Success:   752 /   792 | Failure:     0 | Class count:  3085
# [ ThreadPoolExecutor-0_2   ]  Offset: 64680 | Success:   658 /   687 | Failure:     1 | Class count:  3085
# [ ThreadPoolExecutor-0_23  ]  Offset: 62384 | Success:   758 /   792 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63064 | Success:   644 /   672 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_36  ]  Offset: 65592 | Success:   760 /   800 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_36  ]  Scraping completed in 0:54:58.053227
# [ ThreadPoolExecutor-0_0   ]  Offset: 69560 | Success:   724 /   768 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64688 | Success:   665 /   695 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_0   ]  Offset: 69568 | Success:   732 /   776 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63072 | Success:   651 /   680 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_23  ]  Offset: 62392 | Success:   766 /   800 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_23  ]  Scraping completed in 0:57:34.312454
# [ ThreadPoolExecutor-0_2   ]  Offset: 64696 | Success:   673 /   703 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_0   ]  Offset: 69576 | Success:   739 /   784 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63080 | Success:   657 /   688 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64704 | Success:   680 /   711 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_0   ]  Offset: 69584 | Success:   745 /   792 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63088 | Success:   665 /   696 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64712 | Success:   687 /   719 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_0   ]  Offset: 69592 | Success:   752 /   800 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_0   ]  Scraping completed in 0:54:14.053545
# [ ThreadPoolExecutor-0_45  ]  Offset: 63096 | Success:   672 /   704 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64720 | Success:   695 /   727 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63104 | Success:   680 /   712 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64728 | Success:   703 /   735 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63112 | Success:   687 /   720 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64736 | Success:   711 /   743 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63120 | Success:   695 /   728 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64744 | Success:   719 /   751 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63128 | Success:   703 /   736 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64752 | Success:   727 /   759 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63136 | Success:   711 /   744 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64760 | Success:   734 /   767 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63144 | Success:   719 /   752 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64768 | Success:   742 /   775 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63152 | Success:   726 /   760 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64776 | Success:   750 /   783 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63160 | Success:   734 /   768 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63168 | Success:   742 /   776 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64784 | Success:   758 /   791 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63176 | Success:   750 /   784 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Offset: 64792 | Success:   764 /   799 | Failure:     1 | Class count:  3086
# [ ThreadPoolExecutor-0_2   ]  Scraping completed in 0:59:04.044762
# [ ThreadPoolExecutor-0_45  ]  Offset: 63184 | Success:   756 /   792 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Offset: 63192 | Success:   763 /   800 | Failure:     0 | Class count:  3086
# [ ThreadPoolExecutor-0_45  ]  Scraping completed in 1:00:05.170130
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     334 """Return the Python representation of ``s`` (a ``str`` instance
#     335 containing a JSON document).
#     336
#     337 """
# --> 338 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339 end = _w(s, end).end()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:356, in JSONDecoder.raw_decode(self, s, idx)
#     355 except StopIteration as err:
# --> 356     raise JSONDecodeError("Expecting value", s, err.value) from None
#     357 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 21
#      19     futures = [executor.submit(scrape_observations, offset, step, steps_in_batch) for offset in range(0, 72037, step * steps_in_batch)]
#      20     for future in futures:
# ---> 21         print(f"Thread completed with result {future.result()}")
#      22 print("All threads completed")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2544.0_x64__qbz5n2kfra8p0\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# Cell In[3], line 6, in scrape_observations(offset, step, batch_size)
#       5 def scrape_observations(offset, step, batch_size):
# ----> 6     scrape("https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc", 'post',
#       7           list_key = 'observationList', img_src_key='reprImageUrl',
#       8           get_class_name = lambda obj: '-'.join(re.sub(r"<i>|</i>.*", "", obj['recoShow']['recoIbp']['scientificName']).lower().split(' ')[0:2]),
#       9           params = {
#      10               "max": "8",
#      11               "mediaFilter": "no_of_images",
#      12               "offset": f"{offset}",
#      13               "sort": "created_on",
#      14               "taxon": "70513"
#      15           },
#      16           start_offset = offset, step = step, steps_in_batch = steps_in_batch)
#
# Cell In[1], line 77, in scrape(url, method, list_key, img_src_key, get_class_name, params, start_offset, step, steps_in_batch)
#      75 for offset in range(start_offset, min(total_count, start_offset+step*steps_in_batch), step):
#      76     params['offset'] = f"{offset}"
# ---> 77     response = fetch_json(url, method, headers=headers, params=params)
#      78     for obj in response[list_key]:
#      79         try:
#
# Cell In[1], line 57, in fetch_json(url, method, headers, params)
#      55     return requests.get(url, headers=headers, params=params).json()
#      56 else:
# ---> 57     return requests.post(url, headers=headers, params=params, json={}).json()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(dataset_dir).iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
    if not os.listdir(species_dir):
        os.rmdir(species_dir)
        print(f"Empty folder {species_dir} removed")
# Out:
# Empty folder insect-dataset\indiabiodiversity\acosmerycoides removed
# Empty folder insect-dataset\indiabiodiversity\alcis-maculata removed
# Empty folder insect-dataset\indiabiodiversity\ampelophaga-dolichoides removed
# Empty folder insect-dataset\indiabiodiversity\angonyx removed
# Empty folder insect-dataset\indiabiodiversity\apomyelois-ceratoniae removed
# Empty folder insect-dataset\indiabiodiversity\arcas-imperialis removed
# Empty folder insect-dataset\indiabiodiversity\argyreus-hyperbius removed
# Empty folder insect-dataset\indiabiodiversity\arsacia removed
# Empty folder insect-dataset\indiabiodiversity\axylia-renalis removed
# Empty folder insect-dataset\indiabiodiversity\baradesa-lithosioides removed
# Empty folder insect-dataset\indiabiodiversity\burnia-antica removed
# Empty folder insect-dataset\indiabiodiversity\callambulyx-junonia removed
# Empty folder insect-dataset\indiabiodiversity\chalcosia-pectinicornis removed
# Empty folder insect-dataset\indiabiodiversity\charaxes-horatius removed
# Empty folder insect-dataset\indiabiodiversity\chiasmia-sudanata removed
# Empty folder insect-dataset\indiabiodiversity\chilades-trochylus removed
# Empty folder insect-dataset\indiabiodiversity\clanis-undulosa removed
# Empty folder insect-dataset\indiabiodiversity\condate-purpurea removed
# Empty folder insect-dataset\indiabiodiversity\cosmoclostis-pesseuta removed
# Empty folder insect-dataset\indiabiodiversity\craspedortha removed
# Empty folder insect-dataset\indiabiodiversity\dictyestra-dissecta removed
# Empty folder insect-dataset\indiabiodiversity\dindicodes removed
# Empty folder insect-dataset\indiabiodiversity\disepholcia-caerulea removed
# Empty folder insect-dataset\indiabiodiversity\dophla removed
# Empty folder insect-dataset\indiabiodiversity\doratoptera-nicevillei removed
# Empty folder insect-dataset\indiabiodiversity\eilema-reticulata removed
# Empty folder insect-dataset\indiabiodiversity\estigmene-quadriramosa removed
# Empty folder insect-dataset\indiabiodiversity\eudocima-tyrannus removed
# Empty folder insect-dataset\indiabiodiversity\gonitis removed
# Empty folder insect-dataset\indiabiodiversity\herpetogramma-luctuosalis removed
# Empty folder insect-dataset\indiabiodiversity\kunugia-lineata removed
# Empty folder insect-dataset\indiabiodiversity\lestranicus removed
# Empty folder insect-dataset\indiabiodiversity\lethe-goalpara removed
# Empty folder insect-dataset\indiabiodiversity\locastra-muscosalis removed
# Empty folder insect-dataset\indiabiodiversity\loryma-recusata removed
# Empty folder insect-dataset\indiabiodiversity\macroglossum-assimilis removed
# Empty folder insect-dataset\indiabiodiversity\metapercnia removed
# Empty folder insect-dataset\indiabiodiversity\morwennius removed
# Empty folder insect-dataset\indiabiodiversity\mustilia-hepatica removed
# Empty folder insect-dataset\indiabiodiversity\neocheritra removed
# Empty folder insect-dataset\indiabiodiversity\neurois-atrovirens removed
# Empty folder insect-dataset\indiabiodiversity\nyctemera-formosana removed
# Empty folder insect-dataset\indiabiodiversity\ochrotrigona-triangulifera removed
# Empty folder insect-dataset\indiabiodiversity\orthocabera removed
# Empty folder insect-dataset\indiabiodiversity\orybina-flaviplaga removed
# Empty folder insect-dataset\indiabiodiversity\pantoporia-balina removed
# Empty folder insect-dataset\indiabiodiversity\parum-colligata removed
# Empty folder insect-dataset\indiabiodiversity\polythlipta-cerealis removed
# Empty folder insect-dataset\indiabiodiversity\prabhasa removed
# Empty folder insect-dataset\indiabiodiversity\pseudeuchlora-kafebera removed
# Empty folder insect-dataset\indiabiodiversity\rhynchina-cramboides removed
# Empty folder insect-dataset\indiabiodiversity\scopula-ferrilineata removed
# Empty folder insect-dataset\indiabiodiversity\sisyrophora-pfeifferae removed
# Empty folder insect-dataset\indiabiodiversity\stenodacma removed
# Empty folder insect-dataset\indiabiodiversity\sumalia removed
# Empty folder insect-dataset\indiabiodiversity\symbrenthia-hippoclus removed
# Empty folder insect-dataset\indiabiodiversity\vindusara-moorei removed
# Empty folder insect-dataset\indiabiodiversity\xerodes-contiguaria removed
# Empty folder insect-dataset\indiabiodiversity\xyroptila removed

# %% [markdown]
# # ZIP the data

# %%
import shutil
import time
import datetime

shutil.make_archive(f"{dataset_dir}/../lepidoptera.indiabiodiversity.org.{datetime.datetime.now().strftime("%Y.%m.%d")}", 
                    'zip', f"{dataset_dir}")
# Out:
# 'D:\\Projects\\my-jupyter-notebook\\insect-species-identification\\insect-dataset\\lepidoptera.indiabiodiversity.org.2025.02.10.zip'
