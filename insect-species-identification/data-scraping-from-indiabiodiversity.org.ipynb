# %% [markdown]
# # Scrape https://indiabiodiversity.org

# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor
from PIL import Image
from pathlib import Path
import requests
import time
import datetime

# %%
dataset_dir = "insect-dataset/indiabiodiversity.org"

# %%
page_timeout = 120
image_timeout = 30

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

def download_image(img_url, output_dir):
    try:
        # print(f"{log_header()} Downloading {img_url} into {output_dir}")
        # print(f"{log_header()} Downloading {img_url.split("/")[-1].split("?")[0]} into {output_dir.split("/")[-1]}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name.split("?")[0])
        if Path(img_path).is_file() and check_image(img_path):
            # skipping, already downloaded
            return 'EXISTS'
        img_data = requests.get(img_url, timeout=image_timeout).content
        with open(img_path, 'wb') as file:
            file.write(img_data)
        if not check_image(img_path):
            print(f"{log_header()}Removing corrupted image {file}")
            os.remove(Path(img_path))
            return 'FAILURE'
        return 'SUCCESS'
    except Exception as e:
        print(f"{log_header()}{e}")
        return 'FAILURE'

def fetch_json(url, method, headers, params):
    if method == 'get':
        return requests.get(url, headers=headers, params=params).json()
    else:
        return requests.post(url, headers=headers, params=params, json={}).json()

img_base_url = "https://indiabiodiversity.org/files-api/api/get/crop/"
context_map = {
    "OBSERVATION": "observations",
    "SPECIES": "img"
}
headers = {
    "accept": "application/json, text/plain, */*",
}
def scrape(url, method, list_key, img_src_key, get_class_name, params, start_offset=0, step=10, steps_in_batch=100000):
    print(f"{log_header()}Starting scraping from {url} with offset={start_offset}, step={step}, steps_in_batch={steps_in_batch}")
    start_time = time.time()
    total_count = fetch_json(url, method, headers=headers, params=params)['totalCount']
    # print(f"{log_header()}Total count: {total_count}")
    img_cnt = 0
    success_cnt = 0
    failure_cnt = 0
    for offset in range(start_offset, min(total_count, start_offset+step*steps_in_batch), step):
        params['offset'] = f"{offset}"
        response = fetch_json(url, method, headers=headers, params=params)
        for obj in response[list_key]:
            try:
                class_name = get_class_name(obj)
                if len(class_name.split('-')) == 1:
                    class_name += '-spp'
                if 'factValuePair' in obj:
                    life_stage = [ item for item in obj['factValuePair'] if item["name"] == "Life Stage (Complete Metamorphosis)" ]
                    if len(life_stage) != 1 or life_stage[0]['value'] != 'Adult':
                        # skip non-adult life stage
                        continue
                context_path = context_map[obj['context']] if 'context' in obj else "observations"
                img_url = f"{img_base_url}/{context_path}/{obj[img_src_key]}?h=300"
                target_dir = f"{dataset_dir}/{class_name}"
                download_status = download_image(img_url, target_dir)
                if download_status == 'SUCCESS':
                    success_cnt += 1
                    img_cnt += 1
                elif download_status == 'EXISTS':
                    img_cnt += 1
                else:
                    failure_cnt += 1
            except Exception as e:
                print(f"{log_header()}{e}")
        class_cnt = sum(1 for entry in os.scandir(dataset_dir) if entry.is_dir())
        print(f"{log_header()}Offset: {offset:5} | Success: {success_cnt:5} / {img_cnt:5} | Failure: {failure_cnt:5} | Class count: {class_cnt:5}")
    print(f"{log_header()}Scraping completed in {datetime.timedelta(seconds=(time.time() - start_time))}")

# %%
scrape("https://indiabiodiversity.org/species-api/api/v1/species/list/extended_species/_doc", 'get',
      list_key = 'speciesTiles', img_src_key='reprImage',
      get_class_name = lambda obj: '-'.join(re.sub(r"<i>|</i>.*", "", obj['name']).lower().split(' ')[0:2]),
      params = {
          "view": "grid",
          "max": "16",
          "mediaFilter": "IMAGE",
          "offset": "0",
          "sGroup": "839",
          "sort": "species.lastUpdated",
          "taxon": "70513"
      })
# Out:
# [ MainThread               ]  Starting scraping from https://indiabiodiversity.org/species-api/api/v1/species/list/extended_species/_doc with offset=0, step=10, steps_in_batch=100000
# [ MainThread               ]  Offset:     0 | Success:    16 /    16 | Failure:     0 | Class count:    16
# [ MainThread               ]  Offset:    10 | Success:    26 /    32 | Failure:     0 | Class count:    26
# [ MainThread               ]  Offset:    20 | Success:    36 /    48 | Failure:     0 | Class count:    36
# [ MainThread               ]  Offset:    30 | Success:    46 /    64 | Failure:     0 | Class count:    46
# [ MainThread               ]  Offset:    40 | Success:    56 /    80 | Failure:     0 | Class count:    56
# [ MainThread               ]  Offset:    50 | Success:    66 /    96 | Failure:     0 | Class count:    66
# [ MainThread               ]  Offset:    60 | Success:    76 /   112 | Failure:     0 | Class count:    76
# [ MainThread               ]  Offset:    70 | Success:    86 /   128 | Failure:     0 | Class count:    86
# [ MainThread               ]  Offset:    80 | Success:    96 /   144 | Failure:     0 | Class count:    96
# [ MainThread               ]  Offset:    90 | Success:   106 /   160 | Failure:     0 | Class count:   106
# [ MainThread               ]  Offset:   100 | Success:   116 /   176 | Failure:     0 | Class count:   116
# [ MainThread               ]  Offset:   110 | Success:   126 /   192 | Failure:     0 | Class count:   126
# [ MainThread               ]  Offset:   120 | Success:   136 /   208 | Failure:     0 | Class count:   136
# [ MainThread               ]  Offset:   130 | Success:   146 /   224 | Failure:     0 | Class count:   146
# [ MainThread               ]  Offset:   140 | Success:   156 /   240 | Failure:     0 | Class count:   156
# [ MainThread               ]  Offset:   150 | Success:   166 /   256 | Failure:     0 | Class count:   166
# [ MainThread               ]  Offset:   160 | Success:   176 /   272 | Failure:     0 | Class count:   176
# [ MainThread               ]  Offset:   170 | Success:   186 /   288 | Failure:     0 | Class count:   186
# [ MainThread               ]  Offset:   180 | Success:   196 /   304 | Failure:     0 | Class count:   196
# [ MainThread               ]  Offset:   190 | Success:   206 /   320 | Failure:     0 | Class count:   206
# [ MainThread               ]  Offset:   200 | Success:   216 /   336 | Failure:     0 | Class count:   216
# [ MainThread               ]  Offset:   210 | Success:   226 /   352 | Failure:     0 | Class count:   226
# [ MainThread               ]  Offset:   220 | Success:   236 /   368 | Failure:     0 | Class count:   236
# [ MainThread               ]  Offset:   230 | Success:   246 /   384 | Failure:     0 | Class count:   246
# [ MainThread               ]  Offset:   240 | Success:   256 /   400 | Failure:     0 | Class count:   256
# [ MainThread               ]  Offset:   250 | Success:   266 /   416 | Failure:     0 | Class count:   266
# [ MainThread               ]  Offset:   260 | Success:   276 /   432 | Failure:     0 | Class count:   276
# [ MainThread               ]  Offset:   270 | Success:   286 /   448 | Failure:     0 | Class count:   286
# [ MainThread               ]  Offset:   280 | Success:   296 /   464 | Failure:     0 | Class count:   296
# [ MainThread               ]  Offset:   290 | Success:   306 /   480 | Failure:     0 | Class count:   306
# [ MainThread               ]  Offset:   300 | Success:   316 /   496 | Failure:     0 | Class count:   316
# [ MainThread               ]  Offset:   310 | Success:   326 /   512 | Failure:     0 | Class count:   326
# [ MainThread               ]  Offset:   320 | Success:   336 /   528 | Failure:     0 | Class count:   336
# [ MainThread               ]  Offset:   330 | Success:   346 /   544 | Failure:     0 | Class count:   346
# [ MainThread               ]  Offset:   340 | Success:   356 /   560 | Failure:     0 | Class count:   356
# [ MainThread               ]  Offset:   350 | Success:   366 /   576 | Failure:     0 | Class count:   366
# [ MainThread               ]  Offset:   360 | Success:   376 /   592 | Failure:     0 | Class count:   376
# [ MainThread               ]  Offset:   370 | Success:   386 /   608 | Failure:     0 | Class count:   386
# [ MainThread               ]  Offset:   380 | Success:   396 /   624 | Failure:     0 | Class count:   396
# [ MainThread               ]  Offset:   390 | Success:   406 /   640 | Failure:     0 | Class count:   406
# [ MainThread               ]  Offset:   400 | Success:   416 /   656 | Failure:     0 | Class count:   416
# [ MainThread               ]  Offset:   410 | Success:   426 /   672 | Failure:     0 | Class count:   426
# [ MainThread               ]  Offset:   420 | Success:   436 /   688 | Failure:     0 | Class count:   436
# [ MainThread               ]  Offset:   430 | Success:   446 /   704 | Failure:     0 | Class count:   446
# [ MainThread               ]  Offset:   440 | Success:   456 /   720 | Failure:     0 | Class count:   455
# [ MainThread               ]  Offset:   450 | Success:   466 /   736 | Failure:     0 | Class count:   465
# [ MainThread               ]  Offset:   460 | Success:   476 /   752 | Failure:     0 | Class count:   474
# [ MainThread               ]  Offset:   470 | Success:   486 /   768 | Failure:     0 | Class count:   484
# [ MainThread               ]  Offset:   480 | Success:   496 /   784 | Failure:     0 | Class count:   494
# [ MainThread               ]  Offset:   490 | Success:   506 /   800 | Failure:     0 | Class count:   504
# [ MainThread               ]  Offset:   500 | Success:   516 /   816 | Failure:     0 | Class count:   514
# [ MainThread               ]  Offset:   510 | Success:   526 /   832 | Failure:     0 | Class count:   524
# [ MainThread               ]  Offset:   520 | Success:   536 /   848 | Failure:     0 | Class count:   534
# [ MainThread               ]  Offset:   530 | Success:   546 /   864 | Failure:     0 | Class count:   544
# [ MainThread               ]  Offset:   540 | Success:   556 /   880 | Failure:     0 | Class count:   554
# [ MainThread               ]  Offset:   550 | Success:   566 /   896 | Failure:     0 | Class count:   564
# [ MainThread               ]  Offset:   560 | Success:   576 /   912 | Failure:     0 | Class count:   573
# [ MainThread               ]  Offset:   570 | Success:   586 /   928 | Failure:     0 | Class count:   583
# [ MainThread               ]  Offset:   580 | Success:   596 /   944 | Failure:     0 | Class count:   593
# [ MainThread               ]  Offset:   590 | Success:   606 /   960 | Failure:     0 | Class count:   603
# [ MainThread               ]  Offset:   600 | Success:   616 /   976 | Failure:     0 | Class count:   613
# [ MainThread               ]  Offset:   610 | Success:   626 /   992 | Failure:     0 | Class count:   623
# [ MainThread               ]  Offset:   620 | Success:   636 /  1008 | Failure:     0 | Class count:   633
# [ MainThread               ]  Offset:   630 | Success:   646 /  1024 | Failure:     0 | Class count:   643
# [ MainThread               ]  Offset:   640 | Success:   656 /  1040 | Failure:     0 | Class count:   653
# [ MainThread               ]  Offset:   650 | Success:   666 /  1056 | Failure:     0 | Class count:   663
# [ MainThread               ]  Offset:   660 | Success:   676 /  1072 | Failure:     0 | Class count:   673
# [ MainThread               ]  Offset:   670 | Success:   686 /  1088 | Failure:     0 | Class count:   683
# [ MainThread               ]  Offset:   680 | Success:   696 /  1104 | Failure:     0 | Class count:   691
# [ MainThread               ]  Offset:   690 | Success:   706 /  1120 | Failure:     0 | Class count:   701
# [ MainThread               ]  Offset:   700 | Success:   716 /  1136 | Failure:     0 | Class count:   711
# [ MainThread               ]  Offset:   710 | Success:   726 /  1152 | Failure:     0 | Class count:   721
# [ MainThread               ]  Offset:   720 | Success:   736 /  1168 | Failure:     0 | Class count:   731
# [ MainThread               ]  Offset:   730 | Success:   746 /  1184 | Failure:     0 | Class count:   741
# [ MainThread               ]  Offset:   740 | Success:   756 /  1200 | Failure:     0 | Class count:   751
# [ MainThread               ]  Offset:   750 | Success:   766 /  1216 | Failure:     0 | Class count:   761
# [ MainThread               ]  Offset:   760 | Success:   776 /  1232 | Failure:     0 | Class count:   771
# [ MainThread               ]  Offset:   770 | Success:   786 /  1248 | Failure:     0 | Class count:   781
# [ MainThread               ]  Offset:   780 | Success:   796 /  1264 | Failure:     0 | Class count:   791
# [ MainThread               ]  Offset:   790 | Success:   806 /  1280 | Failure:     0 | Class count:   801
# [ MainThread               ]  Offset:   800 | Success:   816 /  1296 | Failure:     0 | Class count:   811
# [ MainThread               ]  Offset:   810 | Success:   826 /  1312 | Failure:     0 | Class count:   821
# [ MainThread               ]  Offset:   820 | Success:   836 /  1328 | Failure:     0 | Class count:   830
# [ MainThread               ]  Offset:   830 | Success:   846 /  1344 | Failure:     0 | Class count:   839
# [ MainThread               ]  Offset:   840 | Success:   856 /  1360 | Failure:     0 | Class count:   848
# [ MainThread               ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity.org/celastrina-oreana\\72.jpg'>
# [ MainThread               ]  Offset:   850 | Success:   865 /  1375 | Failure:     1 | Class count:   858
# [ MainThread               ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity.org/celastrina-oreana\\72.jpg'>
# [ MainThread               ]  Offset:   860 | Success:   875 /  1390 | Failure:     2 | Class count:   868
# [ MainThread               ]  Offset:   870 | Success:   885 /  1406 | Failure:     2 | Class count:   878
# [ MainThread               ]  Offset:   880 | Success:   895 /  1422 | Failure:     2 | Class count:   888
# [ MainThread               ]  Offset:   890 | Success:   905 /  1438 | Failure:     2 | Class count:   898
# [ MainThread               ]  Offset:   900 | Success:   915 /  1454 | Failure:     2 | Class count:   907
# [ MainThread               ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity.org/udara-dilecta\\72b.jpg'>
# [ MainThread               ]  Offset:   910 | Success:   924 /  1469 | Failure:     3 | Class count:   917
# [ MainThread               ]  Offset:   920 | Success:   934 /  1485 | Failure:     3 | Class count:   927
# [ MainThread               ]  Offset:   930 | Success:   944 /  1501 | Failure:     3 | Class count:   937
# [ MainThread               ]  Offset:   940 | Success:   954 /  1517 | Failure:     3 | Class count:   947
# [ MainThread               ]  Offset:   950 | Success:   964 /  1533 | Failure:     3 | Class count:   957
# [ MainThread               ]  Offset:   960 | Success:   974 /  1549 | Failure:     3 | Class count:   967
# [ MainThread               ]  Offset:   970 | Success:   984 /  1565 | Failure:     3 | Class count:   977
# [ MainThread               ]  Offset:   980 | Success:   988 /  1575 | Failure:     3 | Class count:   981
# [ MainThread               ]  Scraping completed in 0:17:31.058620

# %%
max_workers = 50
step = 8
steps_in_batch = 100

def scrape_observations(offset, step, batch_size):
    scrape("https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc", 'post',
          list_key = 'observationList', img_src_key='reprImageUrl',
          get_class_name = lambda obj: '-'.join(re.sub(r"<i>|</i>.*", "", obj['recoShow']['recoIbp']['scientificName']).lower().split(' ')[0:2]),
          params = {
              "max": "8",
              "mediaFilter": "no_of_images",
              "offset": f"{offset}",
              "sort": "created_on",
              "taxon": "70513",
              "view": "list",
              "speciesName": "IDENTIFIED"
          },
          start_offset = offset, step = step, steps_in_batch = steps_in_batch)

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(scrape_observations, offset, step, steps_in_batch) for offset in range(0, 72037, step * steps_in_batch)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")
print("All threads completed")
# Out:
# [ ThreadPoolExecutor-0_0   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=0, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_1   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_2   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=1600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_3   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=2400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_4   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=3200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_5   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=4000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_6   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=4800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_7   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=5600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_8   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=6400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_9   ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=7200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_10  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=8000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_11  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=8800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_12  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=9600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_13  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=10400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_14  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=11200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_15  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=12000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_16  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=12800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_17  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=13600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_18  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=14400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_19  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=15200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_20  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=16000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_21  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=16800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_22  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=17600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_23  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=18400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_24  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=19200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_25  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=20000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_26  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=20800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_27  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=21600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_28  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=22400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_29  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=23200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_30  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=24000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_31  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=24800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_32  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=25600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_33  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=26400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_34  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=27200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_35  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=28000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_36  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=28800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_37  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=29600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_38  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=30400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_39  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=31200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_40  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=32000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_41  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=32800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_42  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=33600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_43  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=34400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_44  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=35200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_45  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=36000, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_46  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=36800, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_47  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=37600, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_48  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=38400, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_49  ]  Starting scraping from https://indiabiodiversity.org/observation-api/api/v1/observation/list/extended_observation/_doc with offset=39200, step=8, steps_in_batch=100
# [ ThreadPoolExecutor-0_4   ]  Offset:  3200 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_43  ]  Offset: 34400 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_2   ]  Offset:  1600 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_21  ]  Offset: 16800 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_36  ]  Offset: 28800 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_29  ]  Offset: 23200 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_18  ]  Offset: 14400 | Success:     0 /     0 | Failure:     0 | Class count:   981
# [ ThreadPoolExecutor-0_7   ]  Offset:  5600 | Success:     1 /     1 | Failure:     0 | Class count:   982
# [ ThreadPoolExecutor-0_11  ]  Offset:  8800 | Success:     0 /     0 | Failure:     0 | Class count:   982
# [ ThreadPoolExecutor-0_40  ]  Offset: 32000 | Success:     0 /     0 | Failure:     0 | Class count:   982
# [ ThreadPoolExecutor-0_3   ]  Offset:  2400 | Success:     0 /     0 | Failure:     0 | Class count:   982
# [ ThreadPoolExecutor-0_33  ]  Offset: 26400 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_1   ]  Offset:   800 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_32  ]  Offset: 25600 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_17  ]  Offset: 13600 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_8   ]  Offset:  6400 | Success:     1 /     1 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_47  ]  Offset: 37600 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_34  ]  Offset: 27200 | Success:     0 /     0 | Failure:     0 | Class count:   983
# [ ThreadPoolExecutor-0_44  ]  Offset: 35200 | Success:     0 /     0 | Failure:     0 | Class count:   985
# [ ThreadPoolExecutor-0_31  ]  Offset: 24800 | Success:     0 /     0 | Failure:     0 | Class count:   985
# [ ThreadPoolExecutor-0_24  ]  Offset: 19200 | Success:     0 /     0 | Failure:     0 | Class count:   985
# [ ThreadPoolExecutor-0_28  ]  Offset: 22400 | Success:     0 /     0 | Failure:     0 | Class count:   985
# [ ThreadPoolExecutor-0_48  ]  Offset: 38400 | Success:     0 /     0 | Failure:     0 | Class count:   985
# [ ThreadPoolExecutor-0_23  ]  Offset: 18400 | Success:     0 /     0 | Failure:     0 | Class count:   986
# [ ThreadPoolExecutor-0_26  ]  Offset: 20800 | Success:     1 /     1 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_20  ]  Offset: 16000 | Success:     0 /     0 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_35  ]  Offset: 28000 | Success:     0 /     0 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_13  ]  Offset: 10400 | Success:     0 /     0 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_25  ]  Offset: 20000 | Success:     0 /     0 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_9   ]  Offset:  7200 | Success:     1 /     1 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_45  ]  Offset: 36000 | Success:     2 /     2 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_41  ]  Offset: 32800 | Success:     1 /     1 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_14  ]  Offset: 11200 | Success:     0 /     0 | Failure:     0 | Class count:   987
# [ ThreadPoolExecutor-0_49  ]  Offset: 39200 | Success:     0 /     0 | Failure:     0 | Class count:   988
# [ ThreadPoolExecutor-0_16  ]  Offset: 12800 | Success:     0 /     0 | Failure:     0 | Class count:   989
# [ ThreadPoolExecutor-0_22  ]  Offset: 17600 | Success:     1 /     1 | Failure:     0 | Class count:   989
# [ ThreadPoolExecutor-0_12  ]  Offset:  9600 | Success:     2 /     2 | Failure:     0 | Class count:   990
# [ ThreadPoolExecutor-0_39  ]  Offset: 31200 | Success:     1 /     1 | Failure:     0 | Class count:   990
# [ ThreadPoolExecutor-0_46  ]  Offset: 36800 | Success:     3 /     3 | Failure:     0 | Class count:   995
# [ ThreadPoolExecutor-0_10  ]  Offset:  8000 | Success:     4 /     4 | Failure:     0 | Class count:   995
# [ ThreadPoolExecutor-0_30  ]  Offset: 24000 | Success:     0 /     0 | Failure:     0 | Class count:   995
# [ ThreadPoolExecutor-0_15  ]  Offset: 12000 | Success:     3 /     3 | Failure:     0 | Class count:   995
# [ ThreadPoolExecutor-0_27  ]  Offset: 21600 | Success:     2 /     2 | Failure:     0 | Class count:   996
# [ ThreadPoolExecutor-0_42  ]  Offset: 33600 | Success:     2 /     2 | Failure:     0 | Class count:   996
# [ ThreadPoolExecutor-0_5   ]  Offset:  4000 | Success:     7 /     7 | Failure:     0 | Class count:   998
# [ ThreadPoolExecutor-0_19  ]  Offset: 15200 | Success:     5 /     5 | Failure:     0 | Class count:   999
# [ ThreadPoolExecutor-0_38  ]  Offset: 30400 | Success:     7 /     7 | Failure:     0 | Class count:   999
# [ ThreadPoolExecutor-0_6   ]  Offset:  4800 | Success:     8 /     8 | Failure:     0 | Class count:   999
# [ ThreadPoolExecutor-0_37  ]  Offset: 29600 | Success:     8 /     8 | Failure:     0 | Class count:   999
# [ ThreadPoolExecutor-0_2   ]  Offset:  1608 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_4   ]  Offset:  3208 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_43  ]  Offset: 34408 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_29  ]  Offset: 23208 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_7   ]  Offset:  5608 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_36  ]  Offset: 28808 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_21  ]  Offset: 16808 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_18  ]  Offset: 14408 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_33  ]  Offset: 26408 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_40  ]  Offset: 32008 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_1   ]  Offset:   808 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_32  ]  Offset: 25608 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_3   ]  Offset:  2408 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_31  ]  Offset: 24808 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_24  ]  Offset: 19208 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_25  ]  Offset: 20008 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_23  ]  Offset: 18408 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_26  ]  Offset: 20808 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_9   ]  Offset:  7208 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_35  ]  Offset: 28008 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_20  ]  Offset: 16008 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_16  ]  Offset: 12808 | Success:     0 /     0 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_47  ]  Offset: 37608 | Success:     1 /     1 | Failure:     0 | Class count:  1000
# [ ThreadPoolExecutor-0_11  ]  Offset:  8808 | Success:     2 /     2 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_28  ]  Offset: 22408 | Success:     1 /     1 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_8   ]  Offset:  6408 | Success:     2 /     2 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_41  ]  Offset: 32808 | Success:     1 /     1 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_12  ]  Offset:  9608 | Success:     2 /     2 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_10  ]  Offset:  8008 | Success:     4 /     4 | Failure:     0 | Class count:  1001
# [ ThreadPoolExecutor-0_22  ]  Offset: 17608 | Success:     1 /     1 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_15  ]  Offset: 12008 | Success:     3 /     3 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_30  ]  Offset: 24008 | Success:     0 /     0 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_34  ]  Offset: 27208 | Success:     1 /     1 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_14  ]  Offset: 11208 | Success:     1 /     1 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_44  ]  Offset: 35208 | Success:     2 /     2 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_49  ]  Offset: 39208 | Success:     1 /     1 | Failure:     0 | Class count:  1002
# [ ThreadPoolExecutor-0_13  ]  Offset: 10408 | Success:     1 /     1 | Failure:     0 | Class count:  1003
# [ ThreadPoolExecutor-0_17  ]  Offset: 13608 | Success:     2 /     2 | Failure:     0 | Class count:  1003
# [ ThreadPoolExecutor-0_45  ]  Offset: 36008 | Success:     4 /     4 | Failure:     0 | Class count:  1003
# [ ThreadPoolExecutor-0_48  ]  Offset: 38408 | Success:     3 /     3 | Failure:     0 | Class count:  1004
# [ ThreadPoolExecutor-0_39  ]  Offset: 31208 | Success:     4 /     4 | Failure:     0 | Class count:  1004
# [ ThreadPoolExecutor-0_46  ]  Offset: 36808 | Success:     6 /     6 | Failure:     0 | Class count:  1006
# [ ThreadPoolExecutor-0_42  ]  Offset: 33608 | Success:     5 /     5 | Failure:     0 | Class count:  1007
# [ ThreadPoolExecutor-0_37  ]  Offset: 29608 | Success:    10 /    10 | Failure:     0 | Class count:  1011
# [ ThreadPoolExecutor-0_27  ]  Offset: 21608 | Success:    10 /    10 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_5   ]  Offset:  4008 | Success:    14 /    14 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_6   ]  Offset:  4808 | Success:    16 /    16 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_19  ]  Offset: 15208 | Success:    13 /    13 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_38  ]  Offset: 30408 | Success:    15 /    15 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_4   ]  Offset:  3216 | Success:     1 /     1 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_2   ]  Offset:  1616 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_36  ]  Offset: 28816 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_21  ]  Offset: 16816 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_7   ]  Offset:  5616 | Success:     1 /     1 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_29  ]  Offset: 23216 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_33  ]  Offset: 26416 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_3   ]  Offset:  2416 | Success:     1 /     1 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_24  ]  Offset: 19216 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_1   ]  Offset:   816 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_31  ]  Offset: 24816 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_32  ]  Offset: 25616 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_20  ]  Offset: 16016 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_26  ]  Offset: 20816 | Success:     1 /     1 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_43  ]  Offset: 34416 | Success:     4 /     4 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_16  ]  Offset: 12816 | Success:     0 /     0 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_9   ]  Offset:  7216 | Success:     1 /     1 | Failure:     0 | Class count:  1013
# [ ThreadPoolExecutor-0_10  ]  Offset:  8016 | Success:     4 /     4 | Failure:     0 | Class count:  1014
# [ ThreadPoolExecutor-0_25  ]  Offset: 20016 | Success:     0 /     0 | Failure:     0 | Class count:  1015
# [ ThreadPoolExecutor-0_15  ]  Offset: 12016 | Success:     3 /     3 | Failure:     0 | Class count:  1016
# [ ThreadPoolExecutor-0_28  ]  Offset: 22416 | Success:     1 /     1 | Failure:     0 | Class count:  1016
# [ ThreadPoolExecutor-0_30  ]  Offset: 24016 | Success:     0 /     0 | Failure:     0 | Class count:  1016
# [ ThreadPoolExecutor-0_17  ]  Offset: 13616 | Success:     2 /     2 | Failure:     0 | Class count:  1017
# [ ThreadPoolExecutor-0_18  ]  Offset: 14416 | Success:     4 /     4 | Failure:     0 | Class count:  1017
# [ ThreadPoolExecutor-0_39  ]  Offset: 31216 | Success:     4 /     4 | Failure:     0 | Class count:  1019
# [ ThreadPoolExecutor-0_22  ]  Offset: 17616 | Success:     2 /     2 | Failure:     0 | Class count:  1020
# [ ThreadPoolExecutor-0_49  ]  Offset: 39216 | Success:     2 /     2 | Failure:     0 | Class count:  1021
# [ ThreadPoolExecutor-0_34  ]  Offset: 27216 | Success:     2 /     2 | Failure:     0 | Class count:  1021
# [ ThreadPoolExecutor-0_14  ]  Offset: 11216 | Success:     3 /     3 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_13  ]  Offset: 10416 | Success:     2 /     2 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_41  ]  Offset: 32816 | Success:     3 /     3 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_47  ]  Offset: 37616 | Success:     3 /     3 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_8   ]  Offset:  6416 | Success:     4 /     4 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_12  ]  Offset:  9616 | Success:     5 /     5 | Failure:     0 | Class count:  1022
# [ ThreadPoolExecutor-0_45  ]  Offset: 36016 | Success:     6 /     6 | Failure:     0 | Class count:  1023
# [ ThreadPoolExecutor-0_23  ]  Offset: 18416 | Success:     3 /     3 | Failure:     0 | Class count:  1023
# [ ThreadPoolExecutor-0_46  ]  Offset: 36816 | Success:     8 /     8 | Failure:     0 | Class count:  1023
# [ ThreadPoolExecutor-0_11  ]  Offset:  8816 | Success:     6 /     6 | Failure:     0 | Class count:  1023
# [ ThreadPoolExecutor-0_40  ]  Offset: 32016 | Success:     6 /     6 | Failure:     0 | Class count:  1024
# [ ThreadPoolExecutor-0_44  ]  Offset: 35216 | Success:     6 /     6 | Failure:     0 | Class count:  1024
# [ ThreadPoolExecutor-0_35  ]  Offset: 28016 | Success:     8 /     8 | Failure:     0 | Class count:  1027
# [ ThreadPoolExecutor-0_48  ]  Offset: 38416 | Success:     9 /     9 | Failure:     0 | Class count:  1028
# [ ThreadPoolExecutor-0_42  ]  Offset: 33616 | Success:     9 /     9 | Failure:     0 | Class count:  1029
# [ ThreadPoolExecutor-0_37  ]  Offset: 29616 | Success:    18 /    18 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_6   ]  Offset:  4816 | Success:    19 /    19 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_5   ]  Offset:  4016 | Success:    19 /    19 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_4   ]  Offset:  3224 | Success:     1 /     1 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_27  ]  Offset: 21616 | Success:    18 /    18 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_2   ]  Offset:  1624 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_36  ]  Offset: 28824 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_7   ]  Offset:  5624 | Success:     1 /     1 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_21  ]  Offset: 16824 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_29  ]  Offset: 23224 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_3   ]  Offset:  2424 | Success:     1 /     1 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_24  ]  Offset: 19224 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_1   ]  Offset:   824 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_32  ]  Offset: 25624 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_33  ]  Offset: 26424 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_31  ]  Offset: 24824 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_20  ]  Offset: 16024 | Success:     0 /     0 | Failure:     0 | Class count:  1035
# [ ThreadPoolExecutor-0_16  ]  Offset: 12824 | Success:     0 /     0 | Failure:     0 | Class count:  1036
# [ ThreadPoolExecutor-0_38  ]  Offset: 30416 | Success:    23 /    23 | Failure:     0 | Class count:  1036
# [ ThreadPoolExecutor-0_9   ]  Offset:  7224 | Success:     1 /     1 | Failure:     0 | Class count:  1036
# [ ThreadPoolExecutor-0_26  ]  Offset: 20824 | Success:     3 /     3 | Failure:     0 | Class count:  1037
# [ ThreadPoolExecutor-0_19  ]  Offset: 15216 | Success:    21 /    21 | Failure:     0 | Class count:  1037
# [ ThreadPoolExecutor-0_25  ]  Offset: 20024 | Success:     0 /     0 | Failure:     0 | Class count:  1038
# [ ThreadPoolExecutor-0_10  ]  Offset:  8024 | Success:     4 /     4 | Failure:     0 | Class count:  1040
# [ ThreadPoolExecutor-0_30  ]  Offset: 24024 | Success:     0 /     0 | Failure:     0 | Class count:  1040
# [ ThreadPoolExecutor-0_17  ]  Offset: 13624 | Success:     2 /     2 | Failure:     0 | Class count:  1040
# [ ThreadPoolExecutor-0_15  ]  Offset: 12024 | Success:     3 /     3 | Failure:     0 | Class count:  1040
# [ ThreadPoolExecutor-0_34  ]  Offset: 27224 | Success:     2 /     2 | Failure:     0 | Class count:  1040
# [ ThreadPoolExecutor-0_28  ]  Offset: 22424 | Success:     4 /     4 | Failure:     0 | Class count:  1041
# [ ThreadPoolExecutor-0_13  ]  Offset: 10424 | Success:     2 /     2 | Failure:     0 | Class count:  1041
# [ ThreadPoolExecutor-0_49  ]  Offset: 39224 | Success:     2 /     2 | Failure:     0 | Class count:  1041
# [ ThreadPoolExecutor-0_22  ]  Offset: 17624 | Success:     3 /     3 | Failure:     0 | Class count:  1042
# [ ThreadPoolExecutor-0_12  ]  Offset:  9624 | Success:     5 /     5 | Failure:     0 | Class count:  1042
# [ ThreadPoolExecutor-0_46  ]  Offset: 36824 | Success:     8 /     8 | Failure:     0 | Class count:  1042
# [ ThreadPoolExecutor-0_41  ]  Offset: 32824 | Success:     4 /     4 | Failure:     0 | Class count:  1043
# [ ThreadPoolExecutor-0_11  ]  Offset:  8824 | Success:     6 /     6 | Failure:     0 | Class count:  1043
# [ ThreadPoolExecutor-0_43  ]  Offset: 34424 | Success:    12 /    12 | Failure:     0 | Class count:  1043
# [ ThreadPoolExecutor-0_8   ]  Offset:  6424 | Success:     6 /     6 | Failure:     0 | Class count:  1044
# [ ThreadPoolExecutor-0_23  ]  Offset: 18424 | Success:     5 /     5 | Failure:     0 | Class count:  1044
# [ ThreadPoolExecutor-0_44  ]  Offset: 35224 | Success:     7 /     7 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_45  ]  Offset: 36024 | Success:     9 /     9 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_39  ]  Offset: 31224 | Success:     8 /     8 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_14  ]  Offset: 11224 | Success:     7 /     7 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_40  ]  Offset: 32024 | Success:     9 /     9 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_47  ]  Offset: 37624 | Success:     8 /     8 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_18  ]  Offset: 14424 | Success:    12 /    12 | Failure:     0 | Class count:  1045
# [ ThreadPoolExecutor-0_48  ]  Offset: 38424 | Success:    14 /    14 | Failure:     0 | Class count:  1051
# [ ThreadPoolExecutor-0_42  ]  Offset: 33624 | Success:    14 /    14 | Failure:     0 | Class count:  1054
# [ ThreadPoolExecutor-0_35  ]  Offset: 28024 | Success:    16 /    16 | Failure:     0 | Class count:  1056
# [ ThreadPoolExecutor-0_6   ]  Offset:  4824 | Success:    25 /    25 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_37  ]  Offset: 29624 | Success:    26 /    26 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_5   ]  Offset:  4024 | Success:    19 /    19 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_2   ]  Offset:  1632 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_4   ]  Offset:  3232 | Success:     1 /     1 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_24  ]  Offset: 19232 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_21  ]  Offset: 16832 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_36  ]  Offset: 28832 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_29  ]  Offset: 23232 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_32  ]  Offset: 25632 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_20  ]  Offset: 16032 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_3   ]  Offset:  2432 | Success:     1 /     1 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_1   ]  Offset:   832 | Success:     1 /     1 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_31  ]  Offset: 24832 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_7   ]  Offset:  5632 | Success:     2 /     2 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_16  ]  Offset: 12832 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_33  ]  Offset: 26432 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_9   ]  Offset:  7232 | Success:     1 /     1 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_10  ]  Offset:  8032 | Success:     4 /     4 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_30  ]  Offset: 24032 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_25  ]  Offset: 20032 | Success:     0 /     0 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_17  ]  Offset: 13632 | Success:     2 /     2 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_15  ]  Offset: 12032 | Success:     3 /     3 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_26  ]  Offset: 20832 | Success:     5 /     5 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_34  ]  Offset: 27232 | Success:     2 /     2 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_49  ]  Offset: 39232 | Success:     2 /     2 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_27  ]  Offset: 21624 | Success:    25 /    25 | Failure:     0 | Class count:  1057
# [ ThreadPoolExecutor-0_22  ]  Offset: 17632 | Success:     3 /     3 | Failure:     0 | Class count:  1058
# [ ThreadPoolExecutor-0_12  ]  Offset:  9632 | Success:     5 /     5 | Failure:     0 | Class count:  1058
# [ ThreadPoolExecutor-0_13  ]  Offset: 10432 | Success:     4 /     4 | Failure:     0 | Class count:  1060
# [ ThreadPoolExecutor-0_38  ]  Offset: 30424 | Success:    31 /    31 | Failure:     0 | Class count:  1060
# [ ThreadPoolExecutor-0_11  ]  Offset:  8832 | Success:     6 /     6 | Failure:     0 | Class count:  1060
# [ ThreadPoolExecutor-0_23  ]  Offset: 18432 | Success:     5 /     5 | Failure:     0 | Class count:  1060
# [ ThreadPoolExecutor-0_46  ]  Offset: 36832 | Success:    10 /    10 | Failure:     0 | Class count:  1061
# [ ThreadPoolExecutor-0_44  ]  Offset: 35232 | Success:     8 /     8 | Failure:     0 | Class count:  1067
# [ ThreadPoolExecutor-0_19  ]  Offset: 15224 | Success:    29 /    29 | Failure:     0 | Class count:  1067
# [ ThreadPoolExecutor-0_0   ]  Offset:     0 | Success:     6 /     6 | Failure:     0 | Class count:  1067
# [ ThreadPoolExecutor-0_41  ]  Offset: 32832 | Success:     8 /     8 | Failure:     0 | Class count:  1067
# [ ThreadPoolExecutor-0_28  ]  Offset: 22432 | Success:    10 /    10 | Failure:     0 | Class count:  1070
# [ ThreadPoolExecutor-0_14  ]  Offset: 11232 | Success:    10 /    10 | Failure:     0 | Class count:  1071
# [ ThreadPoolExecutor-0_45  ]  Offset: 36032 | Success:    12 /    12 | Failure:     0 | Class count:  1072
# [ ThreadPoolExecutor-0_39  ]  Offset: 31232 | Success:    12 /    12 | Failure:     0 | Class count:  1073
# [ ThreadPoolExecutor-0_43  ]  Offset: 34432 | Success:    20 /    20 | Failure:     0 | Class count:  1073
# [ ThreadPoolExecutor-0_8   ]  Offset:  6432 | Success:    12 /    12 | Failure:     0 | Class count:  1073
# [ ThreadPoolExecutor-0_40  ]  Offset: 32032 | Success:    14 /    14 | Failure:     0 | Class count:  1074
# [ ThreadPoolExecutor-0_6   ]  Offset:  4832 | Success:    26 /    26 | Failure:     0 | Class count:  1075
# [ ThreadPoolExecutor-0_47  ]  Offset: 37632 | Success:    15 /    15 | Failure:     0 | Class count:  1075
# [ ThreadPoolExecutor-0_4   ]  Offset:  3240 | Success:     1 /     1 | Failure:     0 | Class count:  1076
# [ ThreadPoolExecutor-0_21  ]  Offset: 16840 | Success:     0 /     0 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_18  ]  Offset: 14432 | Success:    20 /    20 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_24  ]  Offset: 19240 | Success:     0 /     0 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_36  ]  Offset: 28840 | Success:     0 /     0 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_5   ]  Offset:  4032 | Success:    21 /    21 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_2   ]  Offset:  1640 | Success:     1 /     1 | Failure:     0 | Class count:  1077
# [ ThreadPoolExecutor-0_29  ]  Offset: 23240 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_32  ]  Offset: 25640 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_31  ]  Offset: 24840 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_1   ]  Offset:   840 | Success:     1 /     1 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_3   ]  Offset:  2440 | Success:     1 /     1 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_33  ]  Offset: 26440 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_20  ]  Offset: 16040 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_9   ]  Offset:  7240 | Success:     1 /     1 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_17  ]  Offset: 13640 | Success:     2 /     2 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_10  ]  Offset:  8040 | Success:     4 /     4 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_30  ]  Offset: 24040 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_15  ]  Offset: 12040 | Success:     3 /     3 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_25  ]  Offset: 20040 | Success:     0 /     0 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_48  ]  Offset: 38432 | Success:    18 /    18 | Failure:     0 | Class count:  1078
# [ ThreadPoolExecutor-0_34  ]  Offset: 27240 | Success:     2 /     2 | Failure:     0 | Class count:  1079
# [ ThreadPoolExecutor-0_42  ]  Offset: 33632 | Success:    20 /    20 | Failure:     0 | Class count:  1079
# [ ThreadPoolExecutor-0_35  ]  Offset: 28032 | Success:    24 /    24 | Failure:     0 | Class count:  1080
# [ ThreadPoolExecutor-0_37  ]  Offset: 29632 | Success:    33 /    33 | Failure:     0 | Class count:  1080
# [ ThreadPoolExecutor-0_12  ]  Offset:  9640 | Success:     5 /     5 | Failure:     0 | Class count:  1080
# [ ThreadPoolExecutor-0_13  ]  Offset: 10440 | Success:     5 /     5 | Failure:     0 | Class count:  1082
# [ ThreadPoolExecutor-0_26  ]  Offset: 20840 | Success:     8 /     8 | Failure:     0 | Class count:  1082
# [ ThreadPoolExecutor-0_16  ]  Offset: 12840 | Success:     6 /     6 | Failure:     0 | Class count:  1082
# [ ThreadPoolExecutor-0_7   ]  Offset:  5640 | Success:     8 /     8 | Failure:     0 | Class count:  1082
# [ ThreadPoolExecutor-0_46  ]  Offset: 36840 | Success:    10 /    10 | Failure:     0 | Class count:  1082
# [ ThreadPoolExecutor-0_22  ]  Offset: 17640 | Success:     5 /     5 | Failure:     0 | Class count:  1083
# [ ThreadPoolExecutor-0_49  ]  Offset: 39240 | Success:     6 /     6 | Failure:     0 | Class count:  1083
# [ ThreadPoolExecutor-0_23  ]  Offset: 18440 | Success:     5 /     5 | Failure:     0 | Class count:  1083
# [ ThreadPoolExecutor-0_11  ]  Offset:  8840 | Success:     9 /     9 | Failure:     0 | Class count:  1084
# [ ThreadPoolExecutor-0_0   ]  Offset:     8 | Success:     7 /     7 | Failure:     0 | Class count:  1084
# [ ThreadPoolExecutor-0_27  ]  Offset: 21632 | Success:    32 /    32 | Failure:     0 | Class count:  1085
# [ ThreadPoolExecutor-0_44  ]  Offset: 35240 | Success:     9 /     9 | Failure:     0 | Class count:  1087
# [ ThreadPoolExecutor-0_14  ]  Offset: 11240 | Success:    12 /    12 | Failure:     0 | Class count:  1090
# [ ThreadPoolExecutor-0_41  ]  Offset: 32840 | Success:    11 /    11 | Failure:     0 | Class count:  1091
# [ ThreadPoolExecutor-0_45  ]  Offset: 36040 | Success:    14 /    14 | Failure:     0 | Class count:  1091
# [ ThreadPoolExecutor-0_38  ]  Offset: 30432 | Success:    39 /    39 | Failure:     0 | Class count:  1091
# [ ThreadPoolExecutor-0_4   ]  Offset:  3248 | Success:     1 /     1 | Failure:     0 | Class count:  1093
# [ ThreadPoolExecutor-0_28  ]  Offset: 22440 | Success:    16 /    16 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_39  ]  Offset: 31240 | Success:    17 /    17 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_19  ]  Offset: 15232 | Success:    35 /    35 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_18  ]  Offset: 14440 | Success:    22 /    22 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_21  ]  Offset: 16848 | Success:     0 /     0 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_24  ]  Offset: 19248 | Success:     0 /     0 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_36  ]  Offset: 28848 | Success:     0 /     0 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_6   ]  Offset:  4840 | Success:    29 /    29 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_2   ]  Offset:  1648 | Success:     1 /     1 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_29  ]  Offset: 23248 | Success:     0 /     0 | Failure:     0 | Class count:  1094
# [ ThreadPoolExecutor-0_32  ]  Offset: 25648 | Success:     0 /     0 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_1   ]  Offset:   848 | Success:     1 /     1 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_5   ]  Offset:  4040 | Success:    22 /    22 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_33  ]  Offset: 26448 | Success:     0 /     0 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_8   ]  Offset:  6440 | Success:    17 /    17 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_17  ]  Offset: 13648 | Success:     2 /     2 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_9   ]  Offset:  7248 | Success:     1 /     1 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_40  ]  Offset: 32040 | Success:    20 /    20 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_20  ]  Offset: 16048 | Success:     0 /     0 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_3   ]  Offset:  2448 | Success:     1 /     1 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_31  ]  Offset: 24848 | Success:     0 /     0 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_30  ]  Offset: 24048 | Success:     0 /     0 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_15  ]  Offset: 12048 | Success:     3 /     3 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_10  ]  Offset:  8048 | Success:     4 /     4 | Failure:     0 | Class count:  1095
# [ ThreadPoolExecutor-0_43  ]  Offset: 34440 | Success:    28 /    28 | Failure:     0 | Class count:  1096
# [ ThreadPoolExecutor-0_34  ]  Offset: 27248 | Success:     2 /     2 | Failure:     0 | Class count:  1096
# [ ThreadPoolExecutor-0_12  ]  Offset:  9648 | Success:     5 /     5 | Failure:     0 | Class count:  1097
# [ ThreadPoolExecutor-0_13  ]  Offset: 10448 | Success:     5 /     5 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_25  ]  Offset: 20048 | Success:     2 /     2 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_22  ]  Offset: 17648 | Success:     5 /     5 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_16  ]  Offset: 12848 | Success:     6 /     6 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_47  ]  Offset: 37640 | Success:    23 /    23 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_48  ]  Offset: 38440 | Success:    21 /    21 | Failure:     0 | Class count:  1098
# [ ThreadPoolExecutor-0_46  ]  Offset: 36848 | Success:    11 /    11 | Failure:     0 | Class count:  1100
# [ ThreadPoolExecutor-0_23  ]  Offset: 18448 | Success:     6 /     6 | Failure:     0 | Class count:  1100
# [ ThreadPoolExecutor-0_42  ]  Offset: 33640 | Success:    24 /    24 | Failure:     0 | Class count:  1100
# [ ThreadPoolExecutor-0_0   ]  Offset:    16 | Success:     8 /     8 | Failure:     0 | Class count:  1102
# [ ThreadPoolExecutor-0_7   ]  Offset:  5648 | Success:    13 /    13 | Failure:     0 | Class count:  1104
# [ ThreadPoolExecutor-0_26  ]  Offset: 20848 | Success:    13 /    13 | Failure:     0 | Class count:  1104
# [ ThreadPoolExecutor-0_49  ]  Offset: 39248 | Success:    10 /    10 | Failure:     0 | Class count:  1104
# [ ThreadPoolExecutor-0_35  ]  Offset: 28040 | Success:    32 /    32 | Failure:     0 | Class count:  1106
# [ ThreadPoolExecutor-0_37  ]  Offset: 29640 | Success:    41 /    41 | Failure:     0 | Class count:  1106
# [ ThreadPoolExecutor-0_41  ]  Offset: 32848 | Success:    12 /    12 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_28  ]  Offset: 22448 | Success:    16 /    16 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_4   ]  Offset:  3256 | Success:     1 /     1 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_21  ]  Offset: 16856 | Success:     0 /     0 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_11  ]  Offset:  8848 | Success:    17 /    17 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_45  ]  Offset: 36048 | Success:    18 /    18 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_18  ]  Offset: 14448 | Success:    22 /    22 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_27  ]  Offset: 21640 | Success:    40 /    40 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_6   ]  Offset:  4848 | Success:    29 /    29 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_36  ]  Offset: 28856 | Success:     0 /     0 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_24  ]  Offset: 19256 | Success:     0 /     0 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_38  ]  Offset: 30440 | Success:    43 /    43 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_14  ]  Offset: 11248 | Success:    17 /    17 | Failure:     0 | Class count:  1107
# [ ThreadPoolExecutor-0_29  ]  Offset: 23256 | Success:     0 /     0 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_32  ]  Offset: 25656 | Success:     0 /     0 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_17  ]  Offset: 13656 | Success:     2 /     2 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_33  ]  Offset: 26456 | Success:     0 /     0 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_2   ]  Offset:  1656 | Success:     2 /     2 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_3   ]  Offset:  2456 | Success:     1 /     1 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_40  ]  Offset: 32048 | Success:    20 /    20 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_31  ]  Offset: 24856 | Success:     0 /     0 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_10  ]  Offset:  8056 | Success:     4 /     4 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_30  ]  Offset: 24056 | Success:     0 /     0 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_9   ]  Offset:  7256 | Success:     1 /     1 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_34  ]  Offset: 27256 | Success:     2 /     2 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_15  ]  Offset: 12056 | Success:     3 /     3 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_44  ]  Offset: 35248 | Success:    16 /    16 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_13  ]  Offset: 10456 | Success:     6 /     6 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_5   ]  Offset:  4048 | Success:    24 /    24 | Failure:     0 | Class count:  1108
# [ ThreadPoolExecutor-0_1   ]  Offset:   856 | Success:     3 /     3 | Failure:     0 | Class count:  1109
# [ ThreadPoolExecutor-0_12  ]  Offset:  9656 | Success:     7 /     7 | Failure:     0 | Class count:  1110
# [ ThreadPoolExecutor-0_25  ]  Offset: 20056 | Success:     2 /     2 | Failure:     0 | Class count:  1110
# [ ThreadPoolExecutor-0_22  ]  Offset: 17656 | Success:     5 /     5 | Failure:     0 | Class count:  1110
# [ ThreadPoolExecutor-0_8   ]  Offset:  6448 | Success:    20 /    20 | Failure:     0 | Class count:  1110
# [ ThreadPoolExecutor-0_39  ]  Offset: 31248 | Success:    24 /    24 | Failure:     0 | Class count:  1111
# ...
# [ ThreadPoolExecutor-0_20  ]  Offset: 68776 | Success:     2 /     2 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_44  ]  Offset: 64784 | Success:     3 /     3 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_23  ]  Offset: 66376 | Success:     1 /     1 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_16  ]  Offset: 45560 | Success:   262 /   271 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_29  ]  Offset: 41584 | Success:   231 /   231 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_33  ]  Offset: 51992 | Success:   108 /   109 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_33  ]  Scraping completed in 0:21:43.156389
# [ ThreadPoolExecutor-0_36  ]  Offset: 71176 | Success:     1 /     2 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_9   ]  Offset: 71968 | Success:     9 /     9 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_6   ]  Offset: 65592 | Success:     3 /     3 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_6   ]  Scraping completed in 0:20:37.847432
# [ ThreadPoolExecutor-0_32  ]  Offset: 43192 | Success:   193 /   193 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_32  ]  Scraping completed in 0:22:25.338252
# [ ThreadPoolExecutor-0_13  ]  Offset: 67984 | Success:    10 /    10 | Failure:     0 | Class count:  1967
# [ ThreadPoolExecutor-0_46  ]  Offset: 62376 | Success:    70 /    71 | Failure:     0 | Class count:  1968
# [ ThreadPoolExecutor-0_22  ]  Offset: 52680 | Success:   380 /   390 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_28  ]  Offset: 54368 | Success:   138 /   139 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_39  ]  Offset: 69576 | Success:     3 /     3 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_8   ]  Offset: 55152 | Success:   194 /   197 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_17  ]  Offset: 60784 | Success:    74 /    75 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_1   ]  Offset: 47184 | Success:   161 /   170 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_2   ]  Offset: 46344 | Success:   305 /   312 | Failure:     1 | Class count:  1969
# [ ThreadPoolExecutor-0_30  ]  Offset: 43952 | Success:   314 /   314 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_24  ]  Offset: 42360 | Success:   262 /   262 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_3   ]  Offset: 44760 | Success:   289 /   289 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_11  ]  Offset: 53512 | Success:   265 /   273 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_21  ]  Offset: 47936 | Success:   313 /   323 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_48  ]  Offset: 70376 | Success:     0 /     0 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_7   ]  Offset: 67184 | Success:    14 /    14 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_44  ]  Offset: 64792 | Success:     3 /     3 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_44  ]  Scraping completed in 0:20:50.476297
# [ ThreadPoolExecutor-0_20  ]  Offset: 68784 | Success:     2 /     2 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_23  ]  Offset: 66384 | Success:     1 /     1 | Failure:     0 | Class count:  1969
# [ ThreadPoolExecutor-0_16  ]  Offset: 45568 | Success:   263 /   272 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_29  ]  Offset: 41592 | Success:   233 /   233 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_29  ]  Scraping completed in 0:22:39.590999
# Thread completed with result None
# [ ThreadPoolExecutor-0_5   ]  Offset: 59936 | Success:   174 /   175 | Failure:     3 | Class count:  1970
# [ ThreadPoolExecutor-0_36  ]  Offset: 71184 | Success:     1 /     2 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_13  ]  Offset: 67992 | Success:    10 /    10 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_13  ]  Scraping completed in 0:20:48.418538
# [ ThreadPoolExecutor-0_9   ]  Offset: 71976 | Success:     9 /     9 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_39  ]  Offset: 69584 | Success:     3 /     3 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_46  ]  Offset: 62384 | Success:    70 /    71 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_17  ]  Offset: 60792 | Success:    74 /    75 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_17  ]  Scraping completed in 0:21:24.342298
# [ ThreadPoolExecutor-0_2   ]  Offset: 46352 | Success:   305 /   312 | Failure:     1 | Class count:  1970
# [ ThreadPoolExecutor-0_8   ]  Offset: 55160 | Success:   195 /   198 | Failure:     0 | Class count:  1970
# [ ThreadPoolExecutor-0_30  ]  Offset: 43960 | Success:   315 /   315 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_24  ]  Offset: 42368 | Success:   265 /   265 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_1   ]  Offset: 47192 | Success:   163 /   172 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_1   ]  Scraping completed in 0:22:36.049828
# [ ThreadPoolExecutor-0_22  ]  Offset: 52688 | Success:   384 /   394 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53520 | Success:   268 /   276 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_28  ]  Offset: 54376 | Success:   144 /   145 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_21  ]  Offset: 47944 | Success:   319 /   329 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_48  ]  Offset: 70384 | Success:     0 /     0 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_20  ]  Offset: 68792 | Success:     2 /     2 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_20  ]  Scraping completed in 0:20:48.398437
# [ ThreadPoolExecutor-0_23  ]  Offset: 66392 | Success:     1 /     1 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_23  ]  Scraping completed in 0:20:59.110639
# [ ThreadPoolExecutor-0_16  ]  Offset: 45576 | Success:   263 /   272 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_3   ]  Offset: 44768 | Success:   295 /   295 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_36  ]  Offset: 71192 | Success:     1 /     2 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_36  ]  Scraping completed in 0:20:41.267114
# [ ThreadPoolExecutor-0_5   ]  Offset: 59944 | Success:   175 /   176 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_7   ]  Offset: 67192 | Success:    15 /    15 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_7   ]  Scraping completed in 0:20:59.528686
# [ ThreadPoolExecutor-0_9   ]  Offset: 71984 | Success:     9 /     9 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_2   ]  Offset: 46360 | Success:   305 /   312 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_46  ]  Offset: 62392 | Success:    70 /    71 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_46  ]  Scraping completed in 0:21:29.024617
# [ ThreadPoolExecutor-0_39  ]  Offset: 69592 | Success:     4 /     4 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_39  ]  Scraping completed in 0:20:54.762572
# [ ThreadPoolExecutor-0_24  ]  Offset: 42376 | Success:   265 /   265 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_8   ]  Offset: 55168 | Success:   196 /   199 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53528 | Success:   268 /   276 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_30  ]  Offset: 43968 | Success:   320 /   320 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_22  ]  Offset: 52696 | Success:   388 /   398 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_48  ]  Offset: 70392 | Success:     0 /     0 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_48  ]  Scraping completed in 0:20:54.359470
# [ ThreadPoolExecutor-0_21  ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity.org/lethe-rohria\\v'>
# [ ThreadPoolExecutor-0_16  ]  Offset: 45584 | Success:   263 /   272 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_28  ]  Offset: 54384 | Success:   152 /   153 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_5   ]  Offset: 59952 | Success:   177 /   178 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_21  ]  Offset: 47952 | Success:   324 /   334 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_3   ]  Offset: 44776 | Success:   300 /   300 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_9   ]  Offset: 71992 | Success:     9 /     9 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_9   ]  Scraping completed in 0:20:57.699308
# [ ThreadPoolExecutor-0_2   ]  Offset: 46368 | Success:   305 /   312 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_8   ]  Offset: 55176 | Success:   197 /   200 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_24  ]  Offset: 42384 | Success:   266 /   266 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53536 | Success:   268 /   276 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_30  ]  Offset: 43976 | Success:   326 /   326 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_5   ]  Offset: 59960 | Success:   177 /   178 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_16  ]  Offset: 45592 | Success:   266 /   275 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_16  ]  Scraping completed in 0:23:10.212284
# [ ThreadPoolExecutor-0_22  ]  Offset: 52704 | Success:   395 /   406 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_3   ]  Offset: 44784 | Success:   300 /   300 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_8   ]  Offset: 55184 | Success:   197 /   200 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_2   ]  Offset: 46376 | Success:   305 /   312 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53544 | Success:   268 /   276 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_21  ]  Offset: 47960 | Success:   328 /   338 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_28  ]  Offset: 54392 | Success:   160 /   161 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_28  ]  Scraping completed in 0:22:24.476053
# [ ThreadPoolExecutor-0_24  ]  Offset: 42392 | Success:   268 /   268 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_24  ]  Scraping completed in 0:23:24.594834
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_5   ]  Offset: 59968 | Success:   177 /   178 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_30  ]  Offset: 43984 | Success:   332 /   332 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_3   ]  Offset: 44792 | Success:   300 /   300 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_3   ]  Scraping completed in 0:23:31.507543
# [ ThreadPoolExecutor-0_8   ]  Offset: 55192 | Success:   197 /   200 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_8   ]  Scraping completed in 0:22:32.541186
# [ ThreadPoolExecutor-0_2   ]  Offset: 46384 | Success:   305 /   312 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_22  ]  Offset: 52712 | Success:   400 /   411 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53552 | Success:   271 /   279 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_21  ]  Offset: 47968 | Success:   334 /   344 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_5   ]  Offset: 59976 | Success:   177 /   178 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_2   ]  Offset: 46392 | Success:   305 /   312 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_2   ]  Scraping completed in 0:23:34.391720
# [ ThreadPoolExecutor-0_11  ]  Offset: 53560 | Success:   273 /   281 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_30  ]  Offset: 43992 | Success:   338 /   338 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_30  ]  Scraping completed in 0:23:46.573389
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_22  ]  Offset: 52720 | Success:   408 /   419 | Failure:     0 | Class count:  1971
# [ ThreadPoolExecutor-0_5   ]  Offset: 59984 | Success:   177 /   178 | Failure:     3 | Class count:  1971
# [ ThreadPoolExecutor-0_21  ]  Offset: 47976 | Success:   334 /   345 | Failure:     1 | Class count:  1971
# [ ThreadPoolExecutor-0_11  ]  Offset: 53568 | Success:   275 /   283 | Failure:     0 | Class count:  1972
# [ ThreadPoolExecutor-0_5   ]  Offset: 59992 | Success:   179 /   180 | Failure:     3 | Class count:  1972
# [ ThreadPoolExecutor-0_5   ]  Scraping completed in 0:22:40.287710
# [ ThreadPoolExecutor-0_22  ]  Offset: 52728 | Success:   409 /   420 | Failure:     0 | Class count:  1972
# [ ThreadPoolExecutor-0_21  ]  Removing corrupted image <_io.BufferedWriter name='insect-dataset/indiabiodiversity.org/papilio-bianor\\v'>
# [ ThreadPoolExecutor-0_21  ]  Offset: 47984 | Success:   337 /   348 | Failure:     2 | Class count:  1972
# [ ThreadPoolExecutor-0_11  ]  Offset: 53576 | Success:   275 /   283 | Failure:     0 | Class count:  1972
# [ ThreadPoolExecutor-0_21  ]  Offset: 47992 | Success:   337 /   348 | Failure:     2 | Class count:  1973
# [ ThreadPoolExecutor-0_21  ]  Scraping completed in 0:24:00.284295
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_22  ]  Offset: 52736 | Success:   417 /   428 | Failure:     0 | Class count:  1974
# [ ThreadPoolExecutor-0_11  ]  Offset: 53584 | Success:   275 /   283 | Failure:     0 | Class count:  1974
# [ ThreadPoolExecutor-0_22  ]  Offset: 52744 | Success:   421 /   432 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_11  ]  Offset: 53592 | Success:   275 /   283 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_11  ]  Scraping completed in 0:23:28.410151
# [ ThreadPoolExecutor-0_22  ]  Offset: 52752 | Success:   422 /   433 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Offset: 52760 | Success:   428 /   439 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Offset: 52768 | Success:   429 /   440 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Offset: 52776 | Success:   434 /   445 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Offset: 52784 | Success:   435 /   446 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Offset: 52792 | Success:   436 /   447 | Failure:     0 | Class count:  1975
# [ ThreadPoolExecutor-0_22  ]  Scraping completed in 0:24:43.637274
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# All threads completed

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(dataset_dir).iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
    if not os.listdir(species_dir):
        os.rmdir(species_dir)
        print(f"Empty folder {species_dir} removed")
# Out:
# Empty folder insect-dataset\indiabiodiversity.org\celastrina-oreana removed
# Empty folder insect-dataset\indiabiodiversity.org\lethe-goalpara removed

# %% [markdown]
# # ZIP the data

# %%
import shutil
import time
import datetime

shutil.make_archive(f"{dataset_dir}/../lepidoptera.indiabiodiversity.org.{datetime.datetime.now().strftime("%Y.%m.%d")}", 
                    'zip', f"{dataset_dir}")
# Out:
# 'D:\\Projects\\my-jupyter-notebook\\insect-species-identification\\insect-dataset\\lepidoptera.indiabiodiversity.org.2025.02.10.zip'
