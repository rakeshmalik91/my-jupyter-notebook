# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor
import shutil
from PIL import Image
from pathlib import Path
import time
import datetime

# %%
dataset_dir = "insect-dataset/insecta.pro"

# %%
page_timeout = 120
image_timeout = 30

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False
    
def download_image(img_url, output_dir):
    try:
        # print(f"{log_header()} Downloading {img_url} into {output_dir}")
        # print(f"{log_header()} Downloading {img_url.split("/")[-1].split("?")[0]} into {output_dir.split("/")[-1]}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name.split("?")[0])
        if Path(img_path).is_file() and check_image(img_path):
            # skipping, already downloaded
            return 'EXISTS'
        img_data = requests.get(img_url, timeout=image_timeout, headers=headers).content
        with open(img_path, 'wb') as file:
            file.write(img_data)
        if not check_image(img_path):
            print(f"{log_header()}Removing corrupted image {file.name}")
            os.remove(Path(img_path))
            return 'FAILURE'
        return 'SUCCESS'
    except Exception as e:
        print(f"{log_header()}{e}")
        return 'FAILURE'

def scrape(start, end):
    success_cnt = 0
    failure_cnt = 0
    exists_cnt = 0
    for page in range(start, end, 1):
        try:
            url = f"https://insecta.pro/gallery?page={page}&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10"
            print(f"{log_header()}Scraping {url} ...")
            response = requests.get(url, timeout=page_timeout, headers=headers)
            soup = BeautifulSoup(response.text, 'html.parser')
            div = soup.find("div", class_="gal")
            if div:
                img_tags = div.find_all("img")
                for img in img_tags:
                    try:
                        img_url = img.get('src')
                        img_name = img_url.split("/")[-1].split("?")[0]
                        class_name = re.sub(r" ", "-", img.parent.get("title").lower())
                        class_dir = f"{dataset_dir}/{class_name}"
                        img_url = f"https://insecta.pro{img_url}"
                        if not os.path.exists(class_dir):
                            os.makedirs(class_dir)
                        # print(f"{log_header()}\tDownloading {img_url} in {class_name}")
                        status = download_image(img_url, class_dir)
                        success_cnt += 1 if status=='SUCCESS' else 0
                        failure_cnt += 1 if status=='FAILURE' else 0
                        exists_cnt += 1 if status=='EXISTS' else 0
                        if not os.listdir(class_dir):
                            os.rmdir(class_dir)
                    except Exception as e:
                        print(f"{log_header()}{e}")
        except Exception as e:
            print(f"{log_header()}{e}")
        print(f"{log_header()}SUCCESS: {success_cnt:5} | FAILURE: {failure_cnt:5} | EXISTS: {exists_cnt:5} | CLASSES: {len(os.listdir(dataset_dir)):5}")

start = 0
end = 254
step = 5
max_workers = 100
print(f"{log_header()}Starting scraping...")
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(scrape, offset, offset + step) for offset in range(start, end + 1, step)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")
print(f"{log_header()}Scraping completed")
# Out:
# [ MainThread               ]  Starting scraping...
# [ ThreadPoolExecutor-0_0   ]  Scraping https://insecta.pro/gallery?page=0&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_1   ]  Scraping https://insecta.pro/gallery?page=5&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_2   ]  Scraping https://insecta.pro/gallery?page=10&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  Scraping https://insecta.pro/gallery?page=15&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_4   ]  Scraping https://insecta.pro/gallery?page=20&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_5   ]  Scraping https://insecta.pro/gallery?page=25&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_6   ]  Scraping https://insecta.pro/gallery?page=30&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_7   ]  Scraping https://insecta.pro/gallery?page=35&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_8   ]  Scraping https://insecta.pro/gallery?page=40&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_9   ]  Scraping https://insecta.pro/gallery?page=45&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_10  ]  Scraping https://insecta.pro/gallery?page=50&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_11  ]  Scraping https://insecta.pro/gallery?page=55&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_12  ]  Scraping https://insecta.pro/gallery?page=60&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_13  ]  Scraping https://insecta.pro/gallery?page=65&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_14  ]  Scraping https://insecta.pro/gallery?page=70&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_15  ]  Scraping https://insecta.pro/gallery?page=75&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_16  ]  Scraping https://insecta.pro/gallery?page=80&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_17  ]  Scraping https://insecta.pro/gallery?page=85&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_18  ]  Scraping https://insecta.pro/gallery?page=90&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_19  ]  Scraping https://insecta.pro/gallery?page=95&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_20  ]  Scraping https://insecta.pro/gallery?page=100&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_21  ]  Scraping https://insecta.pro/gallery?page=105&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_22  ]  Scraping https://insecta.pro/gallery?page=110&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_23  ]  Scraping https://insecta.pro/gallery?page=115&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_24  ]  Scraping https://insecta.pro/gallery?page=120&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  Scraping https://insecta.pro/gallery?page=125&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_26  ]  Scraping https://insecta.pro/gallery?page=130&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  Scraping https://insecta.pro/gallery?page=135&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_28  ]  Scraping https://insecta.pro/gallery?page=140&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_29  ]  Scraping https://insecta.pro/gallery?page=145&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_30  ]  Scraping https://insecta.pro/gallery?page=150&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  Scraping https://insecta.pro/gallery?page=155&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_32  ]  Scraping https://insecta.pro/gallery?page=160&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_33  ]  Scraping https://insecta.pro/gallery?page=165&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_34  ]  Scraping https://insecta.pro/gallery?page=170&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_35  ]  Scraping https://insecta.pro/gallery?page=175&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_36  ]  Scraping https://insecta.pro/gallery?page=180&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_37  ]  Scraping https://insecta.pro/gallery?page=185&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_38  ]  Scraping https://insecta.pro/gallery?page=190&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_39  ]  Scraping https://insecta.pro/gallery?page=195&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_40  ]  Scraping https://insecta.pro/gallery?page=200&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  Scraping https://insecta.pro/gallery?page=205&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  Scraping https://insecta.pro/gallery?page=210&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_43  ]  Scraping https://insecta.pro/gallery?page=215&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_44  ]  Scraping https://insecta.pro/gallery?page=220&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_45  ]  Scraping https://insecta.pro/gallery?page=225&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_46  ]  Scraping https://insecta.pro/gallery?page=230&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_47  ]  Scraping https://insecta.pro/gallery?page=235&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_48  ]  Scraping https://insecta.pro/gallery?page=240&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_49  ]  Scraping https://insecta.pro/gallery?page=245&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  Scraping https://insecta.pro/gallery?page=250&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_33  ]  SUCCESS:    11 | FAILURE:     0 | EXISTS:    89 | CLASSES:  1795
# [ ThreadPoolExecutor-0_33  ]  Scraping https://insecta.pro/gallery?page=166&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_8   ]  SUCCESS:     7 | FAILURE:     0 | EXISTS:    80 | CLASSES:  1839
# [ ThreadPoolExecutor-0_8   ]  Scraping https://insecta.pro/gallery?page=41&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_4   ]  SUCCESS:    10 | FAILURE:     0 | EXISTS:    90 | CLASSES:  1844
# [ ThreadPoolExecutor-0_4   ]  Scraping https://insecta.pro/gallery?page=21&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_0   ]  SUCCESS:     9 | FAILURE:     0 | EXISTS:    91 | CLASSES:  1911
# [ ThreadPoolExecutor-0_0   ]  Scraping https://insecta.pro/gallery?page=1&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  SUCCESS:    11 | FAILURE:     0 | EXISTS:    88 | CLASSES:  1921
# [ ThreadPoolExecutor-0_27  ]  Scraping https://insecta.pro/gallery?page=136&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_34  ]  SUCCESS:     6 | FAILURE:     0 | EXISTS:    94 | CLASSES:  1921
# [ ThreadPoolExecutor-0_34  ]  Scraping https://insecta.pro/gallery?page=171&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_0   ]  SUCCESS:     9 | FAILURE:     0 | EXISTS:   191 | CLASSES:  1925
# [ ThreadPoolExecutor-0_0   ]  Scraping https://insecta.pro/gallery?page=2&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_15  ]  SUCCESS:    19 | FAILURE:     0 | EXISTS:    81 | CLASSES:  1956
# [ ThreadPoolExecutor-0_15  ]  Scraping https://insecta.pro/gallery?page=76&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_24  ]  SUCCESS:    17 | FAILURE:     0 | EXISTS:    83 | CLASSES:  1959
# [ ThreadPoolExecutor-0_24  ]  Scraping https://insecta.pro/gallery?page=121&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  SUCCESS:    15 | FAILURE:     0 | EXISTS:    85 | CLASSES:  1969
# [ ThreadPoolExecutor-0_3   ]  Scraping https://insecta.pro/gallery?page=16&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_11  ]  SUCCESS:    17 | FAILURE:     0 | EXISTS:    83 | CLASSES:  1976
# [ ThreadPoolExecutor-0_11  ]  Scraping https://insecta.pro/gallery?page=56&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_22  ]  SUCCESS:    17 | FAILURE:     0 | EXISTS:    81 | CLASSES:  1985
# [ ThreadPoolExecutor-0_22  ]  Scraping https://insecta.pro/gallery?page=111&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_2   ]  SUCCESS:    23 | FAILURE:     0 | EXISTS:    77 | CLASSES:  1999
# [ ThreadPoolExecutor-0_2   ]  Scraping https://insecta.pro/gallery?page=11&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  SUCCESS:    16 | FAILURE:     0 | EXISTS:    84 | CLASSES:  2016
# [ ThreadPoolExecutor-0_50  ]  Scraping https://insecta.pro/gallery?page=251&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_32  ]  SUCCESS:    21 | FAILURE:     0 | EXISTS:    79 | CLASSES:  2025
# [ ThreadPoolExecutor-0_32  ]  Scraping https://insecta.pro/gallery?page=161&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_7   ]  SUCCESS:    19 | FAILURE:     0 | EXISTS:    81 | CLASSES:  2041
# [ ThreadPoolExecutor-0_7   ]  Scraping https://insecta.pro/gallery?page=36&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_19  ]  SUCCESS:    23 | FAILURE:     0 | EXISTS:    77 | CLASSES:  2051
# [ ThreadPoolExecutor-0_19  ]  Scraping https://insecta.pro/gallery?page=96&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  SUCCESS:    20 | FAILURE:     0 | EXISTS:    80 | CLASSES:  2058
# [ ThreadPoolExecutor-0_42  ]  Scraping https://insecta.pro/gallery?page=211&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_5   ]  SUCCESS:    23 | FAILURE:     0 | EXISTS:    77 | CLASSES:  2059
# [ ThreadPoolExecutor-0_5   ]  Scraping https://insecta.pro/gallery?page=26&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_35  ]  SUCCESS:    22 | FAILURE:     0 | EXISTS:    78 | CLASSES:  2063
# [ ThreadPoolExecutor-0_35  ]  Scraping https://insecta.pro/gallery?page=176&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  SUCCESS:    27 | FAILURE:     0 | EXISTS:    73 | CLASSES:  2065
# [ ThreadPoolExecutor-0_41  ]  Scraping https://insecta.pro/gallery?page=206&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_9   ]  SUCCESS:    20 | FAILURE:     0 | EXISTS:    80 | CLASSES:  2069
# [ ThreadPoolExecutor-0_9   ]  Scraping https://insecta.pro/gallery?page=46&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_6   ]  SUCCESS:    21 | FAILURE:     0 | EXISTS:    79 | CLASSES:  2084
# [ ThreadPoolExecutor-0_6   ]  Scraping https://insecta.pro/gallery?page=31&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_38  ]  SUCCESS:    32 | FAILURE:     0 | EXISTS:    68 | CLASSES:  2084
# [ ThreadPoolExecutor-0_38  ]  Scraping https://insecta.pro/gallery?page=191&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_17  ]  SUCCESS:    26 | FAILURE:     0 | EXISTS:    74 | CLASSES:  2084
# [ ThreadPoolExecutor-0_17  ]  Scraping https://insecta.pro/gallery?page=86&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_29  ]  SUCCESS:    20 | FAILURE:     0 | EXISTS:    80 | CLASSES:  2097
# [ ThreadPoolExecutor-0_29  ]  Scraping https://insecta.pro/gallery?page=146&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_10  ]  SUCCESS:    29 | FAILURE:     0 | EXISTS:    71 | CLASSES:  2100
# [ ThreadPoolExecutor-0_10  ]  Scraping https://insecta.pro/gallery?page=51&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_14  ]  SUCCESS:    23 | FAILURE:     0 | EXISTS:    77 | CLASSES:  2107
# [ ThreadPoolExecutor-0_14  ]  Scraping https://insecta.pro/gallery?page=71&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  SUCCESS:    27 | FAILURE:     0 | EXISTS:    73 | CLASSES:  2116
# [ ThreadPoolExecutor-0_31  ]  Scraping https://insecta.pro/gallery?page=156&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_37  ]  SUCCESS:    25 | FAILURE:     0 | EXISTS:    75 | CLASSES:  2125
# [ ThreadPoolExecutor-0_37  ]  Scraping https://insecta.pro/gallery?page=186&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_23  ]  SUCCESS:    33 | FAILURE:     0 | EXISTS:    65 | CLASSES:  2148
# [ ThreadPoolExecutor-0_23  ]  Scraping https://insecta.pro/gallery?page=116&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_39  ]  SUCCESS:    24 | FAILURE:     0 | EXISTS:    76 | CLASSES:  2166
# [ ThreadPoolExecutor-0_39  ]  Scraping https://insecta.pro/gallery?page=196&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_28  ]  SUCCESS:    31 | FAILURE:     0 | EXISTS:    69 | CLASSES:  2205
# [ ThreadPoolExecutor-0_28  ]  Scraping https://insecta.pro/gallery?page=141&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_30  ]  SUCCESS:    30 | FAILURE:     0 | EXISTS:    70 | CLASSES:  2211
# [ ThreadPoolExecutor-0_30  ]  Scraping https://insecta.pro/gallery?page=151&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_1   ]  SUCCESS:    36 | FAILURE:     0 | EXISTS:    64 | CLASSES:  2211
# [ ThreadPoolExecutor-0_1   ]  Scraping https://insecta.pro/gallery?page=6&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_26  ]  SUCCESS:    37 | FAILURE:     0 | EXISTS:    63 | CLASSES:  2252
# [ ThreadPoolExecutor-0_26  ]  Scraping https://insecta.pro/gallery?page=131&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_18  ]  SUCCESS:    37 | FAILURE:     0 | EXISTS:    63 | CLASSES:  2257
# [ ThreadPoolExecutor-0_18  ]  Scraping https://insecta.pro/gallery?page=91&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_21  ]  SUCCESS:    43 | FAILURE:     0 | EXISTS:    55 | CLASSES:  2263
# [ ThreadPoolExecutor-0_21  ]  Scraping https://insecta.pro/gallery?page=106&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_13  ]  SUCCESS:    41 | FAILURE:     0 | EXISTS:    58 | CLASSES:  2263
# [ ThreadPoolExecutor-0_13  ]  Scraping https://insecta.pro/gallery?page=66&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_16  ]  SUCCESS:    39 | FAILURE:     0 | EXISTS:    61 | CLASSES:  2278
# [ ThreadPoolExecutor-0_16  ]  Scraping https://insecta.pro/gallery?page=81&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_12  ]  SUCCESS:    39 | FAILURE:     0 | EXISTS:    61 | CLASSES:  2330
# [ ThreadPoolExecutor-0_12  ]  Scraping https://insecta.pro/gallery?page=61&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_46  ]  SUCCESS:    40 | FAILURE:     0 | EXISTS:    60 | CLASSES:  2333
# [ ThreadPoolExecutor-0_46  ]  Scraping https://insecta.pro/gallery?page=231&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_43  ]  SUCCESS:    43 | FAILURE:     0 | EXISTS:    57 | CLASSES:  2334
# [ ThreadPoolExecutor-0_43  ]  Scraping https://insecta.pro/gallery?page=216&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_40  ]  SUCCESS:    28 | FAILURE:     0 | EXISTS:    72 | CLASSES:  2347
# [ ThreadPoolExecutor-0_40  ]  Scraping https://insecta.pro/gallery?page=201&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_44  ]  SUCCESS:    53 | FAILURE:     0 | EXISTS:    47 | CLASSES:  2347
# [ ThreadPoolExecutor-0_44  ]  Scraping https://insecta.pro/gallery?page=221&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_36  ]  SUCCESS:    32 | FAILURE:     0 | EXISTS:    67 | CLASSES:  2363
# [ ThreadPoolExecutor-0_36  ]  Scraping https://insecta.pro/gallery?page=181&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_20  ]  SUCCESS:    46 | FAILURE:     0 | EXISTS:    54 | CLASSES:  2366
# [ ThreadPoolExecutor-0_20  ]  Scraping https://insecta.pro/gallery?page=101&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  SUCCESS:    43 | FAILURE:     0 | EXISTS:    57 | CLASSES:  2392
# [ ThreadPoolExecutor-0_25  ]  Scraping https://insecta.pro/gallery?page=126&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_49  ]  SUCCESS:    47 | FAILURE:     0 | EXISTS:    53 | CLASSES:  2403
# [ ThreadPoolExecutor-0_49  ]  Scraping https://insecta.pro/gallery?page=246&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_45  ]  SUCCESS:    42 | FAILURE:     0 | EXISTS:    58 | CLASSES:  2425
# [ ThreadPoolExecutor-0_45  ]  Scraping https://insecta.pro/gallery?page=226&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_24  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_47  ]  SUCCESS:    39 | FAILURE:     0 | EXISTS:    61 | CLASSES:  2441
# [ ThreadPoolExecutor-0_47  ]  Scraping https://insecta.pro/gallery?page=236&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_48  ]  SUCCESS:    52 | FAILURE:     0 | EXISTS:    48 | CLASSES:  2520
# [ ThreadPoolExecutor-0_48  ]  Scraping https://insecta.pro/gallery?page=241&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_24  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_4   ]  SUCCESS:   110 | FAILURE:     0 | EXISTS:    90 | CLASSES:  2971
# [ ThreadPoolExecutor-0_4   ]  Scraping https://insecta.pro/gallery?page=22&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  SUCCESS:   115 | FAILURE:     0 | EXISTS:    85 | CLASSES:  2985
# [ ThreadPoolExecutor-0_3   ]  Scraping https://insecta.pro/gallery?page=17&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_47  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_11  ]  SUCCESS:   117 | FAILURE:     0 | EXISTS:    83 | CLASSES:  2999
# [ ThreadPoolExecutor-0_11  ]  Scraping https://insecta.pro/gallery?page=57&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_32  ]  SUCCESS:   121 | FAILURE:     0 | EXISTS:    79 | CLASSES:  3032
# [ ThreadPoolExecutor-0_32  ]  Scraping https://insecta.pro/gallery?page=162&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_8   ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_38  ]  SUCCESS:   132 | FAILURE:     0 | EXISTS:    68 | CLASSES:  3056
# [ ThreadPoolExecutor-0_38  ]  Scraping https://insecta.pro/gallery?page=192&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_5   ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_2   ]  SUCCESS:   123 | FAILURE:     0 | EXISTS:    77 | CLASSES:  3093
# [ ThreadPoolExecutor-0_2   ]  Scraping https://insecta.pro/gallery?page=12&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_5   ]  SUCCESS:   120 | FAILURE:     1 | EXISTS:    79 | CLASSES:  3114
# [ ThreadPoolExecutor-0_5   ]  Scraping https://insecta.pro/gallery?page=27&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_35  ]  SUCCESS:   122 | FAILURE:     0 | EXISTS:    78 | CLASSES:  3120
# [ ThreadPoolExecutor-0_35  ]  Scraping https://insecta.pro/gallery?page=177&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_33  ]  SUCCESS:   111 | FAILURE:     0 | EXISTS:    89 | CLASSES:  3122
# [ ThreadPoolExecutor-0_33  ]  Scraping https://insecta.pro/gallery?page=167&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  SUCCESS:   127 | FAILURE:     0 | EXISTS:    73 | CLASSES:  3127
# [ ThreadPoolExecutor-0_31  ]  Scraping https://insecta.pro/gallery?page=157&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_34  ]  SUCCESS:   106 | FAILURE:     0 | EXISTS:    94 | CLASSES:  3136
# [ ThreadPoolExecutor-0_34  ]  Scraping https://insecta.pro/gallery?page=172&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  SUCCESS:   127 | FAILURE:     0 | EXISTS:    73 | CLASSES:  3140
# [ ThreadPoolExecutor-0_41  ]  Scraping https://insecta.pro/gallery?page=207&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_17  ]  SUCCESS:   126 | FAILURE:     0 | EXISTS:    74 | CLASSES:  3144
# [ ThreadPoolExecutor-0_17  ]  Scraping https://insecta.pro/gallery?page=87&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_8   ]  SUCCESS:   105 | FAILURE:     1 | EXISTS:    80 | CLASSES:  3156
# [ ThreadPoolExecutor-0_8   ]  Scraping https://insecta.pro/gallery?page=42&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_9   ]  SUCCESS:   120 | FAILURE:     0 | EXISTS:    80 | CLASSES:  3157
# [ ThreadPoolExecutor-0_9   ]  Scraping https://insecta.pro/gallery?page=47&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  SUCCESS:   116 | FAILURE:     0 | EXISTS:    84 | CLASSES:  3165
# [ ThreadPoolExecutor-0_50  ]  Scraping https://insecta.pro/gallery?page=252&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_22  ]  SUCCESS:   117 | FAILURE:     0 | EXISTS:    81 | CLASSES:  3192
# [ ThreadPoolExecutor-0_22  ]  Scraping https://insecta.pro/gallery?page=112&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_7   ]  SUCCESS:   119 | FAILURE:     0 | EXISTS:    81 | CLASSES:  3197
# [ ThreadPoolExecutor-0_7   ]  Scraping https://insecta.pro/gallery?page=37&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_14  ]  SUCCESS:   122 | FAILURE:     0 | EXISTS:    78 | CLASSES:  3201
# [ ThreadPoolExecutor-0_14  ]  Scraping https://insecta.pro/gallery?page=72&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_13  ]  SUCCESS:   141 | FAILURE:     0 | EXISTS:    58 | CLASSES:  3232
# [ ThreadPoolExecutor-0_13  ]  Scraping https://insecta.pro/gallery?page=67&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  SUCCESS:   109 | FAILURE:     1 | EXISTS:    88 | CLASSES:  3242
# [ ThreadPoolExecutor-0_27  ]  Scraping https://insecta.pro/gallery?page=137&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_15  ]  SUCCESS:   119 | FAILURE:     0 | EXISTS:    81 | CLASSES:  3255
# [ ThreadPoolExecutor-0_15  ]  Scraping https://insecta.pro/gallery?page=77&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_19  ]  SUCCESS:   123 | FAILURE:     0 | EXISTS:    77 | CLASSES:  3256
# [ ThreadPoolExecutor-0_19  ]  Scraping https://insecta.pro/gallery?page=97&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_29  ]  SUCCESS:   120 | FAILURE:     0 | EXISTS:    80 | CLASSES:  3259
# [ ThreadPoolExecutor-0_29  ]  Scraping https://insecta.pro/gallery?page=147&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_23  ]  SUCCESS:   133 | FAILURE:     0 | EXISTS:    65 | CLASSES:  3259
# [ ThreadPoolExecutor-0_23  ]  Scraping https://insecta.pro/gallery?page=117&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_16  ]  SUCCESS:   139 | FAILURE:     0 | EXISTS:    61 | CLASSES:  3260
# [ ThreadPoolExecutor-0_16  ]  Scraping https://insecta.pro/gallery?page=82&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_10  ]  SUCCESS:   129 | FAILURE:     0 | EXISTS:    71 | CLASSES:  3261
# [ ThreadPoolExecutor-0_10  ]  Scraping https://insecta.pro/gallery?page=52&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_0   ]  SUCCESS:   109 | FAILURE:     0 | EXISTS:   191 | CLASSES:  3261
# [ ThreadPoolExecutor-0_0   ]  Scraping https://insecta.pro/gallery?page=3&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_39  ]  SUCCESS:   124 | FAILURE:     0 | EXISTS:    76 | CLASSES:  3265
# [ ThreadPoolExecutor-0_39  ]  Scraping https://insecta.pro/gallery?page=197&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_6   ]  SUCCESS:   121 | FAILURE:     0 | EXISTS:    79 | CLASSES:  3267
# [ ThreadPoolExecutor-0_6   ]  Scraping https://insecta.pro/gallery?page=32&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_30  ]  SUCCESS:   130 | FAILURE:     0 | EXISTS:    70 | CLASSES:  3277
# [ ThreadPoolExecutor-0_30  ]  Scraping https://insecta.pro/gallery?page=152&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_1   ]  SUCCESS:   136 | FAILURE:     0 | EXISTS:    64 | CLASSES:  3277
# [ ThreadPoolExecutor-0_1   ]  Scraping https://insecta.pro/gallery?page=7&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_26  ]  SUCCESS:   137 | FAILURE:     0 | EXISTS:    63 | CLASSES:  3288
# [ ThreadPoolExecutor-0_26  ]  Scraping https://insecta.pro/gallery?page=132&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_24  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_28  ]  SUCCESS:   131 | FAILURE:     0 | EXISTS:    69 | CLASSES:  3321
# [ ThreadPoolExecutor-0_28  ]  Scraping https://insecta.pro/gallery?page=142&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  SUCCESS:   119 | FAILURE:     1 | EXISTS:    80 | CLASSES:  3336
# [ ThreadPoolExecutor-0_42  ]  Scraping https://insecta.pro/gallery?page=212&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_40  ]  SUCCESS:   128 | FAILURE:     0 | EXISTS:    72 | CLASSES:  3365
# [ ThreadPoolExecutor-0_40  ]  Scraping https://insecta.pro/gallery?page=202&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_21  ]  SUCCESS:   143 | FAILURE:     0 | EXISTS:    55 | CLASSES:  3376
# [ ThreadPoolExecutor-0_21  ]  Scraping https://insecta.pro/gallery?page=107&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_37  ]  SUCCESS:   125 | FAILURE:     0 | EXISTS:    75 | CLASSES:  3384
# [ ThreadPoolExecutor-0_37  ]  Scraping https://insecta.pro/gallery?page=187&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_43  ]  SUCCESS:   143 | FAILURE:     0 | EXISTS:    57 | CLASSES:  3433
# [ ThreadPoolExecutor-0_43  ]  Scraping https://insecta.pro/gallery?page=217&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_36  ]  SUCCESS:   132 | FAILURE:     0 | EXISTS:    67 | CLASSES:  3482
# [ ThreadPoolExecutor-0_36  ]  Scraping https://insecta.pro/gallery?page=182&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_24  ]  SUCCESS:   114 | FAILURE:     3 | EXISTS:    83 | CLASSES:  3488
# [ ThreadPoolExecutor-0_24  ]  Scraping https://insecta.pro/gallery?page=122&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_12  ]  SUCCESS:   139 | FAILURE:     0 | EXISTS:    61 | CLASSES:  3499
# [ ThreadPoolExecutor-0_12  ]  Scraping https://insecta.pro/gallery?page=62&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_49  ]  SUCCESS:   147 | FAILURE:     0 | EXISTS:    53 | CLASSES:  3535
# [ ThreadPoolExecutor-0_49  ]  Scraping https://insecta.pro/gallery?page=247&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_48  ]  SUCCESS:   152 | FAILURE:     0 | EXISTS:    48 | CLASSES:  3540
# [ ThreadPoolExecutor-0_48  ]  Scraping https://insecta.pro/gallery?page=242&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_46  ]  SUCCESS:   140 | FAILURE:     0 | EXISTS:    60 | CLASSES:  3559
# [ ThreadPoolExecutor-0_46  ]  Scraping https://insecta.pro/gallery?page=232&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_44  ]  SUCCESS:   153 | FAILURE:     0 | EXISTS:    47 | CLASSES:  3563
# [ ThreadPoolExecutor-0_44  ]  Scraping https://insecta.pro/gallery?page=222&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_18  ]  SUCCESS:   137 | FAILURE:     0 | EXISTS:    63 | CLASSES:  3591
# [ ThreadPoolExecutor-0_18  ]  Scraping https://insecta.pro/gallery?page=92&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_47  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_17  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_20  ]  SUCCESS:   146 | FAILURE:     0 | EXISTS:    54 | CLASSES:  3623
# [ ThreadPoolExecutor-0_20  ]  Scraping https://insecta.pro/gallery?page=102&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  SUCCESS:   142 | FAILURE:     1 | EXISTS:    57 | CLASSES:  3666
# [ ThreadPoolExecutor-0_25  ]  Scraping https://insecta.pro/gallery?page=127&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_45  ]  SUCCESS:   142 | FAILURE:     0 | EXISTS:    58 | CLASSES:  3791
# [ ThreadPoolExecutor-0_45  ]  Scraping https://insecta.pro/gallery?page=227&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_4   ]  SUCCESS:   210 | FAILURE:     0 | EXISTS:    90 | CLASSES:  3800
# [ ThreadPoolExecutor-0_4   ]  Scraping https://insecta.pro/gallery?page=23&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_16  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_47  ]  SUCCESS:   137 | FAILURE:     2 | EXISTS:    61 | CLASSES:  3861
# [ ThreadPoolExecutor-0_47  ]  Scraping https://insecta.pro/gallery?page=237&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_32  ]  SUCCESS:   221 | FAILURE:     0 | EXISTS:    79 | CLASSES:  3863
# [ ThreadPoolExecutor-0_32  ]  Scraping https://insecta.pro/gallery?page=163&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_38  ]  SUCCESS:   232 | FAILURE:     0 | EXISTS:    68 | CLASSES:  3866
# [ ThreadPoolExecutor-0_38  ]  Scraping https://insecta.pro/gallery?page=193&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_11  ]  SUCCESS:   217 | FAILURE:     0 | EXISTS:    83 | CLASSES:  3886
# [ ThreadPoolExecutor-0_11  ]  Scraping https://insecta.pro/gallery?page=58&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_7   ]  SUCCESS:   218 | FAILURE:     0 | EXISTS:    81 | CLASSES:  3913
# [ ThreadPoolExecutor-0_7   ]  Scraping https://insecta.pro/gallery?page=38&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_33  ]  SUCCESS:   211 | FAILURE:     0 | EXISTS:    89 | CLASSES:  3920
# [ ThreadPoolExecutor-0_33  ]  Scraping https://insecta.pro/gallery?page=168&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_13  ]  SUCCESS:   241 | FAILURE:     0 | EXISTS:    58 | CLASSES:  3938
# [ ThreadPoolExecutor-0_13  ]  Scraping https://insecta.pro/gallery?page=68&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_35  ]  SUCCESS:   222 | FAILURE:     0 | EXISTS:    78 | CLASSES:  3941
# [ ThreadPoolExecutor-0_35  ]  Scraping https://insecta.pro/gallery?page=178&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_39  ]  SUCCESS:   224 | FAILURE:     0 | EXISTS:    76 | CLASSES:  3958
# [ ThreadPoolExecutor-0_39  ]  Scraping https://insecta.pro/gallery?page=198&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_8   ]  SUCCESS:   205 | FAILURE:     1 | EXISTS:    80 | CLASSES:  3958
# [ ThreadPoolExecutor-0_8   ]  Scraping https://insecta.pro/gallery?page=43&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_34  ]  SUCCESS:   206 | FAILURE:     0 | EXISTS:    94 | CLASSES:  3964
# [ ThreadPoolExecutor-0_34  ]  Scraping https://insecta.pro/gallery?page=173&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_5   ]  SUCCESS:   220 | FAILURE:     1 | EXISTS:    79 | CLASSES:  3970
# [ ThreadPoolExecutor-0_5   ]  Scraping https://insecta.pro/gallery?page=28&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_22  ]  SUCCESS:   216 | FAILURE:     0 | EXISTS:    81 | CLASSES:  3974
# [ ThreadPoolExecutor-0_22  ]  Scraping https://insecta.pro/gallery?page=113&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_26  ]  SUCCESS:   235 | FAILURE:     0 | EXISTS:    65 | CLASSES:  3975
# [ ThreadPoolExecutor-0_26  ]  Scraping https://insecta.pro/gallery?page=133&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_19  ]  SUCCESS:   223 | FAILURE:     0 | EXISTS:    77 | CLASSES:  3990
# [ ThreadPoolExecutor-0_19  ]  Scraping https://insecta.pro/gallery?page=98&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_2   ]  SUCCESS:   223 | FAILURE:     0 | EXISTS:    77 | CLASSES:  3990
# [ ThreadPoolExecutor-0_2   ]  Scraping https://insecta.pro/gallery?page=13&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_1   ]  SUCCESS:   236 | FAILURE:     0 | EXISTS:    64 | CLASSES:  4002
# [ ThreadPoolExecutor-0_1   ]  Scraping https://insecta.pro/gallery?page=8&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_23  ]  SUCCESS:   233 | FAILURE:     0 | EXISTS:    65 | CLASSES:  4003
# [ ThreadPoolExecutor-0_23  ]  Scraping https://insecta.pro/gallery?page=118&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  SUCCESS:   227 | FAILURE:     0 | EXISTS:    73 | CLASSES:  4006
# [ ThreadPoolExecutor-0_41  ]  Scraping https://insecta.pro/gallery?page=208&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  SUCCESS:   209 | FAILURE:     1 | EXISTS:    88 | CLASSES:  4006
# [ ThreadPoolExecutor-0_27  ]  Scraping https://insecta.pro/gallery?page=138&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_29  ]  SUCCESS:   220 | FAILURE:     0 | EXISTS:    80 | CLASSES:  4021
# [ ThreadPoolExecutor-0_29  ]  Scraping https://insecta.pro/gallery?page=148&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  SUCCESS:   219 | FAILURE:     1 | EXISTS:    80 | CLASSES:  4023
# [ ThreadPoolExecutor-0_42  ]  Scraping https://insecta.pro/gallery?page=213&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_37  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_0   ]  SUCCESS:   209 | FAILURE:     0 | EXISTS:   191 | CLASSES:  4025
# [ ThreadPoolExecutor-0_0   ]  Scraping https://insecta.pro/gallery?page=4&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_9   ]  SUCCESS:   220 | FAILURE:     0 | EXISTS:    80 | CLASSES:  4028
# [ ThreadPoolExecutor-0_9   ]  Scraping https://insecta.pro/gallery?page=48&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  SUCCESS:   214 | FAILURE:     1 | EXISTS:    85 | CLASSES:  4036
# [ ThreadPoolExecutor-0_3   ]  Scraping https://insecta.pro/gallery?page=18&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_10  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_15  ]  SUCCESS:   218 | FAILURE:     0 | EXISTS:    82 | CLASSES:  4039
# [ ThreadPoolExecutor-0_15  ]  Scraping https://insecta.pro/gallery?page=78&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_14  ]  SUCCESS:   222 | FAILURE:     0 | EXISTS:    78 | CLASSES:  4042
# [ ThreadPoolExecutor-0_14  ]  Scraping https://insecta.pro/gallery?page=73&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_38  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_30  ]  SUCCESS:   230 | FAILURE:     0 | EXISTS:    70 | CLASSES:  4069
# [ ThreadPoolExecutor-0_30  ]  Scraping https://insecta.pro/gallery?page=153&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_17  ]  SUCCESS:   225 | FAILURE:     1 | EXISTS:    74 | CLASSES:  4072
# [ ThreadPoolExecutor-0_17  ]  Scraping https://insecta.pro/gallery?page=88&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  SUCCESS:   226 | FAILURE:     1 | EXISTS:    73 | CLASSES:  4085
# [ ThreadPoolExecutor-0_31  ]  Scraping https://insecta.pro/gallery?page=158&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_40  ]  SUCCESS:   228 | FAILURE:     0 | EXISTS:    72 | CLASSES:  4115
# [ ThreadPoolExecutor-0_40  ]  Scraping https://insecta.pro/gallery?page=203&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  SUCCESS:   215 | FAILURE:     1 | EXISTS:    84 | CLASSES:  4130
# [ ThreadPoolExecutor-0_50  ]  Scraping https://insecta.pro/gallery?page=253&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_48  ]  SUCCESS:   252 | FAILURE:     0 | EXISTS:    48 | CLASSES:  4133
# [ ThreadPoolExecutor-0_48  ]  Scraping https://insecta.pro/gallery?page=243&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_16  ]  SUCCESS:   238 | FAILURE:     1 | EXISTS:    61 | CLASSES:  4134
# ...
# [ ThreadPoolExecutor-0_15  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_23  ]  SUCCESS:   333 | FAILURE:     0 | EXISTS:    65 | CLASSES:  4634
# [ ThreadPoolExecutor-0_23  ]  Scraping https://insecta.pro/gallery?page=119&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_32  ]  SUCCESS:   321 | FAILURE:     0 | EXISTS:    79 | CLASSES:  4634
# [ ThreadPoolExecutor-0_32  ]  Scraping https://insecta.pro/gallery?page=164&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_42  ]  SUCCESS:   319 | FAILURE:     1 | EXISTS:    80 | CLASSES:  4646
# [ ThreadPoolExecutor-0_42  ]  Scraping https://insecta.pro/gallery?page=214&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_9   ]  SUCCESS:   320 | FAILURE:     0 | EXISTS:    80 | CLASSES:  4651
# [ ThreadPoolExecutor-0_9   ]  Scraping https://insecta.pro/gallery?page=49&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_37  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_16  ]  SUCCESS:   338 | FAILURE:     1 | EXISTS:    61 | CLASSES:  4682
# [ ThreadPoolExecutor-0_16  ]  Scraping https://insecta.pro/gallery?page=84&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_28  ]  SUCCESS:   331 | FAILURE:     0 | EXISTS:    69 | CLASSES:  4696
# [ ThreadPoolExecutor-0_28  ]  Scraping https://insecta.pro/gallery?page=144&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_41  ]  SUCCESS:   326 | FAILURE:     1 | EXISTS:    73 | CLASSES:  4696
# [ ThreadPoolExecutor-0_41  ]  Scraping https://insecta.pro/gallery?page=209&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_14  ]  SUCCESS:   322 | FAILURE:     0 | EXISTS:    78 | CLASSES:  4710
# [ ThreadPoolExecutor-0_14  ]  Scraping https://insecta.pro/gallery?page=74&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_6   ]  SUCCESS:   320 | FAILURE:     1 | EXISTS:    79 | CLASSES:  4711
# [ ThreadPoolExecutor-0_6   ]  Scraping https://insecta.pro/gallery?page=34&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_31  ]  SUCCESS:   326 | FAILURE:     1 | EXISTS:    73 | CLASSES:  4711
# [ ThreadPoolExecutor-0_31  ]  Scraping https://insecta.pro/gallery?page=159&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  SUCCESS:   315 | FAILURE:     1 | EXISTS:    84 | CLASSES:  4717
# [ ThreadPoolExecutor-0_50  ]  Scraping https://insecta.pro/gallery?page=254&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_29  ]  SUCCESS:   319 | FAILURE:     0 | EXISTS:    80 | CLASSES:  4725
# [ ThreadPoolExecutor-0_29  ]  Scraping https://insecta.pro/gallery?page=149&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_50  ]  SUCCESS:   318 | FAILURE:     1 | EXISTS:    84 | CLASSES:  4732
# [ ThreadPoolExecutor-0_24  ]  SUCCESS:   313 | FAILURE:     3 | EXISTS:    83 | CLASSES:  4740
# [ ThreadPoolExecutor-0_24  ]  Scraping https://insecta.pro/gallery?page=124&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_36  ]  SUCCESS:   332 | FAILURE:     0 | EXISTS:    67 | CLASSES:  4754
# [ ThreadPoolExecutor-0_36  ]  Scraping https://insecta.pro/gallery?page=184&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_18  ]  SUCCESS:   337 | FAILURE:     0 | EXISTS:    63 | CLASSES:  4757
# [ ThreadPoolExecutor-0_18  ]  Scraping https://insecta.pro/gallery?page=94&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_30  ]  SUCCESS:   330 | FAILURE:     0 | EXISTS:    70 | CLASSES:  4770
# [ ThreadPoolExecutor-0_30  ]  Scraping https://insecta.pro/gallery?page=154&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_48  ]  SUCCESS:   352 | FAILURE:     0 | EXISTS:    48 | CLASSES:  4770
# [ ThreadPoolExecutor-0_48  ]  Scraping https://insecta.pro/gallery?page=244&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_23  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_12  ]  SUCCESS:   339 | FAILURE:     0 | EXISTS:    61 | CLASSES:  4784
# [ ThreadPoolExecutor-0_12  ]  Scraping https://insecta.pro/gallery?page=64&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_3   ]  SUCCESS:   314 | FAILURE:     1 | EXISTS:    85 | CLASSES:  4784
# [ ThreadPoolExecutor-0_3   ]  Scraping https://insecta.pro/gallery?page=19&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  SUCCESS:   339 | FAILURE:     1 | EXISTS:    57 | CLASSES:  4790
# [ ThreadPoolExecutor-0_25  ]  Scraping https://insecta.pro/gallery?page=129&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_40  ]  SUCCESS:   328 | FAILURE:     0 | EXISTS:    72 | CLASSES:  4794
# [ ThreadPoolExecutor-0_40  ]  Scraping https://insecta.pro/gallery?page=204&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_21  ]  SUCCESS:   343 | FAILURE:     0 | EXISTS:    55 | CLASSES:  4805
# [ ThreadPoolExecutor-0_21  ]  Scraping https://insecta.pro/gallery?page=109&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_49  ]  SUCCESS:   347 | FAILURE:     0 | EXISTS:    53 | CLASSES:  4821
# [ ThreadPoolExecutor-0_49  ]  Scraping https://insecta.pro/gallery?page=249&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_10  ]  SUCCESS:   328 | FAILURE:     1 | EXISTS:    71 | CLASSES:  4834
# [ ThreadPoolExecutor-0_10  ]  Scraping https://insecta.pro/gallery?page=54&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_20  ]  SUCCESS:   346 | FAILURE:     0 | EXISTS:    54 | CLASSES:  4842
# [ ThreadPoolExecutor-0_20  ]  Scraping https://insecta.pro/gallery?page=104&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_4   ]  SUCCESS:   410 | FAILURE:     0 | EXISTS:    90 | CLASSES:  4847
# [ ThreadPoolExecutor-0_37  ]  SUCCESS:   323 | FAILURE:     2 | EXISTS:    75 | CLASSES:  4858
# [ ThreadPoolExecutor-0_37  ]  Scraping https://insecta.pro/gallery?page=189&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_30  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_21  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_13  ]  SUCCESS:   441 | FAILURE:     0 | EXISTS:    58 | CLASSES:  4890
# [ ThreadPoolExecutor-0_38  ]  SUCCESS:   431 | FAILURE:     1 | EXISTS:    68 | CLASSES:  4893
# [ ThreadPoolExecutor-0_43  ]  SUCCESS:   343 | FAILURE:     0 | EXISTS:    57 | CLASSES:  4896
# [ ThreadPoolExecutor-0_43  ]  Scraping https://insecta.pro/gallery?page=219&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_46  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_44  ]  SUCCESS:   352 | FAILURE:     1 | EXISTS:    47 | CLASSES:  4909
# [ ThreadPoolExecutor-0_44  ]  Scraping https://insecta.pro/gallery?page=224&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_1   ]  SUCCESS:   436 | FAILURE:     0 | EXISTS:    64 | CLASSES:  4916
# Thread completed with result None
# [ ThreadPoolExecutor-0_2   ]  SUCCESS:   423 | FAILURE:     0 | EXISTS:    77 | CLASSES:  4916
# Thread completed with result None
# [ ThreadPoolExecutor-0_30  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_39  ]  SUCCESS:   424 | FAILURE:     0 | EXISTS:    76 | CLASSES:  4921
# [ ThreadPoolExecutor-0_6   ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out.
# [ ThreadPoolExecutor-0_8   ]  SUCCESS:   404 | FAILURE:     1 | EXISTS:    81 | CLASSES:  4924
# [ ThreadPoolExecutor-0_7   ]  SUCCESS:   418 | FAILURE:     0 | EXISTS:    81 | CLASSES:  4925
# [ ThreadPoolExecutor-0_35  ]  SUCCESS:   421 | FAILURE:     1 | EXISTS:    78 | CLASSES:  4933
# [ ThreadPoolExecutor-0_17  ]  SUCCESS:   425 | FAILURE:     1 | EXISTS:    74 | CLASSES:  4940
# [ ThreadPoolExecutor-0_33  ]  SUCCESS:   411 | FAILURE:     0 | EXISTS:    89 | CLASSES:  4944
# [ ThreadPoolExecutor-0_11  ]  SUCCESS:   416 | FAILURE:     0 | EXISTS:    84 | CLASSES:  4945
# [ ThreadPoolExecutor-0_46  ]  SUCCESS:   338 | FAILURE:     1 | EXISTS:    61 | CLASSES:  4952
# [ ThreadPoolExecutor-0_46  ]  Scraping https://insecta.pro/gallery?page=234&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_27  ]  SUCCESS:   408 | FAILURE:     1 | EXISTS:    88 | CLASSES:  4959
# [ ThreadPoolExecutor-0_19  ]  SUCCESS:   423 | FAILURE:     0 | EXISTS:    77 | CLASSES:  4965
# [ ThreadPoolExecutor-0_5   ]  SUCCESS:   419 | FAILURE:     2 | EXISTS:    79 | CLASSES:  4967
# [ ThreadPoolExecutor-0_31  ]  HTTPSConnectionPool(host='insecta.pro', port=443): Read timed out. (read timeout=30)
# [ ThreadPoolExecutor-0_41  ]  SUCCESS:   426 | FAILURE:     1 | EXISTS:    73 | CLASSES:  4971
# [ ThreadPoolExecutor-0_42  ]  SUCCESS:   419 | FAILURE:     1 | EXISTS:    80 | CLASSES:  4985
# [ ThreadPoolExecutor-0_34  ]  SUCCESS:   406 | FAILURE:     0 | EXISTS:    94 | CLASSES:  4989
# [ ThreadPoolExecutor-0_26  ]  SUCCESS:   435 | FAILURE:     0 | EXISTS:    65 | CLASSES:  4989
# [ ThreadPoolExecutor-0_45  ]  SUCCESS:   342 | FAILURE:     0 | EXISTS:    58 | CLASSES:  4989
# [ ThreadPoolExecutor-0_45  ]  Scraping https://insecta.pro/gallery?page=229&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_28  ]  SUCCESS:   431 | FAILURE:     0 | EXISTS:    69 | CLASSES:  4989
# [ ThreadPoolExecutor-0_15  ]  SUCCESS:   416 | FAILURE:     1 | EXISTS:    82 | CLASSES:  4990
# [ ThreadPoolExecutor-0_24  ]  SUCCESS:   412 | FAILURE:     3 | EXISTS:    83 | CLASSES:  4990
# [ ThreadPoolExecutor-0_32  ]  SUCCESS:   421 | FAILURE:     0 | EXISTS:    79 | CLASSES:  4990
# [ ThreadPoolExecutor-0_22  ]  SUCCESS:   414 | FAILURE:     0 | EXISTS:    81 | CLASSES:  4992
# [ ThreadPoolExecutor-0_9   ]  SUCCESS:   420 | FAILURE:     0 | EXISTS:    80 | CLASSES:  4993
# [ ThreadPoolExecutor-0_12  ]  SUCCESS:   438 | FAILURE:     0 | EXISTS:    62 | CLASSES:  4994
# [ ThreadPoolExecutor-0_23  ]  SUCCESS:   432 | FAILURE:     1 | EXISTS:    65 | CLASSES:  4996
# [ ThreadPoolExecutor-0_16  ]  SUCCESS:   438 | FAILURE:     1 | EXISTS:    61 | CLASSES:  4998
# [ ThreadPoolExecutor-0_29  ]  SUCCESS:   419 | FAILURE:     0 | EXISTS:    80 | CLASSES:  5011
# [ ThreadPoolExecutor-0_31  ]  SUCCESS:   425 | FAILURE:     2 | EXISTS:    73 | CLASSES:  5012
# [ ThreadPoolExecutor-0_3   ]  SUCCESS:   414 | FAILURE:     1 | EXISTS:    85 | CLASSES:  5012
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_18  ]  SUCCESS:   437 | FAILURE:     0 | EXISTS:    63 | CLASSES:  5012
# [ ThreadPoolExecutor-0_47  ]  SUCCESS:   337 | FAILURE:     2 | EXISTS:    61 | CLASSES:  5013
# [ ThreadPoolExecutor-0_47  ]  Scraping https://insecta.pro/gallery?page=239&prec=1&fem=1&live=1&size=m&tx=[1]%20Lepidoptera%20%20[%D0%9E%D1%82%D1%80%D1%8F%D0%B4]&taxlev=10 ...
# [ ThreadPoolExecutor-0_25  ]  SUCCESS:   438 | FAILURE:     1 | EXISTS:    57 | CLASSES:  5013
# [ ThreadPoolExecutor-0_14  ]  SUCCESS:   422 | FAILURE:     0 | EXISTS:    78 | CLASSES:  5013
# [ ThreadPoolExecutor-0_48  ]  SUCCESS:   452 | FAILURE:     0 | EXISTS:    48 | CLASSES:  5015
# [ ThreadPoolExecutor-0_10  ]  SUCCESS:   428 | FAILURE:     1 | EXISTS:    71 | CLASSES:  5015
# [ ThreadPoolExecutor-0_40  ]  SUCCESS:   428 | FAILURE:     0 | EXISTS:    72 | CLASSES:  5015
# [ ThreadPoolExecutor-0_6   ]  SUCCESS:   419 | FAILURE:     2 | EXISTS:    79 | CLASSES:  5015
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_49  ]  SUCCESS:   447 | FAILURE:     0 | EXISTS:    53 | CLASSES:  5018
# [ ThreadPoolExecutor-0_21  ]  SUCCESS:   440 | FAILURE:     1 | EXISTS:    55 | CLASSES:  5018
# [ ThreadPoolExecutor-0_36  ]  SUCCESS:   432 | FAILURE:     0 | EXISTS:    67 | CLASSES:  5025
# [ ThreadPoolExecutor-0_20  ]  SUCCESS:   445 | FAILURE:     0 | EXISTS:    54 | CLASSES:  5028
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_30  ]  SUCCESS:   428 | FAILURE:     2 | EXISTS:    70 | CLASSES:  5035
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_37  ]  SUCCESS:   423 | FAILURE:     2 | EXISTS:    75 | CLASSES:  5035
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_43  ]  SUCCESS:   443 | FAILURE:     0 | EXISTS:    57 | CLASSES:  5061
# Thread completed with result None
# [ ThreadPoolExecutor-0_44  ]  SUCCESS:   452 | FAILURE:     1 | EXISTS:    47 | CLASSES:  5061
# Thread completed with result None
# [ ThreadPoolExecutor-0_46  ]  SUCCESS:   438 | FAILURE:     1 | EXISTS:    61 | CLASSES:  5067
# [ ThreadPoolExecutor-0_45  ]  SUCCESS:   442 | FAILURE:     0 | EXISTS:    58 | CLASSES:  5068
# Thread completed with result None
# Thread completed with result None
# [ ThreadPoolExecutor-0_47  ]  SUCCESS:   437 | FAILURE:     2 | EXISTS:    61 | CLASSES:  5068
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# [ MainThread               ]  Scraping completed

# %%
data_cnt = 0
class_cnt = 0
for class_name in os.listdir(dataset_dir):
    class_cnt += 1
    data_cnt += len(os.listdir(f"{dataset_dir}/{class_name}"))
print(f"Class count: {class_cnt}")
print(f"Data count: {data_cnt}")
# Out:
# Class count: 5068
# Data count: 25221
